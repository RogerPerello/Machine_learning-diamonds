# %%
import os

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import GridSearchCV

from sklearn.metrics import make_scorer

from mlxtend.plotting import plot_decision_regions

if str(os.getcwdb()[-3:]).split("'")[1] != 'src':
    os.chdir(os.path.dirname(os.getcwdb()))

from utils.modeling import *
from utils.functions import *

# %%
df_diamonds = pd.read_csv(r'data\processed\diamonds_training.csv', index_col='id')
df_predict = pd.read_csv(r'data\processed\diamonds_testing.csv', index_col='id')

# %% [markdown]
# # Consideraciones
# - Se localiza el tema en Kaggle: https://www.kaggle.com/datasets/shivam2503/diamonds
#
# - Se empieza a trabajar con ese "dataset" (ver los archivos marcados como "UNUSED")
#
# - Se detecta que existe una competición, si bien ya ha terminado: https://www.kaggle.com/competitions/diamonds-part-datamad0122/overview
#
# - Se elige trabajar con los archivos de la competición, cuyas únicas diferencias es que hay un "train" y un "test", y que la variable "target" está escalada
#
# - El "dataset" final es un listado de diamantes con sus características, y el objetivo es predecir el precio
#
# - Se comparará lo obtenido con los resultados de la competición

# %% [markdown]
# # EDA
# - Los pasos de esta primera parte se detallan de forma más pormenorizada, paso a paso, en el "notebook" titulado "EDA"
#
# - En ese "notebook" se hacen dos cosas:
# 1) Modificaciones esenciales (limpieza); se liquidan duplicados, se cambia el nombre de las columnas y se pasan las categóricas a numéricas, tanto del "train" como del "test".
#
# 2) Modificaciones opcionales (feature engineering); se detectan y ponen a prueba las posibles modifiaciones que llevar a cabo con el "dataframe" de entrenamiento con tal de mejorar el resultado de los modelos. Los resortes de dichos cambios se guardan en forma de funciones (cuando son exclusivos de este proyecto) o clases (cuando es razonable guardarlos para análisis futuros), que se irán llamando a continuación según convenga.

# %% [markdown]
# # Modelaje: selección de cambios
# - Se importan los "dataframes" con las modificaciones esenciales
#
# - Se van intercalando modificiaciones opcionales y diversos modelos hasta dar con el mejor resultado
#
# - Los modelos se prueban en este "notebook" para mayor comodidad, pero se ejecutan sin detallarse en "train.py", desde donde se guardan en la carpeta "model"
#
# - Estas son las modificaciones que se van intercalando:
#
# ---------- Cambios opcionales (probados) ----------
#
# 1) Borrado de "outliers" extremadamente altos ("depth (percentage)", "table (percentage)", "width (millimeters)", "depth (millimeters)").
#
# 2) Borrado de filas que tienen 0 en todas las variables de tamaño ("lenght (millimeters)", "width (millimeters)" y "depth (millimeters)").
#
# 3) Borrado de los "outliers" compartidos moderadamente altos ("depth (percentage)" y "table (percentage)").
#
# 4) Asignación del valor con 0 restante en "lenght" al "width" correspondiente ("lenght (millimeters)").
#
# 5) Asignación del valor con 0 restante de "depth (millimeters)" a partir de una operación con el "lenght", el "width" y el "depth (percentage)" correspondientes ("depth (millimeters)").
#
# 6) Asignación del "outlier" restante del "lenght" al "width" correspondiente ("lenght (millimeters)").
#
# 7) Uso del logaritmo ("weight (carat)", "lenght (millimeters)", "width (millimeters)" y "depth (millimeters)").
#
# 8) Imputación al siguiente valor más alto ("weight (carat)").
#
# 9) Imputación a los valores máximos y mínimos del "boxplot" ("depth (percentage)" y "table (percentage)").
#
# 10) Neutralización de "outliers" con un modelo "ridge" ("depth (millimeters)").
#
# 11) Escalado "MinMax".
#
# ---------- Cambios apuntados (no probados) ----------
#
# 1) Sustitución de valores existentes por valores calculados ("depth (percentage)").
#
# 2) Descarte de las columnas con altísima correlación ("weight (carat)", "lenght (millimeters)", "width (millimeters)" y "depth (millimeters)").
#
# 3) Imputación de los valores máximos de "clarity quality" al que está un punto por debajo ("clarity quality").

# %% [markdown]
# ## Ronda 1: sin cambios
# - Para la primera fase, se prueban todos los modelos sin hacer ninguna modificación adicional
#
# - En esta primera ronda están más detallados los usos de la clase "Regression", que hereda de "Model", para que sirva como ejemplo
#
# - Como era de esperar, los resultados no son demasiado buenos, pero ganan los modelos "de árboles", ya que no se ven afectados por los valores atípicos
#
# - Dado que en la competición se valora la "rsme", esa es la métrica que más se tendrá en cuenta. Puede verse el podio aquí: https://www.kaggle.com/competitions/diamonds-part-datamad0122/leaderboard

# %%
# Lo primero es decirle a la clase con qué modelos se va a trabajar a lo largo de todo el proceso
Regression.add_models(['LinearRegression',
                        'Ridge',
                        'DecisionTreeRegressor',
                        'KNeighborsRegressor',
                        'RandomForestRegressor',
                        'SVR',
                        'XGBRegressor'
                        ]
                        )

# %%
# Se crea la instancia de la clase "Regression" con la columna "price" como "target"
round_1 = Regression(df_diamonds, 'price')

# %%
# Se separa el "dataframe" con los parámetros por defecto. Se guardan las porciones por si acaso
X_train, X_test, y_train, y_test = round_1.split_dataframe()

# %%
# Se establece un "random_state" para los modelos que lo requieren, que siempre será el mismo
round_1.prepare_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ]
                        )
# Out:
# 'Models prepared. Apply them or use kfold (apply + evaluate)'

# %%
# Se solicitan 5 "folds" (número por defecto), del cual se usará el mejor para entrenar los modelos y ver cuál llega más lejos
# Como la "target" es de regresión y esa es la clase que se ha instanciado, se seleccionará automáticamente "KFold" en lugar de "StratifiedKFold"
round_1_dict = round_1.apply_and_evaluate_kfolds()
# Out:
# -- Regression: using mean of 5 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.18 sec(s). Total time: 0.18
# Starting Ridge:
# - Ridge done in 0.08 sec(s). Total time: 0.26
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 3.4 sec(s). Total time: 3.66
# Starting SVR:
# - SVR done in 166.77 sec(s). Total time: 170.44
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 1.36 sec(s). Total time: 171.8
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 117.99 sec(s). Total time: 289.79
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 8.8 sec(s). Total time: 298.59

# %%
# La media y la varianza de las métricas, así como las específicas de cada "fold" entrenado y el modelo en sí, pueden extraerse en un diccionario
# Las varianzas no son muy altas, lo que indica que este conjunto "train" puede ser válido para predecir
round_1_dict
# Out:
# {'LinearRegression': {'models': [LinearRegression(),
#    LinearRegression(),
#    LinearRegression(),
#    LinearRegression(),
#    LinearRegression()],
#   'metrics': {'rmse': 0.18266434126360717,
#    'mse': 0.033668866217605245,
#    'mae': 0.11847602510487627,
#    'r2_score': 0.9671883402028569,
#    'mape': 0.015316754357796062},
#   'all_metrics': {'rmse': [0.18278436404836218,
#     0.16134131610876856,
#     0.21213340614001955,
#     0.1873559277102721,
#     0.16970669231061353],
#    'mse': [0.0334101237405642,
#     0.026031020283709582,
#     0.04500058200056649,
#     0.035102243648176705,
#     0.02880036141500925],
#    'mae': [0.1198527764880509,
#     0.12009375582158771,
#     0.11814603052977636,
#     0.1176840754805362,
#     0.1166034872044301],
#    'r2_score': [0.9675277226414865,
#     0.9749723070956142,
#     0.9554574304863221,
#     0.9657327540523,
#     0.9722514867385628],
#    'mape': [0.015509386119075434,
#     0.015492198456540348,
#     0.015267110508885734,
#     0.015208411444627408,
#     0.015106665259851387]},
#   'variances': {'rmse': 0.00030260464833769786,
#    'mse': 4.2513666127307344e-05,
#    'mae': 1.750995171712013e-06,
#    'r2_score': 4.521474953768103e-05,
#    'mape': 2.5245550976299345e-08}},
#  'Ridge': {'models': [Ridge(), Ridge(), Ridge(), Ridge(), Ridge()],
#   'metrics': {'rmse': 0.18282555104351045,
#    'mse': 0.03371812630447532,
#    'mae': 0.11855388243026935,
#    'r2_score': 0.9671414215565484,
#    'mape': 0.015326633340021923},
#   'all_metrics': {'rmse': [0.18276905196957371,
#     0.16196243259325777,
#     0.2119553298796856,
#     0.18729953378385747,
#     0.1701414069911777],
#    'mse': [0.033404526357856734,
#     0.026231829571525568,
#     0.04492506186440635,
#     0.035081115355650366,
#     0.02894809837293757],
#    'mae': [0.11992008854708046,
#     0.12021075809178733,
#     0.11818718110683206,
#     0.11776357146952647,
#     0.1166878129361203],
#    'r2_score': [0.9675331629016055,
#     0.9747792377063612,
#     0.955532181984304,
#     0.9657533797537142,
#     0.9721091454367574],
#    'mape': [0.015517933751016006,
#     0.015506884497934581,
#     0.01527251895499832,
#     0.015218351926977671,
#     0.015117477569183024]},
#   'variances': {'rmse': 0.0002929441901120718,
#    'mse': 4.126985879320264e-05,
#    'mae': 1.7706065487234867e-06,
#    'r2_score': 4.3973816172389554e-05,
#    'mape': 2.5497138945583064e-08}},
#  'KNeighborsRegressor': {'models': [KNeighborsRegressor(),
#    KNeighborsRegressor(),
#    KNeighborsRegressor(),
#    KNeighborsRegressor(),
#    KNeighborsRegressor()],
#   'metrics': {'rmse': 0.18163222094593917,
#    'mse': 0.03300335952636676,
#    'mae': 0.13574074761610455,
#    'r2_score': 0.9678893372390849,
#    'mape': 0.017877118667641197},
#   'all_metrics': {'rmse': [0.17902427578577568,
#     0.17991294216502207,
#     0.18850435763144893,
#     0.18198108386890866,
#     0.1787384452785404],
#    'mse': [0.032049691320621465,
#     0.03236866675847457,
#     0.0355338928460452,
#     0.03311711488610277,
#     0.03194743182058979],
#    'mae': [0.13568774717514123,
#     0.13438654661016947,
#     0.1376569562146893,
#     0.13620314321031254,
#     0.13476934487021014],
#    'r2_score': [0.9688499667376451,
#     0.9688789358801092,
#     0.9648277684016037,
#     0.9676706613897809,
#     0.9692193537862861],
#    'mape': [0.01784065446349048,
#     0.017684672497371632,
#     0.01815340133782652,
#     0.017978197298285415,
#     0.01772866774123194]},
#   'variances': {'rmse': 1.3095840612302605e-05,
#    'mse': 1.7687680879925906e-06,
#    'mae': 1.3331915569564324e-06,
#    'r2_score': 2.618416278671044e-06,
#    'mape': 2.939036952103525e-08}},
#  'SVR': {'models': [SVR(), SVR(), SVR(), SVR(), SVR()],
#   'metrics': {'rmse': 0.1893278459989636,
#    'mse': 0.03619161503230284,
#    'mae': 0.1261735452547826,
#    'r2_score': 0.9647445691654262,
#    'mape': 0.0163424082248793},
#   'all_metrics': {'rmse': [0.1824308082859353,
#     0.18056371596777324,
#     0.22527947608785187,
#     0.17176107297433196,
#     0.18660415667892563],
#    'mse': [0.03328099981185968,
#     0.032603255524090685,
#     0.05075084234641702,
#     0.029501866189293794,
#     0.034821111289853025],
#    'mae': [0.12601528456603517,
#     0.1282101843588503,
#     0.12701965838429888,
#     0.1252768390982481,
#     0.12434575986648054],
#    'r2_score': [0.9676532219679502,
#     0.9686533889933308,
#     0.9497656958511219,
#     0.9711999120410306,
#     0.9664506269736978],
#    'mape': [0.016322535095688574,
#     0.016558616567680297,
#     0.016475955437785957,
#     0.016237080579421935,
#     0.016117853443819732]},
#   'variances': {'rmse': 0.0003465817616955636,
#    'mse': 5.599002499926202e-05,
#    'mae': 1.8067468141235306e-06,
#    'r2_score': 5.853757284508177e-05,
#    'mape': 2.5298921886004683e-08}},
#  'DecisionTreeRegressor: random_state=43': {'models': [DecisionTreeRegressor(random_state=43),
#    DecisionTreeRegressor(random_state=43),
#    DecisionTreeRegressor(random_state=43),
#    DecisionTreeRegressor(random_state=43),
#    DecisionTreeRegressor(random_state=43)],
#   'metrics': {'rmse': 0.13048008598456368,
#    'mse': 0.01702863716401178,
#    'mae': 0.09079085295470349,
#    'r2_score': 0.9834361835012764,
#    'mape': 0.0117062121831898},
#   'all_metrics': {'rmse': [0.13165454553151656,
#     0.13052387771439253,
#     0.13308192587141227,
#     0.12745778247982428,
#     0.1296822983256727],
#    'mse': [0.017332919359110167,
#     0.017036482653601692,
#     0.017710798993644066,
#     0.0162454863146742,
#     0.016817498499028777],
#    'mae': [0.09176562500000002,
#     0.09052745409604519,
#     0.09070550847457627,
#     0.09001606922126082,
#     0.09093960798163517],
#    'r2_score': [0.983153628246566,
#     0.9836201635057665,
#     0.9824694601659322,
#     0.984140954616334,
#     0.9837967109717831],
#    'mape': [0.011810156578685053,
#     0.011677347532839041,
#     0.01169950184434517,
#     0.011646944884512057,
#     0.01169711007556769]},
#   'variances': {'rmse': 3.584325472653042e-06,
#    'mse': 2.4317975128740895e-07,
#    'mae': 3.2985221419341234e-07,
#    'r2_score': 3.3498450054503724e-07,
#    'mape': 3.0556190195752585e-09}},
#  'RandomForestRegressor: random_state=43': {'models': [RandomForestRegressor(random_state=43),
#    RandomForestRegressor(random_state=43),
#    RandomForestRegressor(random_state=43),
#    RandomForestRegressor(random_state=43),
#    RandomForestRegressor(random_state=43)],
#   'metrics': {'rmse': 0.0942456953279916,
#    'mse': 0.008898190806178924,
#    'mae': 0.06678927621780448,
#    'r2_score': 0.9913401786735141,
#    'mape': 0.008636026561705071},
#   'all_metrics': {'rmse': [0.09239968264264842,
#     0.09419758273499718,
#     0.10192972892119931,
#     0.09085950673231713,
#     0.09184197560879599],
#    'mse': [0.008537701352462145,
#     0.008873184593116638,
#     0.010389669637949175,
#     0.008255449963639982,
#     0.008434948483726678],
#    'mae': [0.0671819796122546,
#     0.06783518627673524,
#     0.06737626269084608,
#     0.06594881578416281,
#     0.06560413672502377],
#    'r2_score': [0.9917019581108374,
#     0.9914688192525658,
#     0.9897160756261625,
#     0.991940927276662,
#     0.9918731131013429],
#    'mape': [0.008677857222756654,
#     0.008761650236875702,
#     0.00870549453541892,
#     0.008558592200592028,
#     0.008476538612882053]},
#   'variances': {'rmse': 1.5939718322304566e-05,
#    'mse': 5.965592605060223e-07,
#    'mae': 7.407252569569322e-07,
#    'r2_score': 6.860122913629793e-07,
#    'mape': 1.075787948801113e-08}},
#  'XGBRegressor: random_state=43': {'models': [XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                 predictor=None, random_state=43, ...),
#    XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                 predictor=None, random_state=43, ...),
#    XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                 predictor=None, random_state=43, ...),
#    XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                 predictor=None, random_state=43, ...),
#    XGBRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                 predictor=None, random_state=43, ...)],
#   'metrics': {'rmse': 0.09076170575844941,
#    'mse': 0.008246528593062819,
#    'mae': 0.0655959786017388,
#    'r2_score': 0.9919759161100286,
#    'mape': 0.008468233206371287},
#   'all_metrics': {'rmse': [0.08996558722752356,
#     0.09144750589231505,
#     0.09615672402069722,
#     0.08799201872225776,
#     0.08824669292945346],
#    'mse': [0.00809380688519315,
#     0.008362646333924997,
#     0.00924611557439253,
#     0.007742595358818161,
#     0.0077874788129852525],
#    'mae': [0.06605196058952202,
#     0.06624132949618969,
#     0.0663223270218251,
#     0.0647224877728141,
#     0.06464178812834308],
#    'r2_score': [0.9921333921387685,
#     0.9919596795656741,
#     0.9908479906837939,
#     0.9924415823075764,
#     0.9924969358543304],
#    'mape': [0.008531660689332372,
#     0.008543769750799632,
#     0.008567596644067978,
#     0.008371561699980611,
#     0.008326577247675836]},
#   'variances': {'rmse': 8.841360879468672e-06,
#    'mse': 3.001313576413901e-07,
#    'mae': 5.650890130495746e-07,
#    'r2_score': 3.5711693472757833e-07,
#    'mape': 9.802739734325601e-09}}}

# %%
# Para una mejor visualización, se ponen esas medias en un "dataframe"
# Las predicciones no son muy buenas, si bien el r2_score es alto para todos los casos
round_1.create_dataframe()
# Out:
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.182664  0.182826             0.181632  0.189328
# mse               0.033669  0.033718             0.033003  0.036192
# mae               0.118476  0.118554             0.135741  0.126174
# r2_score          0.967188  0.967141             0.967889  0.964745
# mape              0.015317  0.015327             0.017877  0.016342
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.130480
# mse                                     0.017029
# mae                                     0.090791
# r2_score                                0.983436
# mape                                    0.011706
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.094246
# mse                                     0.008898
# mae                                     0.066789
# r2_score                                0.991340
# mape                                    0.008636
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.090762  XGBRegressor: random_state=43
# mse                            0.008247  XGBRegressor: random_state=43
# mae                            0.065596  XGBRegressor: random_state=43
# r2_score                       0.991976  XGBRegressor: random_state=43
# mape                           0.008468  XGBRegressor: random_state=43
#
#                         WORST
# rmse                      SVR
# mse                       SVR
# mae       KNeighborsRegressor
# r2_score                  SVR
# mape      KNeighborsRegressor

# %% [markdown]
# ## Ronda 2: escalado
# - Se repite la ronda 1, pero esta vez se escalan las variables
#
# - Respecto a la ronda 1, exceptuando "Ridge" y "XGBRegressor", el escalado "Standard" mejora más que "MinMax" los resultados de los modelos "no de árboles" y también de "DecisionTree". RandomForestRegressor empeora con el escalado. La regresión lineal no se ve afectada en ningún caso

# %%
# Se pone a prueba con el mismo proceso que en la ronda anterior, pero esta vez se aplica un escalado MinMax
df_diamonds_2 = df_diamonds.copy()

round_2 = Regression(df_diamonds_2, 'price')
round_2.split_dataframe(scaler='MinMaxScaler')
round_2.prepare_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ])
round_2.apply_and_evaluate_kfolds()
round_2.create_dataframe()
# Out:
# -- Regression (MinMaxScaler): using mean of 5 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.13 sec(s). Total time: 0.13
# Starting Ridge:
# - Ridge done in 0.09 sec(s). Total time: 0.22
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 1.89 sec(s). Total time: 2.11
# Starting SVR:
# - SVR done in 148.91 sec(s). Total time: 151.02
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 1.18 sec(s). Total time: 152.2
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 104.86 sec(s). Total time: 257.06
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 4.88 sec(s). Total time: 261.94
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.182664  0.181262             0.164514  0.121829
# mse               0.033669  0.033098             0.027074  0.014860
# mae               0.118476  0.124283             0.116946  0.091139
# r2_score          0.967188  0.967752             0.973661  0.985540
# mape              0.015317  0.016057             0.015443  0.012015
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.130760
# mse                                     0.017102
# mae                                     0.090951
# r2_score                                0.983365
# mape                                    0.011723
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.094312
# mse                                     0.008910
# mae                                     0.066860
# r2_score                                0.991329
# mape                                    0.008645
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.090735  XGBRegressor: random_state=43
# mse                            0.008242  XGBRegressor: random_state=43
# mae                            0.065592  XGBRegressor: random_state=43
# r2_score                       0.991981  XGBRegressor: random_state=43
# mape                           0.008468  XGBRegressor: random_state=43
#
#                                            WORST
# rmse                            LinearRegression
# mse                             LinearRegression
# mae                                        Ridge
# r2_score  DecisionTreeRegressor: random_state=43
# mape                                       Ridge

# %%
# Comprobamos si la situación mejora con "StandardScaler"
df_diamonds_2b = df_diamonds.copy()

round_2b = Regression(df_diamonds_2b, 'price')
round_2b.split_dataframe(scaler='StandardScaler')
round_2b.prepare_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ]
                        )
round_2b.apply_and_evaluate_kfolds()
round_2b.create_dataframe()
# Out:
# -- Regression (StandardScaler): using mean of 5 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.13 sec(s). Total time: 0.13
# Starting Ridge:
# - Ridge done in 0.08 sec(s). Total time: 0.21
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 2.86 sec(s). Total time: 3.07
# Starting SVR:
# - SVR done in 129.12 sec(s). Total time: 132.19
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 1.35 sec(s). Total time: 133.54
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 129.78 sec(s). Total time: 263.32
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 13.21 sec(s). Total time: 276.53
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.182664  0.182891             0.144004  0.107316
# mse               0.033669  0.033741             0.020743  0.011518
# mae               0.118476  0.118530             0.106323  0.081209
# r2_score          0.967188  0.967119             0.979820  0.988797
# mape              0.015317  0.015324             0.014035  0.010658
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.130423
# mse                                     0.017014
# mae                                     0.090689
# r2_score                                0.983450
# mape                                    0.011692
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.094255
# mse                                     0.008900
# mae                                     0.066785
# r2_score                                0.991339
# mape                                    0.008636
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.090741  XGBRegressor: random_state=43
# mse                            0.008243  XGBRegressor: random_state=43
# mae                            0.065580  XGBRegressor: random_state=43
# r2_score                       0.991980  XGBRegressor: random_state=43
# mape                           0.008466  XGBRegressor: random_state=43
#
#                                            WORST
# rmse                                       Ridge
# mse                                        Ridge
# mae                                        Ridge
# r2_score  DecisionTreeRegressor: random_state=43
# mape                                       Ridge

# %% [markdown]
# ## Ronda 3: borrado
# - Se borran todos los "outliers" extremadamente altos ("depth (percentage)", "table (percentage)", "width (millimeters)", "depth (millimeters)")
#
# - Se borran las filas que tienen el mismo cero en estas tres columnas: "lenght (millimeters)", "width (millimeters)" y "depth (millimeters)"
#
# - Se borran los "outliers" moderadamente altos compartidos de "depth (percentage)" y "table (percentage)"
#
# - Respecto a la ronda 1, el error mejora en todos los modelos menos "XGBR"

# %%
# Se aplican los borrados, esta vez con una función a medida ya que son cambios exclusivos de este proyecto
df_diamonds_3 = df_diamonds.copy()

df_diamonds_3 = remove_all(df_diamonds_3)

print(f'Deleted rows: {len(df_diamonds) - len(df_diamonds_3)}')
# Out:
# Deleted rows: 20

# %%
# Se prueban los modelos
round_3 = Regression(df_diamonds_3, 'price')
round_3.split_dataframe()
round_3.prepare_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ]
                        )
round_3.apply_and_evaluate_kfolds()
round_3.create_dataframe()
# Out:
# -- Regression: using mean of 5 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.16 sec(s). Total time: 0.16
# Starting Ridge:
# - Ridge done in 0.1 sec(s). Total time: 0.25
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 4.16 sec(s). Total time: 4.41
# Starting SVR:
# - SVR done in 182.14 sec(s). Total time: 186.55
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 1.34 sec(s). Total time: 187.9
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 131.16 sec(s). Total time: 319.05
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 8.56 sec(s). Total time: 327.61
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.152523  0.152468             0.181292  0.167338
# mse               0.023310  0.023292             0.032870  0.028015
# mae               0.114518  0.114516             0.135927  0.126121
# r2_score          0.977458  0.977475             0.968222  0.972910
# mape              0.014986  0.014985             0.017928  0.016343
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.130832
# mse                                     0.017120
# mae                                     0.089546
# r2_score                                0.983450
# mape                                    0.011541
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.093747
# mse                                     0.008793
# mae                                     0.066676
# r2_score                                0.991502
# mape                                    0.008626
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.090978  XGBRegressor: random_state=43
# mse                            0.008279  XGBRegressor: random_state=43
# mae                            0.065759  XGBRegressor: random_state=43
# r2_score                       0.991997  XGBRegressor: random_state=43
# mape                           0.008484  XGBRegressor: random_state=43
#
#                         WORST
# rmse      KNeighborsRegressor
# mse       KNeighborsRegressor
# mae       KNeighborsRegressor
# r2_score                  SVR
# mape      KNeighborsRegressor

# %% [markdown]
# ## Ronda 4: asignación (+ borrado)
#
# - Para poder hacer la asignación, es necesario el borrado aunque haya dado malos resultados para algunos modelos
#
# - Los cambios de esta ronda se aplican a partir de dos hechos probados durante el EDA:
#
# 1) El "lenght" y el "width" son generalmente casi idénticos, ya que los diamantes son semicirculares.
#
# 2) El "depth (percentage)" se obtiene (según el autor del "dataset") de dividir "depth (millimeters)" por la media de "lenght" y "width".
#
# - Se asigna el 0 restante de "lenght" al "width" correspondiente ("lenght (millimeters)")
#
# - Se asigna el 0 restante de "depth (millimeters)" a partir de la operación mencionada
#
# - Se asigna el "outlier" restante del "lenght" al "width" correspondiente ("lenght (millimeters)")
#
# - Respecto a la ronda 3, mejoran todos los modelos

# %%
# Se aplican el borrado y la asignación
df_diamonds_4 = df_diamonds.copy()

df_diamonds_4 = remove_all(df_diamonds_4)
df_diamonds_4 = assign_values(df_diamonds_4)

# %%
# Se prueban los modelos
round_4 = Regression(df_diamonds_4, 'price')
round_4.split_dataframe()
round_4.prepare_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ]
                        )
round_4.apply_and_evaluate_kfolds()
round_4.create_dataframe()
# Out:
# -- Regression: using mean of 5 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.27 sec(s). Total time: 0.27
# Starting Ridge:
# - Ridge done in 0.14 sec(s). Total time: 0.41
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 3.86 sec(s). Total time: 4.27
# Starting SVR:
# - SVR done in 184.19 sec(s). Total time: 188.46
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 1.21 sec(s). Total time: 189.66
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 124.36 sec(s). Total time: 314.02
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 11.7 sec(s). Total time: 325.72
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.147629  0.147579             0.180480  0.164895
# mse               0.021797  0.021782             0.032576  0.027199
# mae               0.113331  0.113336             0.135717  0.125706
# r2_score          0.978930  0.978944             0.968510  0.973708
# mape              0.014799  0.014799             0.017905  0.016295
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.129729
# mse                                     0.016832
# mae                                     0.088872
# r2_score                                0.983728
# mape                                    0.011452
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.093724
# mse                                     0.008789
# mae                                     0.066668
# r2_score                                0.991507
# mape                                    0.008625
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.090881  XGBRegressor: random_state=43
# mse                            0.008261  XGBRegressor: random_state=43
# mae                            0.065547  XGBRegressor: random_state=43
# r2_score                       0.992015  XGBRegressor: random_state=43
# mape                           0.008455  XGBRegressor: random_state=43
#
#                         WORST
# rmse      KNeighborsRegressor
# mse       KNeighborsRegressor
# mae       KNeighborsRegressor
# r2_score                  SVR
# mape      KNeighborsRegressor

# %% [markdown]
# ## Ronda 5: logaritmo (+ borrado y asignación)
#
# - Incluso para los modelos que han dado peores resultados, la asignación y el borrado son necesarios para neutralizar los ceros
#
# - Se aplica el logaritmo a las columnas "weight (carat)", "lenght (millimeters)", "width (millimeters)" y "depth (millimeters)"
#
# - Comparados con la ronda 4, mejoran ligeramente la regresión lineal, "ridge" y SVC

# %%
# Se hacen los retoques
df_diamonds_5 = df_diamonds.copy()

df_diamonds_5 = remove_all(df_diamonds_5)
df_diamonds_5 = assign_values(df_diamonds_5)

df_diamonds_5[['weight (carat)', 'lenght (millimeters)', 'width (millimeters)', 'depth (millimeters)']] = np.log(df_diamonds_5[['weight (carat)', 'lenght (millimeters)', 'width (millimeters)', 'depth (millimeters)']])

# %%
# Se escala y se prueban los modelos
round_5 = Regression(df_diamonds_5, 'price')
round_5.split_dataframe()
round_5.prepare_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ]
                        )
round_5.apply_and_evaluate_kfolds()
round_5.create_dataframe()
# Out:
# -- Regression: using mean of 5 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.33 sec(s). Total time: 0.33
# Starting Ridge:
# - Ridge done in 0.2 sec(s). Total time: 0.53
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 5.5 sec(s). Total time: 6.02
# Starting SVR:
# - SVR done in 345.74 sec(s). Total time: 351.77
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 2.6 sec(s). Total time: 354.36
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 244.96 sec(s). Total time: 599.32
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 14.11 sec(s). Total time: 613.42
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.146282  0.146204             0.352911  0.159452
# mse               0.021401  0.021379             0.124552  0.025428
# mae               0.113335  0.113382             0.259885  0.125998
# r2_score          0.979309  0.979331             0.879584  0.975418
# mape              0.014820  0.014838             0.033432  0.016397
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.129840
# mse                                     0.016861
# mae                                     0.088945
# r2_score                                0.983701
# mape                                    0.011463
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.093827
# mse                                     0.008808
# mae                                     0.066729
# r2_score                                0.991488
# mape                                    0.008635
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.090882  XGBRegressor: random_state=43
# mse                            0.008261  XGBRegressor: random_state=43
# mae                            0.065549  XGBRegressor: random_state=43
# r2_score                       0.992015  XGBRegressor: random_state=43
# mape                           0.008455  XGBRegressor: random_state=43
#
#                         WORST
# rmse      KNeighborsRegressor
# mse       KNeighborsRegressor
# mae       KNeighborsRegressor
# r2_score                  SVR
# mape      KNeighborsRegressor

# %% [markdown]
# ## Ronda 6: valor más alto de "weight"
# - Se imputan los valores atípicos al siguiente valor más alto de "weight"
#
# - Comparados con la ronda 1, mejoran todos menos "ridge", regresión lineal y "RandomForest"

# %%
# Se hacen los retoques pertinentes
df_diamonds_6a = df_diamonds.copy()

df_diamonds_6a = impute_next_higher(df_diamonds_6a, log=False)

# %%
# Se lleva a cabo la prueba
round_6a = Regression(df_diamonds_6a, 'price')
round_6a.split_dataframe()
round_6a.prepare_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ]
                        )
round_6a.apply_and_evaluate_kfolds()
round_6a.create_dataframe()
# Out:
# -- Regression: using mean of 5 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.29 sec(s). Total time: 0.29
# Starting Ridge:
# - Ridge done in 0.19 sec(s). Total time: 0.47
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 6.32 sec(s). Total time: 6.79
# Starting SVR:
# - SVR done in 329.11 sec(s). Total time: 335.9
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 2.53 sec(s). Total time: 338.43
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 212.82 sec(s). Total time: 551.25
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 15.09 sec(s). Total time: 566.34
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.182788  0.182904             0.181511  0.185459
# mse               0.033544  0.033583             0.032961  0.034844
# mae               0.125334  0.125346             0.135657  0.120709
# r2_score          0.967333  0.967295             0.967930  0.966052
# mape              0.016147  0.016149             0.017870  0.015703
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.130361
# mse                                     0.016999
# mae                                     0.090517
# r2_score                                0.983466
# mape                                    0.011679
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.094329
# mse                                     0.008914
# mae                                     0.066856
# r2_score                                0.991324
# mape                                    0.008644
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.090458  XGBRegressor: random_state=43
# mse                            0.008189  XGBRegressor: random_state=43
# mae                            0.065434  XGBRegressor: random_state=43
# r2_score                       0.992032  XGBRegressor: random_state=43
# mape                           0.008448  XGBRegressor: random_state=43
#
#                         WORST
# rmse                      SVR
# mse                       SVR
# mae       KNeighborsRegressor
# r2_score                  SVR
# mape      KNeighborsRegressor

# %% [markdown]
# ## Ronda 7: imputaciones "boxplot"
# - Se imputan los valores atípicos al máximo y al mínimo "depth (percentage)" y "table"
#
# - Comparados con la ronda 1, mejoran todos los modelos no "de árboles"

# %%
df_diamonds_6b = df_diamonds.copy()

df_diamonds_6b = impute_boxplot_min_max(df_diamonds_6b, ['depth (percentage)', 'table (percentage)'])

# %%
# Se lleva a cabo la prueba
round_6b = Regression(df_diamonds_6b, 'price')
round_6b.split_dataframe()
round_6b.prepare_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ]
                        )
round_6b.apply_and_evaluate_kfolds()
round_6b.create_dataframe()
# Out:
# -- Regression: using mean of 5 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.32 sec(s). Total time: 0.32
# Starting Ridge:
# - Ridge done in 0.19 sec(s). Total time: 0.51
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 6.35 sec(s). Total time: 6.86
# Starting SVR:
# - SVR done in 330.58 sec(s). Total time: 337.43
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 2.94 sec(s). Total time: 340.37
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 211.85 sec(s). Total time: 552.22
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 15.91 sec(s). Total time: 568.14
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.182236  0.182393             0.178449  0.188845
# mse               0.033512  0.033560             0.031860  0.036012
# mae               0.118213  0.118289             0.134078  0.125982
# r2_score          0.967341  0.967295             0.969000  0.964919
# mape              0.015287  0.015296             0.017666  0.016315
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.131017
# mse                                     0.017170
# mae                                     0.090738
# r2_score                                0.983301
# mape                                    0.011701
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.094343
# mse                                     0.008916
# mae                                     0.066850
# r2_score                                0.991323
# mape                                    0.008644
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.090439  XGBRegressor: random_state=43
# mse                            0.008185  XGBRegressor: random_state=43
# mae                            0.065478  XGBRegressor: random_state=43
# r2_score                       0.992037  XGBRegressor: random_state=43
# mape                           0.008449  XGBRegressor: random_state=43
#
#                         WORST
# rmse                      SVR
# mse                       SVR
# mae       KNeighborsRegressor
# r2_score                  SVR
# mape      KNeighborsRegressor

# %% [markdown]
# ## Ronda 8: imputaciones "ridge"
# - Se imputan los "outliers" de "depth (millimeters)" aplicando un modelo "Ridge" a "weight (carat)", "lenght (millimeters)" y "width (millimeters)", con las que tiene una altísima correlación
#
# - Comparados con la ronda 1, mejoran todos los modelos de "no árboles"

# %%
# Se hacen los cambios
df_diamonds_7 = df_diamonds.copy()

df_diamonds_7 = apply_ridge(df_diamonds_7)

# %%
# Se prueban los modelos
round_7 = Regression(df_diamonds_7, 'price')
round_7.split_dataframe()
round_7.prepare_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ]
                        )
round_7.apply_and_evaluate_kfolds()
round_7.create_dataframe()
# Out:
# -- Regression: using mean of 5 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.34 sec(s). Total time: 0.34
# Starting Ridge:
# - Ridge done in 0.11 sec(s). Total time: 0.45
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 9.0 sec(s). Total time: 9.46
# Starting SVR:
# - SVR done in 353.22 sec(s). Total time: 362.67
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 3.45 sec(s). Total time: 366.13
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 227.77 sec(s). Total time: 593.89
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 21.44 sec(s). Total time: 615.33
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.176916  0.176822             0.181088  0.185743
# mse               0.031536  0.031506             0.032807  0.034888
# mae               0.116214  0.116236             0.135562  0.125821
# r2_score          0.969274  0.969303             0.968079  0.966007
# mape              0.015108  0.015107             0.017857  0.016300
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.131214
# mse                                     0.017223
# mae                                     0.090723
# r2_score                                0.983247
# mape                                    0.011698
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.094303
# mse                                     0.008909
# mae                                     0.066834
# r2_score                                0.991329
# mape                                    0.008642
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.090404  XGBRegressor: random_state=43
# mse                            0.008181  XGBRegressor: random_state=43
# mae                            0.065434  XGBRegressor: random_state=43
# r2_score                       0.992040  XGBRegressor: random_state=43
# mape                           0.008450  XGBRegressor: random_state=43
#
#                         WORST
# rmse                      SVR
# mse                       SVR
# mae       KNeighborsRegressor
# r2_score                  SVR
# mape      KNeighborsRegressor

# %% [markdown]
# ## Ronda 9: sustitución (+ borrado parcial y asignación)
# - Se sustituyen los valores de "depth (percentage)" por los resultados reales que da el cálculo a partir de las columnas correspondientes
#
# - Como se ha visto en EDA, el resultado serán muchos nuevos "outliers". Por tanto, se aplicará el cambio en el "dataframe" original sin otras modificaciones para comprobar si supone una mejora
#
# - La única modificación adicional indispensable es el tratamiento de los 0 en esas columnas
#
# - Para comprobar si realmente hay mejora, se aplican los modelos dos veces: una solo con las modificaciones de borrado parcial y asignación, y otra con la sustitución
#
# - Comparados exclusivamente con el tratamiento previo (esta misma ronda), mejoran todos menos "DecisionTree" y "XGB"
#
# - En paralelo, se descubre que los modelos "de árboles", "XGB" y k vecinos mejoran más con el borrado parcial que con el total de la ronda 4

# %%
# Se aplican los cambios
df_diamonds_8a = df_diamonds.copy()

df_diamonds_8a = remove_all(df_diamonds_8a, zeros_only=True)

df_diamonds_8a = assign_values(df_diamonds_8a)

df_diamonds_8b = df_diamonds_8a.copy()

df_diamonds_8b['depth (percentage)'] = (df_diamonds_8b['depth (millimeters)'] / ((df_diamonds_8b['lenght (millimeters)']+df_diamonds_8b['width (millimeters)']) / 2)) * 100

# %%
# Se ponen a prueba solo el borrado parcial y la asignación
round_8a = Regression(df_diamonds_8a, 'price')
round_8a.split_dataframe()
round_8a.prepare_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ]
                        )
round_8a.apply_and_evaluate_kfolds()
round_8a.create_dataframe()
# Out:
# -- Regression: using mean of 5 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.2 sec(s). Total time: 0.2
# Starting Ridge:
# - Ridge done in 0.1 sec(s). Total time: 0.3
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 3.27 sec(s). Total time: 3.58
# Starting SVR:
# - SVR done in 153.94 sec(s). Total time: 157.52
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 1.39 sec(s). Total time: 158.91
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 112.4 sec(s). Total time: 271.3
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 5.63 sec(s). Total time: 276.93
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.260782  0.259140             0.179619  0.179242
# mse               0.087050  0.085785             0.032272  0.032667
# mae               0.117522  0.117504             0.135742  0.126245
# r2_score          0.915075  0.916278             0.968722  0.968252
# mape              0.015240  0.015237             0.017870  0.016364
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.129357
# mse                                     0.016741
# mae                                     0.089740
# r2_score                                0.983770
# mape                                    0.011555
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.093658
# mse                                     0.008775
# mae                                     0.066874
# r2_score                                0.991495
# mape                                    0.008651
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.090657  XGBRegressor: random_state=43
# mse                            0.008221  XGBRegressor: random_state=43
# mae                            0.065675  XGBRegressor: random_state=43
# r2_score                       0.992033  XGBRegressor: random_state=43
# mape                           0.008483  XGBRegressor: random_state=43
#
#                         WORST
# rmse         LinearRegression
# mse          LinearRegression
# mae       KNeighborsRegressor
# r2_score                  SVR
# mape      KNeighborsRegressor

# %%
# Se pone a prueba la sustitución
round_8b = Regression(df_diamonds_8b, 'price')
round_8b.split_dataframe()
round_8b.prepare_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ]
                        )
round_8b.apply_and_evaluate_kfolds()
round_8b.create_dataframe()
# Out:
# -- Regression: using mean of 5 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.15 sec(s). Total time: 0.15
# Starting Ridge:
# - Ridge done in 0.09 sec(s). Total time: 0.24
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 2.77 sec(s). Total time: 3.02
# Starting SVR:
# - SVR done in 160.93 sec(s). Total time: 163.95
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 1.39 sec(s). Total time: 165.33
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 137.52 sec(s). Total time: 302.85
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 7.67 sec(s). Total time: 310.51
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.204595  0.202862             0.179321  0.176235
# mse               0.050146  0.050052             0.032161  0.031325
# mae               0.120780  0.120842             0.135853  0.126536
# r2_score          0.951569  0.951689             0.968831  0.969632
# mape              0.015791  0.015790             0.017885  0.016401
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.129540
# mse                                     0.016786
# mae                                     0.089725
# r2_score                                0.983730
# mape                                    0.011560
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.093643
# mse                                     0.008772
# mae                                     0.066871
# r2_score                                0.991498
# mape                                    0.008653
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.091386  XGBRegressor: random_state=43
# mse                            0.008354  XGBRegressor: random_state=43
# mae                            0.066288  XGBRegressor: random_state=43
# r2_score                       0.991903  XGBRegressor: random_state=43
# mape                           0.008558  XGBRegressor: random_state=43
#
#                         WORST
# rmse         LinearRegression
# mse          LinearRegression
# mae       KNeighborsRegressor
# r2_score     LinearRegression
# mape      KNeighborsRegressor

# %% [markdown]
# ## Ronda 10: descarte
# - Se quitan directamente las columnas con altísima correlación, cercana a 1 ("weight", "lenght", "width" y "depth (millimeters)")
#
# - Se quitan también, a parte, las que tienen una correlación próxima a 0
#
# - Se utiliza el "dataframe" sin cambios ni escalado para el contraste
#
# - Comparados con la ronda 1, con el descarte de alta correlación no mejora ninguno
#
# - Comparados con la ronda 1, con el descarte de correlaciones ínfimas mejoran "SVR" y k vecinos

# %%
# Se hace la prueba
df_diamonds_9a = df_diamonds.copy()

df_diamonds_9a = df_diamonds_9a.drop(columns=['weight (carat)', 'lenght (millimeters)', 'width (millimeters)', 'depth (millimeters)'])

round_9a = Regression(df_diamonds_9a, 'price')
round_9a.split_dataframe()
round_9a.prepare_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ]
                        )
round_9a.apply_and_evaluate_kfolds()
round_9a.create_dataframe()
# Out:
# -- Regression: using mean of 5 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.23 sec(s). Total time: 0.23
# Starting Ridge:
# - Ridge done in 0.12 sec(s). Total time: 0.36
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 1.81 sec(s). Total time: 2.16
# Starting SVR:
# - SVR done in 284.91 sec(s). Total time: 287.07
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 0.62 sec(s). Total time: 287.69
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 49.7 sec(s). Total time: 337.39
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 3.69 sec(s). Total time: 341.08
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.967505  0.967505             1.015364  0.974499
# mse               0.936093  0.936093             1.031027  0.949679
# mae               0.800726  0.800727             0.818281  0.789581
# r2_score          0.089654  0.089654            -0.002618  0.076429
# mape              0.105039  0.105039             0.106717  0.103371
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    1.194726
# mse                                     1.427388
# mae                                     0.918272
# r2_score                               -0.388184
# mape                                    0.119392
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    1.017774
# mse                                     1.035893
# mae                                     0.809413
# r2_score                               -0.007383
# mape                                    0.105573
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.947318  XGBRegressor: random_state=43
# mse                            0.897441  XGBRegressor: random_state=43
# mae                            0.775724  XGBRegressor: random_state=43
# r2_score                       0.127223  XGBRegressor: random_state=43
# mape                           0.101540  XGBRegressor: random_state=43
#
#                                            WORST
# rmse      DecisionTreeRegressor: random_state=43
# mse       DecisionTreeRegressor: random_state=43
# mae       DecisionTreeRegressor: random_state=43
# r2_score  RandomForestRegressor: random_state=43
# mape      DecisionTreeRegressor: random_state=43

# %%
# Para sacar más partido a esta ronda, se prueba también si se eliminan las columnas con una correlación próxima a 0
df_diamonds_9b = df_diamonds.copy()

df_diamonds_9b = df_diamonds_9b.drop(columns=['cut quality', 'depth (percentage)'])

round_9b = Regression(df_diamonds_9b, 'price')
round_9b.split_dataframe()
round_9b.prepare_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ]
                        )
round_9b.apply_and_evaluate_kfolds()
round_9b.create_dataframe()
# Out:
# -- Regression: using mean of 5 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.14 sec(s). Total time: 0.14
# Starting Ridge:
# - Ridge done in 0.13 sec(s). Total time: 0.27
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 1.58 sec(s). Total time: 1.85
# Starting SVR:
# - SVR done in 145.99 sec(s). Total time: 147.84
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 1.0 sec(s). Total time: 148.84
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 84.33 sec(s). Total time: 233.16
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 4.21 sec(s). Total time: 237.37
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.206539  0.206540             0.144592  0.172820
# mse               0.043279  0.043274             0.020913  0.030168
# mae               0.128576  0.128630             0.104260  0.117265
# r2_score          0.957918  0.957924             0.979653  0.970607
# mape              0.016604  0.016611             0.013769  0.015292
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.132375
# mse                                     0.017530
# mae                                     0.091861
# r2_score                                0.982949
# mape                                    0.011848
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.095910
# mse                                     0.009216
# mae                                     0.068193
# r2_score                                0.991031
# mape                                    0.008816
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.092922  XGBRegressor: random_state=43
# mse                            0.008640  XGBRegressor: random_state=43
# mae                            0.067016  XGBRegressor: random_state=43
# r2_score                       0.991594  XGBRegressor: random_state=43
# mape                           0.008646  XGBRegressor: random_state=43
#
#                      WORST
# rmse                 Ridge
# mse       LinearRegression
# mae                  Ridge
# r2_score               SVR
# mape                 Ridge

# %% [markdown]
# ## Ronda 11: imputaciones "clarity quality"
# - Se imputan los valores de 7 "clarity quality" al 6. Esto se hace porque se ha visto en el EDA que las variables relacionadas con el tamaño ('weight (carat)', 'lenght (millimeters)', 'width (millimeters)' y 'depth (millimeters)') dejan de disminuir a partir del 6
#
# - Se utiliza el "dataframe" sin cambios ni escalado para el contraste
#
# - Comparados con la ronda 1, mejoran "ridge", regresión lineal y k vecinos

# %%
# Se comprueba
df_diamonds_10 = df_diamonds.copy()

df_diamonds_10.loc[df_diamonds_10['clarity quality'] == 7, 'clarity quality'] = 6

round_10 = Regression(df_diamonds_10, 'price')
round_10.split_dataframe()
round_10.prepare_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ]
                        )
round_10.apply_and_evaluate_kfolds()
round_10.create_dataframe()
# Out:
# -- Regression: using mean of 5 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.17 sec(s). Total time: 0.17
# Starting Ridge:
# - Ridge done in 0.14 sec(s). Total time: 0.3
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 4.34 sec(s). Total time: 4.64
# Starting SVR:
# - SVR done in 203.22 sec(s). Total time: 207.87
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 1.36 sec(s). Total time: 209.23
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 126.28 sec(s). Total time: 335.51
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 7.18 sec(s). Total time: 342.69
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.182263  0.182425             0.181087  0.189843
# mse               0.033524  0.033573             0.032806  0.036387
# mae               0.118175  0.118252             0.135665  0.126377
# r2_score          0.967330  0.967283             0.968081  0.964555
# mape              0.015286  0.015296             0.017872  0.016373
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.131987
# mse                                     0.017425
# mae                                     0.092126
# r2_score                                0.983052
# mape                                    0.011904
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.095414
# mse                                     0.009120
# mae                                     0.068013
# r2_score                                0.991125
# mape                                    0.008810
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.091501  XGBRegressor: random_state=43
# mse                            0.008376  XGBRegressor: random_state=43
# mae                            0.066721  XGBRegressor: random_state=43
# r2_score                       0.991851  XGBRegressor: random_state=43
# mape                           0.008628  XGBRegressor: random_state=43
#
#                         WORST
# rmse                      SVR
# mse                       SVR
# mae       KNeighborsRegressor
# r2_score                  SVR
# mape      KNeighborsRegressor

# %% [markdown]
# # Modelaje: selección de modelos
#
# - Cada uno de los modelos mejora con los siguientes cambios:
#
# ---------- LinearRegression (mejor rmse hasta ahora: 0.146282, ronda 5) ----------
#
# · Borrado
#
# · Asignación
#
# · Logaritmo
#
# · Imputaciones "boxplot"
#
# · Imputaciones "ridge"
#
# · Sustitución
#
# · Imputaciones "clarity quality"
#
# ---------- Ridge (mejor rmse hasta ahora: 0.146204, ronda 5) ----------
#
# · Escalado "MinMax"
#
# · Borrado
#
# · Asignación
#
# · Logaritmo
#
# · Imputaciones "boxplot"
#
# · Imputaciones "ridge"
#
# · Sustitución
#
# · Imputaciones "clarity quality"
#
# ---------- KNeighborsRegressor (mejor rmse hasta ahora: 0.144004, ronda 2) ----------
#
# · Escalado "Standard"
#
# · Borrado parcial
#
# · Asignación
#
# · Valor más alto de "weight"
#
# · Imputaciones "boxplot"
#
# · Imputaciones "ridge"
#
# · Sustitución
#
# · Descarte correlación ínfima
#
# · Imputaciones "clarity quality"
#
# ---------- SVR (mejor rmse hasta ahora: 0.107316, ronda 2) ----------
#
# · Escalado "Standard"
#
# · Borrado
#
# · Asignación
#
# · Valor más alto de "weight"
#
# · Imputaciones "boxplot"
#
# · Imputaciones "ridge"
#
# · Sustitución
#
# · Descarte correlación ínfima
#
# ---------- DecisionTree (mejor rmse hasta ahora: 0.129357, ronda 9) ----------
#
# · Escalado "Standard"
#
# · Borrado parcial
#
# · Asignación
#
# · Valor más alto de "weight"
#
# ---------- RandomForest (mejor rmse hasta ahora: 0.093643, ronda 9) ----------
#
# · Borrado parcial
#
# · Asignación
#
# · Sustitución
#
# ---------- XGBRegressor (mejor rmse hasta ahora: 0.090404, ronda 8) ----------
#
# · Escalado "MinMax"
#
# · Borrado parcial
#
# · Asignación
#
# · Logaritmo
#
# · Valor más alto de "weight"
#
# · Imputaciones "boxplot"
#
# · Imputaciones "ridge"

# %% [markdown]
# ## "Ridge" y "LinearRegression"
#
# - Cambios: escalado "MinMax", borrado, asignación, logaritmo, imputaciones "boxplot", imputaciones "ridge", sustitución e imputaciones "clarity quality"
#
# - Como mejoran con los mismos cambios y "LinearRegression" no se ve afectada por los escalados, se prueban juntos
#
# - Con cambios e hiperparámetros, "LinearRegression" ha mejorado su "rmse" de 0.182664 a 0.143851 (-21.24%)
#
# - Con cambios e hiperparámetros, "Ridge" ha mejorado su "rmse" de 0.182826 a 0.144234 (-21.11%)

# %%
# Se crean el "scorer" y los "kfolds"
rmse = make_scorer(calculate_rmse, greater_is_better=False)
kfolds = KFold(n_splits=5, shuffle=True, random_state=43)

# %%
# Se aplican todos los cambios del listado en común
df_ridge_linear = df_diamonds.copy()

df_ridge_linear = remove_all(df_ridge_linear)

df_ridge_linear = assign_values(df_ridge_linear)

df_ridge_linear[['weight (carat)', 'lenght (millimeters)', 'width (millimeters)', 'depth (millimeters)']] = np.log(df_ridge_linear[['weight (carat)', 'lenght (millimeters)', 'width (millimeters)', 'depth (millimeters)']])

df_ridge_linear = impute_boxplot_min_max(df_ridge_linear, ['depth (percentage)', 'table (percentage)'])

df_ridge_linear = apply_ridge(df_ridge_linear)

df_ridge_linear['depth (percentage)'] = (df_ridge_linear['depth (millimeters)'] / ((df_ridge_linear['lenght (millimeters)']+df_ridge_linear['width (millimeters)']) / 2)) * 100

df_ridge_linear.loc[df_ridge_linear['clarity quality'] == 7.0, 'clarity quality'] = 6.0

# %%
# Se prueban en un "dataframe" conjunto
ridge_linear = Regression(df_ridge_linear, 'price')
X_train, X_test, y_train, y_test = ridge_linear.split_dataframe(scaler='MinMaxScaler')
ridge_linear.prepare_models(selected_list=['LinearRegression', 'Ridge'])
ridge_linear.apply_and_evaluate_kfolds()
ridge_linear.create_dataframe()
# Out:
# -- Regression (MinMaxScaler): using mean of 5 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.16 sec(s). Total time: 0.16
# Starting Ridge:
# - Ridge done in 0.1 sec(s). Total time: 0.27
#           LinearRegression     Ridge              BEST  WORST
# rmse              0.145544  0.146181  LinearRegression  Ridge
# mse               0.021186  0.021372  LinearRegression  Ridge
# mae               0.112806  0.113685  LinearRegression  Ridge
# r2_score          0.979516  0.979337  LinearRegression  Ridge
# mape              0.014745  0.014883  LinearRegression  Ridge

# %%
# Se busca la mejor media de 5 "folds" para la regresión lineal modificando los hiperparámetros
model = LinearRegression()

params = {'fit_intercept': [True, False],
            'positive': [True, False],
            }

grid = GridSearchCV(estimator = model,
                    param_grid = params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END fit_intercept=True, positive=True;, score=-0.148 total time=   0.0s
# [CV 2/5] END fit_intercept=True, positive=True;, score=-0.146 total time=   0.0s
# [CV 3/5] END fit_intercept=True, positive=True;, score=-0.145 total time=   0.0s
# [CV 4/5] END fit_intercept=True, positive=True;, score=-0.143 total time=   0.0s
# [CV 5/5] END fit_intercept=True, positive=True;, score=-0.147 total time=   0.0s
# [CV 1/5] END fit_intercept=True, positive=False;, score=-0.148 total time=   0.0s
# [CV 2/5] END fit_intercept=True, positive=False;, score=-0.146 total time=   0.0s
# [CV 3/5] END fit_intercept=True, positive=False;, score=-0.145 total time=   0.0s
# [CV 4/5] END fit_intercept=True, positive=False;, score=-0.143 total time=   0.0s
# [CV 5/5] END fit_intercept=True, positive=False;, score=-0.147 total time=   0.0s
# [CV 1/5] END fit_intercept=False, positive=True;, score=-0.256 total time=   0.0s
# [CV 2/5] END fit_intercept=False, positive=True;, score=-0.259 total time=   0.0s
# [CV 3/5] END fit_intercept=False, positive=True;, score=-0.278 total time=   0.0s
# [CV 4/5] END fit_intercept=False, positive=True;, score=-0.255 total time=   0.0s
# [CV 5/5] END fit_intercept=False, positive=True;, score=-0.257 total time=   0.0s
# [CV 1/5] END fit_intercept=False, positive=False;, score=-0.184 total time=   0.0s
# [CV 2/5] END fit_intercept=False, positive=False;, score=-0.184 total time=   0.0s
# [CV 3/5] END fit_intercept=False, positive=False;, score=-0.186 total time=   0.0s
# [CV 4/5] END fit_intercept=False, positive=False;, score=-0.181 total time=   0.0s
# [CV 5/5] END fit_intercept=False, positive=False;, score=-0.184 total time=   0.0s
# Best params: {'fit_intercept': True, 'positive': False}
# Best score: -0.14554437761478298

# %%
# Mejor puntuación para regresión lineal
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 0.1438519024266261

# %%
# Se intenta mejorar el "ridge" modificando los hiperparámetros
model = Ridge()

params = {'fit_intercept': [True, False],
            'alpha': np.linspace(1, 100, num=100),
            'solver': ['svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs'],
            'positive': [True, False]

            }

grid = GridSearchCV(estimator = model,
                    param_grid = params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')
# Out:
# Fitting 5 folds for each of 2800 candidates, totalling 14000 fits
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.148 total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.147 total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.147 total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.144 total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.148 total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=False, solver=svd;, score=-0.148 total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=False, solver=svd;, score=-0.147 total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=False, solver=svd;, score=-0.146 total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=False, solver=svd;, score=-0.143 total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=False, solver=svd;, score=-0.147 total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.148 total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.147 total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.146 total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.143 total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.147 total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.148 total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.147 total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.146 total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.143 total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.147 total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.148 total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.147 total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.146 total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.143 total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.147 total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=False, solver=sag;, score=-0.148 total time=   0.1s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=False, solver=sag;, score=-0.147 total time=   0.1s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=False, solver=sag;, score=-0.146 total time=   0.1s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=False, solver=sag;, score=-0.143 total time=   0.1s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=False, solver=sag;, score=-0.147 total time=   0.1s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=False, solver=saga;, score=-0.148 total time=   0.3s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=False, solver=saga;, score=-0.147 total time=   0.2s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=False, solver=saga;, score=-0.146 total time=   0.3s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=False, solver=saga;, score=-0.143 total time=   0.3s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=False, solver=saga;, score=-0.147 total time=   0.4s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.267 total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.265 total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.281 total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.266 total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.259 total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=False, solver=svd;, score=-0.192 total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=False, solver=svd;, score=-0.194 total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=False, solver=svd;, score=-0.205 total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=False, solver=svd;, score=-0.191 total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=False, solver=svd;, score=-0.193 total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.192 total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.194 total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.205 total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.191 total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.193 total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.192 total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.194 total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.205 total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.191 total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.193 total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.193 total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.196 total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.208 total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.193 total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.195 total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=False, solver=sag;, score=-0.192 total time=   0.1s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=False, solver=sag;, score=-0.194 total time=   0.1s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=False, solver=sag;, score=-0.205 total time=   0.2s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=False, solver=sag;, score=-0.191 total time=   0.1s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=False, solver=sag;, score=-0.193 total time=   0.1s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=False, solver=saga;, score=-0.192 total time=   0.3s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=False, solver=saga;, score=-0.194 total time=   0.3s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=False, solver=saga;, score=-0.205 total time=   0.4s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=False, solver=saga;, score=-0.191 total time=   0.3s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=False, solver=saga;, score=-0.193 total time=   0.4s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.149 total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.147 total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.147 total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.144 total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.148 total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=False, solver=svd;, score=-0.149 total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=False, solver=svd;, score=-0.147 total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=False, solver=svd;, score=-0.146 total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=False, solver=svd;, score=-0.144 total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=False, solver=svd;, score=-0.148 total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.149 total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.147 total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.146 total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.144 total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.148 total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.149 total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.147 total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.146 total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.144 total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.148 total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.149 total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.147 total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.146 total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.144 total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.148 total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=False, solver=sag;, score=-0.149 total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=False, solver=sag;, score=-0.147 total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=False, solver=sag;, score=-0.146 total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=False, solver=sag;, score=-0.144 total time=   0.1s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=False, solver=sag;, score=-0.148 total time=   0.1s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=False, solver=saga;, score=-0.149 total time=   0.1s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=False, solver=saga;, score=-0.147 total time=   0.1s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=False, solver=saga;, score=-0.146 total time=   0.2s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=False, solver=saga;, score=-0.144 total time=   0.2s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=False, solver=saga;, score=-0.148 total time=   0.1s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.267 total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.261 total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.279 total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.257 total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.263 total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=False, solver=svd;, score=-0.204 total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=False, solver=svd;, score=-0.207 total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=False, solver=svd;, score=-0.221 total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=False, solver=svd;, score=-0.204 total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=False, solver=svd;, score=-0.205 total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.204 total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.207 total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.221 total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.204 total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.205 total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.204 total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.207 total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.221 total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.204 total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.205 total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.205 total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.208 total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.222 total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.205 total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.206 total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=False, solver=sag;, score=-0.204 total time=   0.1s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=False, solver=sag;, score=-0.207 total time=   0.1s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=False, solver=sag;, score=-0.221 total time=   0.2s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=False, solver=sag;, score=-0.204 total time=   0.1s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=False, solver=sag;, score=-0.205 total time=   0.1s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=False, solver=saga;, score=-0.204 total time=   0.4s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=False, solver=saga;, score=-0.207 total time=   0.3s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=False, solver=saga;, score=-0.221 total time=   0.2s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=False, solver=saga;, score=-0.204 total time=   0.2s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=False, solver=saga;, score=-0.205 total time=   0.3s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.149 total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.147 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.147 total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.144 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.148 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=False, solver=svd;, score=-0.149 total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=False, solver=svd;, score=-0.147 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=False, solver=svd;, score=-0.146 total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=False, solver=svd;, score=-0.144 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=False, solver=svd;, score=-0.148 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.149 total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.147 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.146 total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.144 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.148 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.149 total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.147 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.146 total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.144 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.148 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.149 total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.147 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.146 total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.144 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.148 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=False, solver=sag;, score=-0.149 total time=   0.1s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=False, solver=sag;, score=-0.147 total time=   0.3s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=False, solver=sag;, score=-0.146 total time=   0.1s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=False, solver=sag;, score=-0.144 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=False, solver=sag;, score=-0.148 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=False, solver=saga;, score=-0.149 total time=   0.1s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=False, solver=saga;, score=-0.147 total time=   0.1s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=False, solver=saga;, score=-0.146 total time=   0.1s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=False, solver=saga;, score=-0.144 total time=   0.1s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=False, solver=saga;, score=-0.148 total time=   0.1s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.267 total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.268 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.283 total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.257 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.259 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=False, solver=svd;, score=-0.215 total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=False, solver=svd;, score=-0.219 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=False, solver=svd;, score=-0.233 total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=False, solver=svd;, score=-0.215 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=False, solver=svd;, score=-0.216 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.215 total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.219 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.233 total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.215 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.216 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.215 total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.219 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.233 total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.215 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.216 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.215 total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.219 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.234 total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.216 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.217 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=False, solver=sag;, score=-0.215 total time=   0.1s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=False, solver=sag;, score=-0.219 total time=   0.2s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=False, solver=sag;, score=-0.233 total time=   0.1s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=False, solver=sag;, score=-0.215 total time=   0.1s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=False, solver=sag;, score=-0.216 total time=   0.1s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=False, solver=saga;, score=-0.215 total time=   0.2s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=False, solver=saga;, score=-0.219 total time=   0.1s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=False, solver=saga;, score=-0.233 total time=   0.1s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=False, solver=saga;, score=-0.215 total time=   0.1s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=False, solver=saga;, score=-0.216 total time=   0.1s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END alpha=4.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 2/5] END alpha=4.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 3/5] END alpha=4.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 4/5] END alpha=4.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 5/5] END alpha=4.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 1/5] END alpha=4.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 2/5] END alpha=4.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 3/5] END alpha=4.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 4/5] END alpha=4.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 5/5] END alpha=4.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 1/5] END alpha=4.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 2/5] END alpha=4.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 3/5] END alpha=4.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 4/5] END alpha=4.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 5/5] END alpha=4.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 1/5] END alpha=4.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 2/5] END alpha=4.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 3/5] END alpha=4.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 4/5] END alpha=4.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 5/5] END alpha=4.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 1/5] END alpha=4.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END alpha=4.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END alpha=4.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END alpha=4.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END alpha=4.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END alpha=4.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 2/5] END alpha=4.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 3/5] END alpha=4.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 4/5] END alpha=4.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 5/5] END alpha=4.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 1/5] END alpha=4.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.149 total time=   0.0s
# [CV 2/5] END alpha=4.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.147 total time=   0.0s
# [CV 3/5] END alpha=4.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.147 total time=   0.0s
# [CV 4/5] END alpha=4.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.144 total time=   0.0s
# ...
# [CV 1/5] END alpha=100.0, fit_intercept=True, positive=False, solver=sag;, score=-0.156 total time=   0.1s
# [CV 2/5] END alpha=100.0, fit_intercept=True, positive=False, solver=sag;, score=-0.155 total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=True, positive=False, solver=sag;, score=-0.155 total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=True, positive=False, solver=sag;, score=-0.151 total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=True, positive=False, solver=sag;, score=-0.156 total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=True, positive=False, solver=saga;, score=-0.156 total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=True, positive=False, solver=saga;, score=-0.155 total time=   0.1s
# [CV 3/5] END alpha=100.0, fit_intercept=True, positive=False, solver=saga;, score=-0.155 total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=True, positive=False, solver=saga;, score=-0.151 total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=True, positive=False, solver=saga;, score=-0.156 total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.384 total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.400 total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.401 total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.395 total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.393 total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=False, solver=svd;, score=-0.384 total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=False, solver=svd;, score=-0.400 total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=False, solver=svd;, score=-0.401 total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=False, solver=svd;, score=-0.395 total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=False, solver=svd;, score=-0.393 total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.384 total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.400 total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.401 total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.395 total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.393 total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.384 total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.400 total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.401 total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.395 total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.393 total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.384 total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.400 total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.402 total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.395 total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.393 total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=False, solver=sag;, score=-0.384 total time=   0.1s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=False, solver=sag;, score=-0.400 total time=   0.2s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=False, solver=sag;, score=-0.401 total time=   0.2s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=False, solver=sag;, score=-0.395 total time=   0.1s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=False, solver=sag;, score=-0.393 total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=False, solver=saga;, score=-0.384 total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=False, solver=saga;, score=-0.400 total time=   0.2s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=False, solver=saga;, score=-0.401 total time=   0.2s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=False, solver=saga;, score=-0.395 total time=   0.1s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=False, solver=saga;, score=-0.393 total time=   0.1s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# Best params: {'alpha': 1.0, 'fit_intercept': True, 'positive': False, 'solver': 'lsqr'}
# Best score: -0.14618110818179936
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 7000 fits failed out of a total of 14000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1000 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 1134, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 832, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support positive fitting. Please set the solver to 'auto' or 'lbfgs', or set `positive=False`
#
# --------------------------------------------------------------------------------
# 1000 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 1134, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 832, in fit
#     raise ValueError(
# ValueError: solver='cholesky' does not support positive fitting. Please set the solver to 'auto' or 'lbfgs', or set `positive=False`
#
# --------------------------------------------------------------------------------
# 1000 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 1134, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 832, in fit
#     raise ValueError(
# ValueError: solver='lsqr' does not support positive fitting. Please set the solver to 'auto' or 'lbfgs', or set `positive=False`
#
# --------------------------------------------------------------------------------
# 1000 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 1134, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 832, in fit
#     raise ValueError(
# ValueError: solver='sparse_cg' does not support positive fitting. Please set the solver to 'auto' or 'lbfgs', or set `positive=False`
#
# --------------------------------------------------------------------------------
# 1000 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 1134, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 832, in fit
#     raise ValueError(
# ValueError: solver='sag' does not support positive fitting. Please set the solver to 'auto' or 'lbfgs', or set `positive=False`
#
# --------------------------------------------------------------------------------
# 1000 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 1134, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 832, in fit
#     raise ValueError(
# ValueError: solver='saga' does not support positive fitting. Please set the solver to 'auto' or 'lbfgs', or set `positive=False`
#
# --------------------------------------------------------------------------------
# 1000 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 1134, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 825, in fit
#     raise ValueError(
# ValueError: 'lbfgs' solver can be used only when positive=True. Please use another solver.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\model_selection\_search.py:953: UserWarning: One or more of the test scores are non-finite: [        nan         nan         nan ... -0.39463152 -0.39463809
#          nan]
#   warnings.warn(

# %%
# Mejor puntuación para "ridge"
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 0.14423457559794522

# %% [markdown]
# ## PENDIENTE "KNeighborsRegressor"
#
# - Cambios: escalado "Standard", borrado parcial, asignación, valor más alto de "weight", imputaciones "boxplot", imputaciones "ridge", sustitución, descarte correlación ínfima e imputaciones "clarity quality"
#
# - Con cambios e hiperparámetros, k vecinos ha mejorado su "rmse" de 0.181632 a

# %%
df_neighbors = df_diamonds.copy()

df_neighbors = remove_all(df_neighbors, zeros_only=True)

df_neighbors = assign_values(df_neighbors)

df_neighbors = impute_next_higher(df_neighbors, log=False)

df_neighbors = impute_boxplot_min_max(df_neighbors, ['depth (percentage)', 'table (percentage)'])

df_neighbors = apply_ridge(df_neighbors)

df_neighbors['depth (percentage)'] = (df_neighbors['depth (millimeters)'] / ((df_neighbors['lenght (millimeters)']+df_neighbors['width (millimeters)']) / 2)) * 100

df_neighbors = df_neighbors.drop(columns=['cut quality', 'depth (percentage)'])

df_ridge_linear.loc[df_ridge_linear['clarity quality'] == 7.0, 'clarity quality'] = 6.0

# %%
neighbors = Regression(df_neighbors, 'price')
X_train, X_test, y_train, y_test = neighbors.split_dataframe(scaler='StandardScaler')
neighbors.prepare_models(selected_list=['KNeighborsRegressor'])
neighbors.apply_and_evaluate_kfolds()
neighbors.create_dataframe()
# Out:
# -- Regression (StandardScaler): using mean of 5 folds --
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 1.63 sec(s). Total time: 1.63
#           KNeighborsRegressor
# mae                  0.095323
# mape                 0.012645
# mse                  0.016279
# r2_score             0.984217
# rmse                 0.127563

# %%
# Se usa el "grid"
model = KNeighborsRegressor()

params = {'n_neighbors': range(5, 21),
            'algorithm': ['ball_tree', 'kd_tree', 'brute'],
            'leaf_size': range(20, 41),
            'metric': ['cityblock', 'euclidean', 'l1', 'l2', 'manhattan'],
            'n_jobs': [-1],
            }

grid = GridSearchCV(estimator = model,
                    param_grid = params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')
# Out:
# Fitting 5 folds for each of 5040 candidates, totalling 25200 fits
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=5;, score=-0.126 total time=   5.2s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=5;, score=-0.124 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=5;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=5;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=5;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=6;, score=-0.126 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=6;, score=-0.123 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=6;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=6;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=6;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=7;, score=-0.125 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=7;, score=-0.122 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=7;, score=-0.124 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=7;, score=-0.122 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=7;, score=-0.120 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=8;, score=-0.125 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=8;, score=-0.123 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=8;, score=-0.125 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=8;, score=-0.121 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=8;, score=-0.120 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=9;, score=-0.125 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=9;, score=-0.122 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=9;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=9;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=9;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=10;, score=-0.125 total time=   0.5s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=10;, score=-0.123 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=10;, score=-0.125 total time=   0.5s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=10;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=10;, score=-0.120 total time=   0.5s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=11;, score=-0.125 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=11;, score=-0.123 total time=   0.7s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=11;, score=-0.125 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=11;, score=-0.122 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=11;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=12;, score=-0.125 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=12;, score=-0.123 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=12;, score=-0.125 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=12;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=12;, score=-0.120 total time=   0.5s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=13;, score=-0.125 total time=   0.5s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=13;, score=-0.123 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=13;, score=-0.125 total time=   0.2s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=13;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=13;, score=-0.121 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=14;, score=-0.125 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=14;, score=-0.123 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=14;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=14;, score=-0.122 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=14;, score=-0.121 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=15;, score=-0.125 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=15;, score=-0.124 total time=   0.5s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=15;, score=-0.125 total time=   0.2s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=15;, score=-0.123 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=15;, score=-0.121 total time=   0.5s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=16;, score=-0.125 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=16;, score=-0.124 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=16;, score=-0.125 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=16;, score=-0.123 total time=   0.7s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=16;, score=-0.121 total time=   0.5s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=17;, score=-0.126 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=17;, score=-0.124 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=17;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=17;, score=-0.123 total time=   0.6s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=17;, score=-0.121 total time=   0.2s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=18;, score=-0.126 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=18;, score=-0.124 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=18;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=18;, score=-0.123 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=18;, score=-0.121 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=19;, score=-0.126 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=19;, score=-0.125 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=19;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=19;, score=-0.124 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=19;, score=-0.122 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=20;, score=-0.126 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=20;, score=-0.125 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=20;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=20;, score=-0.124 total time=   0.6s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=20;, score=-0.122 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=5;, score=-0.132 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=5;, score=-0.129 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=5;, score=-0.128 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=5;, score=-0.124 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=5;, score=-0.125 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=6;, score=-0.132 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=6;, score=-0.128 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=6;, score=-0.128 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=6;, score=-0.124 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=6;, score=-0.125 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=7;, score=-0.133 total time=   0.2s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=7;, score=-0.128 total time=   0.2s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=7;, score=-0.128 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=7;, score=-0.124 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=7;, score=-0.126 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=8;, score=-0.133 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=8;, score=-0.128 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=8;, score=-0.129 total time=   0.2s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=8;, score=-0.125 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=8;, score=-0.126 total time=   0.5s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=9;, score=-0.133 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=9;, score=-0.129 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=9;, score=-0.129 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=9;, score=-0.125 total time=   0.2s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=9;, score=-0.127 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=10;, score=-0.134 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=10;, score=-0.129 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=10;, score=-0.129 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=10;, score=-0.126 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=10;, score=-0.127 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=11;, score=-0.135 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=11;, score=-0.130 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=11;, score=-0.130 total time=   0.5s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=11;, score=-0.126 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=11;, score=-0.127 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=12;, score=-0.135 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=12;, score=-0.131 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=12;, score=-0.130 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=12;, score=-0.127 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=12;, score=-0.128 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=13;, score=-0.136 total time=   0.5s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=13;, score=-0.132 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=13;, score=-0.131 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=13;, score=-0.128 total time=   0.6s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=13;, score=-0.128 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=14;, score=-0.136 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=14;, score=-0.132 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=14;, score=-0.131 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=14;, score=-0.129 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=14;, score=-0.128 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=15;, score=-0.136 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=15;, score=-0.132 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=15;, score=-0.131 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=15;, score=-0.129 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=15;, score=-0.128 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=16;, score=-0.136 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=16;, score=-0.133 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=16;, score=-0.131 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=16;, score=-0.129 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=16;, score=-0.129 total time=   0.6s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=17;, score=-0.136 total time=   0.7s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=17;, score=-0.133 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=17;, score=-0.132 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=17;, score=-0.130 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=17;, score=-0.129 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=18;, score=-0.137 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=18;, score=-0.134 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=18;, score=-0.132 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=18;, score=-0.130 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=18;, score=-0.129 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=19;, score=-0.137 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=19;, score=-0.134 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=19;, score=-0.132 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=19;, score=-0.130 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=19;, score=-0.129 total time=   0.6s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=20;, score=-0.137 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=20;, score=-0.134 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=20;, score=-0.132 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=20;, score=-0.130 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=20;, score=-0.130 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=5;, score=-0.126 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=5;, score=-0.124 total time=   0.1s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=5;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=5;, score=-0.122 total time=   0.6s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=5;, score=-0.121 total time=   0.5s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=6;, score=-0.126 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=6;, score=-0.123 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=6;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=6;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=6;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=7;, score=-0.125 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=7;, score=-0.122 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=7;, score=-0.124 total time=   0.2s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=7;, score=-0.122 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=7;, score=-0.120 total time=   0.6s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=8;, score=-0.125 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=8;, score=-0.123 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=8;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=8;, score=-0.121 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=8;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=9;, score=-0.125 total time=   0.2s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=9;, score=-0.122 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=9;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=9;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=9;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=10;, score=-0.125 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=10;, score=-0.123 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=10;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=10;, score=-0.122 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=10;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=11;, score=-0.125 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=11;, score=-0.123 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=11;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=11;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=11;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=12;, score=-0.125 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=12;, score=-0.123 total time=   0.5s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=12;, score=-0.125 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=12;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=12;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=13;, score=-0.125 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=13;, score=-0.123 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=13;, score=-0.125 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=13;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=13;, score=-0.121 total time=   0.2s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=14;, score=-0.125 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=14;, score=-0.123 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=14;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=14;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=14;, score=-0.121 total time=   0.5s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=15;, score=-0.125 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=15;, score=-0.124 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=15;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=15;, score=-0.123 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=15;, score=-0.121 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=16;, score=-0.125 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=16;, score=-0.124 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=16;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=16;, score=-0.123 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=16;, score=-0.121 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=17;, score=-0.126 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=17;, score=-0.124 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=17;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=17;, score=-0.123 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=17;, score=-0.121 total time=   0.5s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=18;, score=-0.126 total time=   0.2s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=18;, score=-0.124 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=18;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=18;, score=-0.123 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=18;, score=-0.121 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=19;, score=-0.126 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=19;, score=-0.125 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=19;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=19;, score=-0.124 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=19;, score=-0.122 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=20;, score=-0.126 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=20;, score=-0.125 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=20;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=20;, score=-0.124 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=20;, score=-0.122 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=5;, score=-0.132 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=5;, score=-0.129 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=5;, score=-0.128 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=5;, score=-0.124 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=5;, score=-0.125 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=6;, score=-0.132 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=6;, score=-0.128 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=6;, score=-0.128 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=6;, score=-0.124 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=6;, score=-0.125 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=7;, score=-0.133 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=7;, score=-0.128 total time=   0.6s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=7;, score=-0.128 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=7;, score=-0.124 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=7;, score=-0.126 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=8;, score=-0.133 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=8;, score=-0.128 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=8;, score=-0.129 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=8;, score=-0.125 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=8;, score=-0.126 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=9;, score=-0.133 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=9;, score=-0.129 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=9;, score=-0.129 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=9;, score=-0.125 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=9;, score=-0.127 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=10;, score=-0.134 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=10;, score=-0.129 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=10;, score=-0.129 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=10;, score=-0.126 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=10;, score=-0.127 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=11;, score=-0.135 total time=   0.7s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=11;, score=-0.130 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=11;, score=-0.130 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=11;, score=-0.126 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=11;, score=-0.127 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=12;, score=-0.135 total time=   0.5s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=12;, score=-0.131 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=12;, score=-0.130 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=12;, score=-0.127 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=12;, score=-0.128 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=13;, score=-0.136 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=13;, score=-0.132 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=13;, score=-0.131 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=13;, score=-0.128 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=13;, score=-0.128 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=14;, score=-0.136 total time=   0.2s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=14;, score=-0.132 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=14;, score=-0.131 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=14;, score=-0.129 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=14;, score=-0.128 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=15;, score=-0.136 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=15;, score=-0.132 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=15;, score=-0.131 total time=   0.5s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=15;, score=-0.129 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=15;, score=-0.128 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=16;, score=-0.136 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=16;, score=-0.133 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=16;, score=-0.131 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=16;, score=-0.129 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=16;, score=-0.129 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=17;, score=-0.136 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=17;, score=-0.133 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=17;, score=-0.132 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=17;, score=-0.130 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=17;, score=-0.129 total time=   0.6s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=18;, score=-0.137 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=18;, score=-0.134 total time=   0.5s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=18;, score=-0.132 total time=   0.6s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=18;, score=-0.130 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=18;, score=-0.129 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=19;, score=-0.137 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=19;, score=-0.134 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=19;, score=-0.132 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=19;, score=-0.130 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=19;, score=-0.129 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=20;, score=-0.137 total time=   0.2s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=20;, score=-0.134 total time=   0.6s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=20;, score=-0.132 total time=   0.5s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=20;, score=-0.130 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=20;, score=-0.130 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=5;, score=-0.126 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=5;, score=-0.124 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=5;, score=-0.125 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=5;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=5;, score=-0.121 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=6;, score=-0.126 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=6;, score=-0.123 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=6;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=6;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=6;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=7;, score=-0.125 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=7;, score=-0.122 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=7;, score=-0.124 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=7;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=7;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=8;, score=-0.125 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=8;, score=-0.123 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=8;, score=-0.125 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=8;, score=-0.121 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=8;, score=-0.120 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=9;, score=-0.125 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=9;, score=-0.122 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=9;, score=-0.125 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=9;, score=-0.122 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=9;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=10;, score=-0.125 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=10;, score=-0.123 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=10;, score=-0.125 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=10;, score=-0.122 total time=   0.6s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=10;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=11;, score=-0.125 total time=   0.5s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=11;, score=-0.123 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=11;, score=-0.125 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=11;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=11;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=12;, score=-0.125 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=12;, score=-0.123 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=12;, score=-0.125 total time=   0.6s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=12;, score=-0.122 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=12;, score=-0.120 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=13;, score=-0.125 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=13;, score=-0.123 total time=   0.2s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=13;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=13;, score=-0.122 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=13;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=14;, score=-0.125 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=14;, score=-0.123 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=14;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=14;, score=-0.122 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=14;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=15;, score=-0.125 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=15;, score=-0.124 total time=   0.5s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=15;, score=-0.125 total time=   0.6s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=15;, score=-0.123 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=15;, score=-0.121 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=16;, score=-0.125 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=16;, score=-0.124 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=16;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=16;, score=-0.123 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=16;, score=-0.121 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=17;, score=-0.126 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=17;, score=-0.124 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=17;, score=-0.125 total time=   0.7s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=17;, score=-0.123 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=17;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=18;, score=-0.126 total time=   0.9s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=18;, score=-0.124 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=18;, score=-0.125 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=18;, score=-0.123 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=18;, score=-0.121 total time=   0.3s
# ...
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=l1, n_jobs=-1, n_neighbors=17;, score=-0.126 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=l1, n_jobs=-1, n_neighbors=17;, score=-0.124 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=l1, n_jobs=-1, n_neighbors=17;, score=-0.125 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=l1, n_jobs=-1, n_neighbors=17;, score=-0.123 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=l1, n_jobs=-1, n_neighbors=17;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=l1, n_jobs=-1, n_neighbors=18;, score=-0.126 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=l1, n_jobs=-1, n_neighbors=18;, score=-0.124 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=l1, n_jobs=-1, n_neighbors=18;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=l1, n_jobs=-1, n_neighbors=18;, score=-0.123 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=l1, n_jobs=-1, n_neighbors=18;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=l1, n_jobs=-1, n_neighbors=19;, score=-0.126 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=l1, n_jobs=-1, n_neighbors=19;, score=-0.125 total time=   0.7s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=l1, n_jobs=-1, n_neighbors=19;, score=-0.125 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=l1, n_jobs=-1, n_neighbors=19;, score=-0.124 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=l1, n_jobs=-1, n_neighbors=19;, score=-0.122 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=l1, n_jobs=-1, n_neighbors=20;, score=-0.126 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=l1, n_jobs=-1, n_neighbors=20;, score=-0.125 total time=   0.5s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=l1, n_jobs=-1, n_neighbors=20;, score=-0.125 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=l1, n_jobs=-1, n_neighbors=20;, score=-0.124 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=l1, n_jobs=-1, n_neighbors=20;, score=-0.122 total time=   0.5s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=5;, score=-0.132 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=5;, score=-0.129 total time=   0.6s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=5;, score=-0.128 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=5;, score=-0.124 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=5;, score=-0.125 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=6;, score=-0.132 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=6;, score=-0.128 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=6;, score=-0.128 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=6;, score=-0.124 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=6;, score=-0.125 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=7;, score=-0.133 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=7;, score=-0.128 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=7;, score=-0.128 total time=   0.5s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=7;, score=-0.124 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=7;, score=-0.126 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=8;, score=-0.133 total time=   0.5s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=8;, score=-0.128 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=8;, score=-0.129 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=8;, score=-0.125 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=8;, score=-0.126 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=9;, score=-0.133 total time=   0.5s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=9;, score=-0.129 total time=   0.6s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=9;, score=-0.129 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=9;, score=-0.125 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=9;, score=-0.127 total time=   0.8s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=10;, score=-0.134 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=10;, score=-0.129 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=10;, score=-0.129 total time=   0.6s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=10;, score=-0.126 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=10;, score=-0.127 total time=   0.2s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=11;, score=-0.135 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=11;, score=-0.130 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=11;, score=-0.130 total time=   0.7s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=11;, score=-0.126 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=11;, score=-0.127 total time=   0.6s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=12;, score=-0.135 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=12;, score=-0.131 total time=   0.6s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=12;, score=-0.130 total time=   0.7s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=12;, score=-0.127 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=12;, score=-0.128 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=13;, score=-0.136 total time=   0.9s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=13;, score=-0.132 total time=   0.7s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=13;, score=-0.131 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=13;, score=-0.128 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=13;, score=-0.128 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=14;, score=-0.136 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=14;, score=-0.132 total time=   0.6s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=14;, score=-0.131 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=14;, score=-0.129 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=14;, score=-0.128 total time=   0.6s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=15;, score=-0.136 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=15;, score=-0.132 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=15;, score=-0.131 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=15;, score=-0.129 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=15;, score=-0.128 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=16;, score=-0.136 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=16;, score=-0.133 total time=   0.5s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=16;, score=-0.131 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=16;, score=-0.129 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=16;, score=-0.129 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=17;, score=-0.136 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=17;, score=-0.133 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=17;, score=-0.132 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=17;, score=-0.130 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=17;, score=-0.129 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=18;, score=-0.137 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=18;, score=-0.134 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=18;, score=-0.132 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=18;, score=-0.130 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=18;, score=-0.129 total time=   0.5s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=19;, score=-0.137 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=19;, score=-0.134 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=19;, score=-0.132 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=19;, score=-0.130 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=19;, score=-0.130 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=20;, score=-0.137 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=20;, score=-0.134 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=20;, score=-0.132 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=20;, score=-0.130 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=l2, n_jobs=-1, n_neighbors=20;, score=-0.130 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=5;, score=-0.126 total time=   0.5s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=5;, score=-0.124 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=5;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=5;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=5;, score=-0.121 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=6;, score=-0.126 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=6;, score=-0.123 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=6;, score=-0.125 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=6;, score=-0.122 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=6;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=7;, score=-0.125 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=7;, score=-0.122 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=7;, score=-0.124 total time=   0.5s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=7;, score=-0.122 total time=   0.6s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=7;, score=-0.120 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=8;, score=-0.125 total time=   0.6s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=8;, score=-0.123 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=8;, score=-0.125 total time=   0.5s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=8;, score=-0.121 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=8;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=9;, score=-0.125 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=9;, score=-0.122 total time=   0.2s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=9;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=9;, score=-0.122 total time=   0.2s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=9;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=10;, score=-0.125 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=10;, score=-0.123 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=10;, score=-0.125 total time=   0.5s
# [CV 4/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=10;, score=-0.122 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=10;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=11;, score=-0.125 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=28, metric=manhattan, n_jobs=-1, n_neighbors=11;, score=-0.123 total time=   0.3s

# %%
# Mejor puntuación para k vecinos
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 0.12031150183849708

# %% [markdown]
# ## "SVR"
#
# - Cambios: escalado "Standard", borrado, asignación, valor más alto de "weight", imputaciones "boxplot", imputaciones "ridge", sustitución y descarte correlación ínfima
#
# - Con cambios e hiperparámetros, "SVR" ha mejorado su "rmse" de 0.189328 a

# %%
df_svr = df_diamonds.copy()

df_svr = remove_all(df_svr)

df_svr = assign_values(df_svr)

df_svr = impute_next_higher(df_svr, log=False)

df_svr = impute_boxplot_min_max(df_svr, ['depth (percentage)', 'table (percentage)'])

df_svr = apply_ridge(df_svr)

df_svr['depth (percentage)'] = (df_svr['depth (millimeters)'] / ((df_svr['lenght (millimeters)']+df_svr['width (millimeters)']) / 2)) * 100

df_svr = df_svr.drop(columns=['cut quality', 'depth (percentage)'])

# %%
svr = Regression(df_svr, 'price')
X_train, X_test, y_train, y_test = svr.split_dataframe(scaler='StandardScaler')
svr.prepare_models(selected_list=['SVR'])
svr.apply_and_evaluate_kfolds()
svr.create_dataframe()
# Out:
# -- Regression (StandardScaler): using best of 10 folds --
# Starting SVR:
# - SVR done in 252.86 sec(s). Total time: 252.86
#                SVR
# mae       0.079636
# mape      0.010407
# mse       0.010841
# r2_score  0.989499
# rmse      0.104119

# %%
# Como es lento, se empieza por probar solo los diferentes "kernels"
model = SVR()

params = {'kernel': ['linear', 'poly', 'rbf']
            }

grid = GridSearchCV(estimator = model,
                    param_grid = params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5] END ....................kernel=linear;, score=-0.151 total time= 1.3min
# [CV 2/5] END ....................kernel=linear;, score=-0.152 total time= 1.2min
# [CV 3/5] END ....................kernel=linear;, score=-0.148 total time= 1.3min
# [CV 4/5] END ....................kernel=linear;, score=-0.149 total time= 1.3min
# [CV 5/5] END ....................kernel=linear;, score=-0.145 total time= 1.3min
# [CV 1/5] END ......................kernel=poly;, score=-0.506 total time= 1.2min
# [CV 2/5] END ......................kernel=poly;, score=-0.507 total time= 1.3min
# [CV 3/5] END ......................kernel=poly;, score=-0.468 total time= 1.2min
# [CV 4/5] END ......................kernel=poly;, score=-0.492 total time= 1.2min
# [CV 5/5] END ......................kernel=poly;, score=-0.446 total time= 1.2min
# [CV 1/5] END .......................kernel=rbf;, score=-0.106 total time=  20.8s
# [CV 2/5] END .......................kernel=rbf;, score=-0.105 total time=  20.6s
# [CV 3/5] END .......................kernel=rbf;, score=-0.104 total time=  20.9s
# [CV 4/5] END .......................kernel=rbf;, score=-0.105 total time=  20.5s
# [CV 5/5] END .......................kernel=rbf;, score=-0.104 total time=  20.7s
# Best params: {'kernel': 'rbf'}

# %%
# "rbf" es el mejor y es bastante rápido. "poly" es tan lento que es inviable iterar con él
# Se prueba con varios "gamma" superiores al estándar
model = SVR()

params = {'kernel': ['rbf'],
            'gamma': range(10, 41),
            }

grid = GridSearchCV(estimator = model,
                    param_grid = params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')

# %%
# Se prueba, también, con varios gamma inferiores al estándar. Este es el mejor "SVR" obtenido
model = SVR()

params = {'kernel': ['rbf'],
            'gamma': [0.0001, 0.0003, 0.0005, 0.0007, 0.001, 0.003, 0.005, 0.007, 0.01, 0.03, 0.05, 0.07, 0.1, 0.3, 0.5, 0.7, 1, 3 , 5, 7],
            }

grid = GridSearchCV(estimator = model,
                    param_grid = params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END .........gamma=0.0001, kernel=rbf;, score=-0.986 total time=  53.3s
# [CV 2/5] END .........gamma=0.0001, kernel=rbf;, score=-0.988 total time=  53.7s
# [CV 3/5] END .........gamma=0.0001, kernel=rbf;, score=-0.959 total time=  56.0s
# [CV 4/5] END .........gamma=0.0001, kernel=rbf;, score=-0.968 total time=  56.0s
# [CV 5/5] END .........gamma=0.0001, kernel=rbf;, score=-0.969 total time=  55.1s
# [CV 1/5] END .........gamma=0.0003, kernel=rbf;, score=-0.990 total time=  54.6s
# [CV 2/5] END .........gamma=0.0003, kernel=rbf;, score=-0.992 total time=  54.6s
# [CV 3/5] END .........gamma=0.0003, kernel=rbf;, score=-0.962 total time=  54.2s
# [CV 4/5] END .........gamma=0.0003, kernel=rbf;, score=-0.971 total time=  54.7s
# [CV 5/5] END .........gamma=0.0003, kernel=rbf;, score=-0.972 total time=  54.5s
# [CV 1/5] END .........gamma=0.0005, kernel=rbf;, score=-0.991 total time=  54.3s
# [CV 2/5] END .........gamma=0.0005, kernel=rbf;, score=-0.993 total time=  51.1s
# [CV 3/5] END .........gamma=0.0005, kernel=rbf;, score=-0.963 total time=  50.9s
# [CV 4/5] END .........gamma=0.0005, kernel=rbf;, score=-0.972 total time=  51.1s
# [CV 5/5] END .........gamma=0.0005, kernel=rbf;, score=-0.973 total time=  51.1s
# [CV 1/5] END .........gamma=0.0007, kernel=rbf;, score=-0.992 total time=  51.0s
# [CV 2/5] END .........gamma=0.0007, kernel=rbf;, score=-0.993 total time=  51.2s
# [CV 3/5] END .........gamma=0.0007, kernel=rbf;, score=-0.963 total time=  50.9s
# [CV 4/5] END .........gamma=0.0007, kernel=rbf;, score=-0.972 total time=  51.1s
# [CV 5/5] END .........gamma=0.0007, kernel=rbf;, score=-0.973 total time=  51.9s
# [CV 1/5] END ..........gamma=0.001, kernel=rbf;, score=-0.992 total time=  54.2s
# [CV 2/5] END ..........gamma=0.001, kernel=rbf;, score=-0.993 total time= 1.2min
# [CV 3/5] END ..........gamma=0.001, kernel=rbf;, score=-0.963 total time= 1.3min
# [CV 4/5] END ..........gamma=0.001, kernel=rbf;, score=-0.972 total time=  56.0s
# [CV 5/5] END ..........gamma=0.001, kernel=rbf;, score=-0.973 total time=  54.7s
# [CV 1/5] END ..........gamma=0.003, kernel=rbf;, score=-0.990 total time=  56.9s
# [CV 2/5] END ..........gamma=0.003, kernel=rbf;, score=-0.992 total time=  56.7s
# [CV 3/5] END ..........gamma=0.003, kernel=rbf;, score=-0.961 total time=  55.1s
# [CV 4/5] END ..........gamma=0.003, kernel=rbf;, score=-0.970 total time=  53.9s
# [CV 5/5] END ..........gamma=0.003, kernel=rbf;, score=-0.971 total time=  52.9s
# [CV 1/5] END ..........gamma=0.005, kernel=rbf;, score=-0.989 total time=  52.8s
# [CV 2/5] END ..........gamma=0.005, kernel=rbf;, score=-0.991 total time=  53.7s
# [CV 3/5] END ..........gamma=0.005, kernel=rbf;, score=-0.960 total time=  53.0s
# [CV 4/5] END ..........gamma=0.005, kernel=rbf;, score=-0.969 total time=  56.8s
# [CV 5/5] END ..........gamma=0.005, kernel=rbf;, score=-0.971 total time=  54.6s
# [CV 1/5] END ..........gamma=0.007, kernel=rbf;, score=-0.988 total time=  49.8s
# [CV 2/5] END ..........gamma=0.007, kernel=rbf;, score=-0.991 total time=  49.6s
# [CV 3/5] END ..........gamma=0.007, kernel=rbf;, score=-0.960 total time=  49.0s
# [CV 4/5] END ..........gamma=0.007, kernel=rbf;, score=-0.969 total time=  49.2s
# [CV 5/5] END ..........gamma=0.007, kernel=rbf;, score=-0.970 total time=  49.4s
# [CV 1/5] END ...........gamma=0.01, kernel=rbf;, score=-0.988 total time=  49.6s
# [CV 2/5] END ...........gamma=0.01, kernel=rbf;, score=-0.990 total time=  51.1s
# [CV 3/5] END ...........gamma=0.01, kernel=rbf;, score=-0.959 total time=  51.1s
# [CV 4/5] END ...........gamma=0.01, kernel=rbf;, score=-0.968 total time=  50.4s
# [CV 5/5] END ...........gamma=0.01, kernel=rbf;, score=-0.970 total time=  50.9s
# [CV 1/5] END ...........gamma=0.03, kernel=rbf;, score=-0.986 total time=  51.3s
# [CV 2/5] END ...........gamma=0.03, kernel=rbf;, score=-0.990 total time=  52.3s
# [CV 3/5] END ...........gamma=0.03, kernel=rbf;, score=-0.960 total time=  51.0s
# [CV 4/5] END ...........gamma=0.03, kernel=rbf;, score=-0.968 total time=  51.2s
# [CV 5/5] END ...........gamma=0.03, kernel=rbf;, score=-0.968 total time=  51.6s
# [CV 1/5] END ...........gamma=0.05, kernel=rbf;, score=-0.985 total time=  50.6s
# [CV 2/5] END ...........gamma=0.05, kernel=rbf;, score=-0.990 total time=  51.1s
# [CV 3/5] END ...........gamma=0.05, kernel=rbf;, score=-0.961 total time=  51.9s
# [CV 4/5] END ...........gamma=0.05, kernel=rbf;, score=-0.967 total time=  51.3s
# [CV 5/5] END ...........gamma=0.05, kernel=rbf;, score=-0.968 total time=  51.4s
# [CV 1/5] END ...........gamma=0.07, kernel=rbf;, score=-0.983 total time=  51.8s
# [CV 2/5] END ...........gamma=0.07, kernel=rbf;, score=-0.990 total time=  51.9s
# [CV 3/5] END ...........gamma=0.07, kernel=rbf;, score=-0.961 total time=  51.5s
# [CV 4/5] END ...........gamma=0.07, kernel=rbf;, score=-0.966 total time=  51.5s
# [CV 5/5] END ...........gamma=0.07, kernel=rbf;, score=-0.967 total time=  51.2s
# [CV 1/5] END ............gamma=0.1, kernel=rbf;, score=-0.981 total time=  51.7s
# [CV 2/5] END ............gamma=0.1, kernel=rbf;, score=-0.989 total time=  51.8s
# [CV 3/5] END ............gamma=0.1, kernel=rbf;, score=-0.961 total time=  52.6s
# [CV 4/5] END ............gamma=0.1, kernel=rbf;, score=-0.964 total time=  51.7s
# [CV 5/5] END ............gamma=0.1, kernel=rbf;, score=-0.966 total time=  52.0s
# [CV 1/5] END ............gamma=0.3, kernel=rbf;, score=-0.975 total time=  51.3s
# [CV 2/5] END ............gamma=0.3, kernel=rbf;, score=-0.984 total time=  51.8s
# [CV 3/5] END ............gamma=0.3, kernel=rbf;, score=-0.958 total time=  52.3s
# [CV 4/5] END ............gamma=0.3, kernel=rbf;, score=-0.956 total time=  52.6s
# [CV 5/5] END ............gamma=0.3, kernel=rbf;, score=-0.964 total time=  52.5s
# [CV 1/5] END ............gamma=0.5, kernel=rbf;, score=-0.975 total time=  53.2s
# [CV 2/5] END ............gamma=0.5, kernel=rbf;, score=-0.987 total time=  52.8s
# [CV 3/5] END ............gamma=0.5, kernel=rbf;, score=-0.960 total time=  52.3s
# [CV 4/5] END ............gamma=0.5, kernel=rbf;, score=-0.959 total time=  53.7s
# [CV 5/5] END ............gamma=0.5, kernel=rbf;, score=-0.967 total time=  52.9s
# [CV 1/5] END ............gamma=0.7, kernel=rbf;, score=-0.978 total time=  54.3s
# [CV 2/5] END ............gamma=0.7, kernel=rbf;, score=-0.992 total time=  53.0s
# [CV 3/5] END ............gamma=0.7, kernel=rbf;, score=-0.964 total time=  53.9s
# [CV 4/5] END ............gamma=0.7, kernel=rbf;, score=-0.963 total time=  54.7s
# [CV 5/5] END ............gamma=0.7, kernel=rbf;, score=-0.971 total time=  53.6s
# [CV 1/5] END ..............gamma=1, kernel=rbf;, score=-0.984 total time=  55.3s
# [CV 2/5] END ..............gamma=1, kernel=rbf;, score=-0.997 total time=  54.8s
# [CV 3/5] END ..............gamma=1, kernel=rbf;, score=-0.969 total time=  54.0s
# [CV 4/5] END ..............gamma=1, kernel=rbf;, score=-0.968 total time=  54.9s
# [CV 5/5] END ..............gamma=1, kernel=rbf;, score=-0.975 total time=  54.7s
# [CV 1/5] END ..............gamma=3, kernel=rbf;, score=-1.013 total time= 1.3min
# [CV 2/5] END ..............gamma=3, kernel=rbf;, score=-1.028 total time= 1.2min
# [CV 3/5] END ..............gamma=3, kernel=rbf;, score=-0.993 total time= 1.2min
# [CV 4/5] END ..............gamma=3, kernel=rbf;, score=-0.991 total time= 1.2min
# [CV 5/5] END ..............gamma=3, kernel=rbf;, score=-0.996 total time= 1.2min
# [CV 1/5] END ..............gamma=5, kernel=rbf;, score=-1.027 total time= 1.2min
# [CV 2/5] END ..............gamma=5, kernel=rbf;, score=-1.037 total time= 1.3min
# [CV 3/5] END ..............gamma=5, kernel=rbf;, score=-1.006 total time= 1.3min
# [CV 4/5] END ..............gamma=5, kernel=rbf;, score=-1.003 total time= 1.3min
# [CV 5/5] END ..............gamma=5, kernel=rbf;, score=-1.005 total time= 1.3min
# [CV 1/5] END ..............gamma=7, kernel=rbf;, score=-1.033 total time= 1.4min
# [CV 2/5] END ..............gamma=7, kernel=rbf;, score=-1.041 total time= 1.4min
# [CV 3/5] END ..............gamma=7, kernel=rbf;, score=-1.014 total time= 1.4min
# [CV 4/5] END ..............gamma=7, kernel=rbf;, score=-1.010 total time= 1.3min
# [CV 5/5] END ..............gamma=7, kernel=rbf;, score=-1.011 total time= 1.4min
# Best score: -0.9675853828459082
# Best params: {'gamma': 0.3, 'kernel': 'rbf'}

# %%
# Mejor puntuación para "SVR"
mean_squared_error(y_test, y_pred, squared=False)

# %% [markdown]
# ## "DecisionTree"
#
# - Cambios: escalado "standard", borrado parcial, asignación y valor más alto de weight
#
# - Con cambios e hiperparámetros, "DecisionTree" ha mejorado su "rmse" de 0.130480 a

# %%
df_tree = df_diamonds.copy()

df_tree = remove_all(df_tree, zeros_only=True)

df_tree = assign_values(df_tree)

df_tree = impute_next_higher(df_tree, log=False)

# %%
tree = Regression(df_tree, 'price')
X_train, X_test, y_train, y_test = tree.split_dataframe(scaler='StandardScaler')
tree.prepare_models(selected_list=['DecisionTreeRegressor'],
                    params_list=[['DecisionTreeRegressor', 'random_state=43']]
                    )
tree.apply_and_evaluate_kfolds()
tree.create_dataframe()

# %%
# Se usa el "grid"
# En una segunda vuelta se miran los hiperparámentros "max_depth" y "min_samples_split", que están relacionados
model = DecisionTreeRegressor()

params = {'criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
            'splitter': ['best', 'random'],
            'max_features': ['auto', 'sqrt', 'log2'],
            'min_samples_leaf': range(1, 11)
            }

grid = GridSearchCV(estimator = model,
                    param_grid = params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')

# %%
# Mejor puntuación para "DecisionTree"
mean_squared_error(y_test, y_pred, squared=False)

# %% [markdown]
# ## "RandomForest"
#
# - Cambios: borrado parcial, asignación y sustitución
#
# - Con cambios e hiperparámetros, "RandomForest" ha mejorado su "rmse" de 0.094246 a

# %%
df_forest = df_diamonds.copy()

df_forest = remove_all(df_forest, zeros_only=True)

df_forest = assign_values(df_forest)

df_forest['depth (percentage)'] = (df_forest['depth (millimeters)'] / ((df_forest['lenght (millimeters)']+df_forest['width (millimeters)']) / 2)) * 100

# %%
forest = Regression(df_forest, 'price')
X_train, X_test, y_train, y_test = forest.split_dataframe()
forest.prepare_models(selected_list=['RandomForestRegressor'],
                        params_list=[['RandomForestRegressor', 'random_state=43']],
                        )
forest.apply_and_evaluate_kfolds()
forest.create_dataframe()

# %%
# En una segunda vuelta se miran los hiperparámentros "max_depth" y "min_samples_split", que están relacionados
# En una tercera vuelta se prueba con "boolstrap=True"
model = RandomForestRegressor()

params = {'criterion': ['gini', 'entropy', 'log_loss'],
            'max_features': ['sqrt', 'log2', None],
            'min_samples_leaf': range(1, 11),
            'oob_score': [True, False]
            }

grid = GridSearchCV(estimator = model,
                    param_grid = params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')

# %%
# Mejor puntuación para "RandomForest"
mean_squared_error(y_test, y_pred, squared=False)

# %% [markdown]
# ## "XGBRegressor"
#
# - Cambios: escalado "minmax", borrado parcial, asignación, logaritmo, valor más alto de "weight", imputaciones "boxplot" e imputaciones "ridge"
#
# - Con cambios e hiperparámetros, "XGBRegressor" ha mejorado su "rmse" de 0.090762 a

# %%
df_xgb = df_diamonds.copy()

df_xgb = remove_all(df_xgb, zeros_only=True)

df_xgb = assign_values(df_xgb)

df_xgb[['weight (carat)', 'lenght (millimeters)', 'width (millimeters)', 'depth (millimeters)']] = np.log(df_xgb[['weight (carat)', 'lenght (millimeters)', 'width (millimeters)', 'depth (millimeters)']])

df_xgb = impute_next_higher(df_xgb, log=True)

df_xgb = impute_boxplot_min_max(df_xgb, ['depth (percentage)', 'table (percentage)'])

df_xgb = apply_ridge(df_xgb)

# %%
xgb = Regression(df_xgb, 'price')
X_train, X_test, y_train, y_test = xgb.split_dataframe(scaler='MinMaxScaler')
xgb.prepare_models(selected_list=['XGBRegressor'],
                    params_list=[['XGBRegressor', 'random_state=43']]
                    )
xgb.apply_and_evaluate_kfolds()
xgb.create_dataframe()

# %%
model = XGBRegressor()

params = {
            }

grid = GridSearchCV(estimator = model,
                    param_grid = params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')

# %%
# Mejor puntuación para "XGBRegressor"
mean_squared_error(y_test, y_pred, squared=False)
