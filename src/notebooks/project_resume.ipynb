# %%
import os

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import GridSearchCV

from sklearn.metrics import make_scorer

from mlxtend.plotting import plot_decision_regions

if str(os.getcwdb()[-3:]).split("'")[1] != 'src':
    os.chdir(os.path.dirname(os.getcwdb()))

from utils.modeling import *
from utils.functions import *

# %%
df_diamonds = pd.read_csv(r'data\processed\diamonds_training.csv', index_col='id')
df_predict = pd.read_csv(r'data\processed\diamonds_testing.csv', index_col='id')

# %% [markdown]
# # Consideraciones
# - Se localiza el tema en Kaggle: https://www.kaggle.com/datasets/shivam2503/diamonds
#
# - Se empieza a trabajar con ese "dataset" (ver los archivos marcados como "UNUSED" y "no competition")
#
# - Se detecta que existe una competición, si bien ya ha terminado: https://www.kaggle.com/competitions/diamonds-part-datamad0122/overview
#
# - Se elige trabajar con los archivos de la competición, cuyas únicas diferencias es que hay un "train" y un "test", y que la variable "target" está escalada
#
# - El "dataset" final es un listado de diamantes con sus características, y el objetivo es predecir el precio
#
# - Se comparará lo obtenido con los resultados de la competición

# %% [markdown]
# # EDA
# - Los pasos de esta primera parte se detallan de forma más pormenorizada, paso a paso, en el "notebook" titulado "EDA_diamonds"
#
# - En ese "notebook" se hacen dos cosas:
# 1) Modificaciones esenciales; se liquidan duplicados, se cambia el nombre de las columnas y se pasan las categóricas a numéricas, tanto del "train" como del "test".
#
# 2) Modificaciones opcionales; se detectan y ponen a prueba las posibles modifiaciones que llevar a cabo con el "dataframe" de entrenamiento con tal de mejorar el resultado de los modelos. Los resortes de dichos cambios se guardan en forma de funciones (cuando son exclusivos de este proyecto) o clases (cuando es razonable guardarlos para análisis futuros), que se irán llamando a continuación según convenga.

# %% [markdown]
# # Modelaje: selección de cambios
# - Se importan los "dataframes" con las modificaciones esenciales
#
# - Se van intercalando modificiaciones opcionales y diversos modelos hasta dar con el mejor resultado
#
# - Los modelos se prueban en este "notebook" para mayor comodidad, pero se ejecutan sin detallarse en "train.py", desde donde se guardan en la carpeta "model"
#
# - Estas son las modificaciones que se van intercalando:
#
# ---------- Cambios opcionales (probados) ----------
#
# 1) Borrado de "outliers" extremadamente altos ("depth (percentage)", "table (percentage)", "width (millimeters)", "depth (millimeters)").
#
# 2) Borrado de filas que tienen 0 en todas las variables de tamaño ("lenght (millimeters)", "width (millimeters)" y "depth (millimeters)").
#
# 3) Borrado de los "outliers" compartidos moderadamente altos ("depth (percentage)" y "table (percentage)").
#
# 4) Asignación del valor con 0 restante en "lenght" al "width" correspondiente ("lenght (millimeters)").
#
# 5) Asignación del valor con 0 restante de "depth (millimeters)" a partir de una operación con el "lenght", el "width" y el "depth (percentage)" correspondientes ("depth (millimeters)").
#
# 6) Asignación del "outlier" restante del "lenght" al "width" correspondiente ("lenght (millimeters)").
#
# 7) Uso del logaritmo ("weight (carat)", "lenght (millimeters)", "width (millimeters)" y "depth (millimeters)").
#
# 8) Imputación al siguiente valor más alto ("weight (carat)").
#
# 9) Imputación a los valores máximos y mínimos del "boxplot" ("depth (percentage)" y "table (percentage)").
#
# 10) Neutralización de "outliers" con un modelo "ridge" ("depth (millimeters)").
#
# 11) Escalado "MinMax".
#
# ---------- Cambios apuntados (no probados) ----------
#
# 1) Sustitución de valores existentes por valores calculados ("depth (percentage)").
#
# 2) Descarte de las columnas con altísima correlación ("weight (carat)", "lenght (millimeters)", "width (millimeters)" y "depth (millimeters)").
#
# 3) Imputación de los valores máximos de "clarity quality" al que está un punto por debajo ("clarity quality").

# %% [markdown]
# ## Ronda 1: sin cambios
# - Para la primera fase, se prueban todos los modelos sin hacer ninguna modificación adicional
#
# - En esta primera ronda están más detallados los usos de la clase "Regression", que hereda de "Model", para que sirva como ejemplo
#
# - Como era de esperar, los resultados no son demasiado buenos, pero ganan los modelos "de árboles", ya que no se ven afectados por los valores atípicos
#
# - Dado que en la competición se valora la "rsme", esa es la métrica que más se tendrá en cuenta. Puede verse el podio aquí: https://www.kaggle.com/competitions/diamonds-part-datamad0122/leaderboard

# %%
# Lo primero es decirle a la clase con qué modelos se va a trabajar a lo largo de todo el proceso
Regression.add_models(['LinearRegression',
                        'Ridge',
                        'DecisionTreeRegressor',
                        'KNeighborsRegressor',
                        'RandomForestRegressor',
                        'SVR',
                        'XGBRegressor'
                        ]
                        )

# %%
# Se crea la instancia de la clase "Regression" con la columna "price" como "target"
round_1 = Regression(df_diamonds, 'price')

# %%
# Se separa el "dataframe" con los parámetros por defecto. Se guardan las porciones por si acaso
X_train, X_test, y_train, y_test = round_1.split_dataframe()

# %%
# Se solicitan 10 "folds", del cual se usará el mejor para comparar los modelos y ver cuál llega más lejos
# Se coge el mejor, y no la media de las métricas, porque de 10 cortes es probable que salgan números de "cortes malos" dispares para los diferentes modelos
# Si fuera el caso, la comparación con las medias seria injusta
# En cambio, con el mejor, es muy probable que de 10 cortes al menos uno de ellos saque el máximo partido a cada modelo
# Así, se comparan en mayor igualdad de condiciones
# Como la "target" es de regresión, la instancia seleccionará automáticamente "KFold" en lugar de "StratifiedFold"
# Se establece un "random_state" para los modelos que lo requieren, que siempre será el mismo
round_1_dict = round_1.apply_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                                    ['RandomForestRegressor', 'random_state=43'],
                                                    ['XGBRegressor', 'random_state=43']
                                                ],
                                    kfolds_num=10
                                    )
# Out:
# -- Regression: using best of 10 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.88 sec(s). Total time: 0.88
# Starting Ridge:
# - Ridge done in 0.41 sec(s). Total time: 1.29
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 15.74 sec(s). Total time: 17.03
# Starting SVR:
# - SVR done in 351.86 sec(s). Total time: 368.89
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 2.64 sec(s). Total time: 371.53
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 229.65 sec(s). Total time: 601.19
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 31.02 sec(s). Total time: 632.21

# %%
# Los resultados, así como el modelo entrenado, pueden visualizarse en un diccionario
round_1_dict

# %%
# Acto seguido, se miran las métricas
round_1_metrics = round_1.evaluate_metrics()

round_1_metrics
# Out:
# {'LinearRegression': {'test': array([8.069, 9.093, 8.297, ..., 9.234, 8.818, 8.368]),
#   'prediction': array([8.1751789 , 8.94534424, 7.94609508, ..., 9.13303572, 8.78005708,
#          8.22465851]),
#   'model': LinearRegression(),
#   'metrics': {'rmse': 0.222037823248969,
#    'mse': 0.0493007949531404,
#    'mae': 0.12289980638635319,
#    'r2_score': 0.9529090797126748,
#    'mape': 0.01587291534328809}},
#  'Ridge': {'test': array([8.069, 9.093, 8.297, ..., 9.234, 8.818, 8.368]),
#   'prediction': array([8.17485364, 8.94499768, 7.94593798, ..., 9.13327901, 8.78003269,
#          8.22426296]),
#   'model': Ridge(),
#   'metrics': {'rmse': 0.2219231703319744,
#    'mse': 0.04924989353019452,
#    'mae': 0.1229616970889257,
#    'r2_score': 0.9529576995138916,
#    'mape': 0.015880870501013333}},
#  'KNeighborsRegressor': {'test': array([8.069, 9.093, 8.297, ..., 9.234, 8.818, 8.368]),
#   'prediction': array([8.2228, 9.072 , 8.0682, ..., 9.09  , 8.7678, 8.706 ]),
#   'model': KNeighborsRegressor(),
#   'metrics': {'rmse': 0.18386510856104435,
#    'mse': 0.03380637814616462,
#    'mae': 0.1351555573865041,
#    'r2_score': 0.9677089698046988,
#    'mape': 0.01780637784629908}},
#  'SVR': {'test': array([8.069, 9.093, 8.297, ..., 9.234, 8.818, 8.368]),
#   'prediction': array([8.1605641 , 8.95509437, 7.9788505 , ..., 9.22422321, 8.8675288 ,
#          8.20764258]),
#   'model': SVR(),
#   'metrics': {'rmse': 0.2090635876352297,
#    'mse': 0.04370758367491336,
#    'mae': 0.12747711693978012,
#    'r2_score': 0.9582515790923197,
#    'mape': 0.01652290177663025}},
#  'DecisionTreeRegressor: random_state=43': {'test': array([8.069, 9.093, 8.297, ..., 9.234, 8.818, 8.368]),
#   'prediction': array([8.275, 9.24 , 8.107, ..., 9.329, 8.951, 8.314]),
#   'model': DecisionTreeRegressor(random_state=43),
#   'metrics': {'rmse': 0.13014173646607205,
#    'mse': 0.016936871570404546,
#    'mae': 0.08869790722583834,
#    'r2_score': 0.9838223122001042,
#    'mape': 0.011416910269644516}},
#  'RandomForestRegressor: random_state=43': {'test': array([8.069, 9.093, 8.297, ..., 9.234, 8.818, 8.368]),
#   'prediction': array([8.20565, 9.13486, 8.15134, ..., 9.27518, 8.90563, 8.34973]),
#   'model': RandomForestRegressor(random_state=43),
#   'metrics': {'rmse': 0.09810128656934056,
#    'mse': 0.009623862426559878,
#    'mae': 0.06712255864004994,
#    'r2_score': 0.9908075206735293,
#    'mape': 0.00868375970565319}},
#  'XGBRegressor: random_state=43': {'test': array([8.069, 9.093, 8.297, ..., 9.234, 8.818, 8.368]),
#   'prediction': array([8.284577, 9.100133, 8.105511, ..., 9.319487, 8.911745, 8.326346],
#         dtype=float32),
#   'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=None, early_stopping_rounds=None,
#                enable_categorical=False, eval_metric=None, feature_types=None,
#                gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                predictor=None, random_state=43, ...),
#   'metrics': {'rmse': 0.09478673498514448,
#    'mse': 0.008984525129144013,
#    'mae': 0.06666612293877985,
#    'r2_score': 0.9914182001106041,
#    'mape': 0.008601638995576083}}}

# %%
# Para una mejor visualización, se ponen en un "dataframe"
# Las predicciones no son muy buenas, si bien el r2_score es alto para todos los casos
round_1.create_dataframe()
# Out:
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.222038  0.221923             0.183865  0.209064
# mse               0.049301  0.049250             0.033806  0.043708
# mae               0.122900  0.122962             0.135156  0.127477
# r2_score          0.952909  0.952958             0.967709  0.958252
# mape              0.015873  0.015881             0.017806  0.016523
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.130142
# mse                                     0.016937
# mae                                     0.088698
# r2_score                                0.983822
# mape                                    0.011417
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.098101
# mse                                     0.009624
# mae                                     0.067123
# r2_score                                0.990808
# mape                                    0.008684
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.094787  XGBRegressor: random_state=43
# mse                            0.008985  XGBRegressor: random_state=43
# mae                            0.066666  XGBRegressor: random_state=43
# r2_score                       0.991418  XGBRegressor: random_state=43
# mape                           0.008602  XGBRegressor: random_state=43
#
#                         WORST
# rmse         LinearRegression
# mse          LinearRegression
# mae       KNeighborsRegressor
# r2_score                  SVR
# mape      KNeighborsRegressor

# %% [markdown]
# ## Ronda 2: escalado
# - Se repite la ronda 1, pero esta vez se escalan las variables
#
# - Exceptuando "Ridge", el escalado "Standard" mejora más que "MinMax" los resultados de los modelos "no de árboles", que solo empeoran. La regresión lineal no se ve afectada en ningún caso

# %%
# Se pone a prueba con el mismo proceso que en la ronda anterior, pero esta vez se aplica un escalado MinMax
# Hay una ligera mejora en los modelos "no de árboles"
df_diamonds_2 = df_diamonds.copy()

round_2 = Regression(df_diamonds_2, 'price')
round_2.split_dataframe(scaler='MinMaxScaler')
round_2.apply_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ],
                        kfolds_num=10
                    )
round_2.evaluate_metrics()
round_2.create_dataframe()
# Out:
# -- Regression (MinMaxScaler): using best of 10 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.24 sec(s). Total time: 0.24
# Starting Ridge:
# - Ridge done in 0.17 sec(s). Total time: 0.41
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 3.38 sec(s). Total time: 3.8
# Starting SVR:
# - SVR done in 285.42 sec(s). Total time: 289.22
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 2.7 sec(s). Total time: 291.92
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 245.17 sec(s). Total time: 537.09
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 10.62 sec(s). Total time: 547.7
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.222038  0.217754             0.165586  0.136532
# mse               0.049301  0.047417             0.027419  0.018641
# mae               0.122900  0.127961             0.115148  0.093104
# r2_score          0.952909  0.954709             0.973810  0.982195
# mape              0.015873  0.016526             0.015207  0.012264
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.130527
# mse                                     0.017037
# mae                                     0.088925
# r2_score                                0.983726
# mape                                    0.011447
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.098128
# mse                                     0.009629
# mae                                     0.067186
# r2_score                                0.990803
# mape                                    0.008692
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.094788  XGBRegressor: random_state=43
# mse                            0.008985  XGBRegressor: random_state=43
# mae                            0.066664  XGBRegressor: random_state=43
# r2_score                       0.991418  XGBRegressor: random_state=43
# mape                           0.008602  XGBRegressor: random_state=43
#
#                      WORST
# rmse      LinearRegression
# mse       LinearRegression
# mae                  Ridge
# r2_score  LinearRegression
# mape                 Ridge

# %%
# Comprobamos si la situación mejora con "StandardScaler". En efecto, es así (salvo para Ridge, que empeora)
df_diamonds_2b = df_diamonds.copy()

round_2b = Regression(df_diamonds_2b, 'price')
round_2b.split_dataframe(scaler='StandardScaler')
round_2b.apply_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ],
                        kfolds_num=10
                    )
round_2b.evaluate_metrics()
round_2b.create_dataframe()
# Out:
# -- Regression (StandardScaler): using best of 10 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.29 sec(s). Total time: 0.29
# Starting Ridge:
# - Ridge done in 0.14 sec(s). Total time: 0.43
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 4.56 sec(s). Total time: 4.99
# Starting SVR:
# - SVR done in 314.16 sec(s). Total time: 319.15
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 2.76 sec(s). Total time: 321.91
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 235.85 sec(s). Total time: 557.76
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 10.85 sec(s). Total time: 568.6
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.222038  0.221959             0.144420  0.110864
# mse               0.049301  0.049266             0.020857  0.012291
# mae               0.122900  0.122939             0.105460  0.083091
# r2_score          0.952909  0.952942             0.980078  0.988260
# mape              0.015873  0.015878             0.013921  0.010905
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.130774
# mse                                     0.017102
# mae                                     0.089279
# r2_score                                0.983665
# mape                                    0.011496
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.098193
# mse                                     0.009642
# mae                                     0.067219
# r2_score                                0.990790
# mape                                    0.008697
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.094777  XGBRegressor: random_state=43
# mse                            0.008983  XGBRegressor: random_state=43
# mae                            0.066659  XGBRegressor: random_state=43
# r2_score                       0.991420  XGBRegressor: random_state=43
# mape                           0.008601  XGBRegressor: random_state=43
#
#                                            WORST
# rmse                            LinearRegression
# mse                             LinearRegression
# mae                                        Ridge
# r2_score  DecisionTreeRegressor: random_state=43
# mape                                       Ridge

# %% [markdown]
# ## Ronda 3: borrado (+ escalado)
# - Se borran todos los "outliers" extremadamente altos ("depth (percentage)", "table (percentage)", "width (millimeters)", "depth (millimeters)")
#
# - Se borran las filas que tienen el mismo cero en estas tres columnas: "lenght (millimeters)", "width (millimeters)" y "depth (millimeters)"
#
# - Se borran los "outliers" moderadamente altos compartidos de "depth (percentage)" y "table (percentage)"
#
# - El error mejora en todos los modelos en distintas medidas

# %%
# Se aplican los borrados, esta vez con una función a medida ya que son cambios exclusivos de este proyecto
df_diamonds_3 = df_diamonds.copy()

df_diamonds_3 = remove_all(df_diamonds_3)

print(f'Deleted rows: {len(df_diamonds) - len(df_diamonds_3)}')
# Out:
# Deleted rows: 20

# %%
# Se escala y se prueban los modelos
round_3 = Regression(df_diamonds_3, 'price')
round_3.split_dataframe(scaler='StandardScaler')
round_3.apply_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ],
                        kfolds_num=10
                    )
round_3.evaluate_metrics()
round_3.create_dataframe()
# Out:
# -- Regression (StandardScaler): using best of 10 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.28 sec(s). Total time: 0.28
# Starting Ridge:
# - Ridge done in 0.14 sec(s). Total time: 0.42
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 4.73 sec(s). Total time: 5.15
# Starting SVR:
# - SVR done in 339.47 sec(s). Total time: 344.62
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 3.08 sec(s). Total time: 347.7
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 271.57 sec(s). Total time: 619.26
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 17.66 sec(s). Total time: 636.92
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.145078  0.145065             0.139798  0.105232
# mse               0.021048  0.021044             0.019543  0.011074
# mae               0.112841  0.112834             0.105272  0.081063
# r2_score          0.979612  0.979616             0.981070  0.989273
# mape              0.014806  0.014805             0.013886  0.010641
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.126619
# mse                                     0.016032
# mae                                     0.088104
# r2_score                                0.984471
# mape                                    0.011362
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.092584
# mse                                     0.008572
# mae                                     0.066677
# r2_score                                0.991697
# mape                                    0.008625
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.090504  XGBRegressor: random_state=43
# mse                            0.008191  XGBRegressor: random_state=43
# mae                            0.065687  XGBRegressor: random_state=43
# r2_score                       0.992066  XGBRegressor: random_state=43
# mape                           0.008474  XGBRegressor: random_state=43
#
#                                            WORST
# rmse                            LinearRegression
# mse                             LinearRegression
# mae                             LinearRegression
# r2_score  DecisionTreeRegressor: random_state=43
# mape                            LinearRegression

# %% [markdown]
# ## Ronda 4: asignación (+ borrado y escalado)
# - Los cambios de esta ronda se aplican a partir de dos hechos probados durante el EDA:
#
# 1) El "lenght" y el "width" son generalmente casi idénticos, ya que los diamantes son semicirculares.
#
# 2) El "depth (percentage)" se obtiene (según el autor del "dataset") de dividir "depth (millimeters)" por la media de "lenght" y "width".
#
# - Se asigna el 0 restante de "lenght" al "width" correspondiente ("lenght (millimeters)")
#
# - Se asigna el 0 restante de "depth (millimeters)" a partir de la operación mencionada
#
# - Se asigna el "outlier" restante del "lenght" al "width" correspondiente ("lenght (millimeters)")
#
# - Mejoran todos menos "DecisionTree" en pequeña medida

# %%
# Se aplican el borrado y la asignación
df_diamonds_4 = df_diamonds.copy()

df_diamonds_4 = remove_all(df_diamonds_4)
df_diamonds_4 = assign_values(df_diamonds_4)

# %%
# Se escala y se prueban los modelos
round_4 = Regression(df_diamonds_4, 'price')
round_4.split_dataframe(scaler='StandardScaler')
round_4.apply_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ],
                        kfolds_num=10
                    )
round_4.evaluate_metrics()
round_4.create_dataframe()
# Out:
# -- Regression (StandardScaler): using best of 10 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.24 sec(s). Total time: 0.25
# Starting Ridge:
# - Ridge done in 0.17 sec(s). Total time: 0.41
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 6.01 sec(s). Total time: 6.42
# Starting SVR:
# - SVR done in 326.11 sec(s). Total time: 332.53
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 3.22 sec(s). Total time: 335.74
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 279.61 sec(s). Total time: 615.36
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 27.84 sec(s). Total time: 643.2
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.144352  0.144347             0.139518  0.105131
# mse               0.020838  0.020836             0.019465  0.011053
# mae               0.112161  0.112159             0.105166  0.081034
# r2_score          0.979816  0.979817             0.981145  0.989294
# mape              0.014685  0.014685             0.013874  0.010637
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.126641
# mse                                     0.016038
# mae                                     0.088464
# r2_score                                0.984465
# mape                                    0.011401
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.092534
# mse                                     0.008563
# mae                                     0.066706
# r2_score                                0.991706
# mape                                    0.008629
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.090370  XGBRegressor: random_state=43
# mse                            0.008167  XGBRegressor: random_state=43
# mae                            0.065605  XGBRegressor: random_state=43
# r2_score                       0.992089  XGBRegressor: random_state=43
# mape                           0.008473  XGBRegressor: random_state=43
#
#                                            WORST
# rmse                            LinearRegression
# mse                             LinearRegression
# mae                             LinearRegression
# r2_score  DecisionTreeRegressor: random_state=43
# mape                            LinearRegression

# %% [markdown]
# ## Ronda 5: logaritmo (+ asignación, borrado y escalado)
# - Se aplica el logaritmo a las columnas "weight (carat)", "lenght (millimeters)", "width (millimeters)" y "depth (millimeters)"
#
# - Mejoran "KNeighbors",  "SVR" y "DecisionTree" (este último, muy poco). "XGBRegressor" se queda igual. El resto, empeoran

# %%
# Se hacen los retoques
df_diamonds_5 = df_diamonds.copy()

df_diamonds_5 = remove_all(df_diamonds_5)
df_diamonds_5 = assign_values(df_diamonds_5)

df_diamonds_5[['weight (carat)', 'lenght (millimeters)', 'width (millimeters)', 'depth (millimeters)']] = np.log(df_diamonds_5[['weight (carat)', 'lenght (millimeters)', 'width (millimeters)', 'depth (millimeters)']])

# %%
# Se escala y se prueban los modelos
round_5 = Regression(df_diamonds_5, 'price')
round_5.split_dataframe(scaler='StandardScaler')
round_5.apply_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ],
                        kfolds_num=10
                    )
round_5.evaluate_metrics()
round_5.create_dataframe()
# Out:
# -- Regression (StandardScaler): using best of 10 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.25 sec(s). Total time: 0.25
# Starting Ridge:
# - Ridge done in 0.18 sec(s). Total time: 0.43
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 6.49 sec(s). Total time: 6.91
# Starting SVR:
# - SVR done in 363.74 sec(s). Total time: 370.66
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 2.61 sec(s). Total time: 373.27
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 232.83 sec(s). Total time: 606.1
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 13.75 sec(s). Total time: 619.85
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.144715  0.144684             0.137727  0.103949
# mse               0.020942  0.020933             0.018969  0.010805
# mae               0.112273  0.112272             0.104003  0.079632
# r2_score          0.979715  0.979723             0.981626  0.989533
# mape              0.014703  0.014703             0.013615  0.010411
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.126594
# mse                                     0.016026
# mae                                     0.088505
# r2_score                                0.984477
# mape                                    0.011404
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.092607
# mse                                     0.008576
# mae                                     0.066736
# r2_score                                0.991693
# mape                                    0.008633
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.090370  XGBRegressor: random_state=43
# mse                            0.008167  XGBRegressor: random_state=43
# mae                            0.065606  XGBRegressor: random_state=43
# r2_score                       0.992089  XGBRegressor: random_state=43
# mape                           0.008473  XGBRegressor: random_state=43
#
#                                            WORST
# rmse                            LinearRegression
# mse                             LinearRegression
# mae                             LinearRegression
# r2_score  DecisionTreeRegressor: random_state=43
# mape                                       Ridge

# %% [markdown]
# ## Ronda 6: imputaciones "boxplot" y valor más alto (+ logaritmo, asignación, borrado y escalado)
# - Se imputan al siguiente valor más alto de "weight", y al máximo y al mínimo "depth (percentage)" y table
#
# - Se prueban por separado
#
# - Todos menos los "de árboles" mejoran con la imputación al "boxplot", pero ninguno con la del valor máximo, con lo que se obviará completamente

# %%
# Se hacen los retoques pertinentes
df_diamonds_6a = df_diamonds.copy()

df_diamonds_6a = remove_all(df_diamonds_6a)
df_diamonds_6a = assign_values(df_diamonds_6a)

df_diamonds_6a[['weight (carat)', 'lenght (millimeters)', 'width (millimeters)', 'depth (millimeters)']] = np.log(df_diamonds_6a[['weight (carat)', 'lenght (millimeters)', 'width (millimeters)', 'depth (millimeters)']])

df_diamonds_6b = df_diamonds_6a.copy()

df_diamonds_6a = impute_next_higher(df_diamonds_6a)

# %%
# Se lleva a cabo la prueba
round_6a = Regression(df_diamonds_6a, 'price')
round_6a.split_dataframe(scaler='StandardScaler')
round_6a.apply_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ],
                        kfolds_num=10
                    )
round_6a.evaluate_metrics()
round_6a.create_dataframe()
# Out:
# -- Regression (StandardScaler): using best of 10 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.39 sec(s). Total time: 0.39
# Starting Ridge:
# - Ridge done in 0.17 sec(s). Total time: 0.56
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 5.65 sec(s). Total time: 6.21
# Starting SVR:
# - SVR done in 292.21 sec(s). Total time: 298.43
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 2.66 sec(s). Total time: 301.09
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 227.26 sec(s). Total time: 528.35
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 10.4 sec(s). Total time: 538.74
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.144734  0.144699             0.137727  0.103957
# mse               0.020948  0.020938             0.018969  0.010807
# mae               0.112266  0.112263             0.104003  0.079636
# r2_score          0.979709  0.979719             0.981626  0.989532
# mape              0.014703  0.014702             0.013615  0.010412
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.126678
# mse                                     0.016047
# mae                                     0.088566
# r2_score                                0.984456
# mape                                    0.011410
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.092642
# mse                                     0.008583
# mae                                     0.066756
# r2_score                                0.991687
# mape                                    0.008636
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.090370  XGBRegressor: random_state=43
# mse                            0.008167  XGBRegressor: random_state=43
# mae                            0.065606  XGBRegressor: random_state=43
# r2_score                       0.992089  XGBRegressor: random_state=43
# mape                           0.008473  XGBRegressor: random_state=43
#
#                                            WORST
# rmse                            LinearRegression
# mse                             LinearRegression
# mae                             LinearRegression
# r2_score  DecisionTreeRegressor: random_state=43
# mape                            LinearRegression

# %%
df_diamonds_6b = impute_boxplot_min_max(df_diamonds_6b, ['depth (percentage)', 'table (percentage)'])

# %%
# Se lleva a cabo la prueba
round_6b = Regression(df_diamonds_6b, 'price')
round_6b.split_dataframe(scaler='StandardScaler')
round_6b.apply_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ],
                        kfolds_num=10
                    )
round_6b.evaluate_metrics()
round_6b.create_dataframe()
# Out:
# -- Regression (StandardScaler): using best of 10 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.25 sec(s). Total time: 0.25
# Starting Ridge:
# - Ridge done in 0.14 sec(s). Total time: 0.39
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 4.47 sec(s). Total time: 4.86
# Starting SVR:
# - SVR done in 284.1 sec(s). Total time: 288.95
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 2.73 sec(s). Total time: 291.69
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 223.98 sec(s). Total time: 515.66
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 10.68 sec(s). Total time: 526.34
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.144535  0.144513             0.136072  0.103508
# mse               0.020890  0.020884             0.018516  0.010714
# mae               0.112202  0.112207             0.103214  0.079396
# r2_score          0.979765  0.979771             0.982065  0.989622
# mape              0.014692  0.014693             0.013516  0.010383
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.127979
# mse                                     0.016379
# mae                                     0.088895
# r2_score                                0.984135
# mape                                    0.011460
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.092796
# mse                                     0.008611
# mae                                     0.066812
# r2_score                                0.991659
# mape                                    0.008642
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.090042  XGBRegressor: random_state=43
# mse                            0.008108  XGBRegressor: random_state=43
# mae                            0.065601  XGBRegressor: random_state=43
# r2_score                       0.992147  XGBRegressor: random_state=43
# mape                           0.008463  XGBRegressor: random_state=43
#
#                                            WORST
# rmse                            LinearRegression
# mse                             LinearRegression
# mae                                        Ridge
# r2_score  DecisionTreeRegressor: random_state=43
# mape                                       Ridge

# %% [markdown]
# ## Ronda 7: imputaciones "ridge" (+ imputaciones "boxplot", logaritmo, asignación, borrado y escalado)
# - Se imputan los "outliers" restantes de "depth (millimeters)" aplicando un modelo "Ridge" a "weight (carat)", "lenght (millimeters)" y "width (millimeters)", con las que tiene una altísima correlación
#
# - Solo mejora "DecisionTree"

# %%
# Se hacen los cambios
df_diamonds_7 = df_diamonds.copy()

df_diamonds_7 = remove_all(df_diamonds_7)
df_diamonds_7 = assign_values(df_diamonds_7)

df_diamonds_7[['weight (carat)', 'lenght (millimeters)', 'width (millimeters)', 'depth (millimeters)']] = np.log(df_diamonds_7[['weight (carat)', 'lenght (millimeters)', 'width (millimeters)', 'depth (millimeters)']])

df_diamonds_7 = impute_boxplot_min_max(df_diamonds_7, ['depth (percentage)', 'table (percentage)'])

df_diamonds_7 = apply_ridge(df_diamonds_7)

# %%
# Se prueban los modelos
round_7 = Regression(df_diamonds_7, 'price')
round_7.split_dataframe(scaler='StandardScaler')
round_7.apply_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ],
                        kfolds_num=10
                    )
round_7.evaluate_metrics()
round_7.create_dataframe()
# Out:
# -- Regression (StandardScaler): using best of 10 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.33 sec(s). Total time: 0.33
# Starting Ridge:
# - Ridge done in 0.16 sec(s). Total time: 0.49
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 5.21 sec(s). Total time: 5.7
# Starting SVR:
# - SVR done in 311.89 sec(s). Total time: 317.59
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 2.6 sec(s). Total time: 320.18
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 219.71 sec(s). Total time: 539.89
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 11.32 sec(s). Total time: 551.21
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.144535  0.144514             0.136075  0.103527
# mse               0.020890  0.020884             0.018516  0.010718
# mae               0.112203  0.112209             0.103214  0.079400
# r2_score          0.979765  0.979771             0.982064  0.989618
# mape              0.014692  0.014693             0.013516  0.010383
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.126511
# mse                                     0.016005
# mae                                     0.088143
# r2_score                                0.984497
# mape                                    0.011364
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.092819
# mse                                     0.008615
# mae                                     0.066837
# r2_score                                0.991655
# mape                                    0.008646
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.090890  XGBRegressor: random_state=43
# mse                            0.008261  XGBRegressor: random_state=43
# mae                            0.065868  XGBRegressor: random_state=43
# r2_score                       0.991998  XGBRegressor: random_state=43
# mape                           0.008505  XGBRegressor: random_state=43
#
#                                            WORST
# rmse                            LinearRegression
# mse                             LinearRegression
# mae                                        Ridge
# r2_score  DecisionTreeRegressor: random_state=43
# mape                                       Ridge

# %% [markdown]
# ## Ronda 8: sustitución (+ borrado parcial y asignación)
# - Se sustituyen los valores de "depth (percentage)" por los resultados reales que da el cálculo a partir de las columnas correspondientes
#
# - Como se ha visto en EDA, el resultado serán muchos nuevos "outliers". Por tanto, se aplicará el cambio en el "dataframe" original sin otras modificaciones para comprobar si supone una mejora
#
# - La única modificación adicional indispensable es el tratamiento de los 0 en esas columnas
#
# - Para comprobar si realmente hay mejora, se aplican los modelos dos veces: una solo con las modificaciones de borrado parcial y asignación, y otra con la sustitución
#
# - Mejoran "SVR" y "RandomForest"

# %%
# Se aplican los cambios
df_diamonds_8a = df_diamonds.copy()

df_diamonds_8a = assign_values(df_diamonds_8a)

df_diamonds_8a = remove_all(df_diamonds_8a, zeros_only=True)

df_diamonds_8b = df_diamonds_8a.copy()

df_diamonds_8b['depth (percentage)'] = (df_diamonds_8b['depth (millimeters)'] / ((df_diamonds_8b['lenght (millimeters)']+df_diamonds_8b['width (millimeters)']) / 2)) * 100

# %%
# Se ponen a prueba solo el borrado parcial y la asignación
round_8a = Regression(df_diamonds_8a, 'price')
round_8a.split_dataframe()
round_8a.apply_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ],
                        kfolds_num=10
                    )
round_8a.evaluate_metrics()
round_8a.create_dataframe()
# Out:
# -- Regression: using best of 10 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.31 sec(s). Total time: 0.31
# Starting Ridge:
# - Ridge done in 0.17 sec(s). Total time: 0.48
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 6.99 sec(s). Total time: 7.47
# Starting SVR:
# - SVR done in 408.32 sec(s). Total time: 415.79
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 3.09 sec(s). Total time: 418.87
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 287.86 sec(s). Total time: 706.73
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 14.35 sec(s). Total time: 721.08
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.154359  0.154318             0.178104  0.161348
# mse               0.023827  0.023814             0.031721  0.026033
# mae               0.115958  0.115950             0.133578  0.123240
# r2_score          0.977030  0.977042             0.969420  0.974903
# mape              0.015024  0.015023             0.017619  0.016011
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.127910
# mse                                     0.016361
# mae                                     0.088054
# r2_score                                0.984227
# mape                                    0.011365
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.092733
# mse                                     0.008599
# mae                                     0.066104
# r2_score                                0.991710
# mape                                    0.008560
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.091120  XGBRegressor: random_state=43
# mse                            0.008303  XGBRegressor: random_state=43
# mae                            0.065954  XGBRegressor: random_state=43
# r2_score                       0.991996  XGBRegressor: random_state=43
# mape                           0.008513  XGBRegressor: random_state=43
#
#                         WORST
# rmse      KNeighborsRegressor
# mse       KNeighborsRegressor
# mae       KNeighborsRegressor
# r2_score                  SVR
# mape      KNeighborsRegressor

# %%
# Se pone a prueba la sustitución
round_8b = Regression(df_diamonds_8b, 'price')
round_8b.split_dataframe()
round_8b.apply_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ],
                        kfolds_num=10
                    )
round_8b.evaluate_metrics()
round_8b.create_dataframe()
# Out:
# -- Regression: using best of 10 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.39 sec(s). Total time: 0.39
# Starting Ridge:
# - Ridge done in 0.19 sec(s). Total time: 0.58
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 6.19 sec(s). Total time: 6.78
# Starting SVR:
# - SVR done in 465.98 sec(s). Total time: 472.75
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 3.64 sec(s). Total time: 476.4
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 327.77 sec(s). Total time: 804.17
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 18.2 sec(s). Total time: 822.36
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.155832  0.156025             0.178175  0.160862
# mse               0.024284  0.024344             0.031746  0.025877
# mae               0.119800  0.119931             0.133753  0.123338
# r2_score          0.976590  0.976532             0.969395  0.975054
# mape              0.015685  0.015691             0.017646  0.016023
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.128324
# mse                                     0.016467
# mae                                     0.088686
# r2_score                                0.984125
# mape                                    0.011451
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.092704
# mse                                     0.008594
# mae                                     0.066106
# r2_score                                0.991715
# mape                                    0.008564
#
#           XGBRegressor: random_state=43  \
# rmse                           0.091325
# mse                            0.008340
# mae                            0.066187
# r2_score                       0.991960
# mape                           0.008551
#
#                                             BEST                WORST
# rmse               XGBRegressor: random_state=43  KNeighborsRegressor
# mse                XGBRegressor: random_state=43  KNeighborsRegressor
# mae       RandomForestRegressor: random_state=43  KNeighborsRegressor
# r2_score           XGBRegressor: random_state=43                  SVR
# mape               XGBRegressor: random_state=43  KNeighborsRegressor

# %% [markdown]
# ## Ronda 9: descarte
# - Se quitan directamente las columnas con altísima correlación, cercana a 1 ("weight", "lenght", "width" y "depth (millimeters)")
#
# - Se utiliza el "dataframe" sin cambios ni escalado para el contraste
#
# - Todos empeoran respecto a la ronda 1
#
# - Con el descarte, en su lugar, de las de correlación poco relevante, mejoran "Kneighbors" y "SVR"

# %%
# Se hace la prueba
df_diamonds_9a = df_diamonds.copy()

df_diamonds_9a = df_diamonds_9a.drop(columns=['weight (carat)', 'lenght (millimeters)', 'width (millimeters)', 'depth (millimeters)'])

round_9a = Regression(df_diamonds_9a, 'price')
round_9a.split_dataframe()
round_9a.apply_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ],
                        kfolds_num=10
                    )
round_9a.evaluate_metrics()
round_9a.create_dataframe()
# Out:
# -- Regression: using best of 10 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.29 sec(s). Total time: 0.29
# Starting Ridge:
# - Ridge done in 0.12 sec(s). Total time: 0.41
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 2.37 sec(s). Total time: 2.78
# Starting SVR:
# - SVR done in 633.18 sec(s). Total time: 635.96
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 1.54 sec(s). Total time: 637.5
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 102.29 sec(s). Total time: 739.78
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 8.89 sec(s). Total time: 748.67
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.979343  0.979343             1.027563  0.986855
# mse               0.959112  0.959112             1.055885  0.973882
# mae               0.814501  0.814502             0.827875  0.803440
# r2_score          0.083879  0.083880            -0.008556  0.069771
# mape              0.107044  0.107044             0.108093  0.105367
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    1.187047
# mse                                     1.409080
# mae                                     0.911736
# r2_score                               -0.345919
# mape                                    0.118900
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    1.025191
# mse                                     1.051016
# mae                                     0.816076
# r2_score                               -0.003905
# mape                                    0.106677
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.957208  XGBRegressor: random_state=43
# mse                            0.916246  XGBRegressor: random_state=43
# mae                            0.787496  XGBRegressor: random_state=43
# r2_score                       0.124824  XGBRegressor: random_state=43
# mape                           0.103121  XGBRegressor: random_state=43
#
#                                            WORST
# rmse      DecisionTreeRegressor: random_state=43
# mse       DecisionTreeRegressor: random_state=43
# mae       DecisionTreeRegressor: random_state=43
# r2_score  RandomForestRegressor: random_state=43
# mape      DecisionTreeRegressor: random_state=43

# %%
# Para sacar más partido a esta ronda, se prueba también si se eliminan las columnas con una correlación próxima a 0
df_diamonds_9b = df_diamonds.copy()

df_diamonds_9b = df_diamonds_9b.drop(columns=['cut quality', 'depth (percentage)'])

round_9b = Regression(df_diamonds_9b, 'price')
round_9b.split_dataframe()
round_9b.apply_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ],
                        kfolds_num=10
                    )
round_9b.evaluate_metrics()
round_9b.create_dataframe()
# Out:
# -- Regression: using best of 10 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.28 sec(s). Total time: 0.28
# Starting Ridge:
# - Ridge done in 0.16 sec(s). Total time: 0.45
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 2.58 sec(s). Total time: 3.03
# Starting SVR:
# - SVR done in 339.54 sec(s). Total time: 342.57
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 2.35 sec(s). Total time: 344.92
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 192.48 sec(s). Total time: 537.4
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 9.3 sec(s). Total time: 546.7
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.225223  0.225136             0.145655  0.207183
# mse               0.050725  0.050686             0.021215  0.042925
# mae               0.131828  0.131875             0.102912  0.119493
# r2_score          0.951548  0.951586             0.979736  0.958999
# mape              0.017005  0.017011             0.013580  0.015578
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.133478
# mse                                     0.017816
# mae                                     0.091243
# r2_score                                0.982982
# mape                                    0.011747
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.099942
# mse                                     0.009988
# mae                                     0.068562
# r2_score                                0.990459
# mape                                    0.008862
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.095847  XGBRegressor: random_state=43
# mse                            0.009187  XGBRegressor: random_state=43
# mae                            0.067723  XGBRegressor: random_state=43
# r2_score                       0.991225  XGBRegressor: random_state=43
# mape                           0.008740  XGBRegressor: random_state=43
#
#                      WORST
# rmse      LinearRegression
# mse       LinearRegression
# mae                  Ridge
# r2_score               SVR
# mape                 Ridge

# %% [markdown]
# ## Ronda 10: imputaciones "clarity quality"
# - Se imputan los valores de 7 "clarity quality" al 6. Esto se hace porque se ha visto en el EDA que las variables relacionadas con el tamaño ('weight (carat)', 'lenght (millimeters)', 'width (millimeters)' y 'depth (millimeters)') dejan de disminuir a partir del 6
#
# - Se utiliza el "dataframe" sin cambios ni escalado para el contraste
#
# - Mejoran "LinearRegression", "Ridge" y "KNeighbors" comparados con la ronda 1

# %%
# Se comprueba
df_diamonds_10 = df_diamonds.copy()

df_diamonds_10.loc[df_diamonds_10['clarity quality'] == 7, 'clarity quality'] = 6

round_10 = Regression(df_diamonds_10, 'price')
round_10.split_dataframe()
round_10.apply_models(params_list=[['DecisionTreeRegressor', 'random_state=43'],
                                    ['RandomForestRegressor', 'random_state=43'],
                                    ['XGBRegressor', 'random_state=43']
                                    ],
                        kfolds_num=10
                    )
round_10.evaluate_metrics()
round_10.create_dataframe()
# Out:
# -- Regression: using best of 10 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.4 sec(s). Total time: 0.4
# Starting Ridge:
# - Ridge done in 0.17 sec(s). Total time: 0.57
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 8.32 sec(s). Total time: 8.89
# Starting SVR:
# - SVR done in 529.65 sec(s). Total time: 538.54
# Starting DecisionTreeRegressor: random_state=43:
# - DecisionTreeRegressor: random_state=43 done in 3.34 sec(s). Total time: 541.88
# Starting RandomForestRegressor: random_state=43:
# - RandomForestRegressor: random_state=43 done in 382.31 sec(s). Total time: 924.18
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 50.09 sec(s). Total time: 974.28
#           LinearRegression     Ridge  KNeighborsRegressor       SVR  \
# rmse              0.221734  0.221619             0.183265  0.209357
# mse               0.049166  0.049115             0.033586  0.043830
# mae               0.122548  0.122607             0.135284  0.127694
# r2_score          0.953038  0.953086             0.967919  0.958134
# mape              0.015838  0.015845             0.017839  0.016556
#
#           DecisionTreeRegressor: random_state=43  \
# rmse                                    0.130545
# mse                                     0.017042
# mae                                     0.089990
# r2_score                                0.983722
# mape                                    0.011599
#
#           RandomForestRegressor: random_state=43  \
# rmse                                    0.099294
# mse                                     0.009859
# mae                                     0.068342
# r2_score                                0.990583
# mape                                    0.008856
#
#           XGBRegressor: random_state=43                           BEST  \
# rmse                           0.094895  XGBRegressor: random_state=43
# mse                            0.009005  XGBRegressor: random_state=43
# mae                            0.067275  XGBRegressor: random_state=43
# r2_score                       0.991399  XGBRegressor: random_state=43
# mape                           0.008688  XGBRegressor: random_state=43
#
#                         WORST
# rmse         LinearRegression
# mse          LinearRegression
# mae       KNeighborsRegressor
# r2_score                  SVR
# mape      KNeighborsRegressor

# %% [markdown]
# # Modelaje: selección de modelos
#
# - Cada uno de los modelos mejora con los siguientes cambios:
#
# ---------- LinearRegression (mejor: 0.144352, ronda 4) ----------
#
#  · Borrado
#
#  · Asignación
#
#  · Imputaciones "boxplot"
#
#  · Imputaciones "clarity quality"
#
# ---------- Ridge (mejor: 0.144347, ronda 4) ----------
#
# · Escalado "MinMax"
#
# · Borrado
#
# · Asignación
#
# · Imputaciones "boxplot"
#
# · Imputaciones "clarity quality"
#
# ---------- KNeighborsRegressor (mejor: 0.136072, ronda 6) ----------
#
# · Escalado "Standard"
#
# · Borrado
#
# · Asignación
#
# · Logaritmo
#
# · Imputaciones "boxplot"
#
# · Descarte correlación ínfima
#
# · Imputaciones "clarity quality"
#
# ---------- SVR (mejor: 0.103508, ronda 6) ----------
#
# · Escalado "Standard"
#
# · Borrado
#
# · Asignación
#
# · Logaritmo
#
# · Imputaciones "boxplot"
#
# · Sustitución
#
# · Descarte correlación ínfima
#
# ---------- DecisionTree (mejor: 0.126511, ronda 7) ----------
#
# · Borrado
#
# · Logaritmo
#
# · Imputaciones "ridge"
#
# ---------- RandomForest (mejor: 0.092534, ronda 4) ----------
#
# · Borrado
#
# · Asignación
#
# · Sustitución
#
# ---------- XGBRegressor (mejor: 0.090042, ronda 6) ----------
#
# · Esclado "Standard"
#
# · Borrado
#
# · Asignación
#
# · Imputaciones "boxplot"

# %% [markdown]
# ## "Ridge" y "LinearRegression"
#
# - Cambios: escalado "MinMax", borrado, asignación, imputaciones "boxplot" e imputaciones "clarity quality"
#
# - Como mejoran con los mismos cambios y "LinearRegression" no se ve afectada por los escalados, se prueban juntos
#
# - Los mejores resultados para estos modelos no bajan de 0.14
#
# - Con cambios e hiperparámetros, "LinearRegression" ha mejorado su "rmse" de 0.222038 a 0.143639
#
# - Con cambios e hiperparámetros, "Ridge" ha mejorado su "rmse" de 0.221923 a 0.144060

# %%
# Se crea el "scorer"
rmse = make_scorer(calculate_rmse, greater_is_better=False)

# %%
# Se aplican todos los cambios del listado en común
df_ridge_linear = df_diamonds.copy()

df_ridge_linear = remove_all(df_ridge_linear)

df_ridge_linear = assign_values(df_ridge_linear)

df_ridge_linear = impute_boxplot_min_max(df_ridge_linear, ['depth (percentage)', 'table (percentage)'])

df_ridge_linear.loc[df_ridge_linear['clarity quality'] == 7, 'clarity quality'] = 6

# %%
# Se prueban en un "dataframe" conjunto
ridge_linear = Regression(df_ridge_linear, 'price')
X_train, X_test, y_train, y_test = ridge_linear.split_dataframe(scaler='MinMaxScaler')
ridge_linear.apply_models(selected_list=['LinearRegression', 'Ridge'],
                        kfolds_num=10
                    )
ridge_linear.evaluate_metrics()
ridge_linear.create_dataframe()
# Out:
# -- Regression (MinMaxScaler): using best of 10 folds --
# Starting LinearRegression:
# - LinearRegression done in 0.34 sec(s). Total time: 0.34
# Starting Ridge:
# - Ridge done in 0.18 sec(s). Total time: 0.52
#           LinearRegression     Ridge              BEST  WORST
# rmse              0.143636  0.144150  LinearRegression  Ridge
# mse               0.020631  0.020779  LinearRegression  Ridge
# mae               0.111701  0.112225  LinearRegression  Ridge
# r2_score          0.980016  0.979873  LinearRegression  Ridge
# mape              0.014615  0.014684  LinearRegression  Ridge

# %%
# Se busca la mejor media de 5 "folds" para la regresión lineal modificando los hiperparámetros
# Se confirma que el mejor modelo para regresión lineal es el que tiene los valores por defecto
model = LinearRegression()

params = {'fit_intercept': [True, False],
            'positive': [True, False],
            }

grid = GridSearchCV(estimator = model,
                    param_grid = params,
                    scoring=rmse,
                    verbose=4
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END fit_intercept=True, positive=True;, score=-0.184 total time=   0.0s
# [CV 2/5] END fit_intercept=True, positive=True;, score=-0.187 total time=   0.0s
# [CV 3/5] END fit_intercept=True, positive=True;, score=-0.177 total time=   0.0s
# [CV 4/5] END fit_intercept=True, positive=True;, score=-0.184 total time=   0.0s
# [CV 5/5] END fit_intercept=True, positive=True;, score=-0.174 total time=   0.0s
# [CV 1/5] END fit_intercept=True, positive=False;, score=-0.149 total time=   0.0s
# [CV 2/5] END fit_intercept=True, positive=False;, score=-0.149 total time=   0.0s
# [CV 3/5] END fit_intercept=True, positive=False;, score=-0.143 total time=   0.0s
# [CV 4/5] END fit_intercept=True, positive=False;, score=-0.148 total time=   0.0s
# [CV 5/5] END fit_intercept=True, positive=False;, score=-0.144 total time=   0.0s
# [CV 1/5] END fit_intercept=False, positive=True;, score=-0.361 total time=   0.0s
# [CV 2/5] END fit_intercept=False, positive=True;, score=-0.363 total time=   0.0s
# [CV 3/5] END fit_intercept=False, positive=True;, score=-0.358 total time=   0.0s
# [CV 4/5] END fit_intercept=False, positive=True;, score=-0.359 total time=   0.0s
# [CV 5/5] END fit_intercept=False, positive=True;, score=-0.361 total time=   0.0s
# [CV 1/5] END fit_intercept=False, positive=False;, score=-0.235 total time=   0.0s
# [CV 2/5] END fit_intercept=False, positive=False;, score=-0.177 total time=   0.0s
# [CV 3/5] END fit_intercept=False, positive=False;, score=-0.177 total time=   0.0s
# [CV 4/5] END fit_intercept=False, positive=False;, score=-0.180 total time=   0.0s
# [CV 5/5] END fit_intercept=False, positive=False;, score=-0.202 total time=   0.0s
# Best params: {'fit_intercept': True, 'positive': False}

# %%
# Mejor puntuación para regresión lineal
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 0.14363969914101388

# %%
# Se intenta mejorar el "ridge" modificando los hiperparámetros
# Se obtiene el mejor modelo para "ridge"
model = Ridge()

params = {'fit_intercept': [True, False],
            'alpha': np.linspace(1, 100, num=100),
            'solver': ['svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs'],
            'positive': [True, False]

            }

grid = GridSearchCV(estimator = model,
                    param_grid = params,
                    scoring=rmse,
                    verbose=4
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
# Out:
# Fitting 5 folds for each of 2800 candidates, totalling 14000 fits
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.184 total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.187 total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.177 total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.184 total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.174 total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=False, solver=svd;, score=-0.149 total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=False, solver=svd;, score=-0.150 total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=False, solver=svd;, score=-0.144 total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=False, solver=svd;, score=-0.149 total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=False, solver=svd;, score=-0.144 total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.149 total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.150 total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.144 total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.149 total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.144 total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.149 total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.150 total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.144 total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.149 total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.144 total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.149 total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.150 total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.144 total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.149 total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.144 total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=False, solver=sag;, score=-0.149 total time=   0.1s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=False, solver=sag;, score=-0.150 total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=False, solver=sag;, score=-0.144 total time=   0.1s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=False, solver=sag;, score=-0.149 total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=False, solver=sag;, score=-0.144 total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=False, solver=saga;, score=-0.149 total time=   0.2s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=False, solver=saga;, score=-0.150 total time=   0.1s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=False, solver=saga;, score=-0.144 total time=   0.2s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=False, solver=saga;, score=-0.149 total time=   0.1s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=False, solver=saga;, score=-0.144 total time=   0.2s
# [CV 1/5] END alpha=1.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.402 total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.410 total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.398 total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.408 total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.401 total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=False, solver=svd;, score=-0.228 total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=False, solver=svd;, score=-0.189 total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=False, solver=svd;, score=-0.189 total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=False, solver=svd;, score=-0.190 total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=False, solver=svd;, score=-0.208 total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.228 total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.189 total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.189 total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.190 total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.208 total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.228 total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.189 total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.189 total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.190 total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.208 total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.228 total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.189 total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.189 total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.190 total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.208 total time=   0.0s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=False, solver=sag;, score=-0.228 total time=   0.1s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=False, solver=sag;, score=-0.189 total time=   0.1s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=False, solver=sag;, score=-0.189 total time=   0.1s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=False, solver=sag;, score=-0.190 total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=False, solver=sag;, score=-0.208 total time=   0.1s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=False, solver=saga;, score=-0.228 total time=   0.1s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=False, solver=saga;, score=-0.189 total time=   0.1s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=False, solver=saga;, score=-0.189 total time=   0.1s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=False, solver=saga;, score=-0.190 total time=   0.1s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=False, solver=saga;, score=-0.208 total time=   0.1s
# [CV 1/5] END alpha=1.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END alpha=1.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END alpha=1.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END alpha=1.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END alpha=1.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.184 total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.187 total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.177 total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.184 total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.174 total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=False, solver=svd;, score=-0.151 total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=False, solver=svd;, score=-0.152 total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=False, solver=svd;, score=-0.146 total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=False, solver=svd;, score=-0.151 total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=False, solver=svd;, score=-0.145 total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.151 total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.152 total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.146 total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.151 total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.145 total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.151 total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.152 total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.146 total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.151 total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.145 total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.151 total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.152 total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.146 total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.151 total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.145 total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=False, solver=sag;, score=-0.151 total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=False, solver=sag;, score=-0.152 total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=False, solver=sag;, score=-0.146 total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=False, solver=sag;, score=-0.151 total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=False, solver=sag;, score=-0.145 total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=False, solver=saga;, score=-0.151 total time=   0.1s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=False, solver=saga;, score=-0.152 total time=   0.1s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=False, solver=saga;, score=-0.146 total time=   0.1s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=False, solver=saga;, score=-0.151 total time=   0.1s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=False, solver=saga;, score=-0.145 total time=   0.1s
# [CV 1/5] END alpha=2.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.402 total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.410 total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.358 total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.409 total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.361 total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=False, solver=svd;, score=-0.232 total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=False, solver=svd;, score=-0.205 total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=False, solver=svd;, score=-0.206 total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=False, solver=svd;, score=-0.205 total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=False, solver=svd;, score=-0.221 total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.232 total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.205 total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.206 total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.205 total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.221 total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.232 total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.205 total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.206 total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.205 total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.221 total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.232 total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.205 total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.206 total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.205 total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.221 total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=False, solver=sag;, score=-0.232 total time=   0.1s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=False, solver=sag;, score=-0.205 total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=False, solver=sag;, score=-0.206 total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=False, solver=sag;, score=-0.205 total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=False, solver=sag;, score=-0.221 total time=   0.0s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=False, solver=saga;, score=-0.232 total time=   0.1s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=False, solver=saga;, score=-0.205 total time=   0.1s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=False, solver=saga;, score=-0.206 total time=   0.1s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=False, solver=saga;, score=-0.205 total time=   0.1s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=False, solver=saga;, score=-0.221 total time=   0.1s
# [CV 1/5] END alpha=2.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END alpha=2.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END alpha=2.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END alpha=2.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END alpha=2.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.184 total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.187 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.177 total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.184 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.174 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=False, solver=svd;, score=-0.153 total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=False, solver=svd;, score=-0.155 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=False, solver=svd;, score=-0.148 total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=False, solver=svd;, score=-0.153 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=False, solver=svd;, score=-0.147 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.153 total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.155 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.148 total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.153 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=False, solver=cholesky;, score=-0.147 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.153 total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.155 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.148 total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.153 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=False, solver=lsqr;, score=-0.147 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.153 total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.155 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.148 total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.153 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=False, solver=sparse_cg;, score=-0.147 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=False, solver=sag;, score=-0.153 total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=False, solver=sag;, score=-0.155 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=False, solver=sag;, score=-0.148 total time=   0.1s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=False, solver=sag;, score=-0.153 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=False, solver=sag;, score=-0.147 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=False, solver=saga;, score=-0.153 total time=   0.1s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=False, solver=saga;, score=-0.155 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=False, solver=saga;, score=-0.148 total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=False, solver=saga;, score=-0.153 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=False, solver=saga;, score=-0.147 total time=   0.1s
# [CV 1/5] END alpha=3.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.361 total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.363 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.358 total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.359 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.361 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=False, solver=svd;, score=-0.240 total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=False, solver=svd;, score=-0.222 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=False, solver=svd;, score=-0.223 total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=False, solver=svd;, score=-0.221 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=False, solver=svd;, score=-0.235 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.240 total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.222 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.223 total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.221 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.235 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.240 total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.222 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.223 total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.221 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.235 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.240 total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.222 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.223 total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.221 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.235 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=False, solver=sag;, score=-0.240 total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=False, solver=sag;, score=-0.222 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=False, solver=sag;, score=-0.223 total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=False, solver=sag;, score=-0.221 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=False, solver=sag;, score=-0.235 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=False, solver=saga;, score=-0.240 total time=   0.1s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=False, solver=saga;, score=-0.222 total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=False, solver=saga;, score=-0.223 total time=   0.1s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=False, solver=saga;, score=-0.221 total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=False, solver=saga;, score=-0.235 total time=   0.0s
# [CV 1/5] END alpha=3.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END alpha=3.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END alpha=3.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END alpha=3.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END alpha=3.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END alpha=4.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 2/5] END alpha=4.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 3/5] END alpha=4.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 4/5] END alpha=4.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 5/5] END alpha=4.0, fit_intercept=True, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 1/5] END alpha=4.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 2/5] END alpha=4.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 3/5] END alpha=4.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 4/5] END alpha=4.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 5/5] END alpha=4.0, fit_intercept=True, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 1/5] END alpha=4.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 2/5] END alpha=4.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 3/5] END alpha=4.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 4/5] END alpha=4.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 5/5] END alpha=4.0, fit_intercept=True, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 1/5] END alpha=4.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 2/5] END alpha=4.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 3/5] END alpha=4.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 4/5] END alpha=4.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 5/5] END alpha=4.0, fit_intercept=True, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 1/5] END alpha=4.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END alpha=4.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END alpha=4.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END alpha=4.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END alpha=4.0, fit_intercept=True, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END alpha=4.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 2/5] END alpha=4.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 3/5] END alpha=4.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 4/5] END alpha=4.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 5/5] END alpha=4.0, fit_intercept=True, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 1/5] END alpha=4.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.184 total time=   0.0s
# [CV 2/5] END alpha=4.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.187 total time=   0.0s
# [CV 3/5] END alpha=4.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.177 total time=   0.0s
# [CV 4/5] END alpha=4.0, fit_intercept=True, positive=True, solver=lbfgs;, score=-0.184 total time=   0.0s
# ...
# [CV 1/5] END alpha=100.0, fit_intercept=True, positive=False, solver=sag;, score=-0.210 total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=True, positive=False, solver=sag;, score=-0.211 total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=True, positive=False, solver=sag;, score=-0.201 total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=True, positive=False, solver=sag;, score=-0.207 total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=True, positive=False, solver=sag;, score=-0.199 total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=True, positive=False, solver=saga;, score=-0.210 total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=True, positive=False, solver=saga;, score=-0.211 total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=True, positive=False, solver=saga;, score=-0.201 total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=True, positive=False, solver=saga;, score=-0.207 total time=   0.2s
# [CV 5/5] END alpha=100.0, fit_intercept=True, positive=False, solver=saga;, score=-0.199 total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=True, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=True, solver=svd;, score=nan total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=True, solver=cholesky;, score=nan total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=True, solver=lsqr;, score=nan total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=True, solver=sparse_cg;, score=nan total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=True, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=True, solver=saga;, score=nan total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.456 total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.462 total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.462 total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.463 total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=True, solver=lbfgs;, score=-0.467 total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=False, solver=svd;, score=-0.454 total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=False, solver=svd;, score=-0.462 total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=False, solver=svd;, score=-0.461 total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=False, solver=svd;, score=-0.461 total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=False, solver=svd;, score=-0.465 total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.454 total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.462 total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.461 total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.461 total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=False, solver=cholesky;, score=-0.465 total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.454 total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.462 total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.461 total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.461 total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=False, solver=lsqr;, score=-0.465 total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.454 total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.462 total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.461 total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.461 total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=False, solver=sparse_cg;, score=-0.465 total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=False, solver=sag;, score=-0.454 total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=False, solver=sag;, score=-0.462 total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=False, solver=sag;, score=-0.461 total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=False, solver=sag;, score=-0.461 total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=False, solver=sag;, score=-0.465 total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=False, solver=saga;, score=-0.454 total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=False, solver=saga;, score=-0.462 total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=False, solver=saga;, score=-0.461 total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=False, solver=saga;, score=-0.461 total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=False, solver=saga;, score=-0.465 total time=   0.0s
# [CV 1/5] END alpha=100.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END alpha=100.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END alpha=100.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END alpha=100.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END alpha=100.0, fit_intercept=False, positive=False, solver=lbfgs;, score=nan total time=   0.0s
# Best params: {'alpha': 1.0, 'fit_intercept': True, 'positive': False, 'solver': 'lsqr'}
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 7000 fits failed out of a total of 14000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1000 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 1134, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 832, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support positive fitting. Please set the solver to 'auto' or 'lbfgs', or set `positive=False`
#
# --------------------------------------------------------------------------------
# 1000 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 1134, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 832, in fit
#     raise ValueError(
# ValueError: solver='cholesky' does not support positive fitting. Please set the solver to 'auto' or 'lbfgs', or set `positive=False`
#
# --------------------------------------------------------------------------------
# 1000 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 1134, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 832, in fit
#     raise ValueError(
# ValueError: solver='lsqr' does not support positive fitting. Please set the solver to 'auto' or 'lbfgs', or set `positive=False`
#
# --------------------------------------------------------------------------------
# 1000 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 1134, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 832, in fit
#     raise ValueError(
# ValueError: solver='sparse_cg' does not support positive fitting. Please set the solver to 'auto' or 'lbfgs', or set `positive=False`
#
# --------------------------------------------------------------------------------
# 1000 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 1134, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 832, in fit
#     raise ValueError(
# ValueError: solver='sag' does not support positive fitting. Please set the solver to 'auto' or 'lbfgs', or set `positive=False`
#
# --------------------------------------------------------------------------------
# 1000 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 1134, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 832, in fit
#     raise ValueError(
# ValueError: solver='saga' does not support positive fitting. Please set the solver to 'auto' or 'lbfgs', or set `positive=False`
#
# --------------------------------------------------------------------------------
# 1000 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 1134, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\linear_model\_ridge.py", line 825, in fit
#     raise ValueError(
# ValueError: 'lbfgs' solver can be used only when positive=True. Please use another solver.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\model_selection\_search.py:953: UserWarning: One or more of the test scores are non-finite: [        nan         nan         nan ... -0.46065812 -0.46066307
#          nan]
#   warnings.warn(

# %%
# Mejor puntuación para "ridge"
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 0.1440602916434586

# %% [markdown]
# ## PENDIENTE "KNeighborsRegressor"
#
# - Cambios: escalado "Standard", borrado, asignación, logaritmo, imputaciones "boxplot", descarte correlación ínfima e imputaciones "clarity quality"
#
# - Como no se puede aplicar el logaritmo si hay ceros, se hace una asignación parcial que no incluye los "outliers"
#
# - Con cambios e hiperparámetros, k vecinos ha mejorado su "rmse" de 0.183865 a

# %%
df_neighbors = df_diamonds.copy()

df_neighbors = remove_all(df_neighbors)

df_neighbors = assign_values(df_neighbors)

df_neighbors[['weight (carat)', 'lenght (millimeters)', 'width (millimeters)', 'depth (millimeters)']] = np.log(df_neighbors[['weight (carat)', 'lenght (millimeters)', 'width (millimeters)', 'depth (millimeters)']])

df_neighbors = impute_boxplot_min_max(df_neighbors, ['depth (percentage)', 'table (percentage)'])

df_neighbors = df_neighbors.drop(columns=['cut quality', 'depth (percentage)'])

df_neighbors.loc[df_neighbors['clarity quality'] == 7, 'clarity quality'] = 6

# %%
neighbors = Regression(df_neighbors, 'price')
X_train, X_test, y_train, y_test = neighbors.split_dataframe(scaler='StandardScaler')
neighbors.apply_models(selected_list=['KNeighborsRegressor'],
                        kfolds_num=10
                    )
neighbors.evaluate_metrics()
neighbors.create_dataframe()
# Out:
# -- Regression (StandardScaler): using best of 10 folds --
# Starting KNeighborsRegressor:
# - KNeighborsRegressor done in 2.57 sec(s). Total time: 2.57
#           KNeighborsRegressor                 BEST                WORST
# mae                  0.093240  KNeighborsRegressor  KNeighborsRegressor
# mape                 0.012333  KNeighborsRegressor  KNeighborsRegressor
# mse                  0.015091  KNeighborsRegressor  KNeighborsRegressor
# r2_score             0.985383  KNeighborsRegressor  KNeighborsRegressor
# rmse                 0.122844  KNeighborsRegressor  KNeighborsRegressor

# %%
# Se usa el "grid"
model = KNeighborsRegressor()

params = {'n_neighbors': range(5, 21),
            'algorithm': ['ball_tree', 'kd_tree', 'brute'],
            'leaf_size': range(20, 41),
            'metric': ['cityblock', 'euclidean', 'l1', 'l2', 'manhattan'],
            'n_jobs': [-1],
            }

grid = GridSearchCV(estimator = model,
                    param_grid = params,
                    scoring=rmse,
                    verbose=4
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
# Out:
# Fitting 5 folds for each of 5040 candidates, totalling 25200 fits
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=5;, score=-0.124 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=5;, score=-0.122 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=5;, score=-0.124 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=5;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=5;, score=-0.123 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=6;, score=-0.123 total time=   0.2s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=6;, score=-0.121 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=6;, score=-0.123 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=6;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=6;, score=-0.122 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=7;, score=-0.123 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=7;, score=-0.122 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=7;, score=-0.122 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=7;, score=-0.121 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=7;, score=-0.122 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=8;, score=-0.122 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=8;, score=-0.121 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=8;, score=-0.122 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=8;, score=-0.121 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=8;, score=-0.121 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=9;, score=-0.122 total time=   0.2s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=9;, score=-0.120 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=9;, score=-0.122 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=9;, score=-0.121 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=9;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=10;, score=-0.122 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=10;, score=-0.121 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=10;, score=-0.122 total time=   0.5s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=10;, score=-0.121 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=10;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=11;, score=-0.122 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=11;, score=-0.120 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=11;, score=-0.123 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=11;, score=-0.121 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=11;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=12;, score=-0.122 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=12;, score=-0.121 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=12;, score=-0.123 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=12;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=12;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=13;, score=-0.122 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=13;, score=-0.121 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=13;, score=-0.123 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=13;, score=-0.121 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=13;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=14;, score=-0.122 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=14;, score=-0.121 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=14;, score=-0.123 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=14;, score=-0.121 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=14;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=15;, score=-0.123 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=15;, score=-0.121 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=15;, score=-0.123 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=15;, score=-0.122 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=15;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=16;, score=-0.123 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=16;, score=-0.121 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=16;, score=-0.124 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=16;, score=-0.122 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=16;, score=-0.121 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=17;, score=-0.123 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=17;, score=-0.121 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=17;, score=-0.123 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=17;, score=-0.122 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=17;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=18;, score=-0.123 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=18;, score=-0.121 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=18;, score=-0.124 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=18;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=18;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=19;, score=-0.123 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=19;, score=-0.121 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=19;, score=-0.124 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=19;, score=-0.122 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=19;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=20;, score=-0.124 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=20;, score=-0.121 total time=   0.5s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=20;, score=-0.124 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=20;, score=-0.122 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=cityblock, n_jobs=-1, n_neighbors=20;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=5;, score=-0.126 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=5;, score=-0.124 total time=   0.2s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=5;, score=-0.126 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=5;, score=-0.122 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=5;, score=-0.124 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=6;, score=-0.127 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=6;, score=-0.124 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=6;, score=-0.125 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=6;, score=-0.123 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=6;, score=-0.123 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=7;, score=-0.127 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=7;, score=-0.123 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=7;, score=-0.125 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=7;, score=-0.123 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=7;, score=-0.124 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=8;, score=-0.127 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=8;, score=-0.124 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=8;, score=-0.126 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=8;, score=-0.124 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=8;, score=-0.124 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=9;, score=-0.127 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=9;, score=-0.124 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=9;, score=-0.126 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=9;, score=-0.124 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=9;, score=-0.124 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=10;, score=-0.127 total time=   0.2s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=10;, score=-0.124 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=10;, score=-0.127 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=10;, score=-0.124 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=10;, score=-0.124 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=11;, score=-0.128 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=11;, score=-0.124 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=11;, score=-0.127 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=11;, score=-0.124 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=11;, score=-0.124 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=12;, score=-0.128 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=12;, score=-0.125 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=12;, score=-0.128 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=12;, score=-0.125 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=12;, score=-0.124 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=13;, score=-0.129 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=13;, score=-0.125 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=13;, score=-0.128 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=13;, score=-0.125 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=13;, score=-0.124 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=14;, score=-0.129 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=14;, score=-0.125 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=14;, score=-0.128 total time=   0.5s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=14;, score=-0.125 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=14;, score=-0.124 total time=   0.5s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=15;, score=-0.129 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=15;, score=-0.126 total time=   0.5s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=15;, score=-0.129 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=15;, score=-0.126 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=15;, score=-0.125 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=16;, score=-0.129 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=16;, score=-0.126 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=16;, score=-0.129 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=16;, score=-0.126 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=16;, score=-0.125 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=17;, score=-0.130 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=17;, score=-0.126 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=17;, score=-0.129 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=17;, score=-0.126 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=17;, score=-0.125 total time=   0.5s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=18;, score=-0.130 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=18;, score=-0.127 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=18;, score=-0.129 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=18;, score=-0.126 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=18;, score=-0.125 total time=   0.5s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=19;, score=-0.130 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=19;, score=-0.127 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=19;, score=-0.129 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=19;, score=-0.126 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=19;, score=-0.125 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=20;, score=-0.130 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=20;, score=-0.127 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=20;, score=-0.130 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=20;, score=-0.126 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_jobs=-1, n_neighbors=20;, score=-0.126 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=5;, score=-0.124 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=5;, score=-0.122 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=5;, score=-0.124 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=5;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=5;, score=-0.123 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=6;, score=-0.123 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=6;, score=-0.121 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=6;, score=-0.123 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=6;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=6;, score=-0.122 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=7;, score=-0.123 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=7;, score=-0.122 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=7;, score=-0.122 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=7;, score=-0.121 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=7;, score=-0.122 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=8;, score=-0.122 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=8;, score=-0.121 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=8;, score=-0.122 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=8;, score=-0.121 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=8;, score=-0.121 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=9;, score=-0.122 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=9;, score=-0.120 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=9;, score=-0.122 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=9;, score=-0.121 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=9;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=10;, score=-0.122 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=10;, score=-0.121 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=10;, score=-0.122 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=10;, score=-0.121 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=10;, score=-0.121 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=11;, score=-0.122 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=11;, score=-0.120 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=11;, score=-0.123 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=11;, score=-0.121 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=11;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=12;, score=-0.122 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=12;, score=-0.121 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=12;, score=-0.123 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=12;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=12;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=13;, score=-0.122 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=13;, score=-0.121 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=13;, score=-0.123 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=13;, score=-0.121 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=13;, score=-0.120 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=14;, score=-0.122 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=14;, score=-0.121 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=14;, score=-0.123 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=14;, score=-0.121 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=14;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=15;, score=-0.123 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=15;, score=-0.121 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=15;, score=-0.123 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=15;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=15;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=16;, score=-0.123 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=16;, score=-0.121 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=16;, score=-0.124 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=16;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=16;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=17;, score=-0.123 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=17;, score=-0.121 total time=   0.2s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=17;, score=-0.123 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=17;, score=-0.122 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=17;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=18;, score=-0.123 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=18;, score=-0.121 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=18;, score=-0.124 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=18;, score=-0.122 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=18;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=19;, score=-0.123 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=19;, score=-0.121 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=19;, score=-0.124 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=19;, score=-0.122 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=19;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=20;, score=-0.124 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=20;, score=-0.121 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=20;, score=-0.124 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=20;, score=-0.122 total time=   0.2s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l1, n_jobs=-1, n_neighbors=20;, score=-0.121 total time=   0.5s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=5;, score=-0.126 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=5;, score=-0.124 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=5;, score=-0.126 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=5;, score=-0.122 total time=   0.2s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=5;, score=-0.124 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=6;, score=-0.127 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=6;, score=-0.124 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=6;, score=-0.125 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=6;, score=-0.123 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=6;, score=-0.123 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=7;, score=-0.127 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=7;, score=-0.123 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=7;, score=-0.125 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=7;, score=-0.123 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=7;, score=-0.124 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=8;, score=-0.127 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=8;, score=-0.124 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=8;, score=-0.126 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=8;, score=-0.124 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=8;, score=-0.124 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=9;, score=-0.127 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=9;, score=-0.124 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=9;, score=-0.126 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=9;, score=-0.124 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=9;, score=-0.124 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=10;, score=-0.127 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=10;, score=-0.124 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=10;, score=-0.127 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=10;, score=-0.124 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=10;, score=-0.124 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=11;, score=-0.128 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=11;, score=-0.124 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=11;, score=-0.127 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=11;, score=-0.124 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=11;, score=-0.124 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=12;, score=-0.128 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=12;, score=-0.125 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=12;, score=-0.128 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=12;, score=-0.125 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=12;, score=-0.124 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=13;, score=-0.129 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=13;, score=-0.125 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=13;, score=-0.128 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=13;, score=-0.125 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=13;, score=-0.124 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=14;, score=-0.129 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=14;, score=-0.125 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=14;, score=-0.128 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=14;, score=-0.125 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=14;, score=-0.124 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=15;, score=-0.129 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=15;, score=-0.126 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=15;, score=-0.129 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=15;, score=-0.126 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=15;, score=-0.125 total time=   0.6s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=16;, score=-0.129 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=16;, score=-0.126 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=16;, score=-0.129 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=16;, score=-0.126 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=16;, score=-0.125 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=17;, score=-0.130 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=17;, score=-0.126 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=17;, score=-0.129 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=17;, score=-0.126 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=17;, score=-0.125 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=18;, score=-0.130 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=18;, score=-0.127 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=18;, score=-0.129 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=18;, score=-0.126 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=18;, score=-0.125 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=19;, score=-0.130 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=19;, score=-0.127 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=19;, score=-0.129 total time=   0.5s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=19;, score=-0.126 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=19;, score=-0.125 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=20;, score=-0.130 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=20;, score=-0.127 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=20;, score=-0.130 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=20;, score=-0.126 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=l2, n_jobs=-1, n_neighbors=20;, score=-0.126 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=5;, score=-0.124 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=5;, score=-0.122 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=5;, score=-0.124 total time=   0.2s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=5;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=5;, score=-0.123 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=6;, score=-0.123 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=6;, score=-0.121 total time=   0.2s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=6;, score=-0.123 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=6;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=6;, score=-0.122 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=7;, score=-0.123 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=7;, score=-0.122 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=7;, score=-0.122 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=7;, score=-0.121 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=7;, score=-0.122 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=8;, score=-0.122 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=8;, score=-0.121 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=8;, score=-0.122 total time=   0.2s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=8;, score=-0.121 total time=   0.2s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=8;, score=-0.121 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=9;, score=-0.122 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=9;, score=-0.120 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=9;, score=-0.122 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=9;, score=-0.121 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=9;, score=-0.121 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=10;, score=-0.122 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=10;, score=-0.121 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=10;, score=-0.122 total time=   0.5s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=10;, score=-0.121 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=10;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=11;, score=-0.122 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=11;, score=-0.120 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=11;, score=-0.123 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=11;, score=-0.121 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=11;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=12;, score=-0.122 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=12;, score=-0.121 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=12;, score=-0.123 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=12;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=12;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=13;, score=-0.122 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=13;, score=-0.121 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=13;, score=-0.123 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=13;, score=-0.121 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=13;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=14;, score=-0.122 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=14;, score=-0.121 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=14;, score=-0.123 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=14;, score=-0.121 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=14;, score=-0.120 total time=   0.3s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=15;, score=-0.123 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=15;, score=-0.121 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=15;, score=-0.123 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=15;, score=-0.122 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=15;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=16;, score=-0.123 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=16;, score=-0.121 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=16;, score=-0.124 total time=   0.3s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=16;, score=-0.122 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=16;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=17;, score=-0.123 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=17;, score=-0.121 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=17;, score=-0.123 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=17;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=17;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=18;, score=-0.123 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=18;, score=-0.121 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=18;, score=-0.124 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=18;, score=-0.122 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_jobs=-1, n_neighbors=18;, score=-0.121 total time=   0.4s
# ...
# [CV 3/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=14;, score=-0.123 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=14;, score=-0.121 total time=   0.8s
# [CV 5/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=14;, score=-0.120 total time=   0.6s
# [CV 1/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=15;, score=-0.123 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=15;, score=-0.121 total time=   0.3s
# [CV 3/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=15;, score=-0.123 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=15;, score=-0.122 total time=   0.3s
# [CV 5/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=15;, score=-0.121 total time=   0.4s
# [CV 1/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=16;, score=-0.123 total time=   0.5s
# [CV 2/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=16;, score=-0.121 total time=   0.8s
# [CV 3/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=16;, score=-0.124 total time=   0.9s
# [CV 4/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=16;, score=-0.122 total time=   0.8s
# [CV 5/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=16;, score=-0.121 total time=   1.0s
# [CV 1/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=17;, score=-0.123 total time=   0.9s
# [CV 2/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=17;, score=-0.121 total time=   0.7s
# [CV 3/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=17;, score=-0.123 total time=   0.7s
# [CV 4/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=17;, score=-0.122 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=17;, score=-0.121 total time=   0.7s
# [CV 1/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=18;, score=-0.123 total time=   0.5s
# [CV 2/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=18;, score=-0.121 total time=   0.6s
# [CV 3/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=18;, score=-0.124 total time=   0.6s
# [CV 4/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=18;, score=-0.122 total time=   0.7s
# [CV 5/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=18;, score=-0.121 total time=   0.7s
# [CV 1/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=19;, score=-0.123 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=19;, score=-0.121 total time=   0.5s
# [CV 3/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=19;, score=-0.124 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=19;, score=-0.122 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=19;, score=-0.121 total time=   0.5s
# [CV 1/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=20;, score=-0.124 total time=   0.5s
# [CV 2/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=20;, score=-0.121 total time=   0.5s
# [CV 3/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=20;, score=-0.124 total time=   0.5s
# [CV 4/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=20;, score=-0.122 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=39, metric=cityblock, n_jobs=-1, n_neighbors=20;, score=-0.121 total time=   0.7s
# [CV 1/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=5;, score=-0.126 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=5;, score=-0.124 total time=   0.6s
# [CV 3/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=5;, score=-0.126 total time=   0.5s
# [CV 4/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=5;, score=-0.122 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=5;, score=-0.124 total time=   0.5s
# [CV 1/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=6;, score=-0.127 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=6;, score=-0.124 total time=   0.5s
# [CV 3/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=6;, score=-0.125 total time=   0.5s
# [CV 4/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=6;, score=-0.123 total time=   0.4s
# [CV 5/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=6;, score=-0.123 total time=   0.5s
# [CV 1/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=7;, score=-0.127 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=7;, score=-0.123 total time=   0.5s
# [CV 3/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=7;, score=-0.125 total time=   0.5s
# [CV 4/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=7;, score=-0.123 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=7;, score=-0.124 total time=   0.5s
# [CV 1/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=8;, score=-0.127 total time=   0.3s
# [CV 2/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=8;, score=-0.124 total time=   0.5s
# [CV 3/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=8;, score=-0.126 total time=   0.5s
# [CV 4/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=8;, score=-0.124 total time=   0.8s
# [CV 5/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=8;, score=-0.124 total time=   0.8s
# [CV 1/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=9;, score=-0.127 total time=   0.5s
# [CV 2/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=9;, score=-0.124 total time=   0.5s
# [CV 3/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=9;, score=-0.126 total time=   0.9s
# [CV 4/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=9;, score=-0.124 total time=   0.5s
# [CV 5/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=9;, score=-0.124 total time=   0.7s
# [CV 1/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=10;, score=-0.127 total time=   0.4s
# [CV 2/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=10;, score=-0.124 total time=   0.4s
# [CV 3/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=10;, score=-0.127 total time=   0.4s
# [CV 4/5] END algorithm=ball_tree, leaf_size=39, metric=euclidean, n_jobs=-1, n_neighbors=10;, score=-0.124 total time=   0.5s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 17
#       4 params = {'n_neighbors': range(5, 21),
#       5             'algorithm': ['ball_tree', 'kd_tree', 'brute'],
#       6             'leaf_size': range(20, 41),
#       7             'metric': ['cityblock', 'euclidean', 'l1', 'l2', 'manhattan'],
#       8             'n_jobs': [-1],
#       9             }
#      11 grid = GridSearchCV(estimator = model,
#      12                     param_grid = params,
#      13                     scoring=rmse,
#      14                     verbose=4
#      15                     )
# ---> 17 grid.fit(X_train, y_train)
#      19 grid.predict(X_test)
#      21 print(f'Best score: {grid.best_score_}')
#
# File c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\model_selection\_search.py:875, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     869     results = self._format_results(
#     870         all_candidate_params, n_splits, all_out, all_more_results
#     871     )
#     873     return results
# --> 875 self._run_search(evaluate_candidates)
#     877 # multimetric is determined here because in the case of a callable
#     878 # self.scoring the return type is only known after calling
#     879 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\model_selection\_search.py:1389, in GridSearchCV._run_search(self, evaluate_candidates)
#    1387 def _run_search(self, evaluate_candidates):
#    1388     """Search all candidates in param_grid"""
# -> 1389     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\model_selection\_search.py:822, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     814 if self.verbose > 0:
#     815     print(
#     816         "Fitting {0} folds for each of {1} candidates,"
#     817         " totalling {2} fits".format(
#     818             n_splits, n_candidates, n_candidates * n_splits
#     819         )
#     820     )
# --> 822 out = parallel(
#     823     delayed(_fit_and_score)(
#     824         clone(base_estimator),
#     825         X,
#     826         y,
#     827         train=train,
#     828         test=test,
#     829         parameters=parameters,
#     830         split_progress=(split_idx, n_splits),
#     831         candidate_progress=(cand_idx, n_candidates),
#     832         **fit_and_score_kwargs,
#     833     )
#     834     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     835         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     836     )
#     837 )
#     839 if len(out) < 1:
#     840     raise ValueError(
#     841         "No fits were performed. "
#     842         "Was the CV iterator empty? "
#     843         "Were there no candidates?"
#     844     )
#
# File c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\joblib\parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\utils\fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\model_selection\_validation.py:686, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684         estimator.fit(X_train, **fit_params)
#     685     else:
# --> 686         estimator.fit(X_train, y_train, **fit_params)
#     688 except Exception:
#     689     # Note fit time as time until error
#     690     fit_time = time.time() - start_time
#
# File c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\neighbors\_regression.py:217, in KNeighborsRegressor.fit(self, X, y)
#     198 """Fit the k-nearest neighbors regressor from the training dataset.
#     199
#     200 Parameters
#    (...)
#     213     The fitted k-nearest neighbors regressor.
#     214 """
#     215 self._validate_params()
# --> 217 return self._fit(X, y)
#
# File c:\Users\Roger\AppData\Local\miniconda3\envs\data_analytics\lib\site-packages\sklearn\neighbors\_base.py:646, in NeighborsBase._fit(self, X, y)
#     639         raise ValueError(
#     640             f'algorithm="{self._fit_method}" does not support 0 < p < 1 for '
#     641             "the Minkowski metric. To resolve this problem either "
#     642             'set p >= 1 or algorithm="brute".'
#     643         )
#     645 if self._fit_method == "ball_tree":
# --> 646     self._tree = BallTree(
#     647         X,
#     648         self.leaf_size,
#     649         metric=self.effective_metric_,
#     650         **self.effective_metric_params_,
#     651     )
#     652 elif self._fit_method == "kd_tree":
#     653     if (
#     654         self.effective_metric_ == "minkowski"
#     655         and self.effective_metric_params_.get("w") is not None
#     656     ):
#
# KeyboardInterrupt:

# %%
# Mejor puntuación para k vecinos
mean_squared_error(y_test, y_pred, squared=False)

# %% [markdown]
# ## "SVR"
#
# - Cambios: escalado "Standard", borrado, asignación, logaritmo, imputaciones "boxplot", sustitución y descarte correlación ínfima
#
# - Con cambios e hiperparámetros, "SVR" ha mejorado su "rmse" de 0.209064 a

# %%
df_svr = df_diamonds.copy()

df_svr = remove_all(df_svr)

df_svr = assign_values(df_svr)

df_svr[['weight (carat)', 'lenght (millimeters)', 'width (millimeters)', 'depth (millimeters)']] = np.log(df_svr[['weight (carat)', 'lenght (millimeters)', 'width (millimeters)', 'depth (millimeters)']])

df_svr = impute_boxplot_min_max(df_svr, ['depth (percentage)', 'table (percentage)'])

df_svr['depth (percentage)'] = (df_svr['depth (millimeters)'] / ((df_svr['lenght (millimeters)']+df_svr['width (millimeters)']) / 2)) * 100

df_svr = df_svr.drop(columns=['cut quality', 'depth (percentage)'])

# %%
svr = Regression(df_svr, 'price')
X_train, X_test, y_train, y_test = svr.split_dataframe(scaler='StandardScaler')
svr.apply_models(selected_list=['SVR'],
                        kfolds_num=10
                    )
svr.evaluate_metrics()
svr.create_dataframe()
# Out:
# -- Regression (StandardScaler): using best of 10 folds --
# Starting SVR:
# - SVR done in 607.84 sec(s). Total time: 607.84
#                SVR BEST WORST
# mae       0.767242  SVR   SVR
# mape      0.099959  SVR   SVR
# mse       0.936805  SVR   SVR
# r2_score  0.092578  SVR   SVR
# rmse      0.967887  SVR   SVR

# %%
# Como es lento, se empieza por probar solo los diferentes "kernels"
model = SVR()

params = {'kernel': ['linear', 'poly', 'rbf']
            }

grid = GridSearchCV(estimator = model,
                    param_grid = params,
                    scoring=rmse,
                    verbose=4,
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5] END ....................kernel=linear;, score=-0.994 total time=  53.1s
# [CV 2/5] END ....................kernel=linear;, score=-0.995 total time=  48.8s
# [CV 3/5] END ....................kernel=linear;, score=-0.965 total time= 1.1min
# [CV 4/5] END ....................kernel=linear;, score=-0.974 total time=  58.9s
# [CV 5/5] END ....................kernel=linear;, score=-0.975 total time=  46.5s
# [CV 1/5] END ......................kernel=poly;, score=-0.995 total time= 1.8min
# [CV 2/5] END ......................kernel=poly;, score=-0.999 total time=19.9min
# [CV 3/5] END ......................kernel=poly;, score=-0.974 total time=23.9min
# [CV 4/5] END ......................kernel=poly;, score=-0.982 total time=18.9min
# [CV 5/5] END ......................kernel=poly;, score=-0.985 total time= 1.4min
# [CV 1/5] END .......................kernel=rbf;, score=-0.977 total time=  51.0s
# [CV 2/5] END .......................kernel=rbf;, score=-0.985 total time=  51.4s
# [CV 3/5] END .......................kernel=rbf;, score=-0.958 total time=  51.3s
# [CV 4/5] END .......................kernel=rbf;, score=-0.958 total time=  51.8s
# [CV 5/5] END .......................kernel=rbf;, score=-0.964 total time=  51.6s
# Best score: -0.9685728197096537
# Best params: {'kernel': 'rbf'}

# %%
# "rbf" es el mejor y es bastante rápido. "poly" es tan lento que es inviable iterar con él
# Se prueba con varios "gamma" superiores al estándar
model = SVR()

params = {'kernel': ['rbf'],
            'gamma': range(10, 41),
            }

grid = GridSearchCV(estimator = model,
                    param_grid = params,
                    scoring=rmse,
                    verbose=4,
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
# Out:
# Fitting 5 folds for each of 31 candidates, totalling 155 fits
# [CV 1/5] END .............gamma=10, kernel=rbf;, score=-1.037 total time= 1.4min
# [CV 2/5] END .............gamma=10, kernel=rbf;, score=-1.044 total time= 1.4min
# [CV 3/5] END .............gamma=10, kernel=rbf;, score=-1.018 total time= 1.4min
# [CV 4/5] END .............gamma=10, kernel=rbf;, score=-1.015 total time= 1.4min
# [CV 5/5] END .............gamma=10, kernel=rbf;, score=-1.014 total time= 1.4min
# [CV 1/5] END .............gamma=11, kernel=rbf;, score=-1.038 total time= 1.4min
# [CV 2/5] END .............gamma=11, kernel=rbf;, score=-1.046 total time= 1.4min
# [CV 3/5] END .............gamma=11, kernel=rbf;, score=-1.019 total time= 1.4min
# [CV 4/5] END .............gamma=11, kernel=rbf;, score=-1.016 total time= 1.4min
# [CV 5/5] END .............gamma=11, kernel=rbf;, score=-1.015 total time= 1.4min
# [CV 1/5] END .............gamma=12, kernel=rbf;, score=-1.039 total time= 1.4min
# [CV 2/5] END .............gamma=12, kernel=rbf;, score=-1.047 total time= 1.4min
# [CV 3/5] END .............gamma=12, kernel=rbf;, score=-1.020 total time= 1.4min
# [CV 4/5] END .............gamma=12, kernel=rbf;, score=-1.018 total time= 1.5min
# [CV 5/5] END .............gamma=12, kernel=rbf;, score=-1.015 total time= 1.5min
# [CV 1/5] END .............gamma=13, kernel=rbf;, score=-1.040 total time= 1.5min
# [CV 2/5] END .............gamma=13, kernel=rbf;, score=-1.048 total time= 1.3min
# [CV 3/5] END .............gamma=13, kernel=rbf;, score=-1.020 total time= 1.4min
# [CV 4/5] END .............gamma=13, kernel=rbf;, score=-1.019 total time= 1.5min
# [CV 5/5] END .............gamma=13, kernel=rbf;, score=-1.016 total time= 1.6min
# [CV 1/5] END .............gamma=14, kernel=rbf;, score=-1.040 total time= 1.5min
# [CV 2/5] END .............gamma=14, kernel=rbf;, score=-1.049 total time= 1.5min
# [CV 3/5] END .............gamma=14, kernel=rbf;, score=-1.020 total time= 1.5min
# [CV 4/5] END .............gamma=14, kernel=rbf;, score=-1.019 total time= 1.5min
# [CV 5/5] END .............gamma=14, kernel=rbf;, score=-1.016 total time= 1.5min
# [CV 1/5] END .............gamma=15, kernel=rbf;, score=-1.041 total time= 1.5min
# [CV 2/5] END .............gamma=15, kernel=rbf;, score=-1.049 total time= 1.5min
# [CV 3/5] END .............gamma=15, kernel=rbf;, score=-1.021 total time= 1.5min
# [CV 4/5] END .............gamma=15, kernel=rbf;, score=-1.020 total time= 1.4min
# [CV 5/5] END .............gamma=15, kernel=rbf;, score=-1.016 total time= 1.5min
# [CV 1/5] END .............gamma=16, kernel=rbf;, score=-1.041 total time= 1.6min
# [CV 2/5] END .............gamma=16, kernel=rbf;, score=-1.050 total time= 1.5min
# [CV 3/5] END .............gamma=16, kernel=rbf;, score=-1.021 total time= 1.6min
# [CV 4/5] END .............gamma=16, kernel=rbf;, score=-1.021 total time= 2.3min
# [CV 5/5] END .............gamma=16, kernel=rbf;, score=-1.015 total time= 1.8min
# [CV 1/5] END .............gamma=17, kernel=rbf;, score=-1.041 total time= 1.6min
# [CV 2/5] END .............gamma=17, kernel=rbf;, score=-1.050 total time= 1.7min
# [CV 3/5] END .............gamma=17, kernel=rbf;, score=-1.021 total time= 1.8min
# [CV 4/5] END .............gamma=17, kernel=rbf;, score=-1.021 total time= 1.8min
# [CV 5/5] END .............gamma=17, kernel=rbf;, score=-1.015 total time= 1.7min
# [CV 1/5] END .............gamma=18, kernel=rbf;, score=-1.041 total time= 1.7min
# [CV 2/5] END .............gamma=18, kernel=rbf;, score=-1.051 total time= 1.7min
# [CV 3/5] END .............gamma=18, kernel=rbf;, score=-1.022 total time= 1.7min
# [CV 4/5] END .............gamma=18, kernel=rbf;, score=-1.021 total time= 1.6min
# [CV 5/5] END .............gamma=18, kernel=rbf;, score=-1.015 total time= 1.9min
# [CV 1/5] END .............gamma=19, kernel=rbf;, score=-1.042 total time= 1.6min
# [CV 2/5] END .............gamma=19, kernel=rbf;, score=-1.051 total time= 1.6min
# [CV 3/5] END .............gamma=19, kernel=rbf;, score=-1.022 total time= 1.9min
# [CV 4/5] END .............gamma=19, kernel=rbf;, score=-1.021 total time= 1.6min
# [CV 5/5] END .............gamma=19, kernel=rbf;, score=-1.015 total time= 1.5min
# [CV 1/5] END .............gamma=20, kernel=rbf;, score=-1.042 total time= 1.5min
# [CV 2/5] END .............gamma=20, kernel=rbf;, score=-1.052 total time= 1.5min
# [CV 3/5] END .............gamma=20, kernel=rbf;, score=-1.022 total time= 1.7min
# [CV 4/5] END .............gamma=20, kernel=rbf;, score=-1.021 total time= 1.9min
# [CV 5/5] END .............gamma=20, kernel=rbf;, score=-1.015 total time= 1.8min
# [CV 1/5] END .............gamma=21, kernel=rbf;, score=-1.042 total time= 1.9min
# [CV 2/5] END .............gamma=21, kernel=rbf;, score=-1.052 total time= 1.9min
# [CV 3/5] END .............gamma=21, kernel=rbf;, score=-1.023 total time= 1.9min
# [CV 4/5] END .............gamma=21, kernel=rbf;, score=-1.021 total time= 1.6min
# [CV 5/5] END .............gamma=21, kernel=rbf;, score=-1.015 total time= 1.6min
# [CV 1/5] END .............gamma=22, kernel=rbf;, score=-1.042 total time= 1.7min
# [CV 2/5] END .............gamma=22, kernel=rbf;, score=-1.053 total time= 1.7min
# [CV 3/5] END .............gamma=22, kernel=rbf;, score=-1.023 total time= 1.9min
# [CV 4/5] END .............gamma=22, kernel=rbf;, score=-1.021 total time= 1.8min
# [CV 5/5] END .............gamma=22, kernel=rbf;, score=-1.015 total time= 1.8min
# [CV 1/5] END .............gamma=23, kernel=rbf;, score=-1.042 total time= 1.7min
# [CV 2/5] END .............gamma=23, kernel=rbf;, score=-1.053 total time= 1.6min
# [CV 3/5] END .............gamma=23, kernel=rbf;, score=-1.023 total time= 1.7min
# [CV 4/5] END .............gamma=23, kernel=rbf;, score=-1.022 total time= 1.6min
# [CV 5/5] END .............gamma=23, kernel=rbf;, score=-1.015 total time= 1.7min
# [CV 1/5] END .............gamma=24, kernel=rbf;, score=-1.042 total time= 1.7min
# [CV 2/5] END .............gamma=24, kernel=rbf;, score=-1.053 total time= 1.7min
# [CV 3/5] END .............gamma=24, kernel=rbf;, score=-1.023 total time= 1.7min
# [CV 4/5] END .............gamma=24, kernel=rbf;, score=-1.022 total time= 1.7min
# [CV 5/5] END .............gamma=24, kernel=rbf;, score=-1.015 total time= 1.6min
# [CV 1/5] END .............gamma=25, kernel=rbf;, score=-1.042 total time= 2.0min
# [CV 2/5] END .............gamma=25, kernel=rbf;, score=-1.054 total time= 1.6min
# [CV 3/5] END .............gamma=25, kernel=rbf;, score=-1.024 total time= 1.6min
# [CV 4/5] END .............gamma=25, kernel=rbf;, score=-1.023 total time= 1.6min
# [CV 5/5] END .............gamma=25, kernel=rbf;, score=-1.016 total time= 1.6min
# [CV 1/5] END .............gamma=26, kernel=rbf;, score=-1.042 total time= 1.7min
# [CV 2/5] END .............gamma=26, kernel=rbf;, score=-1.054 total time= 1.6min
# [CV 3/5] END .............gamma=26, kernel=rbf;, score=-1.024 total time= 1.6min
# [CV 4/5] END .............gamma=26, kernel=rbf;, score=-1.023 total time= 1.7min
# [CV 5/5] END .............gamma=26, kernel=rbf;, score=-1.016 total time= 1.6min
# [CV 1/5] END .............gamma=27, kernel=rbf;, score=-1.042 total time= 1.7min
# [CV 2/5] END .............gamma=27, kernel=rbf;, score=-1.054 total time= 1.7min
# [CV 3/5] END .............gamma=27, kernel=rbf;, score=-1.024 total time= 1.7min
# [CV 4/5] END .............gamma=27, kernel=rbf;, score=-1.023 total time= 1.7min
# [CV 5/5] END .............gamma=27, kernel=rbf;, score=-1.016 total time= 1.7min
# [CV 1/5] END .............gamma=28, kernel=rbf;, score=-1.042 total time= 1.7min
# [CV 2/5] END .............gamma=28, kernel=rbf;, score=-1.054 total time= 1.7min
# [CV 3/5] END .............gamma=28, kernel=rbf;, score=-1.024 total time= 1.7min
# [CV 4/5] END .............gamma=28, kernel=rbf;, score=-1.024 total time= 1.7min
# [CV 5/5] END .............gamma=28, kernel=rbf;, score=-1.016 total time= 1.7min
# [CV 1/5] END .............gamma=29, kernel=rbf;, score=-1.042 total time= 1.7min
# [CV 2/5] END .............gamma=29, kernel=rbf;, score=-1.054 total time= 1.7min
# [CV 3/5] END .............gamma=29, kernel=rbf;, score=-1.024 total time= 1.7min
# [CV 4/5] END .............gamma=29, kernel=rbf;, score=-1.024 total time= 1.7min
# [CV 5/5] END .............gamma=29, kernel=rbf;, score=-1.016 total time= 1.7min
# [CV 1/5] END .............gamma=30, kernel=rbf;, score=-1.042 total time= 1.8min
# [CV 2/5] END .............gamma=30, kernel=rbf;, score=-1.054 total time= 1.8min
# [CV 3/5] END .............gamma=30, kernel=rbf;, score=-1.024 total time= 1.8min
# [CV 4/5] END .............gamma=30, kernel=rbf;, score=-1.024 total time= 1.7min
# [CV 5/5] END .............gamma=30, kernel=rbf;, score=-1.016 total time= 1.7min
# [CV 1/5] END .............gamma=31, kernel=rbf;, score=-1.042 total time= 1.7min
# [CV 2/5] END .............gamma=31, kernel=rbf;, score=-1.054 total time= 1.7min
# [CV 3/5] END .............gamma=31, kernel=rbf;, score=-1.024 total time= 1.7min
# [CV 4/5] END .............gamma=31, kernel=rbf;, score=-1.025 total time= 1.8min
# [CV 5/5] END .............gamma=31, kernel=rbf;, score=-1.016 total time= 1.6min
# [CV 1/5] END .............gamma=32, kernel=rbf;, score=-1.042 total time= 1.8min
# [CV 2/5] END .............gamma=32, kernel=rbf;, score=-1.055 total time= 1.8min
# [CV 3/5] END .............gamma=32, kernel=rbf;, score=-1.025 total time= 1.7min
# [CV 4/5] END .............gamma=32, kernel=rbf;, score=-1.025 total time= 1.8min
# [CV 5/5] END .............gamma=32, kernel=rbf;, score=-1.016 total time= 1.7min
# [CV 1/5] END .............gamma=33, kernel=rbf;, score=-1.042 total time= 1.8min
# [CV 2/5] END .............gamma=33, kernel=rbf;, score=-1.055 total time= 1.8min
# [CV 3/5] END .............gamma=33, kernel=rbf;, score=-1.025 total time= 1.8min
# [CV 4/5] END .............gamma=33, kernel=rbf;, score=-1.025 total time= 1.8min
# [CV 5/5] END .............gamma=33, kernel=rbf;, score=-1.016 total time= 1.8min
# [CV 1/5] END .............gamma=34, kernel=rbf;, score=-1.042 total time= 1.8min
# [CV 2/5] END .............gamma=34, kernel=rbf;, score=-1.055 total time= 1.8min
# [CV 3/5] END .............gamma=34, kernel=rbf;, score=-1.025 total time= 1.8min
# [CV 4/5] END .............gamma=34, kernel=rbf;, score=-1.026 total time= 1.8min
# [CV 5/5] END .............gamma=34, kernel=rbf;, score=-1.016 total time= 1.8min
# [CV 1/5] END .............gamma=35, kernel=rbf;, score=-1.042 total time= 1.9min
# [CV 2/5] END .............gamma=35, kernel=rbf;, score=-1.055 total time= 1.8min
# [CV 3/5] END .............gamma=35, kernel=rbf;, score=-1.025 total time= 1.8min
# [CV 4/5] END .............gamma=35, kernel=rbf;, score=-1.026 total time= 1.8min
# [CV 5/5] END .............gamma=35, kernel=rbf;, score=-1.016 total time= 1.8min
# [CV 1/5] END .............gamma=36, kernel=rbf;, score=-1.041 total time= 1.8min
# [CV 2/5] END .............gamma=36, kernel=rbf;, score=-1.055 total time= 1.8min
# [CV 3/5] END .............gamma=36, kernel=rbf;, score=-1.025 total time= 1.7min
# [CV 4/5] END .............gamma=36, kernel=rbf;, score=-1.026 total time= 1.9min
# [CV 5/5] END .............gamma=36, kernel=rbf;, score=-1.016 total time= 1.8min
# [CV 1/5] END .............gamma=37, kernel=rbf;, score=-1.041 total time= 1.9min
# [CV 2/5] END .............gamma=37, kernel=rbf;, score=-1.055 total time= 1.9min
# [CV 3/5] END .............gamma=37, kernel=rbf;, score=-1.025 total time= 1.9min
# [CV 4/5] END .............gamma=37, kernel=rbf;, score=-1.026 total time= 1.9min
# [CV 5/5] END .............gamma=37, kernel=rbf;, score=-1.016 total time= 1.9min
# [CV 1/5] END .............gamma=38, kernel=rbf;, score=-1.041 total time= 1.9min
# [CV 2/5] END .............gamma=38, kernel=rbf;, score=-1.056 total time= 1.9min
# [CV 3/5] END .............gamma=38, kernel=rbf;, score=-1.026 total time= 1.9min
# [CV 4/5] END .............gamma=38, kernel=rbf;, score=-1.027 total time= 1.9min
# [CV 5/5] END .............gamma=38, kernel=rbf;, score=-1.016 total time= 1.9min
# [CV 1/5] END .............gamma=39, kernel=rbf;, score=-1.041 total time= 1.9min
# [CV 2/5] END .............gamma=39, kernel=rbf;, score=-1.056 total time= 1.9min
# [CV 3/5] END .............gamma=39, kernel=rbf;, score=-1.026 total time= 1.9min
# [CV 4/5] END .............gamma=39, kernel=rbf;, score=-1.027 total time= 1.7min
# [CV 5/5] END .............gamma=39, kernel=rbf;, score=-1.016 total time= 1.9min
# [CV 1/5] END .............gamma=40, kernel=rbf;, score=-1.041 total time= 1.9min
# [CV 2/5] END .............gamma=40, kernel=rbf;, score=-1.056 total time= 1.9min
# [CV 3/5] END .............gamma=40, kernel=rbf;, score=-1.026 total time= 1.8min
# [CV 4/5] END .............gamma=40, kernel=rbf;, score=-1.027 total time= 1.7min
# [CV 5/5] END .............gamma=40, kernel=rbf;, score=-1.016 total time= 1.9min
# Best score: -1.0257922458088118
# Best params: {'gamma': 10, 'kernel': 'rbf'}

# %%
# Se prueba, también, con varios gamma inferiores al estándar. Este es el mejor "SVR" obtenido
model = SVR()

params = {'kernel': ['rbf'],
            'gamma': [0.0001, 0.0003, 0.0005, 0.0007, 0.001, 0.003, 0.005, 0.007, 0.01, 0.03, 0.05, 0.07, 0.1, 0.3, 0.5, 0.7, 1, 3 , 5, 7],
            }

grid = GridSearchCV(estimator = model,
                    param_grid = params,
                    scoring=rmse,
                    verbose=4,
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END .........gamma=0.0001, kernel=rbf;, score=-0.986 total time=  53.3s
# [CV 2/5] END .........gamma=0.0001, kernel=rbf;, score=-0.988 total time=  53.7s
# [CV 3/5] END .........gamma=0.0001, kernel=rbf;, score=-0.959 total time=  56.0s
# [CV 4/5] END .........gamma=0.0001, kernel=rbf;, score=-0.968 total time=  56.0s
# [CV 5/5] END .........gamma=0.0001, kernel=rbf;, score=-0.969 total time=  55.1s
# [CV 1/5] END .........gamma=0.0003, kernel=rbf;, score=-0.990 total time=  54.6s
# [CV 2/5] END .........gamma=0.0003, kernel=rbf;, score=-0.992 total time=  54.6s
# [CV 3/5] END .........gamma=0.0003, kernel=rbf;, score=-0.962 total time=  54.2s
# [CV 4/5] END .........gamma=0.0003, kernel=rbf;, score=-0.971 total time=  54.7s
# [CV 5/5] END .........gamma=0.0003, kernel=rbf;, score=-0.972 total time=  54.5s
# [CV 1/5] END .........gamma=0.0005, kernel=rbf;, score=-0.991 total time=  54.3s
# [CV 2/5] END .........gamma=0.0005, kernel=rbf;, score=-0.993 total time=  51.1s
# [CV 3/5] END .........gamma=0.0005, kernel=rbf;, score=-0.963 total time=  50.9s
# [CV 4/5] END .........gamma=0.0005, kernel=rbf;, score=-0.972 total time=  51.1s
# [CV 5/5] END .........gamma=0.0005, kernel=rbf;, score=-0.973 total time=  51.1s
# [CV 1/5] END .........gamma=0.0007, kernel=rbf;, score=-0.992 total time=  51.0s
# [CV 2/5] END .........gamma=0.0007, kernel=rbf;, score=-0.993 total time=  51.2s
# [CV 3/5] END .........gamma=0.0007, kernel=rbf;, score=-0.963 total time=  50.9s
# [CV 4/5] END .........gamma=0.0007, kernel=rbf;, score=-0.972 total time=  51.1s
# [CV 5/5] END .........gamma=0.0007, kernel=rbf;, score=-0.973 total time=  51.9s
# [CV 1/5] END ..........gamma=0.001, kernel=rbf;, score=-0.992 total time=  54.2s
# [CV 2/5] END ..........gamma=0.001, kernel=rbf;, score=-0.993 total time= 1.2min
# [CV 3/5] END ..........gamma=0.001, kernel=rbf;, score=-0.963 total time= 1.3min
# [CV 4/5] END ..........gamma=0.001, kernel=rbf;, score=-0.972 total time=  56.0s
# [CV 5/5] END ..........gamma=0.001, kernel=rbf;, score=-0.973 total time=  54.7s
# [CV 1/5] END ..........gamma=0.003, kernel=rbf;, score=-0.990 total time=  56.9s
# [CV 2/5] END ..........gamma=0.003, kernel=rbf;, score=-0.992 total time=  56.7s
# [CV 3/5] END ..........gamma=0.003, kernel=rbf;, score=-0.961 total time=  55.1s
# [CV 4/5] END ..........gamma=0.003, kernel=rbf;, score=-0.970 total time=  53.9s
# [CV 5/5] END ..........gamma=0.003, kernel=rbf;, score=-0.971 total time=  52.9s
# [CV 1/5] END ..........gamma=0.005, kernel=rbf;, score=-0.989 total time=  52.8s
# [CV 2/5] END ..........gamma=0.005, kernel=rbf;, score=-0.991 total time=  53.7s
# [CV 3/5] END ..........gamma=0.005, kernel=rbf;, score=-0.960 total time=  53.0s
# [CV 4/5] END ..........gamma=0.005, kernel=rbf;, score=-0.969 total time=  56.8s
# [CV 5/5] END ..........gamma=0.005, kernel=rbf;, score=-0.971 total time=  54.6s
# [CV 1/5] END ..........gamma=0.007, kernel=rbf;, score=-0.988 total time=  49.8s
# [CV 2/5] END ..........gamma=0.007, kernel=rbf;, score=-0.991 total time=  49.6s
# [CV 3/5] END ..........gamma=0.007, kernel=rbf;, score=-0.960 total time=  49.0s
# [CV 4/5] END ..........gamma=0.007, kernel=rbf;, score=-0.969 total time=  49.2s
# [CV 5/5] END ..........gamma=0.007, kernel=rbf;, score=-0.970 total time=  49.4s
# [CV 1/5] END ...........gamma=0.01, kernel=rbf;, score=-0.988 total time=  49.6s
# [CV 2/5] END ...........gamma=0.01, kernel=rbf;, score=-0.990 total time=  51.1s
# [CV 3/5] END ...........gamma=0.01, kernel=rbf;, score=-0.959 total time=  51.1s
# [CV 4/5] END ...........gamma=0.01, kernel=rbf;, score=-0.968 total time=  50.4s
# [CV 5/5] END ...........gamma=0.01, kernel=rbf;, score=-0.970 total time=  50.9s
# [CV 1/5] END ...........gamma=0.03, kernel=rbf;, score=-0.986 total time=  51.3s
# [CV 2/5] END ...........gamma=0.03, kernel=rbf;, score=-0.990 total time=  52.3s
# [CV 3/5] END ...........gamma=0.03, kernel=rbf;, score=-0.960 total time=  51.0s
# [CV 4/5] END ...........gamma=0.03, kernel=rbf;, score=-0.968 total time=  51.2s
# [CV 5/5] END ...........gamma=0.03, kernel=rbf;, score=-0.968 total time=  51.6s
# [CV 1/5] END ...........gamma=0.05, kernel=rbf;, score=-0.985 total time=  50.6s
# [CV 2/5] END ...........gamma=0.05, kernel=rbf;, score=-0.990 total time=  51.1s
# [CV 3/5] END ...........gamma=0.05, kernel=rbf;, score=-0.961 total time=  51.9s
# [CV 4/5] END ...........gamma=0.05, kernel=rbf;, score=-0.967 total time=  51.3s
# [CV 5/5] END ...........gamma=0.05, kernel=rbf;, score=-0.968 total time=  51.4s
# [CV 1/5] END ...........gamma=0.07, kernel=rbf;, score=-0.983 total time=  51.8s
# [CV 2/5] END ...........gamma=0.07, kernel=rbf;, score=-0.990 total time=  51.9s
# [CV 3/5] END ...........gamma=0.07, kernel=rbf;, score=-0.961 total time=  51.5s
# [CV 4/5] END ...........gamma=0.07, kernel=rbf;, score=-0.966 total time=  51.5s
# [CV 5/5] END ...........gamma=0.07, kernel=rbf;, score=-0.967 total time=  51.2s
# [CV 1/5] END ............gamma=0.1, kernel=rbf;, score=-0.981 total time=  51.7s
# [CV 2/5] END ............gamma=0.1, kernel=rbf;, score=-0.989 total time=  51.8s
# [CV 3/5] END ............gamma=0.1, kernel=rbf;, score=-0.961 total time=  52.6s
# [CV 4/5] END ............gamma=0.1, kernel=rbf;, score=-0.964 total time=  51.7s
# [CV 5/5] END ............gamma=0.1, kernel=rbf;, score=-0.966 total time=  52.0s
# [CV 1/5] END ............gamma=0.3, kernel=rbf;, score=-0.975 total time=  51.3s
# [CV 2/5] END ............gamma=0.3, kernel=rbf;, score=-0.984 total time=  51.8s
# [CV 3/5] END ............gamma=0.3, kernel=rbf;, score=-0.958 total time=  52.3s
# [CV 4/5] END ............gamma=0.3, kernel=rbf;, score=-0.956 total time=  52.6s
# [CV 5/5] END ............gamma=0.3, kernel=rbf;, score=-0.964 total time=  52.5s
# [CV 1/5] END ............gamma=0.5, kernel=rbf;, score=-0.975 total time=  53.2s
# [CV 2/5] END ............gamma=0.5, kernel=rbf;, score=-0.987 total time=  52.8s
# [CV 3/5] END ............gamma=0.5, kernel=rbf;, score=-0.960 total time=  52.3s
# [CV 4/5] END ............gamma=0.5, kernel=rbf;, score=-0.959 total time=  53.7s
# [CV 5/5] END ............gamma=0.5, kernel=rbf;, score=-0.967 total time=  52.9s
# [CV 1/5] END ............gamma=0.7, kernel=rbf;, score=-0.978 total time=  54.3s
# [CV 2/5] END ............gamma=0.7, kernel=rbf;, score=-0.992 total time=  53.0s
# [CV 3/5] END ............gamma=0.7, kernel=rbf;, score=-0.964 total time=  53.9s
# [CV 4/5] END ............gamma=0.7, kernel=rbf;, score=-0.963 total time=  54.7s
# [CV 5/5] END ............gamma=0.7, kernel=rbf;, score=-0.971 total time=  53.6s
# [CV 1/5] END ..............gamma=1, kernel=rbf;, score=-0.984 total time=  55.3s
# [CV 2/5] END ..............gamma=1, kernel=rbf;, score=-0.997 total time=  54.8s
# [CV 3/5] END ..............gamma=1, kernel=rbf;, score=-0.969 total time=  54.0s
# [CV 4/5] END ..............gamma=1, kernel=rbf;, score=-0.968 total time=  54.9s
# [CV 5/5] END ..............gamma=1, kernel=rbf;, score=-0.975 total time=  54.7s
# [CV 1/5] END ..............gamma=3, kernel=rbf;, score=-1.013 total time= 1.3min
# [CV 2/5] END ..............gamma=3, kernel=rbf;, score=-1.028 total time= 1.2min
# [CV 3/5] END ..............gamma=3, kernel=rbf;, score=-0.993 total time= 1.2min
# [CV 4/5] END ..............gamma=3, kernel=rbf;, score=-0.991 total time= 1.2min
# [CV 5/5] END ..............gamma=3, kernel=rbf;, score=-0.996 total time= 1.2min
# [CV 1/5] END ..............gamma=5, kernel=rbf;, score=-1.027 total time= 1.2min
# [CV 2/5] END ..............gamma=5, kernel=rbf;, score=-1.037 total time= 1.3min
# [CV 3/5] END ..............gamma=5, kernel=rbf;, score=-1.006 total time= 1.3min
# [CV 4/5] END ..............gamma=5, kernel=rbf;, score=-1.003 total time= 1.3min
# [CV 5/5] END ..............gamma=5, kernel=rbf;, score=-1.005 total time= 1.3min
# [CV 1/5] END ..............gamma=7, kernel=rbf;, score=-1.033 total time= 1.4min
# [CV 2/5] END ..............gamma=7, kernel=rbf;, score=-1.041 total time= 1.4min
# [CV 3/5] END ..............gamma=7, kernel=rbf;, score=-1.014 total time= 1.4min
# [CV 4/5] END ..............gamma=7, kernel=rbf;, score=-1.010 total time= 1.3min
# [CV 5/5] END ..............gamma=7, kernel=rbf;, score=-1.011 total time= 1.4min
# Best score: -0.9675853828459082
# Best params: {'gamma': 0.3, 'kernel': 'rbf'}

# %%
# Mejor puntuación para "SVR"
mean_squared_error(y_test, y_pred, squared=False)

# %% [markdown]
# ## "DecisionTree"
#
# - Cambios: borrado, logaritmo, imputaciones "ridge" y descarte correlación ínfima
#
# - Como hay que aplicar el logaritmo y la asignación no mejora los resultados, se usa una asignación parcial que imputa los valores 0 pero no afecta a los "outliers"
#
# - Con cambios e hiperparámetros, "DecisionTree" ha mejorado su "rmse" de 0.130142 a

# %%
df_tree = df_diamonds.copy()

df_tree = remove_all(df_tree)

df_tree = assign_values(df_tree, outlier=False)

df_tree[['weight (carat)', 'lenght (millimeters)', 'width (millimeters)', 'depth (millimeters)']] = np.log(df_tree[['weight (carat)', 'lenght (millimeters)', 'width (millimeters)', 'depth (millimeters)']])

df_tree = apply_ridge(df_tree)

df_tree = df_tree.drop(columns=['cut quality', 'depth (percentage)'])

# %%
tree = Regression(df_tree, 'price')
X_train, X_test, y_train, y_test = tree.split_dataframe()
tree.apply_models(selected_list=['DecisionTreeRegressor'],
                    params_list=[['DecisionTreeRegressor', 'random_state=43']],
                        kfolds_num=10
                    )
tree.evaluate_metrics()
tree.create_dataframe()

# %%
# Se usa el "grid"
# En una segunda vuelta se miran los hiperparámentros "max_depth" y "min_samples_split", que están relacionados
model = DecisionTreeRegressor()

params = {'criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
            'splitter': ['best', 'random'],
            'max_features': ['auto', 'sqrt', 'log2'],
            'min_samples_leaf': range(1, 11)
            }

grid = GridSearchCV(estimator = model,
                    param_grid = params,
                    scoring=rmse,
                    verbose=4
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')

# %%
# Mejor puntuación para "DecisionTree"
mean_squared_error(y_test, y_pred, squared=False)

# %% [markdown]
# ## "RandomForest"
#
# - Cambios: borrado, asignación y sustitución
#
# - Con cambios e hiperparámetros, "RandomForest" ha mejorado su "rmse" de 0.098101 a

# %%
df_forest = df_diamonds.copy()

df_forest = remove_all(df_forest)

df_forest = assign_values(df_forest)

df_forest['depth (percentage)'] = (df_forest['depth (millimeters)'] / ((df_forest['lenght (millimeters)']+df_forest['width (millimeters)']) / 2)) * 100

# %%
forest = Regression(df_forest, 'price')
X_train, X_test, y_train, y_test = forest.split_dataframe()
forest.apply_models(selected_list=['RandomForestRegressor'],
                    params_list=[['RandomForestRegressor', 'random_state=43']],
                        kfolds_num=10
                    )
forest.evaluate_metrics()
forest.create_dataframe()

# %%
# En una segunda vuelta se miran los hiperparámentros "max_depth" y "min_samples_split", que están relacionados
# En una tercera vuelta se prueba con "boolstrap=True"
model = RandomForestRegressor()

params = {'criterion': ['gini', 'entropy', 'log_loss'],
            'max_features': ['sqrt', 'log2', None],
            'min_samples_leaf': range(1, 11),
            'oob_score': [True, False]
            }

grid = GridSearchCV(estimator = model,
                    param_grid = params,
                    scoring=rmse,
                    verbose=4
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')

# %%
# Mejor puntuación para "RandomForest"
mean_squared_error(y_test, y_pred, squared=False)

# %% [markdown]
# ## "XGBRegressor"
#
# - Cambios: escalado "standard", borrado, asignación e imputaciones "boxplot"
#
# - Con cambios e hiperparámetros, "XGBRegressor" ha mejorado su "rmse" de 0.094787 a

# %%
df_xgb = df_diamonds.copy()

df_xgb = remove_all(df_xgb)

df_xgb = assign_values(df_xgb)

df_xgb = impute_boxplot_min_max(df_xgb, ['depth (percentage)', 'table (percentage)'])

# %%
forest = Regression(df_forest, 'price')
X_train, X_test, y_train, y_test = forest.split_dataframe()
forest.apply_models(selected_list=['XGBRegressor'],
                    params_list=[['XGBRegressor', 'random_state=43']],
                        kfolds_num=10
                    )
forest.evaluate_metrics()
forest.create_dataframe()

# %%
model = XGBRegressor()

params = {
            }

grid = GridSearchCV(estimator = model,
                    param_grid = params,
                    scoring=rmse,
                    verbose=4
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')

# %%
# Mejor puntuación para "XGBRegressor"
mean_squared_error(y_test, y_pred, squared=False)
