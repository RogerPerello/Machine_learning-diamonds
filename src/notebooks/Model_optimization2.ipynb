# %%
import os

from sklearn.model_selection import GridSearchCV

from sklearn.metrics import make_scorer

if str(os.getcwdb()[-3:]).split("'")[1] != 'src':
    os.chdir(os.path.dirname(os.getcwdb()))

from utils.modeling import *
from utils.functions import *

# %%
df_diamonds = pd.read_csv(r'data\processed\diamonds_training.csv', index_col='id')
df_predict = pd.read_csv(r'data\processed\diamonds_testing.csv', index_col='id')

# %%
Regression.add_models(['XGBRegressor'])

rmse = make_scorer(calculate_rmse, greater_is_better=False)

kfolds = KFold(n_splits=5, shuffle=True, random_state=43)

# %% [markdown]
# # Introducción
#
# - Como se ha visto en "Feature_engineering", el mejor modelo a aplicar es "XGBRegressor"
#
# - Si bien se le ha sacado bastante partido con varios parámetros, aún quedan muchas combinaciones por probar
#
# - A continuación, se experimenta de forma extensiva con este modelo con tal de obtener los mejores resultados posibles

# %% [markdown]
# # Ronda 1: base
# - Esta primera ronda se lleva a cabo solo para poder ir comparando las mejoras

# %%
df_1 = df_diamonds.copy()

round_1 = Regression(df_diamonds, 'price')
X_train, X_test, y_train, y_test = round_1.split_dataframe()
round_1.prepare_models(params_list=[['XGBRegressor', 'random_state=43']])
round_1.apply_and_evaluate_kfolds()
round_1.create_dataframe()
# Out:
# -- Regression: using mean of 5 folds --
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 9.3 sec(s). Total time: 9.3
#           XGBRegressor: random_state=43
# mae                            0.065596
# mape                           0.008468
# mse                            0.008247
# r2_score                       0.991976
# rmse                           0.090762

# %% [markdown]
# # Ronda 2: solo cambios
#
# - Similar a la anterior, esta ronda sirve de punto de partida

# %%
df_cambios = df_diamonds.copy()

df_cambios = remove_all(df_cambios, zeros_only=True)

df_cambios = assign_values(df_cambios, outlier=False)

df_2 = df_cambios.copy()

round_2 = Regression(df_2, 'price')
X_train, X_test, y_train, y_test = round_2.split_dataframe()
round_2.prepare_models(params_list=[['XGBRegressor', 'random_state=43']])
round_2.apply_and_evaluate_kfolds()
round_2.create_dataframe()
# Out:
# -- Regression: using mean of 5 folds --
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 6.43 sec(s). Total time: 6.43
#           XGBRegressor: random_state=43
# mae                            0.065675
# mape                           0.008483
# mse                            0.008221
# r2_score                       0.992033
# rmse                           0.090657

# %% [markdown]
# # Ronda 3: "eta"
#
# - Como el "dataset" no es muy grande, se reduce el "learning rate" (por defecto, 3) todo lo posible
# - Dado que durante el "feature engineering" ha salido un "eta" de 1, se mira alrededor de ese número

# %%
model = XGBRegressor(n_estimators=1000, random_state=43)

model.early_stopping_rounds = 300

model.fit(X_train, y_train, eval_set=[(X_test, y_test)]) 

model.best_ntree_limit
# Out:
# [0]	validation_0-rmse:5.15340
# [1]	validation_0-rmse:3.61090
# [2]	validation_0-rmse:2.53117
# [3]	validation_0-rmse:1.77563
# [4]	validation_0-rmse:1.24698
# [5]	validation_0-rmse:0.87780
# [6]	validation_0-rmse:0.62082
# [7]	validation_0-rmse:0.44256
# [8]	validation_0-rmse:0.32017
# [9]	validation_0-rmse:0.23730
# [10]	validation_0-rmse:0.18313
# [11]	validation_0-rmse:0.14890
# [12]	validation_0-rmse:0.12836
# [13]	validation_0-rmse:0.11667
# [14]	validation_0-rmse:0.10953
# [15]	validation_0-rmse:0.10557
# [16]	validation_0-rmse:0.10331
# [17]	validation_0-rmse:0.10162
# [18]	validation_0-rmse:0.10088
# [19]	validation_0-rmse:0.10018
# [20]	validation_0-rmse:0.09962
# [21]	validation_0-rmse:0.09922
# [22]	validation_0-rmse:0.09867
# [23]	validation_0-rmse:0.09845
# [24]	validation_0-rmse:0.09814
# [25]	validation_0-rmse:0.09774
# [26]	validation_0-rmse:0.09759
# [27]	validation_0-rmse:0.09737
# [28]	validation_0-rmse:0.09688
# [29]	validation_0-rmse:0.09675
# [30]	validation_0-rmse:0.09661
# [31]	validation_0-rmse:0.09601
# [32]	validation_0-rmse:0.09573
# [33]	validation_0-rmse:0.09559
# [34]	validation_0-rmse:0.09553
# [35]	validation_0-rmse:0.09540
# [36]	validation_0-rmse:0.09517
# [37]	validation_0-rmse:0.09506
# [38]	validation_0-rmse:0.09448
# [39]	validation_0-rmse:0.09440
# [40]	validation_0-rmse:0.09438
# [41]	validation_0-rmse:0.09422
# [42]	validation_0-rmse:0.09420
# [43]	validation_0-rmse:0.09419
# [44]	validation_0-rmse:0.09411
# [45]	validation_0-rmse:0.09415
# [46]	validation_0-rmse:0.09401
# [47]	validation_0-rmse:0.09401
# [48]	validation_0-rmse:0.09379
# [49]	validation_0-rmse:0.09371
# [50]	validation_0-rmse:0.09348
# [51]	validation_0-rmse:0.09320
# [52]	validation_0-rmse:0.09300
# [53]	validation_0-rmse:0.09290
# [54]	validation_0-rmse:0.09272
# [55]	validation_0-rmse:0.09271
# [56]	validation_0-rmse:0.09270
# [57]	validation_0-rmse:0.09258
# [58]	validation_0-rmse:0.09247
# [59]	validation_0-rmse:0.09243
# [60]	validation_0-rmse:0.09243
# [61]	validation_0-rmse:0.09226
# [62]	validation_0-rmse:0.09216
# [63]	validation_0-rmse:0.09215
# [64]	validation_0-rmse:0.09215
# [65]	validation_0-rmse:0.09215
# [66]	validation_0-rmse:0.09207
# [67]	validation_0-rmse:0.09197
# [68]	validation_0-rmse:0.09178
# [69]	validation_0-rmse:0.09179
# [70]	validation_0-rmse:0.09174
# [71]	validation_0-rmse:0.09170
# [72]	validation_0-rmse:0.09160
# [73]	validation_0-rmse:0.09154
# [74]	validation_0-rmse:0.09146
# [75]	validation_0-rmse:0.09146
# [76]	validation_0-rmse:0.09144
# [77]	validation_0-rmse:0.09141
# [78]	validation_0-rmse:0.09128
# [79]	validation_0-rmse:0.09132
# [80]	validation_0-rmse:0.09133
# [81]	validation_0-rmse:0.09137
# [82]	validation_0-rmse:0.09137
# [83]	validation_0-rmse:0.09136
# [84]	validation_0-rmse:0.09133
# [85]	validation_0-rmse:0.09130
# [86]	validation_0-rmse:0.09126
# [87]	validation_0-rmse:0.09125
# [88]	validation_0-rmse:0.09121
# [89]	validation_0-rmse:0.09114
# [90]	validation_0-rmse:0.09103
# [91]	validation_0-rmse:0.09098
# [92]	validation_0-rmse:0.09097
# [93]	validation_0-rmse:0.09100
# [94]	validation_0-rmse:0.09102
# [95]	validation_0-rmse:0.09102
# [96]	validation_0-rmse:0.09100
# [97]	validation_0-rmse:0.09091
# [98]	validation_0-rmse:0.09089
# [99]	validation_0-rmse:0.09080
# [100]	validation_0-rmse:0.09078
# [101]	validation_0-rmse:0.09075
# [102]	validation_0-rmse:0.09071
# [103]	validation_0-rmse:0.09053
# [104]	validation_0-rmse:0.09052
# [105]	validation_0-rmse:0.09049
# [106]	validation_0-rmse:0.09045
# [107]	validation_0-rmse:0.09044
# [108]	validation_0-rmse:0.09043
# [109]	validation_0-rmse:0.09040
# [110]	validation_0-rmse:0.09039
# [111]	validation_0-rmse:0.09041
# [112]	validation_0-rmse:0.09043
# [113]	validation_0-rmse:0.09043
# [114]	validation_0-rmse:0.09041
# [115]	validation_0-rmse:0.09037
# [116]	validation_0-rmse:0.09039
# [117]	validation_0-rmse:0.09036
# [118]	validation_0-rmse:0.09036
# [119]	validation_0-rmse:0.09034
# [120]	validation_0-rmse:0.09036
# [121]	validation_0-rmse:0.09036
# [122]	validation_0-rmse:0.09035
# [123]	validation_0-rmse:0.09038
# [124]	validation_0-rmse:0.09035
# [125]	validation_0-rmse:0.09036
# [126]	validation_0-rmse:0.09037
# [127]	validation_0-rmse:0.09041
# [128]	validation_0-rmse:0.09040
# [129]	validation_0-rmse:0.09037
# [130]	validation_0-rmse:0.09039
# [131]	validation_0-rmse:0.09040
# [132]	validation_0-rmse:0.09039
# [133]	validation_0-rmse:0.09040
# [134]	validation_0-rmse:0.09039
# [135]	validation_0-rmse:0.09041
# [136]	validation_0-rmse:0.09040
# [137]	validation_0-rmse:0.09039
# [138]	validation_0-rmse:0.09044
# [139]	validation_0-rmse:0.09044
# [140]	validation_0-rmse:0.09044
# [141]	validation_0-rmse:0.09040
# [142]	validation_0-rmse:0.09042
# [143]	validation_0-rmse:0.09038
# [144]	validation_0-rmse:0.09029
# [145]	validation_0-rmse:0.09030
# [146]	validation_0-rmse:0.09025
# [147]	validation_0-rmse:0.09023
# [148]	validation_0-rmse:0.09018
# [149]	validation_0-rmse:0.09013
# [150]	validation_0-rmse:0.09012
# [151]	validation_0-rmse:0.09011
# [152]	validation_0-rmse:0.09012
# [153]	validation_0-rmse:0.09010
# [154]	validation_0-rmse:0.09014
# [155]	validation_0-rmse:0.09016
# [156]	validation_0-rmse:0.09014
# [157]	validation_0-rmse:0.09012
# [158]	validation_0-rmse:0.09013
# [159]	validation_0-rmse:0.09014
# [160]	validation_0-rmse:0.09014
# [161]	validation_0-rmse:0.09014
# [162]	validation_0-rmse:0.09008
# [163]	validation_0-rmse:0.09008
# [164]	validation_0-rmse:0.09007
# [165]	validation_0-rmse:0.09010
# [166]	validation_0-rmse:0.09010
# [167]	validation_0-rmse:0.09008
# [168]	validation_0-rmse:0.09004
# [169]	validation_0-rmse:0.09005
# [411]	validation_0-rmse:0.09070
# [412]	validation_0-rmse:0.09071
# [413]	validation_0-rmse:0.09073
# [414]	validation_0-rmse:0.09075
# [415]	validation_0-rmse:0.09077
# [416]	validation_0-rmse:0.09078
# [417]	validation_0-rmse:0.09079
# [418]	validation_0-rmse:0.09078
# [419]	validation_0-rmse:0.09077
# [420]	validation_0-rmse:0.09078
# [421]	validation_0-rmse:0.09078
# [422]	validation_0-rmse:0.09078
# [423]	validation_0-rmse:0.09079
# [424]	validation_0-rmse:0.09079
# [425]	validation_0-rmse:0.09080
# [426]	validation_0-rmse:0.09081
# [427]	validation_0-rmse:0.09082
# [428]	validation_0-rmse:0.09087
# [429]	validation_0-rmse:0.09087
# [430]	validation_0-rmse:0.09087
# [431]	validation_0-rmse:0.09087
# [432]	validation_0-rmse:0.09088
# [433]	validation_0-rmse:0.09088
# [434]	validation_0-rmse:0.09089
# [435]	validation_0-rmse:0.09089
# [436]	validation_0-rmse:0.09089
# [437]	validation_0-rmse:0.09090
# [438]	validation_0-rmse:0.09092
# [439]	validation_0-rmse:0.09091
# [440]	validation_0-rmse:0.09092
# [441]	validation_0-rmse:0.09092
# [442]	validation_0-rmse:0.09094
# [443]	validation_0-rmse:0.09093
# [444]	validation_0-rmse:0.09091
# [445]	validation_0-rmse:0.09091
# [446]	validation_0-rmse:0.09090
# [447]	validation_0-rmse:0.09090
# [448]	validation_0-rmse:0.09089
# [449]	validation_0-rmse:0.09088
# [450]	validation_0-rmse:0.09088
# [451]	validation_0-rmse:0.09088
# [452]	validation_0-rmse:0.09089
# [453]	validation_0-rmse:0.09090
# [454]	validation_0-rmse:0.09090
# [455]	validation_0-rmse:0.09090
# [456]	validation_0-rmse:0.09090
# [457]	validation_0-rmse:0.09090
# [458]	validation_0-rmse:0.09090
# [459]	validation_0-rmse:0.09089
# [460]	validation_0-rmse:0.09089
# [461]	validation_0-rmse:0.09090
# [462]	validation_0-rmse:0.09090
# [463]	validation_0-rmse:0.09090
# [464]	validation_0-rmse:0.09090
# [465]	validation_0-rmse:0.09090
# [466]	validation_0-rmse:0.09090
# [467]	validation_0-rmse:0.09091
# [468]	validation_0-rmse:0.09091
# [469]	validation_0-rmse:0.09092
# [470]	validation_0-rmse:0.09093
# [471]	validation_0-rmse:0.09094
# [472]	validation_0-rmse:0.09094
# [473]	validation_0-rmse:0.09094
# [474]	validation_0-rmse:0.09095
# [475]	validation_0-rmse:0.09093
# [476]	validation_0-rmse:0.09094
# [477]	validation_0-rmse:0.09095
# [478]	validation_0-rmse:0.09096
# [479]	validation_0-rmse:0.09097
# [480]	validation_0-rmse:0.09097
# [481]	validation_0-rmse:0.09097
# [482]	validation_0-rmse:0.09098
# [483]	validation_0-rmse:0.09099
# [484]	validation_0-rmse:0.09100
# [485]	validation_0-rmse:0.09099
# [486]	validation_0-rmse:0.09099
# [487]	validation_0-rmse:0.09100
# [488]	validation_0-rmse:0.09100
# [489]	validation_0-rmse:0.09100
# [490]	validation_0-rmse:0.09100
# [491]	validation_0-rmse:0.09101
# [492]	validation_0-rmse:0.09099
# [493]	validation_0-rmse:0.09099
# [494]	validation_0-rmse:0.09099
# [495]	validation_0-rmse:0.09099
# 196

# %%
model = XGBRegressor()

params = {'random_state': [43],
          'n_estimators': [195],
          'eta': [0.1, 0.125, 0.15, 0.175, 0.2],
            }

grid = GridSearchCV(estimator=model,
                    param_grid=params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5] END eta=0.1, n_estimators=195, random_state=43;, score=-0.092 total time=   2.3s
# [CV 2/5] END eta=0.1, n_estimators=195, random_state=43;, score=-0.091 total time=   1.8s
# [CV 3/5] END eta=0.1, n_estimators=195, random_state=43;, score=-0.087 total time=   1.8s
# [CV 4/5] END eta=0.1, n_estimators=195, random_state=43;, score=-0.087 total time=   2.0s
# [CV 5/5] END eta=0.1, n_estimators=195, random_state=43;, score=-0.089 total time=   1.8s
# [CV 1/5] END eta=0.125, n_estimators=195, random_state=43;, score=-0.091 total time=   2.3s
# [CV 2/5] END eta=0.125, n_estimators=195, random_state=43;, score=-0.091 total time=   2.6s
# [CV 3/5] END eta=0.125, n_estimators=195, random_state=43;, score=-0.087 total time=   2.5s
# [CV 4/5] END eta=0.125, n_estimators=195, random_state=43;, score=-0.088 total time=   2.8s
# [CV 5/5] END eta=0.125, n_estimators=195, random_state=43;, score=-0.088 total time=   1.9s
# [CV 1/5] END eta=0.15, n_estimators=195, random_state=43;, score=-0.091 total time=   2.7s
# [CV 2/5] END eta=0.15, n_estimators=195, random_state=43;, score=-0.090 total time=   2.2s
# [CV 3/5] END eta=0.15, n_estimators=195, random_state=43;, score=-0.088 total time=   2.7s
# [CV 4/5] END eta=0.15, n_estimators=195, random_state=43;, score=-0.087 total time=   2.3s
# [CV 5/5] END eta=0.15, n_estimators=195, random_state=43;, score=-0.088 total time=   2.5s
# [CV 1/5] END eta=0.175, n_estimators=195, random_state=43;, score=-0.092 total time=   2.7s
# [CV 2/5] END eta=0.175, n_estimators=195, random_state=43;, score=-0.091 total time=   1.9s
# [CV 3/5] END eta=0.175, n_estimators=195, random_state=43;, score=-0.087 total time=   1.8s
# [CV 4/5] END eta=0.175, n_estimators=195, random_state=43;, score=-0.088 total time=   2.2s
# [CV 5/5] END eta=0.175, n_estimators=195, random_state=43;, score=-0.089 total time=   4.1s
# [CV 1/5] END eta=0.2, n_estimators=195, random_state=43;, score=-0.092 total time=   4.7s
# [CV 2/5] END eta=0.2, n_estimators=195, random_state=43;, score=-0.092 total time=   1.9s
# [CV 3/5] END eta=0.2, n_estimators=195, random_state=43;, score=-0.087 total time=   1.8s
# [CV 4/5] END eta=0.2, n_estimators=195, random_state=43;, score=-0.089 total time=   1.8s
# [CV 5/5] END eta=0.2, n_estimators=195, random_state=43;, score=-0.089 total time=   1.8s
# Best params: {'eta': 0.15, 'n_estimators': 195, 'random_state': 43}
# Best score: -0.08897079731883958

# %%
model = XGBRegressor(n_estimators=1000, eta=0.15)

model.early_stopping_rounds = 300

model.fit(X_train, y_train, eval_set=[(X_test, y_test)]) 

model.best_ntree_limit
# Out:
# [0]	validation_0-rmse:6.25481
# [1]	validation_0-rmse:5.31758
# [2]	validation_0-rmse:4.52146
# [3]	validation_0-rmse:3.84486
# [4]	validation_0-rmse:3.26999
# [5]	validation_0-rmse:2.78099
# [6]	validation_0-rmse:2.36548
# [7]	validation_0-rmse:2.01256
# [8]	validation_0-rmse:1.71259
# [9]	validation_0-rmse:1.45772
# [10]	validation_0-rmse:1.24104
# [11]	validation_0-rmse:1.05718
# [12]	validation_0-rmse:0.90112
# [13]	validation_0-rmse:0.76859
# [14]	validation_0-rmse:0.65630
# [15]	validation_0-rmse:0.56107
# [16]	validation_0-rmse:0.48058
# [17]	validation_0-rmse:0.41249
# [18]	validation_0-rmse:0.35531
# [19]	validation_0-rmse:0.30726
# [20]	validation_0-rmse:0.26704
# [21]	validation_0-rmse:0.23362
# [22]	validation_0-rmse:0.20596
# [23]	validation_0-rmse:0.18320
# [24]	validation_0-rmse:0.16485
# [25]	validation_0-rmse:0.14995
# [26]	validation_0-rmse:0.13801
# [27]	validation_0-rmse:0.12861
# [28]	validation_0-rmse:0.12114
# [29]	validation_0-rmse:0.11550
# [30]	validation_0-rmse:0.11118
# [31]	validation_0-rmse:0.10787
# [32]	validation_0-rmse:0.10530
# [33]	validation_0-rmse:0.10317
# [34]	validation_0-rmse:0.10102
# [35]	validation_0-rmse:0.09986
# [36]	validation_0-rmse:0.09901
# [37]	validation_0-rmse:0.09833
# [38]	validation_0-rmse:0.09773
# [39]	validation_0-rmse:0.09724
# [40]	validation_0-rmse:0.09666
# [41]	validation_0-rmse:0.09635
# [42]	validation_0-rmse:0.09605
# [43]	validation_0-rmse:0.09536
# [44]	validation_0-rmse:0.09512
# [45]	validation_0-rmse:0.09474
# [46]	validation_0-rmse:0.09450
# [47]	validation_0-rmse:0.09435
# [48]	validation_0-rmse:0.09422
# [49]	validation_0-rmse:0.09392
# [50]	validation_0-rmse:0.09384
# [51]	validation_0-rmse:0.09372
# [52]	validation_0-rmse:0.09361
# [53]	validation_0-rmse:0.09353
# [54]	validation_0-rmse:0.09348
# [55]	validation_0-rmse:0.09327
# [56]	validation_0-rmse:0.09298
# [57]	validation_0-rmse:0.09292
# [58]	validation_0-rmse:0.09280
# [59]	validation_0-rmse:0.09271
# [60]	validation_0-rmse:0.09256
# [61]	validation_0-rmse:0.09253
# [62]	validation_0-rmse:0.09241
# [63]	validation_0-rmse:0.09233
# [64]	validation_0-rmse:0.09229
# [65]	validation_0-rmse:0.09205
# [66]	validation_0-rmse:0.09194
# [67]	validation_0-rmse:0.09177
# [68]	validation_0-rmse:0.09169
# [69]	validation_0-rmse:0.09168
# [70]	validation_0-rmse:0.09156
# [71]	validation_0-rmse:0.09152
# [72]	validation_0-rmse:0.09150
# [73]	validation_0-rmse:0.09147
# [74]	validation_0-rmse:0.09145
# [75]	validation_0-rmse:0.09140
# [76]	validation_0-rmse:0.09139
# [77]	validation_0-rmse:0.09130
# [78]	validation_0-rmse:0.09125
# [79]	validation_0-rmse:0.09122
# [80]	validation_0-rmse:0.09120
# [81]	validation_0-rmse:0.09100
# [82]	validation_0-rmse:0.09089
# [83]	validation_0-rmse:0.09075
# [84]	validation_0-rmse:0.09066
# [85]	validation_0-rmse:0.09065
# [86]	validation_0-rmse:0.09063
# [87]	validation_0-rmse:0.09052
# [88]	validation_0-rmse:0.09042
# [89]	validation_0-rmse:0.09036
# [90]	validation_0-rmse:0.09030
# [91]	validation_0-rmse:0.09028
# [92]	validation_0-rmse:0.09024
# [93]	validation_0-rmse:0.09017
# [94]	validation_0-rmse:0.09015
# [95]	validation_0-rmse:0.09002
# [96]	validation_0-rmse:0.08993
# [97]	validation_0-rmse:0.08984
# [98]	validation_0-rmse:0.08978
# [99]	validation_0-rmse:0.08974
# [100]	validation_0-rmse:0.08973
# [101]	validation_0-rmse:0.08974
# [102]	validation_0-rmse:0.08977
# [103]	validation_0-rmse:0.08977
# [104]	validation_0-rmse:0.08975
# [105]	validation_0-rmse:0.08973
# [106]	validation_0-rmse:0.08971
# [107]	validation_0-rmse:0.08970
# [108]	validation_0-rmse:0.08971
# [109]	validation_0-rmse:0.08966
# [110]	validation_0-rmse:0.08959
# [111]	validation_0-rmse:0.08953
# [112]	validation_0-rmse:0.08948
# [113]	validation_0-rmse:0.08948
# [114]	validation_0-rmse:0.08946
# [115]	validation_0-rmse:0.08945
# [116]	validation_0-rmse:0.08945
# [117]	validation_0-rmse:0.08943
# [118]	validation_0-rmse:0.08936
# [119]	validation_0-rmse:0.08931
# [120]	validation_0-rmse:0.08928
# [121]	validation_0-rmse:0.08923
# [122]	validation_0-rmse:0.08923
# [123]	validation_0-rmse:0.08923
# [124]	validation_0-rmse:0.08919
# [125]	validation_0-rmse:0.08919
# [126]	validation_0-rmse:0.08920
# [127]	validation_0-rmse:0.08920
# [128]	validation_0-rmse:0.08921
# [129]	validation_0-rmse:0.08921
# [130]	validation_0-rmse:0.08923
# [131]	validation_0-rmse:0.08917
# [132]	validation_0-rmse:0.08912
# [133]	validation_0-rmse:0.08912
# [134]	validation_0-rmse:0.08914
# [135]	validation_0-rmse:0.08912
# [136]	validation_0-rmse:0.08913
# [137]	validation_0-rmse:0.08915
# [138]	validation_0-rmse:0.08907
# [139]	validation_0-rmse:0.08903
# [140]	validation_0-rmse:0.08900
# [141]	validation_0-rmse:0.08898
# [142]	validation_0-rmse:0.08898
# [143]	validation_0-rmse:0.08898
# [144]	validation_0-rmse:0.08898
# [145]	validation_0-rmse:0.08896
# [146]	validation_0-rmse:0.08892
# [147]	validation_0-rmse:0.08892
# [148]	validation_0-rmse:0.08890
# [149]	validation_0-rmse:0.08890
# [150]	validation_0-rmse:0.08890
# [151]	validation_0-rmse:0.08889
# [152]	validation_0-rmse:0.08885
# [153]	validation_0-rmse:0.08882
# [154]	validation_0-rmse:0.08882
# [155]	validation_0-rmse:0.08882
# [156]	validation_0-rmse:0.08881
# [157]	validation_0-rmse:0.08880
# [158]	validation_0-rmse:0.08879
# [159]	validation_0-rmse:0.08877
# [160]	validation_0-rmse:0.08878
# [161]	validation_0-rmse:0.08874
# [162]	validation_0-rmse:0.08872
# [163]	validation_0-rmse:0.08873
# [164]	validation_0-rmse:0.08874
# [165]	validation_0-rmse:0.08874
# [166]	validation_0-rmse:0.08874
# [167]	validation_0-rmse:0.08872
# [168]	validation_0-rmse:0.08870
# [169]	validation_0-rmse:0.08870
# [170]	validation_0-rmse:0.08870
# [171]	validation_0-rmse:0.08867
# [172]	validation_0-rmse:0.08864
# [173]	validation_0-rmse:0.08861
# [174]	validation_0-rmse:0.08860
# [175]	validation_0-rmse:0.08862
# [176]	validation_0-rmse:0.08859
# [177]	validation_0-rmse:0.08856
# [178]	validation_0-rmse:0.08855
# [179]	validation_0-rmse:0.08855
# [180]	validation_0-rmse:0.08854
# [181]	validation_0-rmse:0.08851
# [182]	validation_0-rmse:0.08849
# [183]	validation_0-rmse:0.08851
# [184]	validation_0-rmse:0.08848
# [185]	validation_0-rmse:0.08845
# [186]	validation_0-rmse:0.08843
# [187]	validation_0-rmse:0.08844
# [188]	validation_0-rmse:0.08843
# [189]	validation_0-rmse:0.08841
# [190]	validation_0-rmse:0.08841
# [191]	validation_0-rmse:0.08840
# [192]	validation_0-rmse:0.08838
# [193]	validation_0-rmse:0.08838
# [194]	validation_0-rmse:0.08836
# [195]	validation_0-rmse:0.08839
# [196]	validation_0-rmse:0.08839
# [197]	validation_0-rmse:0.08838
# [198]	validation_0-rmse:0.08838
# [199]	validation_0-rmse:0.08834
# [200]	validation_0-rmse:0.08833
# [201]	validation_0-rmse:0.08833
# [202]	validation_0-rmse:0.08831
# [203]	validation_0-rmse:0.08829
# [204]	validation_0-rmse:0.08829
# [205]	validation_0-rmse:0.08832
# [206]	validation_0-rmse:0.08832
# [207]	validation_0-rmse:0.08830
# [208]	validation_0-rmse:0.08830
# [209]	validation_0-rmse:0.08828
# [210]	validation_0-rmse:0.08828
# [211]	validation_0-rmse:0.08828
# [212]	validation_0-rmse:0.08823
# [213]	validation_0-rmse:0.08825
# [214]	validation_0-rmse:0.08824
# [215]	validation_0-rmse:0.08825
# [216]	validation_0-rmse:0.08826
# [217]	validation_0-rmse:0.08825
# [218]	validation_0-rmse:0.08825
# [219]	validation_0-rmse:0.08825
# [220]	validation_0-rmse:0.08822
# [221]	validation_0-rmse:0.08821
# [222]	validation_0-rmse:0.08820
# [223]	validation_0-rmse:0.08820
# [224]	validation_0-rmse:0.08820
# [225]	validation_0-rmse:0.08819
# [226]	validation_0-rmse:0.08819
# [227]	validation_0-rmse:0.08819
# [228]	validation_0-rmse:0.08820
# [229]	validation_0-rmse:0.08818
# [230]	validation_0-rmse:0.08816
# [231]	validation_0-rmse:0.08815
# [232]	validation_0-rmse:0.08814
# [233]	validation_0-rmse:0.08810
# [234]	validation_0-rmse:0.08809
# [235]	validation_0-rmse:0.08808
# [236]	validation_0-rmse:0.08809
# [237]	validation_0-rmse:0.08809
# [238]	validation_0-rmse:0.08808
# [239]	validation_0-rmse:0.08808
# [240]	validation_0-rmse:0.08806
# [241]	validation_0-rmse:0.08807
# [242]	validation_0-rmse:0.08805
# [243]	validation_0-rmse:0.08805
# [244]	validation_0-rmse:0.08804
# [245]	validation_0-rmse:0.08800
# [246]	validation_0-rmse:0.08799
# [247]	validation_0-rmse:0.08794
# [248]	validation_0-rmse:0.08794
# [249]	validation_0-rmse:0.08794
# [250]	validation_0-rmse:0.08794
# [251]	validation_0-rmse:0.08795
# [252]	validation_0-rmse:0.08795
# [253]	validation_0-rmse:0.08795
# [254]	validation_0-rmse:0.08795
# [255]	validation_0-rmse:0.08797
# [256]	validation_0-rmse:0.08797
# [257]	validation_0-rmse:0.08796
# [258]	validation_0-rmse:0.08795
# [259]	validation_0-rmse:0.08794
# [260]	validation_0-rmse:0.08795
# [261]	validation_0-rmse:0.08794
# [262]	validation_0-rmse:0.08794
# [263]	validation_0-rmse:0.08794
# [264]	validation_0-rmse:0.08794
# [265]	validation_0-rmse:0.08795
# [266]	validation_0-rmse:0.08795
# [267]	validation_0-rmse:0.08795
# [268]	validation_0-rmse:0.08794
# [269]	validation_0-rmse:0.08792
# [270]	validation_0-rmse:0.08789
# [271]	validation_0-rmse:0.08789
# [272]	validation_0-rmse:0.08788
# [273]	validation_0-rmse:0.08787
# [274]	validation_0-rmse:0.08787
# [275]	validation_0-rmse:0.08789
# [276]	validation_0-rmse:0.08788
# [277]	validation_0-rmse:0.08788
# [278]	validation_0-rmse:0.08787
# [279]	validation_0-rmse:0.08787
# [280]	validation_0-rmse:0.08787
# [281]	validation_0-rmse:0.08785
# [282]	validation_0-rmse:0.08784
# [283]	validation_0-rmse:0.08784
# [284]	validation_0-rmse:0.08783
# [285]	validation_0-rmse:0.08782
# [286]	validation_0-rmse:0.08784
# [287]	validation_0-rmse:0.08784
# [288]	validation_0-rmse:0.08783
# [289]	validation_0-rmse:0.08784
# [290]	validation_0-rmse:0.08783
# [291]	validation_0-rmse:0.08783
# [292]	validation_0-rmse:0.08782
# [293]	validation_0-rmse:0.08782
# [294]	validation_0-rmse:0.08781
# [295]	validation_0-rmse:0.08781
# [296]	validation_0-rmse:0.08781
# [297]	validation_0-rmse:0.08781
# [298]	validation_0-rmse:0.08781
# [299]	validation_0-rmse:0.08781
# [300]	validation_0-rmse:0.08780
# [301]	validation_0-rmse:0.08776
# [302]	validation_0-rmse:0.08777
# [303]	validation_0-rmse:0.08776
# [304]	validation_0-rmse:0.08777
# [305]	validation_0-rmse:0.08776
# [306]	validation_0-rmse:0.08775
# [307]	validation_0-rmse:0.08772
# [308]	validation_0-rmse:0.08772
# [309]	validation_0-rmse:0.08772
# [310]	validation_0-rmse:0.08772
# [311]	validation_0-rmse:0.08771
# [312]	validation_0-rmse:0.08770
# [313]	validation_0-rmse:0.08769
# [314]	validation_0-rmse:0.08769
# [315]	validation_0-rmse:0.08769
# [316]	validation_0-rmse:0.08772
# [317]	validation_0-rmse:0.08772
# [318]	validation_0-rmse:0.08772
# [319]	validation_0-rmse:0.08772
# [400]	validation_0-rmse:0.08764
# [401]	validation_0-rmse:0.08764
# [402]	validation_0-rmse:0.08763
# [403]	validation_0-rmse:0.08763
# [404]	validation_0-rmse:0.08763
# [405]	validation_0-rmse:0.08764
# [406]	validation_0-rmse:0.08765
# [407]	validation_0-rmse:0.08765
# [408]	validation_0-rmse:0.08766
# [409]	validation_0-rmse:0.08766
# [410]	validation_0-rmse:0.08766
# [411]	validation_0-rmse:0.08766
# [412]	validation_0-rmse:0.08767
# [413]	validation_0-rmse:0.08766
# [414]	validation_0-rmse:0.08766
# [415]	validation_0-rmse:0.08766
# [416]	validation_0-rmse:0.08767
# [417]	validation_0-rmse:0.08768
# [418]	validation_0-rmse:0.08767
# [419]	validation_0-rmse:0.08766
# [420]	validation_0-rmse:0.08767
# [421]	validation_0-rmse:0.08767
# [422]	validation_0-rmse:0.08767
# [423]	validation_0-rmse:0.08766
# [424]	validation_0-rmse:0.08764
# [425]	validation_0-rmse:0.08761
# [426]	validation_0-rmse:0.08761
# [427]	validation_0-rmse:0.08760
# [428]	validation_0-rmse:0.08761
# [429]	validation_0-rmse:0.08762
# [430]	validation_0-rmse:0.08762
# [431]	validation_0-rmse:0.08762
# [432]	validation_0-rmse:0.08761
# [433]	validation_0-rmse:0.08759
# [434]	validation_0-rmse:0.08759
# [435]	validation_0-rmse:0.08758
# [436]	validation_0-rmse:0.08756
# [437]	validation_0-rmse:0.08757
# [438]	validation_0-rmse:0.08757
# [439]	validation_0-rmse:0.08756
# [440]	validation_0-rmse:0.08756
# [441]	validation_0-rmse:0.08755
# [442]	validation_0-rmse:0.08754
# [443]	validation_0-rmse:0.08754
# [444]	validation_0-rmse:0.08754
# [445]	validation_0-rmse:0.08754
# [446]	validation_0-rmse:0.08754
# [447]	validation_0-rmse:0.08753
# [448]	validation_0-rmse:0.08754
# [449]	validation_0-rmse:0.08753
# [450]	validation_0-rmse:0.08752
# [451]	validation_0-rmse:0.08753
# [452]	validation_0-rmse:0.08753
# [453]	validation_0-rmse:0.08753
# [454]	validation_0-rmse:0.08753
# [455]	validation_0-rmse:0.08754
# [456]	validation_0-rmse:0.08754
# [457]	validation_0-rmse:0.08753
# [458]	validation_0-rmse:0.08754
# [459]	validation_0-rmse:0.08754
# [460]	validation_0-rmse:0.08754
# [461]	validation_0-rmse:0.08754
# [462]	validation_0-rmse:0.08754
# [463]	validation_0-rmse:0.08754
# [464]	validation_0-rmse:0.08754
# [465]	validation_0-rmse:0.08755
# [466]	validation_0-rmse:0.08755
# [467]	validation_0-rmse:0.08755
# [468]	validation_0-rmse:0.08757
# [469]	validation_0-rmse:0.08758
# [470]	validation_0-rmse:0.08757
# [471]	validation_0-rmse:0.08756
# [472]	validation_0-rmse:0.08756
# [473]	validation_0-rmse:0.08756
# [474]	validation_0-rmse:0.08757
# [475]	validation_0-rmse:0.08755
# [476]	validation_0-rmse:0.08755
# [477]	validation_0-rmse:0.08755
# [478]	validation_0-rmse:0.08755
# [479]	validation_0-rmse:0.08755
# [480]	validation_0-rmse:0.08755
# [562]	validation_0-rmse:0.08749
# [563]	validation_0-rmse:0.08750
# [564]	validation_0-rmse:0.08750
# [565]	validation_0-rmse:0.08750
# [566]	validation_0-rmse:0.08751
# [567]	validation_0-rmse:0.08752
# [568]	validation_0-rmse:0.08752
# [569]	validation_0-rmse:0.08752
# [570]	validation_0-rmse:0.08752
# [571]	validation_0-rmse:0.08752
# [572]	validation_0-rmse:0.08752
# [573]	validation_0-rmse:0.08751
# [574]	validation_0-rmse:0.08751
# [575]	validation_0-rmse:0.08750
# [576]	validation_0-rmse:0.08750
# [577]	validation_0-rmse:0.08750
# [578]	validation_0-rmse:0.08749
# [579]	validation_0-rmse:0.08750
# [580]	validation_0-rmse:0.08750
# [581]	validation_0-rmse:0.08749
# [582]	validation_0-rmse:0.08750
# [583]	validation_0-rmse:0.08749
# [584]	validation_0-rmse:0.08749
# [585]	validation_0-rmse:0.08749
# [586]	validation_0-rmse:0.08749
# [587]	validation_0-rmse:0.08749
# [588]	validation_0-rmse:0.08749
# [589]	validation_0-rmse:0.08749
# [590]	validation_0-rmse:0.08749
# [591]	validation_0-rmse:0.08749
# [592]	validation_0-rmse:0.08748
# [593]	validation_0-rmse:0.08747
# [594]	validation_0-rmse:0.08747
# [595]	validation_0-rmse:0.08748
# [596]	validation_0-rmse:0.08748
# [597]	validation_0-rmse:0.08749
# [598]	validation_0-rmse:0.08749
# [599]	validation_0-rmse:0.08750
# [600]	validation_0-rmse:0.08750
# [601]	validation_0-rmse:0.08750
# [602]	validation_0-rmse:0.08750
# [603]	validation_0-rmse:0.08751
# [604]	validation_0-rmse:0.08751
# [605]	validation_0-rmse:0.08751
# [606]	validation_0-rmse:0.08751
# [607]	validation_0-rmse:0.08751
# [608]	validation_0-rmse:0.08752
# [609]	validation_0-rmse:0.08752
# [610]	validation_0-rmse:0.08752
# [611]	validation_0-rmse:0.08752
# [612]	validation_0-rmse:0.08752
# [613]	validation_0-rmse:0.08751
# [614]	validation_0-rmse:0.08751
# [615]	validation_0-rmse:0.08752
# [616]	validation_0-rmse:0.08751
# [617]	validation_0-rmse:0.08751
# [618]	validation_0-rmse:0.08752
# [619]	validation_0-rmse:0.08752
# [620]	validation_0-rmse:0.08751
# [621]	validation_0-rmse:0.08751
# [622]	validation_0-rmse:0.08750
# [623]	validation_0-rmse:0.08749
# [624]	validation_0-rmse:0.08749
# [625]	validation_0-rmse:0.08750
# [626]	validation_0-rmse:0.08750
# [627]	validation_0-rmse:0.08751
# [628]	validation_0-rmse:0.08749
# [629]	validation_0-rmse:0.08749
# [630]	validation_0-rmse:0.08749
# [631]	validation_0-rmse:0.08749
# [632]	validation_0-rmse:0.08748
# [633]	validation_0-rmse:0.08749
# [634]	validation_0-rmse:0.08749
# [635]	validation_0-rmse:0.08749
# [636]	validation_0-rmse:0.08748
# [637]	validation_0-rmse:0.08749
# [638]	validation_0-rmse:0.08749
# [639]	validation_0-rmse:0.08748
# [640]	validation_0-rmse:0.08749
# [641]	validation_0-rmse:0.08749
# [723]	validation_0-rmse:0.08755
# [724]	validation_0-rmse:0.08755
# [725]	validation_0-rmse:0.08755
# [726]	validation_0-rmse:0.08755
# [727]	validation_0-rmse:0.08755
# [728]	validation_0-rmse:0.08756
# [729]	validation_0-rmse:0.08757
# [730]	validation_0-rmse:0.08757
# [731]	validation_0-rmse:0.08758
# [732]	validation_0-rmse:0.08758
# [733]	validation_0-rmse:0.08757
# [734]	validation_0-rmse:0.08757
# [735]	validation_0-rmse:0.08757
# [736]	validation_0-rmse:0.08756
# [737]	validation_0-rmse:0.08756
# [738]	validation_0-rmse:0.08756
# [739]	validation_0-rmse:0.08756
# [740]	validation_0-rmse:0.08757
# [741]	validation_0-rmse:0.08757
# [742]	validation_0-rmse:0.08757
# [743]	validation_0-rmse:0.08758
# [744]	validation_0-rmse:0.08758
# [745]	validation_0-rmse:0.08757
# [746]	validation_0-rmse:0.08757
# [747]	validation_0-rmse:0.08757
# [748]	validation_0-rmse:0.08757
# [749]	validation_0-rmse:0.08758
# [750]	validation_0-rmse:0.08758
# [751]	validation_0-rmse:0.08758
# [752]	validation_0-rmse:0.08758
# [753]	validation_0-rmse:0.08759
# [754]	validation_0-rmse:0.08759
# [755]	validation_0-rmse:0.08758
# [756]	validation_0-rmse:0.08758
# [757]	validation_0-rmse:0.08758
# [758]	validation_0-rmse:0.08759
# [759]	validation_0-rmse:0.08758
# [760]	validation_0-rmse:0.08758
# [761]	validation_0-rmse:0.08758
# [762]	validation_0-rmse:0.08758
# [763]	validation_0-rmse:0.08757
# [764]	validation_0-rmse:0.08756
# [765]	validation_0-rmse:0.08757
# [766]	validation_0-rmse:0.08757
# [767]	validation_0-rmse:0.08758
# [768]	validation_0-rmse:0.08757
# [769]	validation_0-rmse:0.08758
# [770]	validation_0-rmse:0.08757
# [771]	validation_0-rmse:0.08758
# [772]	validation_0-rmse:0.08759
# [773]	validation_0-rmse:0.08759
# [774]	validation_0-rmse:0.08759
# [775]	validation_0-rmse:0.08759
# [776]	validation_0-rmse:0.08759
# [777]	validation_0-rmse:0.08759
# [778]	validation_0-rmse:0.08759
# [779]	validation_0-rmse:0.08760
# [780]	validation_0-rmse:0.08760
# [781]	validation_0-rmse:0.08760
# [782]	validation_0-rmse:0.08760
# [783]	validation_0-rmse:0.08760
# [784]	validation_0-rmse:0.08760
# [785]	validation_0-rmse:0.08761
# [786]	validation_0-rmse:0.08762
# [787]	validation_0-rmse:0.08763
# [788]	validation_0-rmse:0.08763
# [789]	validation_0-rmse:0.08764
# [790]	validation_0-rmse:0.08765
# [791]	validation_0-rmse:0.08765
# [792]	validation_0-rmse:0.08765
# [793]	validation_0-rmse:0.08764
# [794]	validation_0-rmse:0.08764
# [795]	validation_0-rmse:0.08764
# [796]	validation_0-rmse:0.08764
# [797]	validation_0-rmse:0.08764
# [798]	validation_0-rmse:0.08764
# [799]	validation_0-rmse:0.08764
# [800]	validation_0-rmse:0.08765
# [801]	validation_0-rmse:0.08765
# [802]	validation_0-rmse:0.08765
# [803]	validation_0-rmse:0.08765
# [804]	validation_0-rmse:0.08764
# [805]	validation_0-rmse:0.08764
# [806]	validation_0-rmse:0.08764
# [807]	validation_0-rmse:0.08765
# [808]	validation_0-rmse:0.08765
# [809]	validation_0-rmse:0.08766
# [810]	validation_0-rmse:0.08766
# [811]	validation_0-rmse:0.08767
# [812]	validation_0-rmse:0.08767
# [813]	validation_0-rmse:0.08766
# [814]	validation_0-rmse:0.08767
# [815]	validation_0-rmse:0.08767
# [816]	validation_0-rmse:0.08767
# [817]	validation_0-rmse:0.08767
# [818]	validation_0-rmse:0.08768
# [819]	validation_0-rmse:0.08768
# [820]	validation_0-rmse:0.08769
# [821]	validation_0-rmse:0.08768
# [822]	validation_0-rmse:0.08768
# [823]	validation_0-rmse:0.08767
# [824]	validation_0-rmse:0.08768
# [825]	validation_0-rmse:0.08768
# [826]	validation_0-rmse:0.08768
# [827]	validation_0-rmse:0.08768
# [828]	validation_0-rmse:0.08768
# [829]	validation_0-rmse:0.08768
# [830]	validation_0-rmse:0.08769
# [831]	validation_0-rmse:0.08768
# 532

# %% [markdown]
# # Ronda 4: "constraints"
#
# - Se comprueba el número de estimadores
#
# - Se comprueba que el modelo mejora si se aplican "constraints" a "weight (carat)"
#
# - Eso tiene sentido ya que como se ha visto en el EDA a) tiene una altísima correlación con la "target", y b) cuando un diamante pesa más su precio es superior, y las otras columnas de tamaño se ajustan a ese peso

# %%
model = XGBRegressor()

params = {'random_state': [43],
          'n_estimators': [531],
          'eta': [0.15],
          'monotone_constraints':[{"weight (carat)": 1}, {"lenght (millimeters)": 1}, {"width (millimeters)": 1}, {"depth (millimeters)": 1}],
            }

grid = GridSearchCV(estimator=model,
                    param_grid=params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=531, random_state=43;, score=-0.089 total time=   9.8s
# [CV 2/5] END eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=531, random_state=43;, score=-0.089 total time=   8.0s
# [CV 3/5] END eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=531, random_state=43;, score=-0.086 total time=   8.4s
# [CV 4/5] END eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=531, random_state=43;, score=-0.086 total time=   8.9s
# [CV 5/5] END eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=531, random_state=43;, score=-0.087 total time=   7.9s
# [CV 1/5] END eta=0.15, monotone_constraints={'lenght (millimeters)': 1}, n_estimators=531, random_state=43;, score=-0.090 total time=   9.1s
# [CV 2/5] END eta=0.15, monotone_constraints={'lenght (millimeters)': 1}, n_estimators=531, random_state=43;, score=-0.089 total time=   8.6s
# [CV 3/5] END eta=0.15, monotone_constraints={'lenght (millimeters)': 1}, n_estimators=531, random_state=43;, score=-0.088 total time=   8.3s
# [CV 4/5] END eta=0.15, monotone_constraints={'lenght (millimeters)': 1}, n_estimators=531, random_state=43;, score=-0.088 total time=  10.1s
# [CV 5/5] END eta=0.15, monotone_constraints={'lenght (millimeters)': 1}, n_estimators=531, random_state=43;, score=-0.088 total time=   9.7s
# [CV 1/5] END eta=0.15, monotone_constraints={'width (millimeters)': 1}, n_estimators=531, random_state=43;, score=-0.095 total time=   8.2s
# [CV 2/5] END eta=0.15, monotone_constraints={'width (millimeters)': 1}, n_estimators=531, random_state=43;, score=-0.098 total time=   8.0s
# [CV 3/5] END eta=0.15, monotone_constraints={'width (millimeters)': 1}, n_estimators=531, random_state=43;, score=-0.091 total time=  11.5s
# [CV 4/5] END eta=0.15, monotone_constraints={'width (millimeters)': 1}, n_estimators=531, random_state=43;, score=-0.091 total time=  13.8s
# [CV 5/5] END eta=0.15, monotone_constraints={'width (millimeters)': 1}, n_estimators=531, random_state=43;, score=-0.093 total time=   8.3s
# [CV 1/5] END eta=0.15, monotone_constraints={'depth (millimeters)': 1}, n_estimators=531, random_state=43;, score=-0.091 total time=   8.5s
# [CV 2/5] END eta=0.15, monotone_constraints={'depth (millimeters)': 1}, n_estimators=531, random_state=43;, score=-0.090 total time=   9.3s
# [CV 3/5] END eta=0.15, monotone_constraints={'depth (millimeters)': 1}, n_estimators=531, random_state=43;, score=-0.087 total time=   9.6s
# [CV 4/5] END eta=0.15, monotone_constraints={'depth (millimeters)': 1}, n_estimators=531, random_state=43;, score=-0.087 total time=   8.3s
# [CV 5/5] END eta=0.15, monotone_constraints={'depth (millimeters)': 1}, n_estimators=531, random_state=43;, score=-0.087 total time=   8.2s
# Best params: {'eta': 0.15, 'monotone_constraints': {'weight (carat)': 1}, 'n_estimators': 531, 'random_state': 43}
# Best score: -0.08767022894520285

# %%
model = XGBRegressor(n_estimators=1000, eta=0.15, monotone_constraints={"weight (carat)": 1})

model.early_stopping_rounds = 300

model.fit(X_train, y_train, eval_set=[(X_test, y_test)]) 

model.best_ntree_limit
# Out:
# [0]	validation_0-rmse:6.25481
# [1]	validation_0-rmse:5.31758
# [2]	validation_0-rmse:4.52150
# [3]	validation_0-rmse:3.84463
# [4]	validation_0-rmse:3.26964
# [5]	validation_0-rmse:2.78173
# [6]	validation_0-rmse:2.36649
# [7]	validation_0-rmse:2.01309
# [8]	validation_0-rmse:1.71300
# [9]	validation_0-rmse:1.45817
# [10]	validation_0-rmse:1.24123
# [11]	validation_0-rmse:1.05734
# [12]	validation_0-rmse:0.90110
# [13]	validation_0-rmse:0.76855
# [14]	validation_0-rmse:0.65585
# [15]	validation_0-rmse:0.56116
# [16]	validation_0-rmse:0.48050
# [17]	validation_0-rmse:0.41302
# [18]	validation_0-rmse:0.35586
# [19]	validation_0-rmse:0.30790
# [20]	validation_0-rmse:0.26781
# [21]	validation_0-rmse:0.23454
# [22]	validation_0-rmse:0.20698
# [23]	validation_0-rmse:0.18427
# [24]	validation_0-rmse:0.16564
# [25]	validation_0-rmse:0.15081
# [26]	validation_0-rmse:0.13914
# [27]	validation_0-rmse:0.12979
# [28]	validation_0-rmse:0.12263
# [29]	validation_0-rmse:0.11697
# [110]	validation_0-rmse:0.08942
# [111]	validation_0-rmse:0.08939
# [112]	validation_0-rmse:0.08937
# [113]	validation_0-rmse:0.08937
# [114]	validation_0-rmse:0.08929
# [115]	validation_0-rmse:0.08926
# [116]	validation_0-rmse:0.08922
# [117]	validation_0-rmse:0.08920
# [118]	validation_0-rmse:0.08914
# [119]	validation_0-rmse:0.08902
# [120]	validation_0-rmse:0.08901
# [121]	validation_0-rmse:0.08899
# [122]	validation_0-rmse:0.08899
# [123]	validation_0-rmse:0.08895
# [124]	validation_0-rmse:0.08894
# [125]	validation_0-rmse:0.08890
# [126]	validation_0-rmse:0.08889
# [127]	validation_0-rmse:0.08890
# [128]	validation_0-rmse:0.08886
# [129]	validation_0-rmse:0.08884
# [130]	validation_0-rmse:0.08884
# [131]	validation_0-rmse:0.08884
# [132]	validation_0-rmse:0.08883
# [133]	validation_0-rmse:0.08883
# [134]	validation_0-rmse:0.08880
# [135]	validation_0-rmse:0.08878
# [136]	validation_0-rmse:0.08876
# [137]	validation_0-rmse:0.08873
# [138]	validation_0-rmse:0.08868
# [139]	validation_0-rmse:0.08861
# [140]	validation_0-rmse:0.08858
# [141]	validation_0-rmse:0.08858
# [142]	validation_0-rmse:0.08857
# [143]	validation_0-rmse:0.08857
# [144]	validation_0-rmse:0.08857
# [145]	validation_0-rmse:0.08854
# [146]	validation_0-rmse:0.08851
# [147]	validation_0-rmse:0.08851
# [148]	validation_0-rmse:0.08850
# [149]	validation_0-rmse:0.08845
# [150]	validation_0-rmse:0.08841
# [151]	validation_0-rmse:0.08838
# [152]	validation_0-rmse:0.08838
# [153]	validation_0-rmse:0.08838
# [154]	validation_0-rmse:0.08838
# [155]	validation_0-rmse:0.08836
# [156]	validation_0-rmse:0.08836
# [157]	validation_0-rmse:0.08834
# [158]	validation_0-rmse:0.08833
# [159]	validation_0-rmse:0.08831
# [160]	validation_0-rmse:0.08832
# [161]	validation_0-rmse:0.08832
# [162]	validation_0-rmse:0.08825
# [163]	validation_0-rmse:0.08819
# [164]	validation_0-rmse:0.08818
# [165]	validation_0-rmse:0.08816
# [166]	validation_0-rmse:0.08817
# [167]	validation_0-rmse:0.08816
# [168]	validation_0-rmse:0.08813
# [169]	validation_0-rmse:0.08808
# [170]	validation_0-rmse:0.08809
# [171]	validation_0-rmse:0.08808
# [172]	validation_0-rmse:0.08803
# [173]	validation_0-rmse:0.08803
# [174]	validation_0-rmse:0.08800
# [175]	validation_0-rmse:0.08798
# [176]	validation_0-rmse:0.08795
# [177]	validation_0-rmse:0.08797
# [178]	validation_0-rmse:0.08795
# [179]	validation_0-rmse:0.08796
# [180]	validation_0-rmse:0.08796
# [181]	validation_0-rmse:0.08795
# [182]	validation_0-rmse:0.08791
# [183]	validation_0-rmse:0.08789
# [184]	validation_0-rmse:0.08789
# [185]	validation_0-rmse:0.08786
# [186]	validation_0-rmse:0.08785
# [187]	validation_0-rmse:0.08786
# [188]	validation_0-rmse:0.08785
# [189]	validation_0-rmse:0.08787
# [190]	validation_0-rmse:0.08787
# [272]	validation_0-rmse:0.08744
# [273]	validation_0-rmse:0.08744
# [274]	validation_0-rmse:0.08744
# [275]	validation_0-rmse:0.08742
# [276]	validation_0-rmse:0.08743
# [277]	validation_0-rmse:0.08741
# [278]	validation_0-rmse:0.08741
# [279]	validation_0-rmse:0.08740
# [280]	validation_0-rmse:0.08738
# [281]	validation_0-rmse:0.08738
# [282]	validation_0-rmse:0.08736
# [283]	validation_0-rmse:0.08736
# [284]	validation_0-rmse:0.08735
# [285]	validation_0-rmse:0.08735
# [286]	validation_0-rmse:0.08734
# [287]	validation_0-rmse:0.08735
# [288]	validation_0-rmse:0.08733
# [289]	validation_0-rmse:0.08734
# [290]	validation_0-rmse:0.08733
# [291]	validation_0-rmse:0.08733
# [292]	validation_0-rmse:0.08734
# [293]	validation_0-rmse:0.08733
# [294]	validation_0-rmse:0.08732
# [295]	validation_0-rmse:0.08732
# [296]	validation_0-rmse:0.08732
# [297]	validation_0-rmse:0.08729
# [298]	validation_0-rmse:0.08729
# [299]	validation_0-rmse:0.08728
# [300]	validation_0-rmse:0.08727
# [301]	validation_0-rmse:0.08728
# [302]	validation_0-rmse:0.08729
# [303]	validation_0-rmse:0.08728
# [304]	validation_0-rmse:0.08727
# [305]	validation_0-rmse:0.08725
# [306]	validation_0-rmse:0.08724
# [307]	validation_0-rmse:0.08723
# [308]	validation_0-rmse:0.08724
# [309]	validation_0-rmse:0.08724
# [310]	validation_0-rmse:0.08725
# [311]	validation_0-rmse:0.08725
# [312]	validation_0-rmse:0.08725
# [313]	validation_0-rmse:0.08724
# [314]	validation_0-rmse:0.08724
# [315]	validation_0-rmse:0.08724
# [316]	validation_0-rmse:0.08725
# [317]	validation_0-rmse:0.08723
# [318]	validation_0-rmse:0.08724
# [319]	validation_0-rmse:0.08724
# [320]	validation_0-rmse:0.08724
# [321]	validation_0-rmse:0.08724
# [322]	validation_0-rmse:0.08723
# [323]	validation_0-rmse:0.08722
# [324]	validation_0-rmse:0.08723
# [325]	validation_0-rmse:0.08722
# [326]	validation_0-rmse:0.08721
# [327]	validation_0-rmse:0.08721
# [328]	validation_0-rmse:0.08720
# [329]	validation_0-rmse:0.08721
# [330]	validation_0-rmse:0.08720
# [331]	validation_0-rmse:0.08718
# [332]	validation_0-rmse:0.08717
# [333]	validation_0-rmse:0.08718
# [334]	validation_0-rmse:0.08716
# [335]	validation_0-rmse:0.08714
# [336]	validation_0-rmse:0.08715
# [337]	validation_0-rmse:0.08714
# [338]	validation_0-rmse:0.08715
# [339]	validation_0-rmse:0.08715
# [340]	validation_0-rmse:0.08716
# [341]	validation_0-rmse:0.08716
# [342]	validation_0-rmse:0.08715
# [343]	validation_0-rmse:0.08715
# [344]	validation_0-rmse:0.08717
# [345]	validation_0-rmse:0.08717
# [346]	validation_0-rmse:0.08718
# [347]	validation_0-rmse:0.08718
# [348]	validation_0-rmse:0.08719
# [349]	validation_0-rmse:0.08717
# [350]	validation_0-rmse:0.08716
# [351]	validation_0-rmse:0.08716
# [352]	validation_0-rmse:0.08716
# [353]	validation_0-rmse:0.08715
# [354]	validation_0-rmse:0.08717
# [355]	validation_0-rmse:0.08716
# [356]	validation_0-rmse:0.08717
# [357]	validation_0-rmse:0.08716
# [358]	validation_0-rmse:0.08715
# [359]	validation_0-rmse:0.08716
# [360]	validation_0-rmse:0.08715
# [361]	validation_0-rmse:0.08716
# [362]	validation_0-rmse:0.08716
# [363]	validation_0-rmse:0.08716
# [364]	validation_0-rmse:0.08716
# [365]	validation_0-rmse:0.08714
# [366]	validation_0-rmse:0.08715
# [367]	validation_0-rmse:0.08716
# [368]	validation_0-rmse:0.08716
# [369]	validation_0-rmse:0.08716
# [370]	validation_0-rmse:0.08718
# [371]	validation_0-rmse:0.08719
# [372]	validation_0-rmse:0.08720
# [373]	validation_0-rmse:0.08720
# [374]	validation_0-rmse:0.08720
# [375]	validation_0-rmse:0.08722
# [376]	validation_0-rmse:0.08723
# [377]	validation_0-rmse:0.08721
# [378]	validation_0-rmse:0.08721
# [379]	validation_0-rmse:0.08721
# [380]	validation_0-rmse:0.08723
# [381]	validation_0-rmse:0.08723
# [382]	validation_0-rmse:0.08723
# [383]	validation_0-rmse:0.08723
# [384]	validation_0-rmse:0.08723
# [385]	validation_0-rmse:0.08726
# [386]	validation_0-rmse:0.08726
# [387]	validation_0-rmse:0.08727
# [388]	validation_0-rmse:0.08728
# [389]	validation_0-rmse:0.08728
# [390]	validation_0-rmse:0.08727
# [391]	validation_0-rmse:0.08727
# [392]	validation_0-rmse:0.08726
# [393]	validation_0-rmse:0.08727
# [394]	validation_0-rmse:0.08727
# [395]	validation_0-rmse:0.08726
# [396]	validation_0-rmse:0.08726
# [397]	validation_0-rmse:0.08728
# [398]	validation_0-rmse:0.08729
# [399]	validation_0-rmse:0.08728
# [400]	validation_0-rmse:0.08728
# [401]	validation_0-rmse:0.08726
# [402]	validation_0-rmse:0.08728
# [403]	validation_0-rmse:0.08728
# [404]	validation_0-rmse:0.08728
# [405]	validation_0-rmse:0.08728
# [406]	validation_0-rmse:0.08728
# [407]	validation_0-rmse:0.08726
# [408]	validation_0-rmse:0.08727
# [409]	validation_0-rmse:0.08727
# [410]	validation_0-rmse:0.08727
# [411]	validation_0-rmse:0.08727
# [412]	validation_0-rmse:0.08728
# [413]	validation_0-rmse:0.08728
# [414]	validation_0-rmse:0.08727
# [415]	validation_0-rmse:0.08726
# [416]	validation_0-rmse:0.08729
# [417]	validation_0-rmse:0.08730
# [418]	validation_0-rmse:0.08730
# [419]	validation_0-rmse:0.08731
# [420]	validation_0-rmse:0.08730
# [421]	validation_0-rmse:0.08730
# [422]	validation_0-rmse:0.08730
# [423]	validation_0-rmse:0.08730
# [424]	validation_0-rmse:0.08730
# [425]	validation_0-rmse:0.08731
# [426]	validation_0-rmse:0.08730
# [427]	validation_0-rmse:0.08729
# [428]	validation_0-rmse:0.08729
# [429]	validation_0-rmse:0.08730
# [430]	validation_0-rmse:0.08730
# [431]	validation_0-rmse:0.08731
# [432]	validation_0-rmse:0.08730
# [433]	validation_0-rmse:0.08730
# [434]	validation_0-rmse:0.08730
# [435]	validation_0-rmse:0.08731
# [436]	validation_0-rmse:0.08731
# [437]	validation_0-rmse:0.08732
# [438]	validation_0-rmse:0.08731
# [439]	validation_0-rmse:0.08730
# [440]	validation_0-rmse:0.08731
# [441]	validation_0-rmse:0.08731
# [442]	validation_0-rmse:0.08731
# [443]	validation_0-rmse:0.08729
# [444]	validation_0-rmse:0.08729
# [445]	validation_0-rmse:0.08729
# [446]	validation_0-rmse:0.08730
# [447]	validation_0-rmse:0.08730
# [448]	validation_0-rmse:0.08730
# [449]	validation_0-rmse:0.08730
# [450]	validation_0-rmse:0.08731
# [451]	validation_0-rmse:0.08730
# [452]	validation_0-rmse:0.08730
# [453]	validation_0-rmse:0.08731
# [454]	validation_0-rmse:0.08732
# [455]	validation_0-rmse:0.08732
# [456]	validation_0-rmse:0.08733
# [457]	validation_0-rmse:0.08734
# [458]	validation_0-rmse:0.08734
# [459]	validation_0-rmse:0.08734
# [460]	validation_0-rmse:0.08735
# [461]	validation_0-rmse:0.08735
# [462]	validation_0-rmse:0.08735
# [463]	validation_0-rmse:0.08736
# [464]	validation_0-rmse:0.08737
# [465]	validation_0-rmse:0.08737
# [466]	validation_0-rmse:0.08737
# [467]	validation_0-rmse:0.08737
# [468]	validation_0-rmse:0.08736
# [469]	validation_0-rmse:0.08735
# [470]	validation_0-rmse:0.08736
# [471]	validation_0-rmse:0.08735
# [472]	validation_0-rmse:0.08734
# [473]	validation_0-rmse:0.08734
# [474]	validation_0-rmse:0.08735
# [475]	validation_0-rmse:0.08734
# [476]	validation_0-rmse:0.08733
# [477]	validation_0-rmse:0.08734
# [478]	validation_0-rmse:0.08732
# [479]	validation_0-rmse:0.08731
# [480]	validation_0-rmse:0.08731
# [481]	validation_0-rmse:0.08731
# [482]	validation_0-rmse:0.08731
# [483]	validation_0-rmse:0.08731
# [484]	validation_0-rmse:0.08733
# [485]	validation_0-rmse:0.08733
# [486]	validation_0-rmse:0.08732
# [487]	validation_0-rmse:0.08732
# [488]	validation_0-rmse:0.08732
# [489]	validation_0-rmse:0.08732
# [490]	validation_0-rmse:0.08732
# [491]	validation_0-rmse:0.08732
# [492]	validation_0-rmse:0.08731
# [493]	validation_0-rmse:0.08730
# [494]	validation_0-rmse:0.08731
# [495]	validation_0-rmse:0.08731
# [496]	validation_0-rmse:0.08732
# [497]	validation_0-rmse:0.08733
# [498]	validation_0-rmse:0.08733
# [499]	validation_0-rmse:0.08733
# [500]	validation_0-rmse:0.08732
# [501]	validation_0-rmse:0.08732
# [502]	validation_0-rmse:0.08732
# [503]	validation_0-rmse:0.08733
# [504]	validation_0-rmse:0.08732
# [505]	validation_0-rmse:0.08732
# [506]	validation_0-rmse:0.08732
# [507]	validation_0-rmse:0.08732
# [508]	validation_0-rmse:0.08732
# [509]	validation_0-rmse:0.08731
# [510]	validation_0-rmse:0.08732
# [511]	validation_0-rmse:0.08732
# [512]	validation_0-rmse:0.08732
# [594]	validation_0-rmse:0.08742
# [595]	validation_0-rmse:0.08742
# [596]	validation_0-rmse:0.08742
# [597]	validation_0-rmse:0.08743
# [598]	validation_0-rmse:0.08742
# [599]	validation_0-rmse:0.08742
# [600]	validation_0-rmse:0.08742
# [601]	validation_0-rmse:0.08743
# [602]	validation_0-rmse:0.08743
# [603]	validation_0-rmse:0.08743
# [604]	validation_0-rmse:0.08744
# [605]	validation_0-rmse:0.08743
# [606]	validation_0-rmse:0.08744
# [607]	validation_0-rmse:0.08743
# [608]	validation_0-rmse:0.08743
# [609]	validation_0-rmse:0.08743
# [610]	validation_0-rmse:0.08743
# [611]	validation_0-rmse:0.08744
# [612]	validation_0-rmse:0.08744
# [613]	validation_0-rmse:0.08744
# [614]	validation_0-rmse:0.08745
# [615]	validation_0-rmse:0.08746
# [616]	validation_0-rmse:0.08746
# [617]	validation_0-rmse:0.08746
# [618]	validation_0-rmse:0.08747
# [619]	validation_0-rmse:0.08745
# [620]	validation_0-rmse:0.08746
# [621]	validation_0-rmse:0.08747
# [622]	validation_0-rmse:0.08747
# [623]	validation_0-rmse:0.08747
# [624]	validation_0-rmse:0.08748
# [625]	validation_0-rmse:0.08747
# [626]	validation_0-rmse:0.08748
# [627]	validation_0-rmse:0.08748
# [628]	validation_0-rmse:0.08748
# [629]	validation_0-rmse:0.08748
# [630]	validation_0-rmse:0.08748
# [631]	validation_0-rmse:0.08749
# [632]	validation_0-rmse:0.08748
# [633]	validation_0-rmse:0.08749
# [634]	validation_0-rmse:0.08748
# [635]	validation_0-rmse:0.08748
# [636]	validation_0-rmse:0.08749
# 338

# %% [markdown]
# # Ronda 4: "subsample" y "colsample_bytree"

# %%
model = XGBRegressor()

params = {'random_state': [43],
          'n_estimators': [337],
          'eta': [0.15],
          'monotone_constraints':[{"weight (carat)": 1}],
          'subsample': np.linspace(0.5, 1.0, num=11),
          'colsample_bytree': np.linspace(0.5, 1.0, num=11)
            }

grid = GridSearchCV(estimator=model,
                    param_grid=params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')
# Out:
# Fitting 5 folds for each of 121 candidates, totalling 605 fits
# [CV 1/5] END colsample_bytree=0.5, eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=337, random_state=43, subsample=0.5;, score=-0.094 total time=   5.7s
# [CV 2/5] END colsample_bytree=0.5, eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=337, random_state=43, subsample=0.5;, score=-0.091 total time=   6.2s
# [CV 3/5] END colsample_bytree=0.5, eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=337, random_state=43, subsample=0.5;, score=-0.089 total time=   6.6s
# [CV 4/5] END colsample_bytree=0.5, eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=337, random_state=43, subsample=0.5;, score=-0.088 total time=   7.9s
# [CV 5/5] END colsample_bytree=0.5, eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=337, random_state=43, subsample=0.5;, score=-0.090 total time=   5.8s
# [CV 1/5] END colsample_bytree=0.5, eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=337, random_state=43, subsample=0.55;, score=-0.094 total time=   6.3s
# [CV 2/5] END colsample_bytree=0.5, eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=337, random_state=43, subsample=0.55;, score=-0.092 total time=   8.0s
# [CV 3/5] END colsample_bytree=0.5, eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=337, random_state=43, subsample=0.55;, score=-0.088 total time=   6.6s
# [CV 4/5] END colsample_bytree=0.5, eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=337, random_state=43, subsample=0.55;, score=-0.088 total time=   7.0s
# [CV 5/5] END colsample_bytree=0.5, eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=337, random_state=43, subsample=0.55;, score=-0.089 total time=   8.2s
# [CV 1/5] END colsample_bytree=0.5, eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=337, random_state=43, subsample=0.6;, score=-0.094 total time=   6.2s
# [CV 2/5] END colsample_bytree=0.5, eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=337, random_state=43, subsample=0.6;, score=-0.091 total time=   5.9s
# [CV 3/5] END colsample_bytree=0.5, eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=337, random_state=43, subsample=0.6;, score=-0.087 total time=   6.7s
# [CV 4/5] END colsample_bytree=0.5, eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=337, random_state=43, subsample=0.6;, score=-0.088 total time=   6.3s
# [CV 5/5] END colsample_bytree=0.5, eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=337, random_state=43, subsample=0.6;, score=-0.089 total time=   6.4s
# [CV 1/5] END colsample_bytree=0.5, eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=337, random_state=43, subsample=0.65;, score=-0.093 total time=   7.2s
# [CV 2/5] END colsample_bytree=0.5, eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=337, random_state=43, subsample=0.65;, score=-0.091 total time=   7.0s
# [CV 3/5] END colsample_bytree=0.5, eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=337, random_state=43, subsample=0.65;, score=-0.087 total time=   6.1s
# [CV 4/5] END colsample_bytree=0.5, eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=337, random_state=43, subsample=0.65;, score=-0.088 total time=   6.5s
# [CV 5/5] END colsample_bytree=0.5, eta=0.15, monotone_constraints={'weight (carat)': 1}, n_estimators=337, random_state=43, subsample=0.65;, score=-0.089 total time=   5.5s

# %%
model = XGBRegressor(n_estimators=1000, eta=0.15, monotone_constraints={"weight (carat)": 1}, subsample=None, colsample_bytree=None)

model.early_stopping_rounds = 300

model.fit(X_train, y_train, eval_set=[(X_test, y_test)]) 

model.best_ntree_limit

# %% [markdown]
# # Ronda 5: "max_depth" y "min_child_weight"

# %%
model = XGBRegressor()

params = {'random_state': [43],
          'n_estimators': [],
          'eta': [0.15],
          'monotone_constraints':[{"weight (carat)": 1}],
          'subsample': [],
          'colsample_bytree': [],
          'max_depth': range(1, 11),
          'min_child_weight': range(1, 11)
            }

grid = GridSearchCV(estimator=model,
                    param_grid=params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 1/5] END max_depth=1, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.136 total time=   0.8s
# [CV 2/5] END max_depth=1, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.134 total time=   0.6s
# [CV 3/5] END max_depth=1, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.129 total time=   0.6s
# [CV 4/5] END max_depth=1, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.133 total time=   0.6s
# [CV 5/5] END max_depth=1, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.131 total time=   0.6s
# [CV 1/5] END max_depth=1, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.136 total time=   0.6s
# [CV 2/5] END max_depth=1, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.134 total time=   0.6s
# [CV 3/5] END max_depth=1, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.129 total time=   0.6s
# [CV 4/5] END max_depth=1, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.133 total time=   0.6s
# [CV 5/5] END max_depth=1, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.131 total time=   0.6s
# [CV 1/5] END max_depth=1, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.136 total time=   0.6s
# [CV 2/5] END max_depth=1, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.134 total time=   0.6s
# [CV 3/5] END max_depth=1, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.129 total time=   0.6s
# [CV 4/5] END max_depth=1, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.132 total time=   0.6s
# [CV 5/5] END max_depth=1, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.131 total time=   0.6s
# [CV 1/5] END max_depth=1, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.136 total time=   0.6s
# [CV 2/5] END max_depth=1, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.134 total time=   0.6s
# [CV 3/5] END max_depth=1, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.129 total time=   0.7s
# [CV 4/5] END max_depth=1, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.132 total time=   0.7s
# [CV 5/5] END max_depth=1, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.131 total time=   0.6s
# [CV 1/5] END max_depth=1, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.136 total time=   0.8s
# [CV 2/5] END max_depth=1, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.134 total time=   0.6s
# [CV 3/5] END max_depth=1, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.129 total time=   0.8s
# [CV 4/5] END max_depth=1, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.133 total time=   0.9s
# [CV 5/5] END max_depth=1, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.131 total time=   0.6s
# [CV 1/5] END max_depth=1, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.136 total time=   0.6s
# [CV 2/5] END max_depth=1, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.134 total time=   0.6s
# [CV 3/5] END max_depth=1, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.129 total time=   0.5s
# [CV 4/5] END max_depth=1, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.133 total time=   0.6s
# [CV 5/5] END max_depth=1, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.131 total time=   0.7s
# [CV 1/5] END max_depth=1, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.136 total time=   0.8s
# [CV 2/5] END max_depth=1, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.134 total time=   0.8s
# [CV 3/5] END max_depth=1, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.129 total time=   0.7s
# [CV 4/5] END max_depth=1, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.133 total time=   0.6s
# [CV 5/5] END max_depth=1, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.131 total time=   0.6s
# [CV 1/5] END max_depth=1, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.136 total time=   0.8s
# [CV 2/5] END max_depth=1, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.134 total time=   0.6s
# [CV 3/5] END max_depth=1, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.129 total time=   0.5s
# [CV 4/5] END max_depth=1, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.133 total time=   0.7s
# [CV 5/5] END max_depth=1, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.131 total time=   0.6s
# [CV 1/5] END max_depth=1, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.136 total time=   1.0s
# [CV 2/5] END max_depth=1, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.134 total time=   0.8s
# [CV 3/5] END max_depth=1, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.129 total time=   0.8s
# [CV 4/5] END max_depth=1, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.133 total time=   0.6s
# [CV 5/5] END max_depth=1, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.131 total time=   0.7s
# [CV 1/5] END max_depth=1, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.136 total time=   0.7s
# [CV 2/5] END max_depth=1, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.134 total time=   0.6s
# [CV 3/5] END max_depth=1, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.129 total time=   0.7s
# [CV 4/5] END max_depth=1, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.133 total time=   0.6s
# [CV 5/5] END max_depth=1, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.131 total time=   0.6s
# [CV 1/5] END max_depth=2, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.105 total time=   0.9s
# [CV 2/5] END max_depth=2, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.101 total time=   1.6s
# [CV 3/5] END max_depth=2, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.099 total time=   1.1s
# [CV 4/5] END max_depth=2, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.098 total time=   1.1s
# [CV 5/5] END max_depth=2, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.101 total time=   1.0s
# [CV 1/5] END max_depth=2, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.105 total time=   1.0s
# [CV 2/5] END max_depth=2, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.101 total time=   1.0s
# [CV 3/5] END max_depth=2, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.099 total time=   1.5s
# [CV 4/5] END max_depth=2, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.099 total time=   2.4s
# [CV 5/5] END max_depth=2, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.101 total time=   1.3s
# [CV 1/5] END max_depth=2, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.105 total time=   1.1s
# [CV 2/5] END max_depth=2, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.101 total time=   1.2s
# [CV 3/5] END max_depth=2, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.099 total time=   1.5s
# [CV 4/5] END max_depth=2, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.100 total time=   1.1s
# [CV 5/5] END max_depth=2, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.101 total time=   2.4s
# [CV 1/5] END max_depth=2, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.105 total time=   1.4s
# [CV 2/5] END max_depth=2, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.101 total time=   1.3s
# [CV 3/5] END max_depth=2, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.099 total time=   1.2s
# [CV 4/5] END max_depth=2, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.099 total time=   1.2s
# [CV 5/5] END max_depth=2, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.101 total time=   1.0s
# [CV 1/5] END max_depth=2, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.105 total time=   1.1s
# [CV 2/5] END max_depth=2, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.101 total time=   1.0s
# [CV 3/5] END max_depth=2, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.099 total time=   1.0s
# [CV 4/5] END max_depth=2, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.099 total time=   1.0s
# [CV 5/5] END max_depth=2, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.101 total time=   1.2s
# [CV 1/5] END max_depth=2, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.105 total time=   1.1s
# [CV 2/5] END max_depth=2, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.101 total time=   1.1s
# [CV 3/5] END max_depth=2, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.099 total time=   1.1s
# [CV 4/5] END max_depth=2, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.099 total time=   1.8s
# [CV 5/5] END max_depth=2, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.101 total time=   1.1s
# [CV 1/5] END max_depth=2, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.104 total time=   1.4s
# [CV 2/5] END max_depth=2, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.101 total time=   1.4s
# [CV 3/5] END max_depth=2, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.099 total time=   1.3s
# [CV 4/5] END max_depth=2, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.099 total time=   1.3s
# [CV 5/5] END max_depth=2, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.101 total time=   1.2s
# [CV 1/5] END max_depth=2, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.105 total time=   1.1s
# [CV 2/5] END max_depth=2, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.101 total time=   1.2s
# [CV 3/5] END max_depth=2, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.099 total time=   0.9s
# [CV 4/5] END max_depth=2, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.099 total time=   1.0s
# [CV 5/5] END max_depth=2, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.101 total time=   0.9s
# [CV 1/5] END max_depth=2, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.105 total time=   0.9s
# [CV 2/5] END max_depth=2, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.101 total time=   0.9s
# [CV 3/5] END max_depth=2, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.099 total time=   0.9s
# [CV 4/5] END max_depth=2, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.099 total time=   0.9s
# [CV 5/5] END max_depth=2, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.101 total time=   0.9s
# [CV 1/5] END max_depth=2, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.105 total time=   0.9s
# [CV 2/5] END max_depth=2, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.101 total time=   0.9s
# [CV 3/5] END max_depth=2, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.099 total time=   0.9s
# [CV 4/5] END max_depth=2, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.099 total time=   0.9s
# [CV 5/5] END max_depth=2, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.101 total time=   0.9s
# [CV 1/5] END max_depth=3, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.098 total time=   1.4s
# [CV 2/5] END max_depth=3, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.094 total time=   1.3s
# [CV 3/5] END max_depth=3, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   1.3s
# [CV 4/5] END max_depth=3, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   1.3s
# [CV 5/5] END max_depth=3, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   1.3s
# [CV 1/5] END max_depth=3, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.098 total time=   1.4s
# [CV 2/5] END max_depth=3, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.094 total time=   1.3s
# [CV 3/5] END max_depth=3, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   1.4s
# [CV 4/5] END max_depth=3, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   1.3s
# [CV 5/5] END max_depth=3, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   1.4s
# [CV 1/5] END max_depth=3, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.098 total time=   1.6s
# [CV 2/5] END max_depth=3, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.094 total time=   1.3s
# [CV 3/5] END max_depth=3, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   1.3s
# [CV 4/5] END max_depth=3, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   1.4s
# [CV 5/5] END max_depth=3, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   1.3s
# [CV 1/5] END max_depth=3, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.097 total time=   1.3s
# [CV 2/5] END max_depth=3, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.094 total time=   1.3s
# [CV 3/5] END max_depth=3, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   1.3s
# [CV 4/5] END max_depth=3, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   1.4s
# [CV 5/5] END max_depth=3, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   1.3s
# [CV 1/5] END max_depth=3, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.098 total time=   1.3s
# [CV 2/5] END max_depth=3, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.094 total time=   1.4s
# [CV 3/5] END max_depth=3, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   1.3s
# [CV 4/5] END max_depth=3, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   1.3s
# [CV 5/5] END max_depth=3, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   1.3s
# [CV 1/5] END max_depth=3, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.098 total time=   1.3s
# [CV 2/5] END max_depth=3, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.095 total time=   1.3s
# [CV 3/5] END max_depth=3, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   1.3s
# [CV 4/5] END max_depth=3, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   1.4s
# [CV 5/5] END max_depth=3, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   1.3s
# [CV 1/5] END max_depth=3, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.098 total time=   1.3s
# [CV 2/5] END max_depth=3, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.094 total time=   1.3s
# [CV 3/5] END max_depth=3, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   1.3s
# [CV 4/5] END max_depth=3, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   1.3s
# [CV 5/5] END max_depth=3, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.094 total time=   1.3s
# [CV 1/5] END max_depth=3, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.097 total time=   1.3s
# [CV 2/5] END max_depth=3, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.094 total time=   1.3s
# [CV 3/5] END max_depth=3, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   1.5s
# [CV 4/5] END max_depth=3, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   1.3s
# [CV 5/5] END max_depth=3, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   1.3s
# [CV 1/5] END max_depth=3, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.098 total time=   1.3s
# [CV 2/5] END max_depth=3, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.094 total time=   1.3s
# [CV 3/5] END max_depth=3, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   1.3s
# [CV 4/5] END max_depth=3, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   1.3s
# [CV 5/5] END max_depth=3, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   1.3s
# [CV 1/5] END max_depth=3, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.098 total time=   1.3s
# [CV 2/5] END max_depth=3, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.095 total time=   1.3s
# [CV 3/5] END max_depth=3, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   1.3s
# [CV 4/5] END max_depth=3, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   1.3s
# [CV 5/5] END max_depth=3, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.094 total time=   1.3s
# [CV 1/5] END max_depth=4, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.094 total time=   1.8s
# [CV 2/5] END max_depth=4, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   1.8s
# [CV 3/5] END max_depth=4, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   1.8s
# [CV 4/5] END max_depth=4, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   1.8s
# [CV 5/5] END max_depth=4, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   1.8s
# [CV 1/5] END max_depth=4, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.095 total time=   1.8s
# [CV 2/5] END max_depth=4, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   1.8s
# [CV 3/5] END max_depth=4, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   1.8s
# [CV 4/5] END max_depth=4, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   1.8s
# [CV 5/5] END max_depth=4, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   1.8s
# [CV 1/5] END max_depth=4, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.095 total time=   1.9s
# [CV 2/5] END max_depth=4, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   1.8s
# [CV 3/5] END max_depth=4, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   1.8s
# [CV 4/5] END max_depth=4, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   1.8s
# [CV 5/5] END max_depth=4, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   1.8s
# [CV 1/5] END max_depth=4, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.095 total time=   1.8s
# [CV 2/5] END max_depth=4, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   1.8s
# [CV 3/5] END max_depth=4, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   1.8s
# [CV 4/5] END max_depth=4, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   1.8s
# [CV 5/5] END max_depth=4, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   1.8s
# [CV 1/5] END max_depth=4, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.095 total time=   1.8s
# [CV 2/5] END max_depth=4, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   1.8s
# [CV 3/5] END max_depth=4, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   1.8s
# [CV 4/5] END max_depth=4, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   1.8s
# [CV 5/5] END max_depth=4, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   1.8s
# [CV 1/5] END max_depth=4, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.094 total time=   1.8s
# [CV 2/5] END max_depth=4, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   1.8s
# [CV 3/5] END max_depth=4, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   1.8s
# [CV 4/5] END max_depth=4, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   1.8s
# [CV 5/5] END max_depth=4, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   1.8s
# [CV 1/5] END max_depth=4, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.095 total time=   1.9s
# [CV 2/5] END max_depth=4, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   1.8s
# [CV 3/5] END max_depth=4, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   1.8s
# [CV 4/5] END max_depth=4, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   1.8s
# [CV 5/5] END max_depth=4, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   1.8s
# [CV 1/5] END max_depth=4, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.094 total time=   1.8s
# [CV 2/5] END max_depth=4, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   1.9s
# [CV 3/5] END max_depth=4, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   1.8s
# [CV 4/5] END max_depth=4, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   1.8s
# [CV 5/5] END max_depth=4, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   1.8s
# [CV 1/5] END max_depth=4, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.095 total time=   1.8s
# [CV 2/5] END max_depth=4, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   1.8s
# [CV 3/5] END max_depth=4, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   1.8s
# [CV 4/5] END max_depth=4, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   1.8s
# [CV 5/5] END max_depth=4, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   1.8s
# [CV 1/5] END max_depth=4, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.094 total time=   1.8s
# [CV 2/5] END max_depth=4, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   1.8s
# [CV 3/5] END max_depth=4, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   1.8s
# [CV 4/5] END max_depth=4, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   1.8s
# [CV 5/5] END max_depth=4, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   1.8s
# [CV 1/5] END max_depth=5, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   2.3s
# [CV 2/5] END max_depth=5, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   2.5s
# [CV 3/5] END max_depth=5, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.088 total time=   2.3s
# [CV 4/5] END max_depth=5, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   2.3s
# [CV 5/5] END max_depth=5, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   2.3s
# [CV 1/5] END max_depth=5, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   2.3s
# [CV 2/5] END max_depth=5, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   2.3s
# [CV 3/5] END max_depth=5, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   2.3s
# [CV 4/5] END max_depth=5, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   2.3s
# [CV 5/5] END max_depth=5, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   2.3s
# [CV 1/5] END max_depth=5, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   2.3s
# [CV 2/5] END max_depth=5, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   2.3s
# [CV 3/5] END max_depth=5, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   2.3s
# [CV 4/5] END max_depth=5, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   2.3s
# [CV 5/5] END max_depth=5, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   2.3s
# [CV 1/5] END max_depth=5, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   2.3s
# [CV 2/5] END max_depth=5, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   2.3s
# [CV 3/5] END max_depth=5, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   2.3s
# [CV 4/5] END max_depth=5, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   2.3s
# [CV 5/5] END max_depth=5, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   2.2s
# [CV 1/5] END max_depth=5, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   2.3s
# [CV 2/5] END max_depth=5, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   2.5s
# [CV 3/5] END max_depth=5, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   2.3s
# [CV 4/5] END max_depth=5, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   2.3s
# [CV 5/5] END max_depth=5, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   2.7s
# [CV 1/5] END max_depth=5, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   2.5s
# [CV 2/5] END max_depth=5, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   2.4s
# [CV 3/5] END max_depth=5, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   2.2s
# [CV 4/5] END max_depth=5, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   2.2s
# [CV 5/5] END max_depth=5, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   2.2s
# [CV 1/5] END max_depth=5, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   2.3s
# [CV 2/5] END max_depth=5, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   2.2s
# [CV 3/5] END max_depth=5, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.088 total time=   2.3s
# [CV 4/5] END max_depth=5, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   2.3s
# [CV 5/5] END max_depth=5, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   2.2s
# [CV 1/5] END max_depth=5, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   2.3s
# [CV 2/5] END max_depth=5, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   2.2s
# [CV 3/5] END max_depth=5, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   2.3s
# [CV 4/5] END max_depth=5, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   2.2s
# [CV 5/5] END max_depth=5, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   2.2s
# [CV 1/5] END max_depth=5, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   2.7s
# [CV 2/5] END max_depth=5, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   3.0s
# [CV 3/5] END max_depth=5, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   2.5s
# [CV 4/5] END max_depth=5, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   2.3s
# [CV 5/5] END max_depth=5, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   2.2s
# [CV 1/5] END max_depth=5, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   2.2s
# [CV 2/5] END max_depth=5, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   2.2s
# [CV 3/5] END max_depth=5, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   2.2s
# [CV 4/5] END max_depth=5, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   2.3s
# [CV 5/5] END max_depth=5, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   2.2s
# [CV 1/5] END max_depth=6, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   2.8s
# [CV 2/5] END max_depth=6, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   2.8s
# [CV 3/5] END max_depth=6, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.088 total time=   2.8s
# [CV 4/5] END max_depth=6, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   2.8s
# [CV 5/5] END max_depth=6, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   2.8s
# [CV 1/5] END max_depth=6, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   2.8s
# [CV 2/5] END max_depth=6, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   2.8s
# [CV 3/5] END max_depth=6, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.088 total time=   3.0s
# [CV 4/5] END max_depth=6, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   2.8s
# [CV 5/5] END max_depth=6, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   2.8s
# [CV 1/5] END max_depth=6, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   2.8s
# [CV 2/5] END max_depth=6, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   2.8s
# [CV 3/5] END max_depth=6, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.088 total time=   2.8s
# [CV 4/5] END max_depth=6, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   3.5s
# [CV 5/5] END max_depth=6, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   2.9s
# [CV 1/5] END max_depth=6, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   3.7s
# [CV 2/5] END max_depth=6, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   4.7s
# [CV 3/5] END max_depth=6, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   3.1s
# [CV 4/5] END max_depth=6, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   2.7s
# [CV 5/5] END max_depth=6, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   3.0s
# [CV 1/5] END max_depth=6, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   3.8s
# [CV 2/5] END max_depth=6, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   3.3s
# [CV 3/5] END max_depth=6, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   2.8s
# [CV 4/5] END max_depth=6, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   2.8s
# [CV 5/5] END max_depth=6, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   2.8s
# [CV 1/5] END max_depth=6, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   2.8s
# [CV 2/5] END max_depth=6, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   2.8s
# [CV 3/5] END max_depth=6, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   2.8s
# [CV 4/5] END max_depth=6, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   2.8s
# [CV 5/5] END max_depth=6, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   3.8s
# [CV 1/5] END max_depth=6, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   3.3s
# [CV 2/5] END max_depth=6, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   5.5s
# [CV 3/5] END max_depth=6, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   6.4s
# [CV 4/5] END max_depth=6, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   3.8s
# [CV 5/5] END max_depth=6, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   3.1s
# [CV 1/5] END max_depth=6, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   3.1s
# [CV 2/5] END max_depth=6, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   2.8s
# [CV 3/5] END max_depth=6, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.088 total time=   2.9s
# [CV 4/5] END max_depth=6, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   3.1s
# [CV 5/5] END max_depth=6, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   2.9s
# [CV 1/5] END max_depth=6, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   3.0s
# [CV 2/5] END max_depth=6, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   4.0s
# [CV 3/5] END max_depth=6, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   3.0s
# [CV 4/5] END max_depth=6, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   5.8s
# [CV 5/5] END max_depth=6, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.088 total time=   3.5s
# [CV 1/5] END max_depth=6, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   3.1s
# [CV 2/5] END max_depth=6, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   3.1s
# [CV 3/5] END max_depth=6, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.088 total time=   2.8s
# [CV 4/5] END max_depth=6, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   2.8s
# [CV 5/5] END max_depth=6, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.089 total time=   3.0s
# [CV 1/5] END max_depth=7, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   4.4s
# [CV 2/5] END max_depth=7, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   4.0s
# [CV 3/5] END max_depth=7, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   3.7s
# ...
# [CV 2/5] END max_depth=9, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   4.6s
# [CV 3/5] END max_depth=9, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   4.6s
# [CV 4/5] END max_depth=9, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   4.6s
# [CV 5/5] END max_depth=9, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   4.8s
# [CV 1/5] END max_depth=9, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   4.6s
# [CV 2/5] END max_depth=9, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   4.6s
# [CV 3/5] END max_depth=9, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   4.6s
# [CV 4/5] END max_depth=9, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   4.6s
# [CV 5/5] END max_depth=9, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   4.7s
# [CV 1/5] END max_depth=9, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   5.5s
# [CV 2/5] END max_depth=9, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   5.0s
# [CV 3/5] END max_depth=9, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   5.4s
# [CV 4/5] END max_depth=9, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   4.5s
# [CV 5/5] END max_depth=9, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   4.5s
# [CV 1/5] END max_depth=9, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   4.7s
# [CV 2/5] END max_depth=9, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   4.5s
# [CV 3/5] END max_depth=9, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   4.4s
# [CV 4/5] END max_depth=9, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   4.4s
# [CV 5/5] END max_depth=9, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   4.5s
# [CV 1/5] END max_depth=9, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   4.4s
# [CV 2/5] END max_depth=9, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   4.4s
# [CV 3/5] END max_depth=9, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   4.3s
# [CV 4/5] END max_depth=9, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   4.4s
# [CV 5/5] END max_depth=9, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   4.4s
# [CV 1/5] END max_depth=9, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   4.3s
# [CV 2/5] END max_depth=9, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   4.3s
# [CV 3/5] END max_depth=9, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   4.5s
# [CV 4/5] END max_depth=9, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   4.3s
# [CV 5/5] END max_depth=9, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   4.3s
# [CV 1/5] END max_depth=9, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   4.3s
# [CV 2/5] END max_depth=9, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   4.3s
# [CV 3/5] END max_depth=9, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   4.3s
# [CV 4/5] END max_depth=9, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   4.3s
# [CV 5/5] END max_depth=9, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   4.3s
# [CV 1/5] END max_depth=9, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   4.2s
# [CV 2/5] END max_depth=9, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   4.3s
# [CV 3/5] END max_depth=9, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   4.3s
# [CV 4/5] END max_depth=9, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   4.9s
# [CV 5/5] END max_depth=9, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   6.5s
# [CV 1/5] END max_depth=9, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   4.8s
# [CV 2/5] END max_depth=9, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   3.9s
# [CV 3/5] END max_depth=9, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   4.0s
# [CV 4/5] END max_depth=9, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   4.0s
# [CV 5/5] END max_depth=9, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   3.9s
# [CV 1/5] END max_depth=9, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   3.9s
# [CV 2/5] END max_depth=9, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   3.9s
# [CV 3/5] END max_depth=9, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   3.9s
# [CV 4/5] END max_depth=9, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   3.9s
# [CV 5/5] END max_depth=9, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   3.8s
# [CV 1/5] END max_depth=10, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.094 total time=   5.0s
# [CV 2/5] END max_depth=10, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.094 total time=   4.9s
# [CV 3/5] END max_depth=10, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   4.8s
# [CV 4/5] END max_depth=10, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   4.9s
# [CV 5/5] END max_depth=10, min_child_weight=1, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   4.8s
# [CV 1/5] END max_depth=10, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.094 total time=   4.7s
# [CV 2/5] END max_depth=10, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.095 total time=   4.8s
# [CV 3/5] END max_depth=10, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   4.7s
# [CV 4/5] END max_depth=10, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   4.8s
# [CV 5/5] END max_depth=10, min_child_weight=2, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   5.0s
# [CV 1/5] END max_depth=10, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.094 total time=   4.7s
# [CV 2/5] END max_depth=10, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.094 total time=   4.7s
# [CV 3/5] END max_depth=10, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   4.7s
# [CV 4/5] END max_depth=10, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   4.7s
# [CV 5/5] END max_depth=10, min_child_weight=3, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   4.6s
# [CV 1/5] END max_depth=10, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.094 total time=   4.6s
# [CV 2/5] END max_depth=10, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   4.6s
# [CV 3/5] END max_depth=10, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   5.1s
# [CV 4/5] END max_depth=10, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   4.7s
# [CV 5/5] END max_depth=10, min_child_weight=4, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   4.6s
# [CV 1/5] END max_depth=10, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.094 total time=   4.5s
# [CV 2/5] END max_depth=10, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=   4.5s
# [CV 3/5] END max_depth=10, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   4.6s
# [CV 4/5] END max_depth=10, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   4.5s
# [CV 5/5] END max_depth=10, min_child_weight=5, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   4.7s
# [CV 1/5] END max_depth=10, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   4.5s
# [CV 2/5] END max_depth=10, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   4.5s
# [CV 3/5] END max_depth=10, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   5.1s
# [CV 4/5] END max_depth=10, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   6.2s
# [CV 5/5] END max_depth=10, min_child_weight=6, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.092 total time=  26.2s
# [CV 1/5] END max_depth=10, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=  16.1s
# [CV 2/5] END max_depth=10, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=  15.2s
# [CV 3/5] END max_depth=10, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=  10.1s
# [CV 4/5] END max_depth=10, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   4.9s
# [CV 5/5] END max_depth=10, min_child_weight=7, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   5.0s
# [CV 1/5] END max_depth=10, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   4.9s
# [CV 2/5] END max_depth=10, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   4.8s
# [CV 3/5] END max_depth=10, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   4.9s
# [CV 4/5] END max_depth=10, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   4.8s
# [CV 5/5] END max_depth=10, min_child_weight=8, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   4.8s
# [CV 1/5] END max_depth=10, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   4.9s
# [CV 2/5] END max_depth=10, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   5.1s
# [CV 3/5] END max_depth=10, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   4.8s
# [CV 4/5] END max_depth=10, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   4.9s
# [CV 5/5] END max_depth=10, min_child_weight=9, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   4.8s
# [CV 1/5] END max_depth=10, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   4.8s
# [CV 2/5] END max_depth=10, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.093 total time=   5.2s
# [CV 3/5] END max_depth=10, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   5.4s
# [CV 4/5] END max_depth=10, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.091 total time=   4.8s
# [CV 5/5] END max_depth=10, min_child_weight=10, monotone_constraints={'weight (carat)': 1}, n_estimators=195, random_state=43;, score=-0.090 total time=   4.8s
# Best params: {'max_depth': 6, 'min_child_weight': 2, 'monotone_constraints': {'weight (carat)': 1}, 'n_estimators': 195, 'random_state': 43}
# Best score: -0.08977119390057887

# %%
model = XGBRegressor(random_state=43, n_estimators=1000, eta=0.15, monotone_constraints={"weight (carat)": 1}, subsample=None, colsample_bytree=None, max_depth=None, min_child_weight=None)

model.early_stopping_rounds = 300

model.fit(X_train, y_train, eval_set=[(X_test, y_test)]) 

model.best_ntree_limit

# %% [markdown]
# # Ronda 6: "num_parallel_tree"

# %%
model = XGBRegressor()

params = {'random_state': [43],
          'n_estimators': [],
          'eta': [0.15],
          'monotone_constraints':[{"weight (carat)": 1}],
          'subsample': [],
          'colsample_bytree': [],
          'max_depth': [],
          'min_child_weight': [],
          'num_parallel_tree': range(1, 6)
            }

grid = GridSearchCV(estimator=model,
                    param_grid=params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')

# %%
model = XGBRegressor(random_state=43, n_estimators=1000, eta=0.15, monotone_constraints={"weight (carat)": 1}, subsample=None, colsample_bytree=None, max_depth=None, min_child_weight=None, num_parallel_tree=None)

model.early_stopping_rounds = 300

model.fit(X_train, y_train, eval_set=[(X_test, y_test)]) 

model.best_ntree_limit

# %% [markdown]
# # Ronda 7: hiperparámetros de regularización

# %%
model = XGBRegressor()

params = {'random_state': [43],
          'n_estimators': [],
          'eta': [0.15],
          'monotone_constraints':[{"weight (carat)": 1}],
          'subsample': [],
          'colsample_bytree': [],
          'max_depth': [],
          'min_child_weight': [],
          'num_parallel_tree': [],
          'max_delta_step': range(0, 6),
          'gamma': np.linspace(0, 0.5, num=6),
          'lambda': np.linspace(0, 1, num=11),
          'reg_alpha': np.linspace(0, 0.5, num=6)
            }

grid = GridSearchCV(estimator=model,
                    param_grid=params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')

# %%
model = XGBRegressor(random_state=43, 
                        n_estimators=1000, 
                        eta=0.15,
                        monotone_constraints={"weight (carat)": 1}, 
                        subsample=None, 
                        colsample_bytree=None, 
                        max_depth=None, 
                        min_child_weight=None, 
                        num_parallel_tree=None,
                        max_delta_step=None,
                        gamma=None,
                        reg_lambda=None,
                        reg_alpha=None
                    )

model.early_stopping_rounds = 300

model.fit(X_train, y_train, eval_set=[(X_test, y_test)]) 

model.best_ntree_limit
