# %%
import os

from sklearn.model_selection import GridSearchCV

from sklearn.metrics import make_scorer

if str(os.getcwdb()[-3:]).split("'")[1] != 'src':
    os.chdir(os.path.dirname(os.getcwdb()))

from utils.modeling import *
from utils.functions import *

# %%
df_diamonds = pd.read_csv(r'data\processed\diamonds_training.csv', index_col='id')
df_predict = pd.read_csv(r'data\processed\diamonds_testing.csv', index_col='id')

# %%
Regression.add_models(['XGBRegressor'])

rmse = make_scorer(calculate_rmse, greater_is_better=False)

kfolds = KFold(n_splits=5, shuffle=True, random_state=43)

# %% [markdown]
# # Introducción
#
# - Como se ha visto en "Feature_engineering", el mejor modelo a aplicar es "XGBRegressor"
#
# - Si bien se le ha sacado bastante partido con varios parámetros, aún quedan muchas combinaciones por probar
#
# - A continuación, se experimenta de forma extensiva con este modelo con tal de obtener los mejores resultados posibles

# %% [markdown]
# # Ronda 1: base
# - Esta primera ronda se lleva a cabo solo para poder ir comparando las mejoras

# %%
df_1 = df_diamonds.copy()

round_1 = Regression(df_diamonds, 'price')
X_train, X_test, y_train, y_test = round_1.split_dataframe()
round_1.prepare_models(params_list=[['XGBRegressor', 'random_state=43']])
round_1.apply_and_evaluate_kfolds()
round_1.create_dataframe()
# Out:
# -- Regression: using mean of 5 folds --
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 9.3 sec(s). Total time: 9.3
#           XGBRegressor: random_state=43
# mae                            0.065596
# mape                           0.008468
# mse                            0.008247
# r2_score                       0.991976
# rmse                           0.090762

# %% [markdown]
# # Ronda 2: solo cambios
#
# - Similar a la anterior, esta ronda sirve de punto de partida

# %%
df_cambios = df_diamonds.copy()

df_cambios = remove_all(df_cambios, zeros_only=True)

df_cambios = assign_values(df_cambios, outlier=False)

df_2 = df_cambios.copy()

round_2 = Regression(df_2, 'price')
X_train, X_test, y_train, y_test = round_2.split_dataframe()
round_2.prepare_models(params_list=[['XGBRegressor', 'random_state=43']])
round_2.apply_and_evaluate_kfolds()
round_2.create_dataframe()
# Out:
# -- Regression: using mean of 5 folds --
# Starting XGBRegressor: random_state=43:
# - XGBRegressor: random_state=43 done in 5.43 sec(s). Total time: 5.43
#           XGBRegressor: random_state=43
# mae                            0.065675
# mape                           0.008483
# mse                            0.008221
# r2_score                       0.992033
# rmse                           0.090657

# %% [markdown]
# # Ronda 3: "estimators"
#
# - Se utiliza "gbtree" porque ofrece buenos resultados y es relativamente rápido
#
# - Como es una cifra que puede variar mucho, se buscan los "estimators" primero
#
# - Se encuentra el número de "estimators" óptimo para los valores por defecto

# %%
# Aunque dé a entender que el mejor estimador es 196, al examinar los resultados se ve claro que hay que restarle 1 y es 195
model = XGBRegressor(n_estimators=1000)

model.early_stopping_rounds = 300

model.fit(X_train, y_train, eval_set=[(X_test, y_test)]) 

model.best_ntree_limit
# Out:
# [0]	validation_0-rmse:5.15340
# [1]	validation_0-rmse:3.61090
# [2]	validation_0-rmse:2.53117
# [3]	validation_0-rmse:1.77563
# [4]	validation_0-rmse:1.24698
# [5]	validation_0-rmse:0.87780
# 196

# %% [markdown]
# # Ronda 4: "max_depth" y "min_child_weight"
#
# - Estos dos influyen mucho, así que se buscan inmediatamente después de los "estimators"

# %%
model = XGBRegressor()

params = {'random_state': [43],
          'booster': ['gbtree'],
          'n_estimators': [195],
          'max_depth': range(3, 21),
          'min_child_weight': range(1, 11)
            }

grid = GridSearchCV(estimator=model,
                    param_grid=params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')
# Out:
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# [CV 1/5] END booster=gbtree, max_depth=3, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.098 total time=   2.5s
# [CV 2/5] END booster=gbtree, max_depth=3, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.094 total time=   2.3s
# [CV 3/5] END booster=gbtree, max_depth=3, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.093 total time=   2.1s
# [CV 4/5] END booster=gbtree, max_depth=3, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.092 total time=   1.7s
# [CV 5/5] END booster=gbtree, max_depth=3, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.092 total time=   1.7s
# [CV 1/5] END booster=gbtree, max_depth=3, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.098 total time=   2.1s
# [CV 2/5] END booster=gbtree, max_depth=3, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.094 total time=   2.8s
# [CV 3/5] END booster=gbtree, max_depth=3, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.092 total time=   3.8s
# [CV 4/5] END booster=gbtree, max_depth=3, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.091 total time=   8.0s
# [CV 5/5] END booster=gbtree, max_depth=3, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.092 total time=   1.9s
# [CV 1/5] END booster=gbtree, max_depth=3, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.098 total time=   2.6s
# [CV 2/5] END booster=gbtree, max_depth=3, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.093 total time=   2.4s
# [CV 3/5] END booster=gbtree, max_depth=3, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.092 total time=   6.3s
# [CV 4/5] END booster=gbtree, max_depth=3, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.091 total time=   2.2s
# [CV 5/5] END booster=gbtree, max_depth=3, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.093 total time=   1.6s
# [CV 1/5] END booster=gbtree, max_depth=3, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.098 total time=   2.1s
# [CV 2/5] END booster=gbtree, max_depth=3, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.094 total time=   1.7s
# [CV 3/5] END booster=gbtree, max_depth=3, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.092 total time=   2.8s
# [CV 4/5] END booster=gbtree, max_depth=3, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.091 total time=   2.0s
# [CV 5/5] END booster=gbtree, max_depth=3, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.093 total time=   2.7s
# [CV 1/5] END booster=gbtree, max_depth=3, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.098 total time=   1.6s
# [CV 2/5] END booster=gbtree, max_depth=3, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.094 total time=   1.1s
# [CV 3/5] END booster=gbtree, max_depth=3, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.092 total time=   1.1s
# [CV 4/5] END booster=gbtree, max_depth=3, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.091 total time=   1.4s
# [CV 5/5] END booster=gbtree, max_depth=3, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.093 total time=   1.8s
# [CV 1/5] END booster=gbtree, max_depth=3, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.098 total time=   1.8s
# [CV 2/5] END booster=gbtree, max_depth=3, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.094 total time=   1.5s
# [CV 3/5] END booster=gbtree, max_depth=3, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.092 total time=   2.0s
# [CV 4/5] END booster=gbtree, max_depth=3, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.092 total time=   1.8s
# [CV 5/5] END booster=gbtree, max_depth=3, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.093 total time=   1.7s
# [CV 1/5] END booster=gbtree, max_depth=3, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.099 total time=   2.1s
# [CV 2/5] END booster=gbtree, max_depth=3, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.094 total time=   1.6s
# [CV 3/5] END booster=gbtree, max_depth=3, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.092 total time=   1.4s
# [CV 4/5] END booster=gbtree, max_depth=3, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.091 total time=   1.3s
# [CV 5/5] END booster=gbtree, max_depth=3, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.092 total time=   1.2s
# [CV 1/5] END booster=gbtree, max_depth=3, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.098 total time=   1.1s
# [CV 2/5] END booster=gbtree, max_depth=3, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.094 total time=   1.3s
# [CV 3/5] END booster=gbtree, max_depth=3, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.092 total time=   1.1s
# [CV 4/5] END booster=gbtree, max_depth=3, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.091 total time=   1.1s
# [CV 5/5] END booster=gbtree, max_depth=3, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.092 total time=   1.0s
# [CV 1/5] END booster=gbtree, max_depth=3, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.098 total time=   1.1s
# [CV 2/5] END booster=gbtree, max_depth=3, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.094 total time=   1.1s
# [CV 3/5] END booster=gbtree, max_depth=3, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.092 total time=   1.1s
# [CV 4/5] END booster=gbtree, max_depth=3, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.091 total time=   1.3s
# [CV 5/5] END booster=gbtree, max_depth=3, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.093 total time=   1.1s
# [CV 1/5] END booster=gbtree, max_depth=3, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.097 total time=   1.1s
# [CV 2/5] END booster=gbtree, max_depth=3, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.094 total time=   1.1s
# [CV 3/5] END booster=gbtree, max_depth=3, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.092 total time=   1.1s
# [CV 4/5] END booster=gbtree, max_depth=3, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.091 total time=   1.1s
# [CV 5/5] END booster=gbtree, max_depth=3, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.093 total time=   1.1s
# [CV 1/5] END booster=gbtree, max_depth=4, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.094 total time=   1.5s
# [CV 2/5] END booster=gbtree, max_depth=4, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.092 total time=   1.8s
# [CV 3/5] END booster=gbtree, max_depth=4, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.090 total time=   1.8s
# [CV 4/5] END booster=gbtree, max_depth=4, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.090 total time=   1.5s
# [CV 5/5] END booster=gbtree, max_depth=4, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.091 total time=   1.4s
# [CV 1/5] END booster=gbtree, max_depth=4, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.094 total time=   1.4s
# [CV 2/5] END booster=gbtree, max_depth=4, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.092 total time=   1.4s
# [CV 3/5] END booster=gbtree, max_depth=4, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.089 total time=   1.4s
# [CV 4/5] END booster=gbtree, max_depth=4, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.090 total time=   1.4s
# [CV 5/5] END booster=gbtree, max_depth=4, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.091 total time=   1.4s
# [CV 1/5] END booster=gbtree, max_depth=4, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.094 total time=   1.5s
# [CV 2/5] END booster=gbtree, max_depth=4, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.092 total time=   1.6s
# [CV 3/5] END booster=gbtree, max_depth=4, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.090 total time=   1.5s
# [CV 4/5] END booster=gbtree, max_depth=4, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.090 total time=   1.4s
# [CV 5/5] END booster=gbtree, max_depth=4, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.091 total time=   1.4s
# [CV 1/5] END booster=gbtree, max_depth=4, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.094 total time=   1.5s
# [CV 2/5] END booster=gbtree, max_depth=4, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.093 total time=   1.5s
# [CV 3/5] END booster=gbtree, max_depth=4, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.089 total time=   1.4s
# [CV 4/5] END booster=gbtree, max_depth=4, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.090 total time=   1.5s
# [CV 5/5] END booster=gbtree, max_depth=4, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.091 total time=   1.4s
# [CV 1/5] END booster=gbtree, max_depth=4, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.095 total time=   1.6s
# [CV 2/5] END booster=gbtree, max_depth=4, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.093 total time=   1.5s
# [CV 3/5] END booster=gbtree, max_depth=4, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.089 total time=   1.4s
# [CV 4/5] END booster=gbtree, max_depth=4, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.090 total time=   1.5s
# [CV 5/5] END booster=gbtree, max_depth=4, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.091 total time=   1.4s
# [CV 1/5] END booster=gbtree, max_depth=4, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.095 total time=   1.5s
# [CV 2/5] END booster=gbtree, max_depth=4, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.093 total time=   1.4s
# [CV 3/5] END booster=gbtree, max_depth=4, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.089 total time=   1.4s
# [CV 4/5] END booster=gbtree, max_depth=4, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.090 total time=   1.4s
# [CV 5/5] END booster=gbtree, max_depth=4, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.092 total time=   1.7s
# [CV 1/5] END booster=gbtree, max_depth=4, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.095 total time=   1.4s
# [CV 2/5] END booster=gbtree, max_depth=4, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.093 total time=   1.5s
# [CV 3/5] END booster=gbtree, max_depth=4, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.089 total time=   1.4s
# [CV 4/5] END booster=gbtree, max_depth=4, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.090 total time=   1.5s
# [CV 5/5] END booster=gbtree, max_depth=4, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.091 total time=   1.5s
# [CV 1/5] END booster=gbtree, max_depth=4, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.095 total time=   1.5s
# [CV 2/5] END booster=gbtree, max_depth=4, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.094 total time=   1.5s
# [CV 3/5] END booster=gbtree, max_depth=4, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.089 total time=   1.6s
# [CV 4/5] END booster=gbtree, max_depth=4, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.090 total time=   1.5s
# [CV 5/5] END booster=gbtree, max_depth=4, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.091 total time=   1.5s
# [CV 1/5] END booster=gbtree, max_depth=4, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.095 total time=   1.5s
# [CV 2/5] END booster=gbtree, max_depth=4, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.094 total time=   1.5s
# [CV 3/5] END booster=gbtree, max_depth=4, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.090 total time=   1.7s
# [CV 4/5] END booster=gbtree, max_depth=4, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.090 total time=   2.1s
# [CV 5/5] END booster=gbtree, max_depth=4, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.091 total time=   2.0s
# [CV 1/5] END booster=gbtree, max_depth=4, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.094 total time=   2.2s
# [CV 2/5] END booster=gbtree, max_depth=4, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.093 total time=   2.1s
# [CV 3/5] END booster=gbtree, max_depth=4, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.089 total time=   1.6s
# [CV 4/5] END booster=gbtree, max_depth=4, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.090 total time=   1.5s
# [CV 5/5] END booster=gbtree, max_depth=4, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.091 total time=   1.5s
# [CV 1/5] END booster=gbtree, max_depth=5, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.092 total time=   2.3s
# [CV 2/5] END booster=gbtree, max_depth=5, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.091 total time=   2.2s
# [CV 3/5] END booster=gbtree, max_depth=5, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.090 total time=   2.1s
# [CV 4/5] END booster=gbtree, max_depth=5, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.089 total time=   2.1s
# [CV 5/5] END booster=gbtree, max_depth=5, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.091 total time=   2.3s
# [CV 1/5] END booster=gbtree, max_depth=5, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.093 total time=   2.3s
# [CV 2/5] END booster=gbtree, max_depth=5, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.092 total time=   2.5s
# [CV 3/5] END booster=gbtree, max_depth=5, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.089 total time=   7.4s
# [CV 4/5] END booster=gbtree, max_depth=5, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.089 total time=  10.1s
# [CV 5/5] END booster=gbtree, max_depth=5, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.091 total time=   8.7s
# [CV 1/5] END booster=gbtree, max_depth=5, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.092 total time=   7.4s
# [CV 2/5] END booster=gbtree, max_depth=5, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.092 total time=  22.1s
# [CV 3/5] END booster=gbtree, max_depth=5, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.089 total time=  10.3s
# [CV 4/5] END booster=gbtree, max_depth=5, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.089 total time=   9.9s
# [CV 5/5] END booster=gbtree, max_depth=5, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.091 total time=   9.9s
# [CV 1/5] END booster=gbtree, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.092 total time=  19.5s
# [CV 2/5] END booster=gbtree, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.092 total time=  12.8s
# [CV 3/5] END booster=gbtree, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.090 total time=   3.6s
# [CV 4/5] END booster=gbtree, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.089 total time=   4.0s
# [CV 5/5] END booster=gbtree, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.090 total time=  10.3s
# [CV 1/5] END booster=gbtree, max_depth=5, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.092 total time=   3.1s
# [CV 2/5] END booster=gbtree, max_depth=5, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.092 total time=   2.9s
# [CV 3/5] END booster=gbtree, max_depth=5, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.089 total time=   2.8s
# [CV 4/5] END booster=gbtree, max_depth=5, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.089 total time=   2.7s
# [CV 5/5] END booster=gbtree, max_depth=5, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.091 total time=   2.7s
# [CV 1/5] END booster=gbtree, max_depth=5, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.093 total time=   2.6s
# [CV 2/5] END booster=gbtree, max_depth=5, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.092 total time=   2.6s
# [CV 3/5] END booster=gbtree, max_depth=5, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.089 total time=   2.6s
# [CV 4/5] END booster=gbtree, max_depth=5, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.090 total time=   2.6s
# [CV 5/5] END booster=gbtree, max_depth=5, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.090 total time=   2.6s
# [CV 1/5] END booster=gbtree, max_depth=5, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.093 total time=   2.5s
# [CV 2/5] END booster=gbtree, max_depth=5, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.093 total time=   2.5s
# [CV 3/5] END booster=gbtree, max_depth=5, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.089 total time=   3.2s
# [CV 4/5] END booster=gbtree, max_depth=5, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.089 total time=   2.6s
# [CV 5/5] END booster=gbtree, max_depth=5, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.090 total time=   2.6s
# [CV 1/5] END booster=gbtree, max_depth=5, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.093 total time=   8.3s
# [CV 2/5] END booster=gbtree, max_depth=5, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.092 total time=   4.7s
# [CV 3/5] END booster=gbtree, max_depth=5, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.089 total time=   4.0s
# [CV 4/5] END booster=gbtree, max_depth=5, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.089 total time=   7.2s
# [CV 5/5] END booster=gbtree, max_depth=5, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.090 total time=   5.4s
# [CV 1/5] END booster=gbtree, max_depth=5, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.092 total time=   3.3s
# [CV 2/5] END booster=gbtree, max_depth=5, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.091 total time=   2.4s
# [CV 3/5] END booster=gbtree, max_depth=5, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.089 total time=   2.0s
# [CV 4/5] END booster=gbtree, max_depth=5, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.090 total time=   2.2s
# [CV 5/5] END booster=gbtree, max_depth=5, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.090 total time=   2.0s
# [CV 1/5] END booster=gbtree, max_depth=5, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.092 total time=   2.0s
# [CV 2/5] END booster=gbtree, max_depth=5, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.093 total time=   2.0s
# [CV 3/5] END booster=gbtree, max_depth=5, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.090 total time=   2.0s
# [CV 4/5] END booster=gbtree, max_depth=5, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.090 total time=   1.9s
# [CV 5/5] END booster=gbtree, max_depth=5, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.090 total time=   2.3s
# [CV 1/5] END booster=gbtree, max_depth=6, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.092 total time=   2.5s
# [CV 2/5] END booster=gbtree, max_depth=6, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.091 total time=   2.5s
# [CV 3/5] END booster=gbtree, max_depth=6, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.089 total time=   2.5s
# [CV 4/5] END booster=gbtree, max_depth=6, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.088 total time=   2.5s
# [CV 5/5] END booster=gbtree, max_depth=6, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.090 total time=   2.5s
# [CV 1/5] END booster=gbtree, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.092 total time=   2.5s
# [CV 2/5] END booster=gbtree, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.091 total time=   2.8s
# [CV 3/5] END booster=gbtree, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.088 total time=   2.5s
# [CV 4/5] END booster=gbtree, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.088 total time=   2.5s
# [CV 5/5] END booster=gbtree, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.090 total time=   2.5s
# [CV 1/5] END booster=gbtree, max_depth=6, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.092 total time=   2.5s
# [CV 2/5] END booster=gbtree, max_depth=6, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.092 total time=   2.5s
# [CV 3/5] END booster=gbtree, max_depth=6, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.089 total time=   2.7s
# [CV 4/5] END booster=gbtree, max_depth=6, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.088 total time=   2.5s
# [CV 5/5] END booster=gbtree, max_depth=6, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.090 total time=   2.5s
# [CV 1/5] END booster=gbtree, max_depth=6, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.092 total time=   2.5s
# [CV 2/5] END booster=gbtree, max_depth=6, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.091 total time=   2.4s
# [CV 3/5] END booster=gbtree, max_depth=6, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.088 total time=   2.5s
# [CV 4/5] END booster=gbtree, max_depth=6, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.088 total time=   2.7s
# [CV 5/5] END booster=gbtree, max_depth=6, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.090 total time=   2.5s
# [CV 1/5] END booster=gbtree, max_depth=6, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.093 total time=   2.4s
# [CV 2/5] END booster=gbtree, max_depth=6, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.092 total time=   2.4s
# [CV 3/5] END booster=gbtree, max_depth=6, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.089 total time=   2.4s
# [CV 4/5] END booster=gbtree, max_depth=6, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.089 total time=   2.5s
# [CV 5/5] END booster=gbtree, max_depth=6, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.090 total time=   2.7s
# [CV 1/5] END booster=gbtree, max_depth=6, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.092 total time=   2.5s
# [CV 2/5] END booster=gbtree, max_depth=6, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.092 total time=   2.4s
# [CV 3/5] END booster=gbtree, max_depth=6, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.089 total time=   2.4s
# [CV 4/5] END booster=gbtree, max_depth=6, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.089 total time=   2.8s
# [CV 5/5] END booster=gbtree, max_depth=6, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.090 total time=   2.4s
# [CV 1/5] END booster=gbtree, max_depth=6, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.093 total time=   2.4s
# [CV 2/5] END booster=gbtree, max_depth=6, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.092 total time=   2.4s
# [CV 3/5] END booster=gbtree, max_depth=6, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.090 total time=   4.0s
# [CV 4/5] END booster=gbtree, max_depth=6, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.089 total time=   9.8s
# [CV 5/5] END booster=gbtree, max_depth=6, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.090 total time=   8.6s
# [CV 1/5] END booster=gbtree, max_depth=6, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.092 total time=   8.5s
# [CV 2/5] END booster=gbtree, max_depth=6, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.093 total time=   9.8s
# [CV 3/5] END booster=gbtree, max_depth=6, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.090 total time=  11.7s
# [CV 4/5] END booster=gbtree, max_depth=6, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.089 total time=  11.8s
# [CV 5/5] END booster=gbtree, max_depth=6, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.090 total time=  10.5s
# [CV 1/5] END booster=gbtree, max_depth=6, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.092 total time=   8.1s
# [CV 2/5] END booster=gbtree, max_depth=6, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.092 total time=   6.9s
# [CV 3/5] END booster=gbtree, max_depth=6, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.089 total time=   8.0s
# [CV 4/5] END booster=gbtree, max_depth=6, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.089 total time=  21.8s
# [CV 5/5] END booster=gbtree, max_depth=6, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.089 total time=   8.7s
# [CV 1/5] END booster=gbtree, max_depth=6, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.092 total time=   6.7s
# [CV 2/5] END booster=gbtree, max_depth=6, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.092 total time=   7.7s
# [CV 3/5] END booster=gbtree, max_depth=6, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.088 total time=  23.2s
# [CV 4/5] END booster=gbtree, max_depth=6, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.089 total time=  22.8s
# [CV 5/5] END booster=gbtree, max_depth=6, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.090 total time=   9.6s
# [CV 1/5] END booster=gbtree, max_depth=7, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.092 total time=   3.3s
# [CV 2/5] END booster=gbtree, max_depth=7, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.091 total time=   3.7s
# [CV 3/5] END booster=gbtree, max_depth=7, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.089 total time=  19.4s
# [CV 4/5] END booster=gbtree, max_depth=7, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.089 total time=  15.6s
# [CV 5/5] END booster=gbtree, max_depth=7, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.091 total time=  12.2s
# [CV 1/5] END booster=gbtree, max_depth=7, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.092 total time=   6.1s
# [CV 2/5] END booster=gbtree, max_depth=7, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.091 total time=   6.8s
# [CV 3/5] END booster=gbtree, max_depth=7, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.089 total time=   6.1s
# [CV 4/5] END booster=gbtree, max_depth=7, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.089 total time=   6.0s
# [CV 5/5] END booster=gbtree, max_depth=7, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.091 total time=   4.9s
# [CV 1/5] END booster=gbtree, max_depth=7, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.093 total time=   4.4s
# [CV 2/5] END booster=gbtree, max_depth=7, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.092 total time=   5.1s
# [CV 3/5] END booster=gbtree, max_depth=7, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.090 total time=   4.9s
# [CV 4/5] END booster=gbtree, max_depth=7, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.089 total time=   4.9s
# [CV 5/5] END booster=gbtree, max_depth=7, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.090 total time=   4.8s
# [CV 1/5] END booster=gbtree, max_depth=7, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.092 total time=   4.7s
# [CV 2/5] END booster=gbtree, max_depth=7, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.091 total time=   4.7s
# [CV 3/5] END booster=gbtree, max_depth=7, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.089 total time=   5.0s
# [CV 4/5] END booster=gbtree, max_depth=7, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.089 total time=   4.7s
# [CV 5/5] END booster=gbtree, max_depth=7, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.090 total time=   5.1s
# [CV 1/5] END booster=gbtree, max_depth=7, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.092 total time=   4.7s
# [CV 2/5] END booster=gbtree, max_depth=7, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.091 total time=   4.8s
# [CV 3/5] END booster=gbtree, max_depth=7, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.089 total time=   4.8s
# [CV 4/5] END booster=gbtree, max_depth=7, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.088 total time=   5.5s
# [CV 5/5] END booster=gbtree, max_depth=7, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.090 total time=   7.2s
# [CV 1/5] END booster=gbtree, max_depth=7, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.092 total time=   5.4s
# [CV 2/5] END booster=gbtree, max_depth=7, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.092 total time=   5.5s
# [CV 3/5] END booster=gbtree, max_depth=7, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.089 total time=   6.0s
# [CV 4/5] END booster=gbtree, max_depth=7, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.089 total time=   5.2s
# [CV 5/5] END booster=gbtree, max_depth=7, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.090 total time=   5.3s
# [CV 1/5] END booster=gbtree, max_depth=7, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.092 total time=   5.2s
# [CV 2/5] END booster=gbtree, max_depth=7, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.092 total time=   5.5s
# [CV 3/5] END booster=gbtree, max_depth=7, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.089 total time=  12.1s
# [CV 4/5] END booster=gbtree, max_depth=7, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.089 total time=  12.5s
# [CV 5/5] END booster=gbtree, max_depth=7, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.090 total time=   9.4s
# [CV 1/5] END booster=gbtree, max_depth=7, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.092 total time=   6.8s
# [CV 2/5] END booster=gbtree, max_depth=7, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.092 total time=   6.4s
# [CV 3/5] END booster=gbtree, max_depth=7, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.088 total time=   5.5s
# [CV 4/5] END booster=gbtree, max_depth=7, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.089 total time=  11.1s
# [CV 5/5] END booster=gbtree, max_depth=7, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.091 total time=   9.6s
# [CV 1/5] END booster=gbtree, max_depth=7, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.092 total time=   7.2s
# [CV 2/5] END booster=gbtree, max_depth=7, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.092 total time=  22.8s
# [CV 3/5] END booster=gbtree, max_depth=7, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.089 total time=  15.2s
# [CV 4/5] END booster=gbtree, max_depth=7, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.089 total time=   9.7s
# [CV 5/5] END booster=gbtree, max_depth=7, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.091 total time=   9.0s
# [CV 1/5] END booster=gbtree, max_depth=7, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.092 total time=  14.9s
# [CV 2/5] END booster=gbtree, max_depth=7, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.092 total time=  12.4s
# [CV 3/5] END booster=gbtree, max_depth=7, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.089 total time=   8.5s
# [CV 4/5] END booster=gbtree, max_depth=7, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.089 total time=   9.3s
# [CV 5/5] END booster=gbtree, max_depth=7, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.090 total time=  10.0s
# [CV 1/5] END booster=gbtree, max_depth=8, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.093 total time=  15.2s
# [CV 2/5] END booster=gbtree, max_depth=8, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.092 total time=  21.0s
# [CV 3/5] END booster=gbtree, max_depth=8, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.089 total time=   6.2s
# [CV 4/5] END booster=gbtree, max_depth=8, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.090 total time=   5.4s
# [CV 5/5] END booster=gbtree, max_depth=8, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.091 total time=   5.3s
# [CV 1/5] END booster=gbtree, max_depth=8, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.093 total time=   5.4s
# [CV 2/5] END booster=gbtree, max_depth=8, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.092 total time=   5.1s
# [CV 3/5] END booster=gbtree, max_depth=8, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.090 total time=   5.1s
# [CV 4/5] END booster=gbtree, max_depth=8, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.090 total time=   4.7s
# [CV 5/5] END booster=gbtree, max_depth=8, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.092 total time=   4.7s
# [CV 1/5] END booster=gbtree, max_depth=8, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.093 total time=   4.4s
# [CV 2/5] END booster=gbtree, max_depth=8, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.091 total time=  20.1s
# [CV 3/5] END booster=gbtree, max_depth=8, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.091 total time=  28.5s
# [CV 4/5] END booster=gbtree, max_depth=8, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.089 total time=  20.1s
# [CV 5/5] END booster=gbtree, max_depth=8, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.092 total time=  21.1s
# [CV 1/5] END booster=gbtree, max_depth=8, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.092 total time=  21.4s
# [CV 2/5] END booster=gbtree, max_depth=8, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.093 total time=  22.7s
# [CV 3/5] END booster=gbtree, max_depth=8, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.090 total time=  14.6s
# [CV 4/5] END booster=gbtree, max_depth=8, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.090 total time=  12.6s
# [CV 5/5] END booster=gbtree, max_depth=8, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.091 total time=   6.7s
# [CV 1/5] END booster=gbtree, max_depth=8, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.093 total time=   6.4s
# [CV 2/5] END booster=gbtree, max_depth=8, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.092 total time=   6.0s
# [CV 3/5] END booster=gbtree, max_depth=8, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.089 total time=   5.8s
# [CV 4/5] END booster=gbtree, max_depth=8, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.090 total time=   7.9s
# [CV 5/5] END booster=gbtree, max_depth=8, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.091 total time=  10.5s
# [CV 1/5] END booster=gbtree, max_depth=8, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.093 total time=  11.9s
# [CV 2/5] END booster=gbtree, max_depth=8, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.093 total time=  17.2s
# [CV 3/5] END booster=gbtree, max_depth=8, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.090 total time=  26.9s
# [CV 4/5] END booster=gbtree, max_depth=8, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.090 total time=  28.2s
# [CV 5/5] END booster=gbtree, max_depth=8, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.091 total time=  17.2s
# [CV 1/5] END booster=gbtree, max_depth=8, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.092 total time=  24.2s
# [CV 2/5] END booster=gbtree, max_depth=8, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.092 total time=  21.9s
# [CV 3/5] END booster=gbtree, max_depth=8, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.090 total time=  29.9s
# [CV 4/5] END booster=gbtree, max_depth=8, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.089 total time=  27.3s
# [CV 5/5] END booster=gbtree, max_depth=8, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.091 total time=  21.5s
# [CV 1/5] END booster=gbtree, max_depth=8, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.092 total time=   3.9s
# [CV 2/5] END booster=gbtree, max_depth=8, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.092 total time=  21.7s
# [CV 3/5] END booster=gbtree, max_depth=8, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.089 total time=   6.1s
# [CV 4/5] END booster=gbtree, max_depth=8, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.089 total time=   4.8s
# [CV 5/5] END booster=gbtree, max_depth=8, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.090 total time=   4.2s
# [CV 1/5] END booster=gbtree, max_depth=8, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.092 total time=   3.6s
# [CV 2/5] END booster=gbtree, max_depth=8, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.092 total time=   3.0s
# [CV 3/5] END booster=gbtree, max_depth=8, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.089 total time=   3.2s
# [CV 4/5] END booster=gbtree, max_depth=8, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.090 total time=   2.9s
# [CV 5/5] END booster=gbtree, max_depth=8, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.090 total time=   2.9s
# [CV 1/5] END booster=gbtree, max_depth=8, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.091 total time=   2.9s
# [CV 2/5] END booster=gbtree, max_depth=8, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.092 total time=   2.9s
# [CV 3/5] END booster=gbtree, max_depth=8, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.089 total time=   3.2s
# [CV 4/5] END booster=gbtree, max_depth=8, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.089 total time=   2.9s
# [CV 5/5] END booster=gbtree, max_depth=8, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.090 total time=   2.9s
# [CV 1/5] END booster=gbtree, max_depth=9, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.094 total time=   3.8s
# [CV 2/5] END booster=gbtree, max_depth=9, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.094 total time=   3.7s
# [CV 3/5] END booster=gbtree, max_depth=9, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.091 total time=   3.7s
# [CV 4/5] END booster=gbtree, max_depth=9, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.092 total time=   3.8s
# [CV 5/5] END booster=gbtree, max_depth=9, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.092 total time=   4.0s
# [CV 1/5] END booster=gbtree, max_depth=9, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.094 total time=   3.8s
# [CV 2/5] END booster=gbtree, max_depth=9, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.093 total time=   4.5s
# [CV 3/5] END booster=gbtree, max_depth=9, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.091 total time=   3.7s
# [CV 4/5] END booster=gbtree, max_depth=9, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.090 total time=   3.7s
# [CV 5/5] END booster=gbtree, max_depth=9, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.092 total time=   4.6s
# [CV 1/5] END booster=gbtree, max_depth=9, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.094 total time=   5.2s
# [CV 2/5] END booster=gbtree, max_depth=9, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.094 total time=   3.8s
# [CV 3/5] END booster=gbtree, max_depth=9, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.092 total time=   3.8s
# [CV 4/5] END booster=gbtree, max_depth=9, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.090 total time=   4.2s
# [CV 5/5] END booster=gbtree, max_depth=9, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.092 total time=   4.0s
# [CV 1/5] END booster=gbtree, max_depth=9, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.093 total time=   4.1s
# [CV 2/5] END booster=gbtree, max_depth=9, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.094 total time=   5.3s
# [CV 3/5] END booster=gbtree, max_depth=9, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.091 total time=  28.6s
# [CV 4/5] END booster=gbtree, max_depth=9, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.091 total time=   4.0s
# [CV 5/5] END booster=gbtree, max_depth=9, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.092 total time=   3.4s
# [CV 1/5] END booster=gbtree, max_depth=9, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.093 total time=   9.2s
# [CV 2/5] END booster=gbtree, max_depth=9, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.093 total time=  37.9s
# [CV 3/5] END booster=gbtree, max_depth=9, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.090 total time=  34.6s
# [CV 4/5] END booster=gbtree, max_depth=9, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.090 total time=  20.4s
# [CV 5/5] END booster=gbtree, max_depth=9, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.091 total time=  11.6s
# [CV 1/5] END booster=gbtree, max_depth=9, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.093 total time=  13.1s
# [CV 2/5] END booster=gbtree, max_depth=9, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.093 total time=  15.6s
# [CV 3/5] END booster=gbtree, max_depth=9, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.090 total time=  18.3s
# [CV 4/5] END booster=gbtree, max_depth=9, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.090 total time=  13.7s
# [CV 5/5] END booster=gbtree, max_depth=9, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.091 total time=   9.7s
# [CV 1/5] END booster=gbtree, max_depth=9, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.093 total time=   9.0s
# [CV 2/5] END booster=gbtree, max_depth=9, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.093 total time=  26.1s
# [CV 3/5] END booster=gbtree, max_depth=9, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.090 total time=  28.0s
# [CV 4/5] END booster=gbtree, max_depth=9, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.090 total time=   5.2s
# [CV 5/5] END booster=gbtree, max_depth=9, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.090 total time=   9.3s
# [CV 1/5] END booster=gbtree, max_depth=9, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.093 total time=  10.2s
# [CV 2/5] END booster=gbtree, max_depth=9, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.092 total time=  17.1s
# [CV 3/5] END booster=gbtree, max_depth=9, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.090 total time=  27.5s
# [CV 4/5] END booster=gbtree, max_depth=9, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.089 total time=  26.2s
# [CV 5/5] END booster=gbtree, max_depth=9, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.090 total time=   3.8s
# [CV 1/5] END booster=gbtree, max_depth=9, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.093 total time=   4.0s
# [CV 2/5] END booster=gbtree, max_depth=9, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.093 total time=   3.4s
# [CV 3/5] END booster=gbtree, max_depth=9, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.090 total time=   3.4s
# [CV 4/5] END booster=gbtree, max_depth=9, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.089 total time=   8.3s
# [CV 5/5] END booster=gbtree, max_depth=9, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.091 total time=  44.2s
# [CV 1/5] END booster=gbtree, max_depth=9, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.092 total time=   6.8s
# [CV 2/5] END booster=gbtree, max_depth=9, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.093 total time=   7.8s
# [CV 3/5] END booster=gbtree, max_depth=9, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.089 total time=   3.6s
# [CV 4/5] END booster=gbtree, max_depth=9, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.090 total time=  17.5s
# [CV 5/5] END booster=gbtree, max_depth=9, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.090 total time=   5.7s
# [CV 1/5] END booster=gbtree, max_depth=10, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.094 total time=   6.8s
# [CV 2/5] END booster=gbtree, max_depth=10, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.094 total time=  20.9s
# [CV 3/5] END booster=gbtree, max_depth=10, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.093 total time=  26.1s
# [CV 4/5] END booster=gbtree, max_depth=10, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.092 total time=  20.7s
# [CV 5/5] END booster=gbtree, max_depth=10, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.093 total time=  22.2s
# [CV 1/5] END booster=gbtree, max_depth=10, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.094 total time=   8.9s
# [CV 2/5] END booster=gbtree, max_depth=10, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.094 total time=   8.6s
# [CV 3/5] END booster=gbtree, max_depth=10, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.092 total time=   8.1s
# [CV 4/5] END booster=gbtree, max_depth=10, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.092 total time=   7.8s
# [CV 5/5] END booster=gbtree, max_depth=10, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.093 total time=   8.3s
# [CV 1/5] END booster=gbtree, max_depth=10, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.094 total time=   7.0s
# [CV 2/5] END booster=gbtree, max_depth=10, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.094 total time=   7.4s
# [CV 3/5] END booster=gbtree, max_depth=10, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.093 total time=   7.1s
# [CV 4/5] END booster=gbtree, max_depth=10, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.091 total time=   7.7s
# [CV 5/5] END booster=gbtree, max_depth=10, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.093 total time=   7.3s
# [CV 1/5] END booster=gbtree, max_depth=10, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.094 total time=   8.5s
# [CV 2/5] END booster=gbtree, max_depth=10, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.095 total time=   6.4s
# [CV 3/5] END booster=gbtree, max_depth=10, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.091 total time=   9.9s
# ...
# [CV 1/5] END booster=gbtree, max_depth=18, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.095 total time=   6.3s
# [CV 2/5] END booster=gbtree, max_depth=18, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.096 total time=   5.9s
# [CV 3/5] END booster=gbtree, max_depth=18, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.092 total time=   6.0s
# [CV 4/5] END booster=gbtree, max_depth=18, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.092 total time=   6.1s
# [CV 5/5] END booster=gbtree, max_depth=18, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.096 total time=   6.0s
# [CV 1/5] END booster=gbtree, max_depth=18, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.096 total time=   6.1s
# [CV 2/5] END booster=gbtree, max_depth=18, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.096 total time=   5.8s
# [CV 3/5] END booster=gbtree, max_depth=18, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.093 total time=   5.6s
# [CV 4/5] END booster=gbtree, max_depth=18, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.093 total time=   5.9s
# [CV 5/5] END booster=gbtree, max_depth=18, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.093 total time=   6.1s
# [CV 1/5] END booster=gbtree, max_depth=18, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.096 total time=   5.7s
# [CV 2/5] END booster=gbtree, max_depth=18, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.096 total time=   5.6s
# [CV 3/5] END booster=gbtree, max_depth=18, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.092 total time=   5.7s
# [CV 4/5] END booster=gbtree, max_depth=18, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.093 total time=   5.8s
# [CV 5/5] END booster=gbtree, max_depth=18, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.095 total time=   5.9s
# [CV 1/5] END booster=gbtree, max_depth=18, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.096 total time=   5.6s
# [CV 2/5] END booster=gbtree, max_depth=18, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.095 total time=   5.4s
# [CV 3/5] END booster=gbtree, max_depth=18, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.093 total time=   5.6s
# [CV 4/5] END booster=gbtree, max_depth=18, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.092 total time=   5.6s
# [CV 5/5] END booster=gbtree, max_depth=18, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.093 total time=   5.5s
# [CV 1/5] END booster=gbtree, max_depth=19, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.097 total time=   3.9s
# [CV 2/5] END booster=gbtree, max_depth=19, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.098 total time=   3.7s
# [CV 3/5] END booster=gbtree, max_depth=19, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.094 total time=   3.8s
# [CV 4/5] END booster=gbtree, max_depth=19, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.094 total time=   3.7s
# [CV 5/5] END booster=gbtree, max_depth=19, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.096 total time=   3.7s
# [CV 1/5] END booster=gbtree, max_depth=19, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.095 total time=   4.0s
# [CV 2/5] END booster=gbtree, max_depth=19, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.097 total time=   4.5s
# [CV 3/5] END booster=gbtree, max_depth=19, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.093 total time=   4.1s
# [CV 4/5] END booster=gbtree, max_depth=19, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.093 total time=   4.0s
# [CV 5/5] END booster=gbtree, max_depth=19, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.095 total time=   4.1s
# [CV 1/5] END booster=gbtree, max_depth=19, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.096 total time=   4.7s
# [CV 2/5] END booster=gbtree, max_depth=19, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.097 total time=   4.7s
# [CV 3/5] END booster=gbtree, max_depth=19, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.093 total time=   5.0s
# [CV 4/5] END booster=gbtree, max_depth=19, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.094 total time=   4.6s
# [CV 5/5] END booster=gbtree, max_depth=19, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.095 total time=   4.7s
# [CV 1/5] END booster=gbtree, max_depth=19, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.097 total time=   5.8s
# [CV 2/5] END booster=gbtree, max_depth=19, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.096 total time=   5.8s
# [CV 3/5] END booster=gbtree, max_depth=19, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.093 total time=   5.7s
# [CV 4/5] END booster=gbtree, max_depth=19, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.093 total time=   6.0s
# [CV 5/5] END booster=gbtree, max_depth=19, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.096 total time=   5.7s
# [CV 1/5] END booster=gbtree, max_depth=19, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.097 total time=   6.4s
# [CV 2/5] END booster=gbtree, max_depth=19, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.095 total time=   6.3s
# [CV 3/5] END booster=gbtree, max_depth=19, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.093 total time=   6.1s
# [CV 4/5] END booster=gbtree, max_depth=19, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.094 total time=   6.2s
# [CV 5/5] END booster=gbtree, max_depth=19, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.095 total time=   6.5s
# [CV 1/5] END booster=gbtree, max_depth=19, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.096 total time=   6.2s
# [CV 2/5] END booster=gbtree, max_depth=19, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.096 total time=   6.0s
# [CV 3/5] END booster=gbtree, max_depth=19, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.093 total time=   5.9s
# [CV 4/5] END booster=gbtree, max_depth=19, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.093 total time=   6.1s
# [CV 5/5] END booster=gbtree, max_depth=19, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.096 total time=   6.1s
# [CV 1/5] END booster=gbtree, max_depth=19, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.095 total time=   6.1s
# [CV 2/5] END booster=gbtree, max_depth=19, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.095 total time=   5.7s
# [CV 3/5] END booster=gbtree, max_depth=19, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.093 total time=   5.7s
# [CV 4/5] END booster=gbtree, max_depth=19, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.093 total time=   5.9s
# [CV 5/5] END booster=gbtree, max_depth=19, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.095 total time=   5.8s
# [CV 1/5] END booster=gbtree, max_depth=19, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.096 total time=   5.8s
# [CV 2/5] END booster=gbtree, max_depth=19, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.096 total time=   5.7s
# [CV 3/5] END booster=gbtree, max_depth=19, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.092 total time=   5.7s
# [CV 4/5] END booster=gbtree, max_depth=19, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.093 total time=   5.7s
# [CV 5/5] END booster=gbtree, max_depth=19, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.094 total time=   5.8s
# [CV 1/5] END booster=gbtree, max_depth=19, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.096 total time=   5.7s
# [CV 2/5] END booster=gbtree, max_depth=19, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.095 total time=   5.5s
# [CV 3/5] END booster=gbtree, max_depth=19, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.092 total time=   5.7s
# [CV 4/5] END booster=gbtree, max_depth=19, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.093 total time=   5.4s
# [CV 5/5] END booster=gbtree, max_depth=19, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.094 total time=   5.7s
# [CV 1/5] END booster=gbtree, max_depth=19, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.096 total time=   5.5s
# [CV 2/5] END booster=gbtree, max_depth=19, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.097 total time=   5.3s
# [CV 3/5] END booster=gbtree, max_depth=19, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.092 total time=   5.3s
# [CV 4/5] END booster=gbtree, max_depth=19, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.093 total time=   5.5s
# [CV 5/5] END booster=gbtree, max_depth=19, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.094 total time=   5.7s
# [CV 1/5] END booster=gbtree, max_depth=20, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.095 total time=   3.4s
# [CV 2/5] END booster=gbtree, max_depth=20, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.098 total time=   3.5s
# [CV 3/5] END booster=gbtree, max_depth=20, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.094 total time=   3.5s
# [CV 4/5] END booster=gbtree, max_depth=20, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.094 total time=   3.7s
# [CV 5/5] END booster=gbtree, max_depth=20, min_child_weight=1, n_estimators=195, random_state=43;, score=-0.096 total time=   3.7s
# [CV 1/5] END booster=gbtree, max_depth=20, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.095 total time=   4.0s
# [CV 2/5] END booster=gbtree, max_depth=20, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.097 total time=   4.0s
# [CV 3/5] END booster=gbtree, max_depth=20, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.093 total time=   3.9s
# [CV 4/5] END booster=gbtree, max_depth=20, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.093 total time=   3.9s
# [CV 5/5] END booster=gbtree, max_depth=20, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.096 total time=   4.0s
# [CV 1/5] END booster=gbtree, max_depth=20, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.096 total time=   4.5s
# [CV 2/5] END booster=gbtree, max_depth=20, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.097 total time=   4.9s
# [CV 3/5] END booster=gbtree, max_depth=20, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.092 total time=   4.9s
# [CV 4/5] END booster=gbtree, max_depth=20, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.094 total time=   4.4s
# [CV 5/5] END booster=gbtree, max_depth=20, min_child_weight=3, n_estimators=195, random_state=43;, score=-0.095 total time=   4.6s
# [CV 1/5] END booster=gbtree, max_depth=20, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.096 total time=   5.3s
# [CV 2/5] END booster=gbtree, max_depth=20, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.096 total time=   6.1s
# [CV 3/5] END booster=gbtree, max_depth=20, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.093 total time=   5.3s
# [CV 4/5] END booster=gbtree, max_depth=20, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.093 total time=   5.8s
# [CV 5/5] END booster=gbtree, max_depth=20, min_child_weight=4, n_estimators=195, random_state=43;, score=-0.096 total time=   5.4s
# [CV 1/5] END booster=gbtree, max_depth=20, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.096 total time=   6.6s
# [CV 2/5] END booster=gbtree, max_depth=20, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.096 total time=   6.9s
# [CV 3/5] END booster=gbtree, max_depth=20, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.093 total time=   6.8s
# [CV 4/5] END booster=gbtree, max_depth=20, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.094 total time=   6.8s
# [CV 5/5] END booster=gbtree, max_depth=20, min_child_weight=5, n_estimators=195, random_state=43;, score=-0.095 total time=   6.9s
# [CV 1/5] END booster=gbtree, max_depth=20, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.096 total time=   6.7s
# [CV 2/5] END booster=gbtree, max_depth=20, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.097 total time=   6.4s
# [CV 3/5] END booster=gbtree, max_depth=20, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.093 total time=   6.4s
# [CV 4/5] END booster=gbtree, max_depth=20, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.094 total time=   6.5s
# [CV 5/5] END booster=gbtree, max_depth=20, min_child_weight=6, n_estimators=195, random_state=43;, score=-0.095 total time=   6.5s
# [CV 1/5] END booster=gbtree, max_depth=20, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.095 total time=   6.6s
# [CV 2/5] END booster=gbtree, max_depth=20, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.096 total time=   6.0s
# [CV 3/5] END booster=gbtree, max_depth=20, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.092 total time=   6.2s
# [CV 4/5] END booster=gbtree, max_depth=20, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.093 total time=   6.2s
# [CV 5/5] END booster=gbtree, max_depth=20, min_child_weight=7, n_estimators=195, random_state=43;, score=-0.095 total time=   6.3s
# [CV 1/5] END booster=gbtree, max_depth=20, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.095 total time=   6.3s
# [CV 2/5] END booster=gbtree, max_depth=20, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.095 total time=   5.9s
# [CV 3/5] END booster=gbtree, max_depth=20, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.093 total time=   5.9s
# [CV 4/5] END booster=gbtree, max_depth=20, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.093 total time=   6.0s
# [CV 5/5] END booster=gbtree, max_depth=20, min_child_weight=8, n_estimators=195, random_state=43;, score=-0.094 total time=   6.1s
# [CV 1/5] END booster=gbtree, max_depth=20, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.096 total time=   5.9s
# [CV 2/5] END booster=gbtree, max_depth=20, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.096 total time=   5.8s
# [CV 3/5] END booster=gbtree, max_depth=20, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.092 total time=   5.7s
# [CV 4/5] END booster=gbtree, max_depth=20, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.094 total time=   6.1s
# [CV 5/5] END booster=gbtree, max_depth=20, min_child_weight=9, n_estimators=195, random_state=43;, score=-0.095 total time=   6.0s
# [CV 1/5] END booster=gbtree, max_depth=20, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.095 total time=   5.7s
# [CV 2/5] END booster=gbtree, max_depth=20, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.096 total time=   5.7s
# [CV 3/5] END booster=gbtree, max_depth=20, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.092 total time=   5.5s
# [CV 4/5] END booster=gbtree, max_depth=20, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.092 total time=   5.8s
# [CV 5/5] END booster=gbtree, max_depth=20, min_child_weight=10, n_estimators=195, random_state=43;, score=-0.093 total time=   5.7s
# Best params: {'booster': 'gbtree', 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 195, 'random_state': 43}
# Best score: -0.09001301413019257

# %% [markdown]
# # Ronda 5: "gamma"
#
# - "Gamma", que es un tanto menos importante que los dos anteriores, se localiza a continuación

# %%
model = XGBRegressor()

params = {'random_state': [43],
          'booster': ['gbtree'],
          'n_estimators': [195],
          'max_depth': [6],
          'min_child_weight': [2],
          'gamma': np.linspace(0, 6, num=61)
            }

grid = GridSearchCV(estimator=model,
                    param_grid=params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')
# Out:
# Fitting 5 folds for each of 61 candidates, totalling 305 fits
# [CV 1/5] END booster=gbtree, gamma=0.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.092 total time=   2.7s
# [CV 2/5] END booster=gbtree, gamma=0.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.091 total time=   2.1s
# [CV 3/5] END booster=gbtree, gamma=0.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.088 total time=   2.3s
# [CV 4/5] END booster=gbtree, gamma=0.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.088 total time=   2.4s
# [CV 5/5] END booster=gbtree, gamma=0.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.090 total time=   2.5s
# [CV 1/5] END booster=gbtree, gamma=0.1, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.097 total time=   1.8s
# [CV 2/5] END booster=gbtree, gamma=0.1, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.098 total time=   1.6s
# [CV 3/5] END booster=gbtree, gamma=0.1, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.095 total time=   1.6s
# [CV 4/5] END booster=gbtree, gamma=0.1, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.096 total time=   1.5s
# [CV 5/5] END booster=gbtree, gamma=0.1, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.095 total time=   1.8s
# [CV 1/5] END booster=gbtree, gamma=0.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.101 total time=   1.7s
# [CV 2/5] END booster=gbtree, gamma=0.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.102 total time=   1.6s
# [CV 3/5] END booster=gbtree, gamma=0.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.096 total time=   1.6s
# [CV 4/5] END booster=gbtree, gamma=0.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.099 total time=   1.7s
# [CV 5/5] END booster=gbtree, gamma=0.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.099 total time=   1.5s
# [CV 1/5] END booster=gbtree, gamma=0.30000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.102 total time=   2.3s
# [CV 2/5] END booster=gbtree, gamma=0.30000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.102 total time=   2.0s
# [CV 3/5] END booster=gbtree, gamma=0.30000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.098 total time=   6.0s
# [CV 4/5] END booster=gbtree, gamma=0.30000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.099 total time=  10.2s
# [CV 5/5] END booster=gbtree, gamma=0.30000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.100 total time=   5.2s
# [CV 1/5] END booster=gbtree, gamma=0.4, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.105 total time=   2.4s
# [CV 2/5] END booster=gbtree, gamma=0.4, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.104 total time=   2.2s
# [CV 3/5] END booster=gbtree, gamma=0.4, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.102 total time=   1.9s
# [CV 4/5] END booster=gbtree, gamma=0.4, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.102 total time=   2.0s
# [CV 5/5] END booster=gbtree, gamma=0.4, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.101 total time=   2.0s
# [CV 1/5] END booster=gbtree, gamma=0.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.105 total time=   2.4s
# [CV 2/5] END booster=gbtree, gamma=0.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.105 total time=   1.9s
# [CV 3/5] END booster=gbtree, gamma=0.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.101 total time=   1.9s
# [CV 4/5] END booster=gbtree, gamma=0.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.102 total time=   1.7s
# [CV 5/5] END booster=gbtree, gamma=0.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.103 total time=   2.0s
# [CV 1/5] END booster=gbtree, gamma=0.6000000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.106 total time=   2.0s
# [CV 2/5] END booster=gbtree, gamma=0.6000000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.106 total time=   2.0s
# [CV 3/5] END booster=gbtree, gamma=0.6000000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.104 total time=   1.7s
# [CV 4/5] END booster=gbtree, gamma=0.6000000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.104 total time=   1.8s
# [CV 5/5] END booster=gbtree, gamma=0.6000000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.103 total time=   1.8s
# [CV 1/5] END booster=gbtree, gamma=0.7000000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.108 total time=   1.8s
# [CV 2/5] END booster=gbtree, gamma=0.7000000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.107 total time=   1.9s
# [CV 3/5] END booster=gbtree, gamma=0.7000000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.105 total time=   1.8s
# [CV 4/5] END booster=gbtree, gamma=0.7000000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.105 total time=   1.8s
# [CV 5/5] END booster=gbtree, gamma=0.7000000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.107 total time=   1.9s
# [CV 1/5] END booster=gbtree, gamma=0.8, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.107 total time=   1.7s
# [CV 2/5] END booster=gbtree, gamma=0.8, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.108 total time=   1.8s
# [CV 3/5] END booster=gbtree, gamma=0.8, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.104 total time=   1.9s
# [CV 4/5] END booster=gbtree, gamma=0.8, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.106 total time=   2.3s
# [CV 5/5] END booster=gbtree, gamma=0.8, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.106 total time=   2.1s
# [CV 1/5] END booster=gbtree, gamma=0.9, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.108 total time=   1.8s
# [CV 2/5] END booster=gbtree, gamma=0.9, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.107 total time=   1.7s
# [CV 3/5] END booster=gbtree, gamma=0.9, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.106 total time=   1.8s
# [CV 4/5] END booster=gbtree, gamma=0.9, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.107 total time=   2.0s
# [CV 5/5] END booster=gbtree, gamma=0.9, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.105 total time=   1.9s
# [CV 1/5] END booster=gbtree, gamma=1.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.111 total time=   1.8s
# [CV 2/5] END booster=gbtree, gamma=1.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.108 total time=   1.8s
# [CV 3/5] END booster=gbtree, gamma=1.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.108 total time=   1.8s
# [CV 4/5] END booster=gbtree, gamma=1.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.107 total time=   1.7s
# [CV 5/5] END booster=gbtree, gamma=1.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.106 total time=   2.0s
# [CV 1/5] END booster=gbtree, gamma=1.1, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.109 total time=   1.8s
# [CV 2/5] END booster=gbtree, gamma=1.1, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.109 total time=   1.7s
# [CV 3/5] END booster=gbtree, gamma=1.1, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.107 total time=   1.8s
# [CV 4/5] END booster=gbtree, gamma=1.1, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.108 total time=   1.7s
# [CV 5/5] END booster=gbtree, gamma=1.1, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.107 total time=   1.7s
# [CV 1/5] END booster=gbtree, gamma=1.2000000000000002, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.111 total time=   1.9s
# [CV 2/5] END booster=gbtree, gamma=1.2000000000000002, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.111 total time=   1.8s
# [CV 3/5] END booster=gbtree, gamma=1.2000000000000002, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.109 total time=   1.8s
# [CV 4/5] END booster=gbtree, gamma=1.2000000000000002, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.108 total time=   1.7s
# [CV 5/5] END booster=gbtree, gamma=1.2000000000000002, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.107 total time=   1.7s
# [CV 1/5] END booster=gbtree, gamma=1.3, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.111 total time=   2.0s
# [CV 2/5] END booster=gbtree, gamma=1.3, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.111 total time=   1.9s
# [CV 3/5] END booster=gbtree, gamma=1.3, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.108 total time=   2.0s
# [CV 4/5] END booster=gbtree, gamma=1.3, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.111 total time=   1.7s
# [CV 5/5] END booster=gbtree, gamma=1.3, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.110 total time=   1.8s
# [CV 1/5] END booster=gbtree, gamma=1.4000000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.112 total time=   1.9s
# [CV 2/5] END booster=gbtree, gamma=1.4000000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.112 total time=   1.7s
# [CV 3/5] END booster=gbtree, gamma=1.4000000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.109 total time=   2.0s
# [CV 4/5] END booster=gbtree, gamma=1.4000000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.111 total time=   2.5s
# [CV 5/5] END booster=gbtree, gamma=1.4000000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.110 total time=   1.7s
# [CV 1/5] END booster=gbtree, gamma=1.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.112 total time=   1.7s
# [CV 2/5] END booster=gbtree, gamma=1.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.111 total time=   1.7s
# [CV 3/5] END booster=gbtree, gamma=1.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.112 total time=   1.9s
# [CV 4/5] END booster=gbtree, gamma=1.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.111 total time=   1.8s
# [CV 5/5] END booster=gbtree, gamma=1.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.111 total time=   2.0s
# [CV 1/5] END booster=gbtree, gamma=1.6, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.113 total time=   1.8s
# [CV 2/5] END booster=gbtree, gamma=1.6, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.114 total time=   1.7s
# [CV 3/5] END booster=gbtree, gamma=1.6, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.111 total time=   1.9s
# [CV 4/5] END booster=gbtree, gamma=1.6, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.112 total time=   1.7s
# [CV 5/5] END booster=gbtree, gamma=1.6, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.111 total time=   1.8s
# [CV 1/5] END booster=gbtree, gamma=1.7000000000000002, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.113 total time=   1.9s
# [CV 2/5] END booster=gbtree, gamma=1.7000000000000002, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.114 total time=   1.9s
# [CV 3/5] END booster=gbtree, gamma=1.7000000000000002, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.111 total time=   1.8s
# [CV 4/5] END booster=gbtree, gamma=1.7000000000000002, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.111 total time=   1.8s
# [CV 5/5] END booster=gbtree, gamma=1.7000000000000002, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.112 total time=   1.9s
# [CV 1/5] END booster=gbtree, gamma=1.8, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.114 total time=   1.9s
# [CV 2/5] END booster=gbtree, gamma=1.8, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.115 total time=   2.0s
# [CV 3/5] END booster=gbtree, gamma=1.8, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.112 total time=   1.9s
# [CV 4/5] END booster=gbtree, gamma=1.8, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.114 total time=   2.3s
# [CV 5/5] END booster=gbtree, gamma=1.8, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.113 total time=   3.0s
# [CV 1/5] END booster=gbtree, gamma=1.9000000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.114 total time=   2.3s
# [CV 2/5] END booster=gbtree, gamma=1.9000000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.115 total time=   1.8s
# [CV 3/5] END booster=gbtree, gamma=1.9000000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.113 total time=   1.9s
# [CV 4/5] END booster=gbtree, gamma=1.9000000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.112 total time=   1.9s
# [CV 5/5] END booster=gbtree, gamma=1.9000000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.114 total time=   1.7s
# [CV 1/5] END booster=gbtree, gamma=2.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.115 total time=   2.0s
# [CV 2/5] END booster=gbtree, gamma=2.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.115 total time=   1.9s
# [CV 3/5] END booster=gbtree, gamma=2.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.113 total time=   1.8s
# [CV 4/5] END booster=gbtree, gamma=2.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.113 total time=   1.7s
# [CV 5/5] END booster=gbtree, gamma=2.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.115 total time=   1.7s
# [CV 1/5] END booster=gbtree, gamma=2.1, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.115 total time=   1.8s
# [CV 2/5] END booster=gbtree, gamma=2.1, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.116 total time=   1.9s
# [CV 3/5] END booster=gbtree, gamma=2.1, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.114 total time=   1.9s
# [CV 4/5] END booster=gbtree, gamma=2.1, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.115 total time=   1.7s
# [CV 5/5] END booster=gbtree, gamma=2.1, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.115 total time=   2.0s
# [CV 1/5] END booster=gbtree, gamma=2.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.117 total time=   1.8s
# [CV 2/5] END booster=gbtree, gamma=2.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.118 total time=   1.8s
# [CV 3/5] END booster=gbtree, gamma=2.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.114 total time=   1.7s
# [CV 4/5] END booster=gbtree, gamma=2.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.116 total time=   1.8s
# [CV 5/5] END booster=gbtree, gamma=2.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.115 total time=   1.8s
# [CV 1/5] END booster=gbtree, gamma=2.3000000000000003, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.116 total time=   1.8s
# [CV 2/5] END booster=gbtree, gamma=2.3000000000000003, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.117 total time=   1.8s
# [CV 3/5] END booster=gbtree, gamma=2.3000000000000003, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.115 total time=   1.8s
# [CV 4/5] END booster=gbtree, gamma=2.3000000000000003, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.116 total time=   1.8s
# [CV 5/5] END booster=gbtree, gamma=2.3000000000000003, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.115 total time=   1.9s
# [CV 1/5] END booster=gbtree, gamma=2.4000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.116 total time=   1.9s
# [CV 2/5] END booster=gbtree, gamma=2.4000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.118 total time=   1.8s
# [CV 3/5] END booster=gbtree, gamma=2.4000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.114 total time=   1.8s
# [CV 4/5] END booster=gbtree, gamma=2.4000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.116 total time=   1.7s
# [CV 5/5] END booster=gbtree, gamma=2.4000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.115 total time=   1.7s
# [CV 1/5] END booster=gbtree, gamma=2.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.116 total time=   2.0s
# [CV 2/5] END booster=gbtree, gamma=2.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.118 total time=   1.8s
# [CV 3/5] END booster=gbtree, gamma=2.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.116 total time=   1.9s
# [CV 4/5] END booster=gbtree, gamma=2.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.117 total time=   1.7s
# [CV 5/5] END booster=gbtree, gamma=2.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.115 total time=   1.8s
# [CV 1/5] END booster=gbtree, gamma=2.6, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.117 total time=   1.8s
# [CV 2/5] END booster=gbtree, gamma=2.6, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.117 total time=   2.0s
# [CV 3/5] END booster=gbtree, gamma=2.6, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.115 total time=   1.8s
# [CV 4/5] END booster=gbtree, gamma=2.6, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.118 total time=   1.9s
# [CV 5/5] END booster=gbtree, gamma=2.6, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.116 total time=   1.8s
# [CV 1/5] END booster=gbtree, gamma=2.7, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.118 total time=   1.7s
# [CV 2/5] END booster=gbtree, gamma=2.7, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.117 total time=   1.8s
# [CV 3/5] END booster=gbtree, gamma=2.7, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.116 total time=   1.9s
# [CV 4/5] END booster=gbtree, gamma=2.7, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.118 total time=   2.0s
# [CV 5/5] END booster=gbtree, gamma=2.7, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.116 total time=   2.0s
# [CV 1/5] END booster=gbtree, gamma=2.8000000000000003, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.116 total time=   1.8s
# [CV 2/5] END booster=gbtree, gamma=2.8000000000000003, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.118 total time=   1.8s
# [CV 3/5] END booster=gbtree, gamma=2.8000000000000003, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.117 total time=   1.7s
# [CV 4/5] END booster=gbtree, gamma=2.8000000000000003, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.120 total time=   1.9s
# [CV 5/5] END booster=gbtree, gamma=2.8000000000000003, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.117 total time=   2.0s
# [CV 1/5] END booster=gbtree, gamma=2.9000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.118 total time=   1.8s
# [CV 2/5] END booster=gbtree, gamma=2.9000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.117 total time=   1.8s
# [CV 3/5] END booster=gbtree, gamma=2.9000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.117 total time=   1.8s
# [CV 4/5] END booster=gbtree, gamma=2.9000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.118 total time=   1.7s
# [CV 5/5] END booster=gbtree, gamma=2.9000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.118 total time=   1.9s
# [CV 1/5] END booster=gbtree, gamma=3.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.119 total time=   2.1s
# [CV 2/5] END booster=gbtree, gamma=3.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.119 total time=   1.8s
# [CV 3/5] END booster=gbtree, gamma=3.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.116 total time=   1.8s
# [CV 4/5] END booster=gbtree, gamma=3.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.118 total time=   1.9s
# [CV 5/5] END booster=gbtree, gamma=3.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.116 total time=   1.9s
# [CV 1/5] END booster=gbtree, gamma=3.1, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.119 total time=   2.0s
# [CV 2/5] END booster=gbtree, gamma=3.1, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.120 total time=   2.1s
# [CV 3/5] END booster=gbtree, gamma=3.1, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.116 total time=   3.1s
# [CV 4/5] END booster=gbtree, gamma=3.1, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.119 total time=   1.8s
# [CV 5/5] END booster=gbtree, gamma=3.1, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.119 total time=   2.0s
# [CV 1/5] END booster=gbtree, gamma=3.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.118 total time=   2.2s
# [CV 2/5] END booster=gbtree, gamma=3.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.119 total time=   2.6s
# [CV 3/5] END booster=gbtree, gamma=3.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.120 total time=   2.4s
# [CV 4/5] END booster=gbtree, gamma=3.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.120 total time=   2.2s
# [CV 5/5] END booster=gbtree, gamma=3.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.119 total time=   2.2s
# [CV 1/5] END booster=gbtree, gamma=3.3000000000000003, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.120 total time=   4.3s
# [CV 2/5] END booster=gbtree, gamma=3.3000000000000003, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.120 total time=   4.0s
# [CV 3/5] END booster=gbtree, gamma=3.3000000000000003, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.119 total time=   2.1s
# [CV 4/5] END booster=gbtree, gamma=3.3000000000000003, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.119 total time=   2.3s
# [CV 5/5] END booster=gbtree, gamma=3.3000000000000003, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.117 total time=   2.5s
# [CV 1/5] END booster=gbtree, gamma=3.4000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.120 total time=   1.8s
# [CV 2/5] END booster=gbtree, gamma=3.4000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.120 total time=   2.0s
# [CV 3/5] END booster=gbtree, gamma=3.4000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.120 total time=   1.7s
# [CV 4/5] END booster=gbtree, gamma=3.4000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.118 total time=   2.3s
# [CV 5/5] END booster=gbtree, gamma=3.4000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.120 total time=   2.0s
# [CV 1/5] END booster=gbtree, gamma=3.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.121 total time=   1.7s
# [CV 2/5] END booster=gbtree, gamma=3.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.121 total time=   1.7s
# [CV 3/5] END booster=gbtree, gamma=3.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.119 total time=   2.0s
# [CV 4/5] END booster=gbtree, gamma=3.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.121 total time=   2.7s
# [CV 5/5] END booster=gbtree, gamma=3.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.120 total time=   3.2s
# [CV 1/5] END booster=gbtree, gamma=3.6, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.120 total time=   2.7s
# [CV 2/5] END booster=gbtree, gamma=3.6, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.122 total time=   2.4s
# [CV 3/5] END booster=gbtree, gamma=3.6, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.121 total time=   2.2s
# [CV 4/5] END booster=gbtree, gamma=3.6, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.121 total time=   1.8s
# [CV 5/5] END booster=gbtree, gamma=3.6, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.118 total time=   2.0s
# [CV 1/5] END booster=gbtree, gamma=3.7, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.120 total time=   2.1s
# [CV 2/5] END booster=gbtree, gamma=3.7, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.120 total time=   1.8s
# [CV 3/5] END booster=gbtree, gamma=3.7, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.121 total time=   2.4s
# [CV 4/5] END booster=gbtree, gamma=3.7, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.121 total time=   2.0s
# [CV 5/5] END booster=gbtree, gamma=3.7, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.121 total time=   2.3s
# [CV 1/5] END booster=gbtree, gamma=3.8000000000000003, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.121 total time=   2.0s
# [CV 2/5] END booster=gbtree, gamma=3.8000000000000003, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.122 total time=   2.0s
# [CV 3/5] END booster=gbtree, gamma=3.8000000000000003, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.121 total time=   1.9s
# [CV 4/5] END booster=gbtree, gamma=3.8000000000000003, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.121 total time=   2.5s
# [CV 5/5] END booster=gbtree, gamma=3.8000000000000003, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.121 total time=   2.3s
# [CV 1/5] END booster=gbtree, gamma=3.9000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.122 total time=   2.1s
# [CV 2/5] END booster=gbtree, gamma=3.9000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.122 total time=   2.0s
# [CV 3/5] END booster=gbtree, gamma=3.9000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.121 total time=   1.7s
# [CV 4/5] END booster=gbtree, gamma=3.9000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.120 total time=   1.6s
# [CV 5/5] END booster=gbtree, gamma=3.9000000000000004, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.121 total time=   1.7s
# [CV 1/5] END booster=gbtree, gamma=4.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.123 total time=   2.1s
# [CV 2/5] END booster=gbtree, gamma=4.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.124 total time=   1.7s
# [CV 3/5] END booster=gbtree, gamma=4.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.122 total time=   2.0s
# [CV 4/5] END booster=gbtree, gamma=4.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.124 total time=   1.8s
# [CV 5/5] END booster=gbtree, gamma=4.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.122 total time=   1.7s
# [CV 1/5] END booster=gbtree, gamma=4.1000000000000005, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.124 total time=   1.7s
# [CV 2/5] END booster=gbtree, gamma=4.1000000000000005, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.124 total time=   1.8s
# [CV 3/5] END booster=gbtree, gamma=4.1000000000000005, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.123 total time=   1.7s
# [CV 4/5] END booster=gbtree, gamma=4.1000000000000005, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.124 total time=   1.6s
# [CV 5/5] END booster=gbtree, gamma=4.1000000000000005, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.120 total time=   1.7s
# [CV 1/5] END booster=gbtree, gamma=4.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.124 total time=   1.7s
# [CV 2/5] END booster=gbtree, gamma=4.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.124 total time=   1.8s
# [CV 3/5] END booster=gbtree, gamma=4.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.120 total time=   1.8s
# [CV 4/5] END booster=gbtree, gamma=4.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.124 total time=   1.9s
# [CV 5/5] END booster=gbtree, gamma=4.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.122 total time=   1.9s
# [CV 1/5] END booster=gbtree, gamma=4.3, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.125 total time=   2.0s
# [CV 2/5] END booster=gbtree, gamma=4.3, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.123 total time=   1.8s
# [CV 3/5] END booster=gbtree, gamma=4.3, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.119 total time=   2.2s
# [CV 4/5] END booster=gbtree, gamma=4.3, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.123 total time=   1.7s
# [CV 5/5] END booster=gbtree, gamma=4.3, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.123 total time=   1.7s
# [CV 1/5] END booster=gbtree, gamma=4.4, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.123 total time=   1.9s
# [CV 2/5] END booster=gbtree, gamma=4.4, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.123 total time=   1.8s
# [CV 3/5] END booster=gbtree, gamma=4.4, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.122 total time=   1.8s
# [CV 4/5] END booster=gbtree, gamma=4.4, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.123 total time=   1.7s
# [CV 5/5] END booster=gbtree, gamma=4.4, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.119 total time=   1.7s
# [CV 1/5] END booster=gbtree, gamma=4.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.123 total time=   1.7s
# [CV 2/5] END booster=gbtree, gamma=4.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.122 total time=   1.8s
# [CV 3/5] END booster=gbtree, gamma=4.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.123 total time=   2.0s
# [CV 4/5] END booster=gbtree, gamma=4.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.125 total time=   1.9s
# [CV 5/5] END booster=gbtree, gamma=4.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.123 total time=   3.2s
# [CV 1/5] END booster=gbtree, gamma=4.6000000000000005, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.124 total time=   1.8s
# [CV 2/5] END booster=gbtree, gamma=4.6000000000000005, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.122 total time=   2.1s
# [CV 3/5] END booster=gbtree, gamma=4.6000000000000005, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.123 total time=   2.9s
# [CV 4/5] END booster=gbtree, gamma=4.6000000000000005, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.125 total time=   2.2s
# [CV 5/5] END booster=gbtree, gamma=4.6000000000000005, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.122 total time=   4.8s
# [CV 1/5] END booster=gbtree, gamma=4.7, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.124 total time=   2.6s
# [CV 2/5] END booster=gbtree, gamma=4.7, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.123 total time=   1.8s
# [CV 3/5] END booster=gbtree, gamma=4.7, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.123 total time=   1.8s
# [CV 4/5] END booster=gbtree, gamma=4.7, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.125 total time=   2.0s
# [CV 5/5] END booster=gbtree, gamma=4.7, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.123 total time=   1.8s
# [CV 1/5] END booster=gbtree, gamma=4.800000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.124 total time=   1.9s
# [CV 2/5] END booster=gbtree, gamma=4.800000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.125 total time=   1.7s
# [CV 3/5] END booster=gbtree, gamma=4.800000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.122 total time=   1.8s
# [CV 4/5] END booster=gbtree, gamma=4.800000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.126 total time=   2.0s
# [CV 5/5] END booster=gbtree, gamma=4.800000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.123 total time=   1.7s
# [CV 1/5] END booster=gbtree, gamma=4.9, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.124 total time=   2.0s
# [CV 2/5] END booster=gbtree, gamma=4.9, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.124 total time=   2.4s
# [CV 3/5] END booster=gbtree, gamma=4.9, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.123 total time=   2.0s
# [CV 4/5] END booster=gbtree, gamma=4.9, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.126 total time=   1.7s
# [CV 5/5] END booster=gbtree, gamma=4.9, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.124 total time=   1.7s
# [CV 1/5] END booster=gbtree, gamma=5.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.126 total time=   1.9s
# [CV 2/5] END booster=gbtree, gamma=5.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.126 total time=   1.6s
# [CV 3/5] END booster=gbtree, gamma=5.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.125 total time=   3.5s
# [CV 4/5] END booster=gbtree, gamma=5.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.127 total time=   2.2s
# [CV 5/5] END booster=gbtree, gamma=5.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.125 total time=   1.8s
# [CV 1/5] END booster=gbtree, gamma=5.1000000000000005, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.125 total time=   1.6s
# [CV 2/5] END booster=gbtree, gamma=5.1000000000000005, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.126 total time=   1.7s
# [CV 3/5] END booster=gbtree, gamma=5.1000000000000005, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.124 total time=   1.7s
# [CV 4/5] END booster=gbtree, gamma=5.1000000000000005, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.126 total time=   1.7s
# [CV 5/5] END booster=gbtree, gamma=5.1000000000000005, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.124 total time=   1.7s
# [CV 1/5] END booster=gbtree, gamma=5.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.127 total time=   1.7s
# [CV 2/5] END booster=gbtree, gamma=5.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.125 total time=   1.7s
# [CV 3/5] END booster=gbtree, gamma=5.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.123 total time=   1.7s
# [CV 4/5] END booster=gbtree, gamma=5.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.126 total time=   1.7s
# [CV 5/5] END booster=gbtree, gamma=5.2, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.125 total time=   1.7s
# [CV 1/5] END booster=gbtree, gamma=5.300000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.127 total time=   1.6s
# [CV 2/5] END booster=gbtree, gamma=5.300000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.128 total time=   2.0s
# [CV 3/5] END booster=gbtree, gamma=5.300000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.124 total time=   1.7s
# [CV 4/5] END booster=gbtree, gamma=5.300000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.127 total time=   1.7s
# [CV 5/5] END booster=gbtree, gamma=5.300000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.124 total time=   1.7s
# [CV 1/5] END booster=gbtree, gamma=5.4, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.128 total time=   1.8s
# [CV 2/5] END booster=gbtree, gamma=5.4, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.128 total time=   1.6s
# [CV 3/5] END booster=gbtree, gamma=5.4, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.124 total time=   1.8s
# [CV 4/5] END booster=gbtree, gamma=5.4, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.127 total time=   1.7s
# [CV 5/5] END booster=gbtree, gamma=5.4, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.124 total time=   1.7s
# [CV 1/5] END booster=gbtree, gamma=5.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.126 total time=   1.8s
# [CV 2/5] END booster=gbtree, gamma=5.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.128 total time=   1.8s
# [CV 3/5] END booster=gbtree, gamma=5.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.126 total time=   1.9s
# [CV 4/5] END booster=gbtree, gamma=5.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.127 total time=   1.8s
# [CV 5/5] END booster=gbtree, gamma=5.5, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.125 total time=   1.8s
# [CV 1/5] END booster=gbtree, gamma=5.6000000000000005, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.127 total time=   2.0s
# [CV 2/5] END booster=gbtree, gamma=5.6000000000000005, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.127 total time=   2.5s
# [CV 3/5] END booster=gbtree, gamma=5.6000000000000005, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.126 total time=   2.2s
# [CV 4/5] END booster=gbtree, gamma=5.6000000000000005, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.127 total time=   2.5s
# [CV 5/5] END booster=gbtree, gamma=5.6000000000000005, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.126 total time=   2.0s
# [CV 1/5] END booster=gbtree, gamma=5.7, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.127 total time=   2.3s
# [CV 2/5] END booster=gbtree, gamma=5.7, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.127 total time=   2.1s
# [CV 3/5] END booster=gbtree, gamma=5.7, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.126 total time=   2.1s
# [CV 4/5] END booster=gbtree, gamma=5.7, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.127 total time=   2.1s
# [CV 5/5] END booster=gbtree, gamma=5.7, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.126 total time=   2.0s
# [CV 1/5] END booster=gbtree, gamma=5.800000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.127 total time=   1.8s
# [CV 2/5] END booster=gbtree, gamma=5.800000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.127 total time=   1.9s
# [CV 3/5] END booster=gbtree, gamma=5.800000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.125 total time=   1.9s
# [CV 4/5] END booster=gbtree, gamma=5.800000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.127 total time=   2.0s
# [CV 5/5] END booster=gbtree, gamma=5.800000000000001, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.127 total time=   2.0s
# [CV 1/5] END booster=gbtree, gamma=5.9, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.128 total time=   1.9s
# [CV 2/5] END booster=gbtree, gamma=5.9, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.130 total time=   1.9s
# [CV 3/5] END booster=gbtree, gamma=5.9, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.125 total time=   2.0s
# [CV 4/5] END booster=gbtree, gamma=5.9, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.128 total time=   1.8s
# [CV 5/5] END booster=gbtree, gamma=5.9, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.124 total time=   2.2s
# [CV 1/5] END booster=gbtree, gamma=6.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.129 total time=   2.1s
# [CV 2/5] END booster=gbtree, gamma=6.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.129 total time=   2.2s
# [CV 3/5] END booster=gbtree, gamma=6.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.125 total time=   2.0s
# [CV 4/5] END booster=gbtree, gamma=6.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.128 total time=   1.9s
# [CV 5/5] END booster=gbtree, gamma=6.0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43;, score=-0.126 total time=   2.8s
# Best params: {'booster': 'gbtree', 'gamma': 0.0, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 195, 'random_state': 43}
# Best score: -0.09001301413019257

# %% [markdown]
# # Ronda 6: "subsample" y "colsample_bytree"
# - Quizá más relevantes que "gamma", pero con un valor por defecto que suele ser razonable, estos dos parámetros son los siguientes de la lista

# %%
model = XGBRegressor()

params = {'random_state': [43],
          'booster': ['gbtree'],
          'n_estimators': [195],
          'max_depth': [6],
          'min_child_weight': [2],
          'gamma': [0],
          'subsample': np.linspace(0.5, 1.0, num=11),
          'colsample_bytree': np.linspace(0.5, 1.0, num=11)
            }

grid = GridSearchCV(estimator=model,
                    param_grid=params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')
# Out:
# Fitting 5 folds for each of 121 candidates, totalling 605 fits
# [CV 1/5] END booster=gbtree, colsample_bytree=0.5, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.5;, score=-0.097 total time=   2.2s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.5, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.5;, score=-0.095 total time=   1.6s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.5, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.5;, score=-0.092 total time=   1.6s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.5, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.5;, score=-0.093 total time=   1.8s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.5, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.5;, score=-0.093 total time=   3.5s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.5, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.55;, score=-0.096 total time=   1.9s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.5, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.55;, score=-0.096 total time=   1.8s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.5, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.55;, score=-0.092 total time=   1.9s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.5, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.55;, score=-0.092 total time=   1.9s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.5, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.55;, score=-0.093 total time=   1.8s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.5, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.6;, score=-0.096 total time=   1.8s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.5, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.6;, score=-0.094 total time=   1.7s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.5, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.6;, score=-0.090 total time=   2.1s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.5, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.6;, score=-0.092 total time=   2.1s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.5, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.6;, score=-0.093 total time=   3.7s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.5, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.65;, score=-0.095 total time=   2.0s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.5, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.65;, score=-0.093 total time=   2.3s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.5, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0
5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.65;, score=-0.091 total time=   2.3s
# [CV 5/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.65;, score=-0.091 total time=   2.7s
# [CV 1/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.7;, score=-0.093 total time=   2.3s
# [CV 2/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.7;, score=-0.093 total time=   2.3s
# [CV 3/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.7;, score=-0.090 total time=   2.2s
# [CV 4/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.7;, score=-0.090 total time=   2.2s
# [CV 5/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.7;, score=-0.092 total time=   2.4s
# [CV 1/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.75;, score=-0.093 total time=   2.3s
# [CV 2/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.75;, score=-0.093 total time=   3.0s
# [CV 3/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.75;, score=-0.089 total time=   2.4s
# [CV 4/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.75;, score=-0.091 total time=   4.9s
# [CV 5/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.75;, score=-0.091 total time=   3.9s
# [CV 1/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.8;, score=-0.093 total time=   2.6s
# [CV 2/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.8;, score=-0.093 total time=   2.4s
# [CV 3/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.8;, score=-0.090 total time=   4.6s
# [CV 4/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.8;, score=-0.091 total time=   3.0s
# [CV 5/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.8;, score=-0.092 total time=   3.1s
# [CV 1/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.8500000000000001;, score=-0.093 total time=   2.6s
# [CV 2/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.8500000000000001;, score=-0.091 total time=   2.9s
# [CV 3/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.8500000000000001;, score=-0.090 total time=   2.4s
# [CV 4/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.8500000000000001;, score=-0.090 total time=   2.4s
# [CV 5/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.8500000000000001;, score=-0.092 total time=   2.8s
# [CV 1/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.9;, score=-0.094 total time=   3.1s
# [CV 2/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.9;, score=-0.091 total time=   3.1s
# [CV 3/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.9;, score=-0.088 total time=   2.9s
# [CV 4/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.9;, score=-0.089 total time=   2.6s
# [CV 5/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.9;, score=-0.090 total time=   2.9s
# [CV 1/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.95;, score=-0.092 total time=   4.1s
# [CV 2/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.95;, score=-0.092 total time=   3.7s
# [CV 3/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.95;, score=-0.089 total time=   3.7s
# [CV 4/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.95;, score=-0.090 total time=   2.8s
# [CV 5/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=0.95;, score=-0.091 total time=   2.1s
# [CV 1/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=1.0;, score=-0.092 total time=   1.9s
# [CV 2/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=1.0;, score=-0.091 total time=   1.8s
# [CV 3/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=1.0;, score=-0.088 total time=   2.0s
# [CV 4/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=1.0;, score=-0.088 total time=   2.0s
# [CV 5/5] END booster=gbtree, colsample_bytree=1.0, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, subsample=1.0;, score=-0.090 total time=   2.7s
# Best params: {'booster': 'gbtree', 'colsample_bytree': 0.7, 'gamma': 0, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 195, 'random_state': 43, 'subsample': 1.0}
# Best score: -0.0896772180021331

# %% [markdown]
# # Ronda 7: "sampling"
#
# - Con lo obtenido de los parámetros anteriores, toca elegir el "sampling_method". Como "subsample" es superior a 0.5, solo hay que probar "uniform" y "gradient_based"
# - No hay diferencia, pero "gradient_based" es algo más rápido

# %%
model = XGBRegressor()

params = {'random_state': [43],
          'booster': ['gbtree'],
          'n_estimators': [195],
          'max_depth': [6],
          'min_child_weight': [2],
          'gamma': [0],
          'subsample': [1],
          'colsample_bytree': [0.7],
          'sampling_method': ['uniform', 'gradient_based']
            }

grid = GridSearchCV(estimator=model,
                    param_grid=params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, sampling_method=uniform, subsample=1;, score=-0.093 total time=   2.1s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, sampling_method=uniform, subsample=1;, score=-0.090 total time=   1.4s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, sampling_method=uniform, subsample=1;, score=-0.088 total time=   1.5s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, sampling_method=uniform, subsample=1;, score=-0.087 total time=   1.6s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, sampling_method=uniform, subsample=1;, score=-0.090 total time=   1.6s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, sampling_method=gradient_based, subsample=1;, score=-0.093 total time=   1.5s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, sampling_method=gradient_based, subsample=1;, score=-0.090 total time=   1.4s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, sampling_method=gradient_based, subsample=1;, score=-0.088 total time=   1.4s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, sampling_method=gradient_based, subsample=1;, score=-0.087 total time=   1.4s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, sampling_method=gradient_based, subsample=1;, score=-0.090 total time=   1.4s
# Best params: {'booster': 'gbtree', 'colsample_bytree': 0.7, 'gamma': 0, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 195, 'random_state': 43, 'sampling_method': 'uniform', 'subsample': 1}
# Best score: -0.0896772180021331

# %% [markdown]
# # Ronda 8: parámetros adicionales
#
# - Se prueban varios otros parámetros a priori de importancia reducida

# %%
model = XGBRegressor()

params = {'random_state': [43],
          'booster': ['gbtree'],
          'n_estimators': [195],
          'max_depth': [6],
          'min_child_weight': [2],
          'gamma': [0],
          'subsample': [1],
          'colsample_bytree': [0.7],
          'sampling_method': ['gradient_based'],
          'scale_pos_weight': range(0, 4),
          'max_delta_step': range(0, 4),
          'lambda': np.linspace(0, 0.5, num=6),
          'reg_alpha': np.linspace(0, 0.5, num=6)
          }

grid = GridSearchCV(estimator=model,
                    param_grid=params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')
# Out:
# Fitting 5 folds for each of 576 candidates, totalling 2880 fits
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.0, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.093 total time=   1.8s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.0, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.091 total time=   1.5s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.0, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   3.4s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.0, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.089 total time=   1.7s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.0, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   1.9s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.0, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.093 total time=   1.8s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.0, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.091 total time=   2.1s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.0, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.090 total time=   2.3s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.0, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.089 total time=   1.6s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.0, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.090 total time=   1.8s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.0, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.093 total time=   1.5s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.0, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.091 total time=   2.0s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.0, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.090 total time=   2.5s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.0, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.089 total time=   1.7s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.0, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.090 total time=   1.7s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.0, sampling_method=gradient_based, scale_pos_weight=3, subsample=1;, score=-0.093 total time=   1.7s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.0, sampling_method=gradient_based, scale_pos_weight=3, subsample=1;, score=-0.091 total time=   2.0s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.0, sampling_method=gradient_based, scale_pos_weight=3, subsample=1;, score=-0.090 total time=   1.8s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.0, sampling_method=gradient_based, scale_pos_weight=3, subsample=1;, score=-0.089 total time=   2.0s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.0, sampling_method=gradient_based, scale_pos_weight=3, subsample=1;, score=-0.090 total time=   2.3s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.1, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.092 total time=   2.3s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.1, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   1.5s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.1, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   2.4s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.1, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   3.0s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.1, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.089 total time=   2.4s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.1, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.092 total time=   2.8s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.1, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.090 total time=   2.6s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.1, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.088 total time=   1.9s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.1, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.087 total time=   1.9s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.1, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.089 total time=   1.9s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.1, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.092 total time=   2.5s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.1, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.090 total time=   1.9s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.1, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.088 total time=   1.9s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.1, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.087 total time=   1.8s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.1, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.089 total time=   2.0s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.1, sampling_method=gradient_based, scale_pos_weight=3, subsample=1;, score=-0.092 total time=   2.0s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.1, sampling_method=gradient_based, scale_pos_weight=3, subsample=1;, score=-0.090 total time=   1.9s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.1, sampling_method=gradient_based, scale_pos_weight=3, subsample=1;, score=-0.088 total time=   1.8s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.1, sampling_method=gradient_based, scale_pos_weight=3, subsample=1;, score=-0.087 total time=   1.8s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.1, sampling_method=gradient_based, scale_pos_weight=3, subsample=1;, score=-0.089 total time=   1.8s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.091 total time=   1.9s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.091 total time=   2.1s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   1.9s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   1.8s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   2.0s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.091 total time=   2.6s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.091 total time=   2.8s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.088 total time=   2.3s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.088 total time=   2.0s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.088 total time=   1.6s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.091 total time=   1.6s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.091 total time=   1.6s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.088 total time=   1.6s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.088 total time=   1.7s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.088 total time=   1.8s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=3, subsample=1;, score=-0.091 total time=   1.6s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=3, subsample=1;, score=-0.091 total time=   2.1s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=3, subsample=1;, score=-0.088 total time=   1.9s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=3, subsample=1;, score=-0.088 total time=   1.8s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=3, subsample=1;, score=-0.088 total time=   1.6s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.30000000000000004, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.092 total time=   2.0s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.30000000000000004, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.091 total time=   1.8s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.30000000000000004, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.8s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.30000000000000004, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   1.7s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.30000000000000004, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.089 total time=   1.5s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.30000000000000004, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.092 total time=   2.3s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.30000000000000004, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.091 total time=   1.9s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.30000000000000004, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.087 total time=   1.8s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.30000000000000004, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.088 total time=   1.5s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.30000000000000004, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.089 total time=   1.6s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.30000000000000004, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.092 total time=   1.6s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.30000000000000004, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.091 total time=   1.5s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.30000000000000004, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.087 total time=   1.5s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.30000000000000004, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.088 total time=   1.6s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.30000000000000004, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.089 total time=   1.5s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.30000000000000004, sampling_method=gradient_based, scale_pos_weight=3, subsample=1;, score=-0.092 total time=   1.5s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.30000000000000004, sampling_method=gradient_based, scale_pos_weight=3, subsample=1;, score=-0.091 total time=   1.7s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.30000000000000004, sampling_method=gradient_based, scale_pos_weight=3, subsample=1;, score=-0.087 total time=   1.5s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.30000000000000004, sampling_method=gradient_based, scale_pos_weight=3, subsample=1;, score=-0.088 total time=   1.5s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.30000000000000004, sampling_method=gradient_based, scale_pos_weight=3, subsample=1;, score=-0.089 total time=   1.6s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.092 total time=   1.6s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   1.5s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   1.5s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.7s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.089 total time=   1.5s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.092 total time=   1.5s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.090 total time=   1.7s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.088 total time=   1.5s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.087 total time=   1.5s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.089 total time=   1.7s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.092 total time=   1.6s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.090 total time=   1.5s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.088 total time=   1.6s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0.087 total time=   1.6s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, gamma=0, lambda=0.0, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=2, subsample=1;, score=-0
# %%
model = XGBRegressor()

params = {'random_state': [43],
          'booster': ['gbtree'],
          'n_estimators': [195],
          'max_depth': [6],
          'min_child_weight': [2],
          'gamma': [0],
          'subsample': [1],
          'colsample_bytree': [0.7],
          'sampling_method': ['gradient_based'],
          'scale_pos_weight': [0],
          'max_delta_step': [0],
          'lambda': [0.3],
          'reg_alpha': [0.3],
          'eta': np.linspace(0, 1, num=10)
          }

grid = GridSearchCV(estimator=model,
                    param_grid=params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.0, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-7.353 total time=   1.8s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.0, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-7.367 total time=   1.4s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.0, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-7.335 total time=   1.5s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.0, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-7.361 total time=   1.4s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.0, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-7.350 total time=   1.5s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.1111111111111111, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.091 total time=   1.5s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.1111111111111111, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   1.7s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.1111111111111111, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.086 total time=   1.6s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.1111111111111111, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.7s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.1111111111111111, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   1.5s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.2222222222222222, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.091 total time=   1.6s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.2222222222222222, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   1.6s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.2222222222222222, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.7s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.2222222222222222, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.9s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.2222222222222222, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   2.3s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.3333333333333333, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.092 total time=   2.6s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.3333333333333333, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   2.5s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.3333333333333333, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   1.8s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.3333333333333333, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   1.8s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.3333333333333333, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.089 total time=   2.4s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.4444444444444444, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.094 total time=   2.4s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.4444444444444444, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.092 total time=   1.9s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.4444444444444444, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   2.6s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.4444444444444444, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.089 total time=   2.2s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.4444444444444444, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   2.6s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.5555555555555556, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.094 total time=   2.3s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.5555555555555556, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.093 total time=   1.6s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.5555555555555556, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.092 total time=   2.4s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.5555555555555556, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.091 total time=   1.9s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.5555555555555556, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.092 total time=   1.7s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.6666666666666666, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.097 total time=   1.6s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.6666666666666666, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.097 total time=   1.7s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.6666666666666666, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.094 total time=   1.6s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.6666666666666666, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.093 total time=   1.9s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.6666666666666666, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.095 total time=   1.6s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.7777777777777777, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.099 total time=   1.9s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.7777777777777777, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.100 total time=   2.0s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.7777777777777777, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.095 total time=   2.1s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.7777777777777777, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.099 total time=   3.0s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.7777777777777777, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.098 total time=   2.1s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.8888888888888888, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.105 total time=   2.8s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.8888888888888888, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.103 total time=   2.0s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.8888888888888888, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.101 total time=   2.2s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.8888888888888888, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.103 total time=   1.5s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.8888888888888888, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.100 total time=   2.1s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=1.0, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.105 total time=   1.6s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=1.0, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.108 total time=   1.7s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=1.0, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.106 total time=   2.0s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=1.0, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.104 total time=   2.0s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=1.0, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.104 total time=   1.8s
# Best params: {'booster': 'gbtree', 'colsample_bytree': 0.7, 'eta': 0.1111111111111111, 'gamma': 0, 'lambda': 0.3, 'max_delta_step': 0, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 195, 'random_state': 43, 'reg_alpha': 0.3, 'sampling_method': 'gradient_based', 'scale_pos_weight': 0, 'subsample': 1}
# Best score: -0.08831419660962588

# %%
model = XGBRegressor()

params = {'random_state': [43],
          'booster': ['gbtree'],
          'n_estimators': [195],
          'max_depth': [6],
          'min_child_weight': [2],
          'gamma': [0],
          'subsample': [1],
          'colsample_bytree': [0.7],
          'sampling_method': ['gradient_based'],
          'scale_pos_weight': [0],
          'max_delta_step': [0],
          'lambda': [0.3],
          'reg_alpha': [0.3],
          'eta': np.linspace(0.01, 0.2, num=100)
          }

grid = GridSearchCV(estimator=model,
                    param_grid=params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}

# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.089 total time=   1.7s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.086 total time=   1.8s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.7s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   1.7s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18464646464646464, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   2.0s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18464646464646464, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.089 total time=   1.7s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18464646464646464, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.6s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18464646464646464, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.7s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18464646464646464, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   1.8s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18656565656565657, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   1.7s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18656565656565657, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.089 total time=   1.6s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18656565656565657, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.9s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18656565656565657, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.6s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18656565656565657, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   1.7s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.1884848484848485, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   2.0s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.1884848484848485, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.089 total time=   1.6s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.1884848484848485, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.7s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.1884848484848485, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.9s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.1884848484848485, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.6s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.1904040404040404, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   1.7s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.1904040404040404, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   1.7s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.1904040404040404, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   2.1s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.1904040404040404, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.9s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.1904040404040404, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.7s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.19232323232323234, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   1.6s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.19232323232323234, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   1.8s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.19232323232323234, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.5s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.19232323232323234, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.9s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.19232323232323234, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   1.6s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.19424242424242424, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   1.9s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.19424242424242424, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.089 total time=   1.6s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.19424242424242424, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.086 total time=   1.8s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.19424242424242424, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.9s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.19424242424242424, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   1.6s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.19616161616161618, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   1.7s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.19616161616161618, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   1.6s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.19616161616161618, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.7s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.19616161616161618, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.5s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.19616161616161618, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   2.0s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.19808080808080808, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.091 total time=   1.7s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.19808080808080808, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   1.8s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.19808080808080808, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.086 total time=   1.9s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.19808080808080808, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.6s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.19808080808080808, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   2.2s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.2, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.091 total time=   1.6s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.2, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   1.7s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.2, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.9s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.2, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.9s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.2, gamma=0, lambda=0.3, max_delta_step=0, max_depth=6, min_child_weight=2, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.087 total time=   1.7s
# Best params: {'booster': 'gbtree', 'colsample_bytree': 0.7, 'eta': 0.18272727272727274, 'gamma': 0, 'lambda': 0.3, 'max_delta_step': 0, 'max_depth': 6, 'min_child_weight': 2, 'n_estimators': 195, 'random_state': 43, 'reg_alpha': 0.3, 'sampling_method': 'gradient_based', 'scale_pos_weight': 0, 'subsample': 1}
# Best score: -0.08796637519349203

# %% [markdown]
# # Ronda 10: rejuste general
#
# - Se supone que los valores óptimos obtenidos al probar los hiperparámetros por separado pueden haber oscilado ligeramente al aplicarse de manera consecutiva
#
# - Por tanto, se prueban todos a la vez con un rango reducido para cada uno

# %%
model = XGBRegressor()

params = {'random_state': [43],
          'booster': ['gbtree'],
          'n_estimators': [194, 195, 196],
          'max_depth': [5, 6, 7],
          'min_child_weight': [2, 3, 4],
          'gamma': [0, 0.1],
          'subsample': [1],
          'colsample_bytree': [0.7, 0.8],
          'sampling_method': ['gradient_based'],
          'scale_pos_weight': [0, 1],
          'max_delta_step': [1, 2, 3],
          'lambda': [0.2, 0.3, 0.4],
          'reg_alpha': [0.2, 0.3, 0.4],
          'eta': [0.18272727272727274]
          }


grid = GridSearchCV(estimator=model,
                    param_grid=params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')
# Out:
# Fitting 5 folds for each of 5832 candidates, totalling 29160 fits
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=1, max_depth=5, min_child_weight=2, n_estimators=194, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.094 total time=   1.1s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=1, max_depth=5, min_child_weight=2, n_estimators=194, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.091 total time=   1.4s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=1, max_depth=5, min_child_weight=2, n_estimators=194, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   1.0s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=1, max_depth=5, min_child_weight=2, n_estimators=194, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.089 total time=   2.0s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=1, max_depth=5, min_child_weight=2, n_estimators=194, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   3.2s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=1, max_depth=5, min_child_weight=2, n_estimators=194, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.094 total time=   2.7s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=1, max_depth=5, min_child_weight=2, n_estimators=194, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.091 total time=   8.7s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=1, max_depth=5, min_child_weight=2, n_estimators=194, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.088 total time=   2.1s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=1, max_depth=5, min_child_weight=2, n_estimators=194, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.089 total time=   2.0s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=1, max_depth=5, min_child_weight=2, n_estimators=194, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0

# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.089 total time=   1.7s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   2.0s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.093 total time=   3.6s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.090 total time=   3.4s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.088 total time=   4.8s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.089 total time=   4.0s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.088 total time=   2.9s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.093 total time=   2.2s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.091 total time=   1.6s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   1.6s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.089 total time=   1.8s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.089 total time=   3.1s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.093 total time=   3.6s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.091 total time=   3.1s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.088 total time=   3.0s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.089 total time=   2.9s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.089 total time=   2.3s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.093 total time=   1.9s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   1.2s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   1.5s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.089 total time=   1.2s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.089 total time=   1.9s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.093 total time=   1.5s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.090 total time=   1.2s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.088 total time=   1.2s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.089 total time=   1.9s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=195, random_state=43, reg_alpha=0.4, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.089 total time=   1.6s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=196, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.093 total time=   1.3s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=196, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.090 total time=   1.1s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=196, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   1.9s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=196, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   1.9s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=196, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   2.0s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=196, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.093 total time=   2.0s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=196, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.090 total time=   2.0s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=196, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.088 total time=   2.2s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=196, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.088 total time=   1.3s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=196, random_state=43, reg_alpha=0.2, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.088 total time=   5.0s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=196, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.093 total time=   1.4s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=196, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.091 total time=   2.5s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=196, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.088 total time=   1.7s
# [CV 4/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=196, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.089 total time=   1.7s
# [CV 5/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=196, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=0, subsample=1;, score=-0.089 total time=   2.0s
# [CV 1/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=196, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.093 total time=   2.1s
# [CV 2/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=196, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.091 total time=   1.8s
# [CV 3/5] END booster=gbtree, colsample_bytree=0.7, eta=0.18272727272727274, gamma=0, lambda=0.2, max_delta_step=3, max_depth=5, min_child_weight=4, n_estimators=196, random_state=43, reg_alpha=0.3, sampling_method=gradient_based, scale_pos_weight=1, subsample=1;, score=-0.088 total time=   2.7s

# %% [markdown]
# # Ronda 11: sustitución
#
# - Aunque la sustitución de valores de "depth (percentage)" por los resultados reales que da el cálculo a partir de las columnas correspondientes no ha dado buenos resultados durante el "feature engineering", quizá ahora mejore con los nuevos hiperparámetros

# %%
df_11 = df_cambios.copy()

df_11['depth (percentage)'] = (df_11['depth (millimeters)'] / ((df_11['lenght (millimeters)']+df_11['width (millimeters)']) / 2)) * 100

round_11 = Regression(df_11, 'price')
X_train, X_test, y_train, y_test = round_11.split_dataframe()

model = XGBRegressor()

params = {'random_state': [43],
          'booster': ['gbtree'],
          'n_estimators': [194, 195, 196],
          'max_depth': [5, 6, 7],
          'min_child_weight': [2, 3, 4],
          'gamma': [0, 0.1],
          'subsample': [1],
          'colsample_bytree': [0.7, 0.8],
          'sampling_method': ['gradient_based'],
          'scale_pos_weight': [0, 1],
          'max_delta_step': [1, 2, 3],
          'lambda': [0.2, 0.3, 0.4],
          'reg_alpha': [0.2, 0.3, 0.4],
          'eta': [0.18272727272727274]
          }


grid = GridSearchCV(estimator=model,
                    param_grid=params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')

# %% [markdown]
# # Ronda 12: sin borrado
#
# - Asimismo, se prueba sin el borrado

# %%
df_12 = df_diamonds.copy()

df_12 = assign_values(df_12, outlier=False)

round_12 = Regression(df_12, 'price')
X_train, X_test, y_train, y_test = round_12.split_dataframe()

model = XGBRegressor()

params = {'random_state': [43],
          'booster': ['gbtree'],
          'n_estimators': [194, 195, 196],
          'max_depth': [5, 6, 7],
          'min_child_weight': [2, 3, 4],
          'gamma': [0, 0.1],
          'subsample': [1],
          'colsample_bytree': [0.7, 0.8],
          'sampling_method': ['gradient_based'],
          'scale_pos_weight': [0, 1],
          'max_delta_step': [1, 2, 3],
          'lambda': [0.2, 0.3, 0.4],
          'reg_alpha': [0.2, 0.3, 0.4],
          'eta': [0.18272727272727274]
          }


grid = GridSearchCV(estimator=model,
                    param_grid=params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')

# %% [markdown]
# # Ronda 13: sin asignación
#
# - Igual que en el caso anterior, pero esta vez sin la asignación

# %%
df_13 = df_diamonds.copy()

df_13 = remove_all(df_13, zeros_only=True)

round_13 = Regression(df_13, 'price')
X_train, X_test, y_train, y_test = round_13.split_dataframe()

model = XGBRegressor()

params = {'random_state': [43],
          'booster': ['gbtree'],
          'n_estimators': [194, 195, 196],
          'max_depth': [5, 6, 7],
          'min_child_weight': [2, 3, 4],
          'gamma': [0, 0.1],
          'subsample': [1],
          'colsample_bytree': [0.7, 0.8],
          'sampling_method': ['gradient_based'],
          'scale_pos_weight': [0, 1],
          'max_delta_step': [1, 2, 3],
          'lambda': [0.2, 0.3, 0.4],
          'reg_alpha': [0.2, 0.3, 0.4],
          'eta': [0.18272727272727274]
          }


grid = GridSearchCV(estimator=model,
                    param_grid=params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')

# %% [markdown]
# # Ronda 14: asignación y borrado modelados con "ridge"
#
# - Utilizando una técnica parecida a la usada en la fase de "Imputaciones 'ridge'" en el "feature engineering" para imputar los valores atípicos de "depth", sería posible "imputar" todos los valores 0 de las variables que tienen que ver con el tamaño de los diamantes a partir de una predicción. Ello serviría como alternativa a los cambios de borrado y asignación

# %%
df_14 = df_diamonds.copy()

cols = ['width (millimeters)', 'lenght (millimeters)', 'depth (millimeters)']
df = df_14.copy()[['width (millimeters)', 'lenght (millimeters)', 'depth (millimeters)', 'weight (carat)']]
for index, col in enumerate(cols):
    cols.pop(index)
    df_train = df.drop(df[(df[cols[0]] == 0) | (df[cols[1]] == 0) | (df[col] == 0)].index)
    df_test = df[df[col] == 0]
    X_train = df_train.drop(columns=col)
    y_train = df_train[col]
    x_test = df_test.drop(columns=col)
    y_test = df_test[col]
    cols.insert(0, col)
    ridge = Ridge()
    ridge.fit(X_train, y_train)
    y_pred = ridge.predict(x_test)
    df_14.loc[df_diamonds[col] == 0, col] = y_pred

# %%
round_14 = Regression(df_14, 'price')
X_train, X_test, y_train, y_test = round_14.split_dataframe()

model = XGBRegressor()

params = {'random_state': [43],
          'booster': ['gbtree'],
          'n_estimators': [194, 195, 196],
          'max_depth': [5, 6, 7],
          'min_child_weight': [2, 3, 4],
          'gamma': [0, 0.1],
          'subsample': [1],
          'colsample_bytree': [0.7, 0.8],
          'sampling_method': ['gradient_based'],
          'scale_pos_weight': [0, 1],
          'max_delta_step': [1, 2, 3],
          'lambda': [0.2, 0.3, 0.4],
          'reg_alpha': [0.2, 0.3, 0.4],
          'eta': [0.18272727272727274]
          }


grid = GridSearchCV(estimator=model,
                    param_grid=params,
                    scoring=rmse,
                    verbose=4,
                    cv=kfolds
                    )

grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)

print(f'Best params: {grid.best_params_}')
print(f'Best score: {grid.best_score_}')

# %% [markdown]
# # Ronda 15: ajuste final
